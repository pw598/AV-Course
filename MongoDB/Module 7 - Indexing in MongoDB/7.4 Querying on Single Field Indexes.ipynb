# %% [markdown]
# # Querying on Single Field Indexes

# %% [markdown]
# ---
# ### Connecting to MongoDB using Pymongo
# ----

# %%
# Importing the required libraries

import pymongo

import pprint as pp
pp.sorted = lambda x, key=None: x

# %%
# Connect to local host

client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
# Connect to database

db = client['nyc']

# %%
# Sample document

pp.pprint(
    db.airbnb.find_one()
)
# Out:
# {'_id': ObjectId('60c21bf5b653d40e79b4a7d0'),
#  'accom_id': 2595,
#  'description': 'Skylit Midtown Castle',
#  'host': {'id': 2845,
#           'name': 'Jennifer',
#           'listings_count': 3,
#           'neighbourhood_list': ['Midtown', "Hell's Kitchen"]},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98559, 40.75356]},
#  'room_type': 'Entire home/apt',
#  'price': 150,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 48,
#              'last_review': datetime.datetime(2019, 11, 4, 0, 0),
#              'reviews_per_month': 0.35},
#  'availability_365': 365}

# %% [markdown]
# ---
# ### Querying on single index
#
#
# Create single index on `price` field.
#
#
# ----

# %%
# Create single index

db.airbnb.create_index('price',
                       name = 'price_index')
# Out:
# 'price_index'

# %%
# Get indexes

pp.pprint(
    db.airbnb.index_information()
)
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]},
#  'price_index': {'v': 2, 'key': [('price', 1)]}}

# %% [markdown]
# ---
# Look for accomodations in the `price` range of 150-170.
#
# ---

# %%
# Query

pp.pprint(
            db.airbnb.find({
                                'price': {
                                            '$gt': 150,
                                            '$lt': 170
                                        }
                            })\
                     .explain()['executionStats']
        )
# Out:
# {'executionSuccess': True,
#  'nReturned': 1215,
#  'executionTimeMillis': 4,
#  'totalKeysExamined': 1215,
#  'totalDocsExamined': 1215,
#  'executionStages': {'stage': 'FETCH',
#                      'nReturned': 1215,
#                      'executionTimeMillisEstimate': 0,
#                      'works': 1216,
#                      'advanced': 1215,
#                      'needTime': 0,
#                      'needYield': 0,
#                      'saveState': 1,
#                      'restoreState': 1,
#                      'isEOF': 1,
#                      'docsExamined': 1215,
#                      'alreadyHasObj': 0,
#                      'inputStage': {'stage': 'IXSCAN',
#                                     'nReturned': 1215,
#                                     'executionTimeMillisEstimate': 0,
#                                     'works': 1216,
#                                     'advanced': 1215,
#                                     'needTime': 0,
#                                     'needYield': 0,
#                                     'saveState': 1,
#                                     'restoreState': 1,
#                                     'isEOF': 1,
#                                     'keyPattern': {'price': 1},
#                                     'indexName': 'price_index',
#                                     'isMultiKey': False,
#                                     'multiKeyPaths': {'price': []},
#                                     'isUnique': False,
#                                     'isSparse': False,
#                                     'isPartial': False,
#                                     'indexVersion': 2,
#                                     'direction': 'forward',
#                                     'indexBounds': {'price': ['(150, 170)']},
#                                     'keysExamined': 1215,
#                                     'seeks': 1,
#                                     'dupsTested': 0,
#                                     'dupsDropped': 0}},
#  'allPlansExecution': []}

# %% [markdown]
# ---
# Mongodb used the `price_index` that we created to examine only 1215 docs that were then returned.
#
# ---
# For example, we want to look for those accomodations where the `price` is between 150-170 and the number of `reviews` are more than 50.
#
# ---

# %%
# Query

pp.pprint(
            db.airbnb.find({
                                'price': {
                                            '$gt': 150,
                                            '$lt': 170
                                        },
                                'reviews.number_of_reviews': {'$gt': 50}
                            })\
                     .explain()['executionStats']
        )
# Out:
# {'executionSuccess': True,
#  'nReturned': 201,
#  'executionTimeMillis': 2,
#  'totalKeysExamined': 1215,
#  'totalDocsExamined': 1215,
#  'executionStages': {'stage': 'FETCH',
#                      'filter': {'reviews.number_of_reviews': {'$gt': 50}},
#                      'nReturned': 201,
#                      'executionTimeMillisEstimate': 0,
#                      'works': 1216,
#                      'advanced': 201,
#                      'needTime': 1014,
#                      'needYield': 0,
#                      'saveState': 1,
#                      'restoreState': 1,
#                      'isEOF': 1,
#                      'docsExamined': 1215,
#                      'alreadyHasObj': 0,
#                      'inputStage': {'stage': 'IXSCAN',
#                                     'nReturned': 1215,
#                                     'executionTimeMillisEstimate': 0,
#                                     'works': 1216,
#                                     'advanced': 1215,
#                                     'needTime': 0,
#                                     'needYield': 0,
#                                     'saveState': 1,
#                                     'restoreState': 1,
#                                     'isEOF': 1,
#                                     'keyPattern': {'price': 1},
#                                     'indexName': 'price_index',
#                                     'isMultiKey': False,
#                                     'multiKeyPaths': {'price': []},
#                                     'isUnique': False,
#                                     'isSparse': False,
#                                     'isPartial': False,
#                                     'indexVersion': 2,
#                                     'direction': 'forward',
#                                     'indexBounds': {'price': ['(150, 170)']},
#                                     'keysExamined': 1215,
#                                     'seeks': 1,
#                                     'dupsTested': 0,
#                                     'dupsDropped': 0}},
#  'allPlansExecution': []}

# %% [markdown]
# ---
# Mongodb examined only 1215 documents that had price between 150 and 170. From that it returned only 201 documents that had number of reviews more than 50.
#
# We can further improve the performance of such queries using `Compound Indexes`.
#
# ----

# %% [markdown]
# ### [Using indexes with Aggregation pipelines](https://docs.mongodb.com/manual/core/aggregation-pipeline/#pipeline-operators-and-indexes)
#
# Starting in MongoDB 3.2, indexes can cover an aggregation pipeline.
#
# ----
# For example, creating aggregation pipeline to filter documents that have `price` between 150 and 170.
#
# ---

# %%
# Aggregation Pipeline

cur = db.airbnb.aggregate([
                                {
                                    '$match':{
                                                'price':{'$gt':150, '$lt':170}
                                            }
                                }
                            ])

for doc in cur:
    pp.pprint(doc)
# Out:
# {'_id': ObjectId('60c21bf6b653d40e79b4aa69'),
#  'accom_id': 435909,
#  'description': 'Sunny West Village Dream',
#  'host': {'id': 2165401,
#           'name': 'Andrew',
#           'listings_count': 1,
#           'neighbourhood_list': ['West Village']},
#  'neighbourhood': {'name': 'West Village', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00418, 40.73553]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 88,
#  'reviews': {'number_of_reviews': 19,
#              'last_review': datetime.datetime(2016, 12, 24, 0, 0),
#              'reviews_per_month': 0.18},
#  'availability_365': 159}
# {'_id': ObjectId('60c21bf6b653d40e79b4af32'),
#  'accom_id': 1780748,
#  'description': 'Sunny 1 bedroom In The Heart of NYC',
#  'host': {'id': 9293512,
#           'name': 'Pk',
#           'listings_count': 1,
#           'neighbourhood_list': ['Murray Hill']},
#  'neighbourhood': {'name': 'Murray Hill', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97218, 40.74749]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 39,
#              'last_review': datetime.datetime(2019, 9, 26, 0, 0),
#              'reviews_per_month': 0.43},
#  'availability_365': 362}
# {'_id': ObjectId('60c21bf6b653d40e79b4b3d9'),
#  'accom_id': 3530395,
#  'description': '1 BR in Great NYC Neighborhood',
#  'host': {'id': 7665324,
#           'name': 'Edward',
#           'listings_count': 2,
#           'neighbourhood_list': ['Lower East Side']},
#  'neighbourhood': {'name': 'Lower East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99201, 40.72128]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 5,
#              'last_review': datetime.datetime(2019, 4, 8, 0, 0),
#              'reviews_per_month': 0.07},
#  'availability_365': 144}
# {'_id': ObjectId('60c21bf7b653d40e79b4bfd5'),
#  'accom_id': 7545274,
#  'description': 'Charming 1 Bedroom Apt - Midtown East',
#  'host': {'id': 25846948,
#           'name': 'Morgan',
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper East Side']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96248, 40.76157]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 19,
#              'last_review': datetime.datetime(2017, 6, 26, 0, 0),
#              'reviews_per_month': 0.28},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4d3c5'),
#  'accom_id': 14318774,
#  'description': 'New York Masterpiece',
#  'host': {'id': 37718300,
#           'name': 'Martha',
#           'listings_count': 2,
#           'neighbourhood_list': ['Forest Hills']},
#  'neighbourhood': {'name': 'Forest Hills', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.85542, 40.73438]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 117,
#              'last_review': datetime.datetime(2021, 3, 14, 0, 0),
#              'reviews_per_month': 2.1},
#  'availability_365': 354}
# {'_id': ObjectId('60c21bf9b653d40e79b4d810'),
#  'accom_id': 16308886,
#  'description': 'SUNNY 2BD W. ELEVATOR / PERFECT 4 SMALL FAMILY',
#  'host': {'id': 106714852,
#           'name': 'Ben',
#           'listings_count': 1,
#           'neighbourhood_list': ['Lower East Side']},
#  'neighbourhood': {'name': 'Lower East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98982, 40.71358]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2019, 1, 6, 0, 0),
#              'reviews_per_month': 0.06},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf9b653d40e79b4d8b3'),
#  'accom_id': 16428383,
#  'description': '2 blocks to 2 ⭐️⭐️⭐️⭐️⭐️',
#  'host': {'id': 45247495,
#           'name': 'Carlos',
#           'listings_count': 1,
#           'neighbourhood_list': ['Fieldston']},
#  'neighbourhood': {'name': 'Fieldston', 'group': 'Bronx'},
#  'location': {'type': 'Point', 'coordinates': [-73.89789, 40.89338]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 6,
#  'reviews': {'number_of_reviews': 14,
#              'last_review': datetime.datetime(2020, 11, 4, 0, 0),
#              'reviews_per_month': 0.3},
#  'availability_365': 345}
# {'_id': ObjectId('60c21bf9b653d40e79b4e105'),
#  'accom_id': 19969013,
#  'description': 'Downtown Brooklyn Condo',
#  'host': {'id': 71841088,
#           'name': 'Pristine Posh',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.94751, 40.69292]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf9b653d40e79b4e1dc'),
#  'accom_id': 20263650,
#  'description': 'Light Filled Quiet UWS studio',
#  'host': {'id': 170094,
#           'name': 'Lee',
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper West Side']},
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97674, 40.79312]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 9,
#              'last_review': datetime.datetime(2020, 1, 2, 0, 0),
#              'reviews_per_month': 0.21},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfab653d40e79b4e317'),
#  'accom_id': 20758288,
#  'description': 'Charming 1 bed in ❤️ of Greenwich Village.',
#  'host': {'id': 2739935,
#           'name': 'Brooke',
#           'listings_count': 1,
#           'neighbourhood_list': ['Greenwich Village']},
#  'neighbourhood': {'name': 'Greenwich Village', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99998, 40.72895]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 4,
#              'last_review': datetime.datetime(2018, 1, 3, 0, 0),
#              'reviews_per_month': 0.09},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfab653d40e79b4e3d1'),
#  'accom_id': 21025488,
#  'description': 'Apartment with Garden & Patio',
#  'host': {'id': 151421618,
#           'name': 'Adesh & Viviana',
#           'listings_count': 2,
#           'neighbourhood_list': ['Ozone Park']},
#  'neighbourhood': {'name': 'Ozone Park', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.84401, 40.68524]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 32,
#              'last_review': datetime.datetime(2020, 11, 1, 0, 0),
#              'reviews_per_month': 1.01},
#  'availability_365': 265}
# {'_id': ObjectId('60c21bfab653d40e79b4e41d'),
#  'accom_id': 21141576,
#  'description': 'Brand new, comfortable, refined, our first！全新，商务最佳',
#  'host': {'id': 152530167,
#           'name': 'Luxi',
#           'listings_count': 1,
#           'neighbourhood_list': ['Flushing']},
#  'neighbourhood': {'name': 'Flushing', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.82625, 40.76391]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 24,
#              'last_review': datetime.datetime(2019, 6, 6, 0, 0),
#              'reviews_per_month': 0.57},
#  'availability_365': 89}
# {'_id': ObjectId('60c21bfab653d40e79b4e4a7'),
#  'accom_id': 21293326,
#  'description': 'Huge Designer Room | Lower East Side /East Village',
#  'host': {'id': 10994839,
#           'name': 'Michael',
#           'listings_count': 1,
#           'neighbourhood_list': ['Lower East Side']},
#  'neighbourhood': {'name': 'Lower East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.9815, 40.7198]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 48,
#              'last_review': datetime.datetime(2020, 2, 28, 0, 0),
#              'reviews_per_month': 1.15},
#  'availability_365': 90}
# {'_id': ObjectId('60c21bfab653d40e79b4e515'),
#  'accom_id': 21450176,
#  'description': 'Private Room in Convenient Midtown East Location',
#  'host': {'id': 121809482,
#           'name': 'Gina',
#           'listings_count': 2,
#           'neighbourhood_list': ['Midtown']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97027, 40.75214]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 25,
#              'last_review': datetime.datetime(2019, 1, 18, 0, 0),
#              'reviews_per_month': 0.61},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfab653d40e79b4e91b'),
#  'accom_id': 22431770,
#  'description': 'Freehand New York - Queen Room',
#  'host': {'id': 164291123,
#           'name': 'Freehand',
#           'listings_count': 3,
#           'neighbourhood_list': ['Flatiron District']},
#  'neighbourhood': {'name': 'Flatiron District', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98599, 40.7403]},
#  'room_type': 'Hotel room',
#  'price': 151,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 153,
#              'last_review': datetime.datetime(2021, 3, 21, 0, 0),
#              'reviews_per_month': 4.01},
#  'availability_365': 365}
# {'_id': ObjectId('60c21bfab653d40e79b4e957'),
#  'accom_id': 22505480,
#  'description': 'Studio in Luxury Building - UWS - Indoor Pool, Gym',
#  'host': {'id': 126687208,
#           'name': nan,
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper West Side']},
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96413, 40.79289]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfbb653d40e79b4f50f'),
#  'accom_id': 28409473,
#  'description': 'CoZy room with your own bathroom/entrance in UES!',
#  'host': {'id': 109378554,
#           'name': 'Adele',
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper East Side']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95638, 40.76998]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 57,
#              'last_review': datetime.datetime(2020, 1, 28, 0, 0),
#              'reviews_per_month': 1.82},
#  'availability_365': 89}
# {'_id': ObjectId('60c21bfbb653d40e79b4f9e8'),
#  'accom_id': 30394133,
#  'description': 'Friendly Midtown East Studio w/ Great light + Gym by '
#                 'Blueground',
#  'host': {'id': 107434423,
#           'name': 'Blueground',
#           'listings_count': 266,
#           'neighbourhood_list': ['Kips Bay',
#                                  'Murray Hill',
#                                  'Tribeca',
#                                  'Upper East Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'East Village',
#                                  'Upper West Side',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Midtown',
#                                  'Nolita',
#                                  'SoHo',
#                                  'Battery Park City']},
#  'neighbourhood': {'name': 'Kips Bay', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97986, 40.74572]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2020, 7, 19, 0, 0),
#              'reviews_per_month': 0.08},
#  'availability_365': 342}
# {'_id': ObjectId('60c21bfcb653d40e79b4ff34'),
#  'accom_id': 32729130,
#  'description': 'cozy and charming experience in China Town!',
#  'host': {'id': 50333451,
#           'name': 'Jennifer',
#           'listings_count': 1,
#           'neighbourhood_list': ['Chinatown']},
#  'neighbourhood': {'name': 'Chinatown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99792, 40.71547]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfcb653d40e79b50112'),
#  'accom_id': 33743082,
#  'description': 'NEWLY-RENOVATED APARTMENT, 35 MINS FROM MANHATTAN',
#  'host': {'id': 619942,
#           'name': 'Stacy',
#           'listings_count': 6,
#           'neighbourhood_list': ['Cypress Hills']},
#  'neighbourhood': {'name': 'Cypress Hills', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.87265, 40.68851]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 28}
# {'_id': ObjectId('60c21bfcb653d40e79b50508'),
#  'accom_id': 35258943,
#  'description': 'The Baly Simpson Inn',
#  'host': {'id': 20324421,
#           'name': 'Marcus',
#           'listings_count': 1,
#           'neighbourhood_list': ['Prospect-Lefferts Gardens']},
#  'neighbourhood': {'name': 'Prospect-Lefferts Gardens', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.94986, 40.65889]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 125,
#              'last_review': datetime.datetime(2021, 4, 8, 0, 0),
#              'reviews_per_month': 5.65},
#  'availability_365': 65}
# {'_id': ObjectId('60c21bfcb653d40e79b5084e'),
#  'accom_id': 36601094,
#  'description': 'Sohotel, Deluxe Queen',
#  'host': {'id': 266797018,
#           'name': 'Sohotel',
#           'listings_count': 13,
#           'neighbourhood_list': ['Little Italy', 'Tribeca']},
#  'neighbourhood': {'name': 'Tribeca', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00945, 40.72179]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2020, 9, 20, 0, 0),
#              'reviews_per_month': 0.15},
#  'availability_365': 53}
# {'_id': ObjectId('60c21bfdb653d40e79b50d4f'),
#  'accom_id': 38697036,
#  'description': 'Spacious 1 bedroom apt with garden access',
#  'host': {'id': 31481921,
#           'name': 'Alexandre',
#           'listings_count': 1,
#           'neighbourhood_list': ['Carroll Gardens']},
#  'neighbourhood': {'name': 'Carroll Gardens', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-74.0003, 40.67732]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 37,
#              'last_review': datetime.datetime(2021, 3, 21, 0, 0),
#              'reviews_per_month': 1.99},
#  'availability_365': 29}
# {'_id': ObjectId('60c21bfdb653d40e79b50e5e'),
#  'accom_id': 39086622,
#  'description': 'Charming & Bright BR ☼ Balcony in the Heart of LES',
#  'host': {'id': 13006166,
#           'name': 'Patricia',
#           'listings_count': 2,
#           'neighbourhood_list': ['Lower East Side']},
#  'neighbourhood': {'name': 'Lower East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.9865, 40.71937]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 13,
#              'last_review': datetime.datetime(2020, 8, 16, 0, 0),
#              'reviews_per_month': 0.73},
#  'availability_365': 365}
# {'_id': ObjectId('60c21bfdb653d40e79b51366'),
#  'accom_id': 40537067,
#  'description': 'Stylish Parlour Apt in Bedford Stuyvesant',
#  'host': {'id': 67122613,
#           'name': 'Donna',
#           'listings_count': 2,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.92976, 40.68263]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 28,
#              'last_review': datetime.datetime(2021, 3, 28, 0, 0),
#              'reviews_per_month': 1.94},
#  'availability_365': 330}
# {'_id': ObjectId('60c21bfdb653d40e79b51678'),
#  'accom_id': 41430114,
#  'description': 'Private & Serene Bedford Ave Sanctuary w Backyard',
#  'host': {'id': 279237710,
#           'name': 'Ralph',
#           'listings_count': 1,
#           'neighbourhood_list': ['Williamsburg']},
#  'neighbourhood': {'name': 'Williamsburg', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.96233, 40.71442]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 3,
#              'last_review': datetime.datetime(2020, 2, 16, 0, 0),
#              'reviews_per_month': 0.21},
#  'availability_365': 39}
# {'_id': ObjectId('60c21bfdb653d40e79b51741'),
#  'accom_id': 41733738,
#  'description': 'Paradise OASIS STUDIO W/Backyard + RUM PUNCH',
#  'host': {'id': 329582733,
#           'name': 'Swipe',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bergen Beach']},
#  'neighbourhood': {'name': 'Bergen Beach', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.91445, 40.62806]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 71,
#              'last_review': datetime.datetime(2021, 3, 25, 0, 0),
#              'reviews_per_month': 4.93},
#  'availability_365': 364}
# {'_id': ObjectId('60c21bfdb653d40e79b51790'),
#  'accom_id': 41838215,
#  'description': 'Chelsea Studio w/ queen & full kitchen',
#  'host': {'id': 24709527,
#           'name': 'Richard',
#           'listings_count': 1,
#           'neighbourhood_list': ['Chelsea']},
#  'neighbourhood': {'name': 'Chelsea', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99569, 40.74858]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2020, 3, 14, 0, 0),
#              'reviews_per_month': 0.15},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfdb653d40e79b5186b'),
#  'accom_id': 42095151,
#  'description': '1 Bedroom in Fort Greene Luxury Building',
#  'host': {'id': 991082,
#           'name': 'Courtney',
#           'listings_count': 1,
#           'neighbourhood_list': ['Fort Greene']},
#  'neighbourhood': {'name': 'Fort Greene', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.9702, 40.68308]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 31,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2020, 12, 13, 0, 0),
#              'reviews_per_month': 0.25},
#  'availability_365': 251}
# {'_id': ObjectId('60c21bfeb653d40e79b52703'),
#  'accom_id': 45795737,
#  'description': 'Furnished 3BR Near 61 St Station-7 train. Cozy RMs',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.90077, 40.74239]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 217}
# {'_id': ObjectId('60c21bfeb653d40e79b529b9'),
#  'accom_id': 46353785,
#  'description': 'Luxury Penthouse in Downtown Brooklyn - Sanitized',
#  'host': {'id': 204049784,
#           'name': 'Jonathan',
#           'listings_count': 1,
#           'neighbourhood_list': ['Boerum Hill']},
#  'neighbourhood': {'name': 'Boerum Hill', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.97904, 40.6853]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 14,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 91}
# {'_id': ObjectId('60c21bffb653d40e79b52ce8'),
#  'accom_id': 46963460,
#  'description': 'Spacious & Stylish 3 BR Apt in Bushwick',
#  'host': {'id': 375549800,
#           'name': 'Kristina & Evans',
#           'listings_count': 12,
#           'neighbourhood_list': ['Bushwick']},
#  'neighbourhood': {'name': 'Bushwick', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.92084, 40.70007]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 35,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 119}
# {'_id': ObjectId('60c21bf6b653d40e79b4ab3d'),
#  'accom_id': 602070,
#  'description': 'Amazing Greenpoint/WBurg, BRKLN 1BR',
#  'host': {'id': 2640845,
#           'name': 'Zach',
#           'listings_count': 1,
#           'neighbourhood_list': ['Greenpoint']},
#  'neighbourhood': {'name': 'Greenpoint', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.95114, 40.72162]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 46,
#              'last_review': datetime.datetime(2020, 1, 21, 0, 0),
#              'reviews_per_month': 0.43},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf6b653d40e79b4b48d'),
#  'accom_id': 3767156,
#  'description': 'Mid-Century Modern Garden Paradise',
#  'host': {'id': 16351647,
#           'name': 'Carmia And Joe',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.91003, 40.68217]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 5,
#  'reviews': {'number_of_reviews': 278,
#              'last_review': datetime.datetime(2021, 3, 19, 0, 0),
#              'reviews_per_month': 3.41},
#  'availability_365': 264}
# {'_id': ObjectId('60c21bf7b653d40e79b4bb1a'),
#  'accom_id': 6044964,
#  'description': 'Beach Lovers Dream!',
#  'host': {'id': 31204745,
#           'name': 'Monika',
#           'listings_count': 1,
#           'neighbourhood_list': ['Arverne']},
#  'neighbourhood': {'name': 'Arverne', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.7929, 40.59005]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 232,
#              'last_review': datetime.datetime(2021, 3, 19, 0, 0),
#              'reviews_per_month': 3.25},
#  'availability_365': 270}
# {'_id': ObjectId('60c21bf7b653d40e79b4be09'),
#  'accom_id': 6965441,
#  'description': 'Chelsea NYC 1 Bedroom near Highline + Meatpacking',
#  'host': {'id': 19228782,
#           'name': 'Ben',
#           'listings_count': 1,
#           'neighbourhood_list': ['Chelsea']},
#  'neighbourhood': {'name': 'Chelsea', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00203, 40.74467]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 4,
#  'reviews': {'number_of_reviews': 19,
#              'last_review': datetime.datetime(2020, 12, 23, 0, 0),
#              'reviews_per_month': 0.32},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf7b653d40e79b4c247'),
#  'accom_id': 8381381,
#  'description': 'Studio in Manhattan',
#  'host': {'id': 2284111,
#           'name': 'Su',
#           'listings_count': 1,
#           'neighbourhood_list': ["Hell's Kitchen"]},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98388, 40.76599]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf7b653d40e79b4c61e'),
#  'accom_id': 9549544,
#  'description': 'Luxury Suite in the heart of Midtown NYC',
#  'host': {'id': 49451877,
#           'name': 'Sean',
#           'listings_count': 1,
#           'neighbourhood_list': ['Midtown']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98001, 40.76397]},
#  'room_type': 'Private room',
#  'price': 152,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2016, 12, 30, 0, 0),
#              'reviews_per_month': 0.03},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4c7d7'),
#  'accom_id': 9903132,
#  'description': 'large Tribeca loft',
#  'host': {'id': 50925964,
#           'name': nan,
#           'listings_count': 1,
#           'neighbourhood_list': ['Chinatown']},
#  'neighbourhood': {'name': 'Chinatown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00216, 40.71847]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 20,
#              'last_review': datetime.datetime(2020, 1, 5, 0, 0),
#              'reviews_per_month': 0.31},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4d186'),
#  'accom_id': 13595786,
#  'description': 'Light and spacious 2 bedroom loft in Bushwick',
#  'host': {'id': 6802844,
#           'name': 'Kaia',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bushwick']},
#  'neighbourhood': {'name': 'Bushwick', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.92019, 40.70627]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4d3b7'),
#  'accom_id': 14296562,
#  'description': 'Entire Home in Gramercy, Duplex Loft',
#  'host': {'id': 6543299,
#           'name': 'Sun-Young',
#           'listings_count': 1,
#           'neighbourhood_list': ['Kips Bay']},
#  'neighbourhood': {'name': 'Kips Bay', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98141, 40.73832]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 12,
#              'last_review': datetime.datetime(2018, 7, 8, 0, 0),
#              'reviews_per_month': 0.24},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4d3fc'),
#  'accom_id': 14429957,
#  'description': 'Amazing Private Room close Time Sq & Central Park.',
#  'host': {'id': 713764,
#           'name': 'Michelle & Heddy',
#           'listings_count': 2,
#           'neighbourhood_list': ["Hell's Kitchen", 'West Village']},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98902, 40.76475]},
#  'room_type': 'Private room',
#  'price': 152,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 161,
#              'last_review': datetime.datetime(2020, 3, 10, 0, 0),
#              'reviews_per_month': 2.88},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf9b653d40e79b4dbf0'),
#  'accom_id': 18103710,
#  'description': 'Elegant Upper East Side Studio',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96279, 40.763]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2020, 1, 20, 0, 0),
#              'reviews_per_month': 0.07},
#  'availability_365': 320}
# {'_id': ObjectId('60c21bf9b653d40e79b4dd80'),
#  'accom_id': 18789421,
#  'description': 'Peace in Brooklyn',
#  'host': {'id': 130774685,
#           'name': 'Edmund',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.92521, 40.68744]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 4,
#  'reviews': {'number_of_reviews': 123,
#              'last_review': datetime.datetime(2021, 3, 28, 0, 0),
#              'reviews_per_month': 2.66},
#  'availability_365': 347}
# {'_id': ObjectId('60c21bfab653d40e79b4e279'),
#  'accom_id': 20557017,
#  'description': 'Cozy Apartment/Near LGA airport and subway',
#  'host': {'id': 146812160,
#           'name': 'Bei Lei',
#           'listings_count': 1,
#           'neighbourhood_list': ['Flushing']},
#  'neighbourhood': {'name': 'Flushing', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.83184, 40.76164]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 19,
#              'last_review': datetime.datetime(2018, 1, 10, 0, 0),
#              'reviews_per_month': 0.43},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfab653d40e79b4e420'),
#  'accom_id': 21148292,
#  'description': 'Clean, Comfortable One Bedroom on the Upper East Side',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95842, 40.77118]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 3,
#              'last_review': datetime.datetime(2021, 2, 8, 0, 0),
#              'reviews_per_month': 0.07},
#  'availability_365': 311}
# {'_id': ObjectId('60c21bfbb653d40e79b4f2fc'),
#  'accom_id': 27477710,
#  'description': 'Beautiful Two Bedroom! 8min to LGA & 17 to JFK 中英文',
#  'host': {'id': 157337532,
#           'name': 'Henry',
#           'listings_count': 4,
#           'neighbourhood_list': ['College Point']},
#  'neighbourhood': {'name': 'College Point', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.84257, 40.77873]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 138,
#              'last_review': datetime.datetime(2021, 4, 4, 0, 0),
#              'reviews_per_month': 4.35},
#  'availability_365': 84}
# {'_id': ObjectId('60c21bfbb653d40e79b4faa5'),
#  'accom_id': 30674463,
#  'description': 'Prime Location Affordable 2 Bedrooms',
#  'host': {'id': 229284767,
#           'name': 'Ned',
#           'listings_count': 1,
#           'neighbourhood_list': ['Midtown']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98429, 40.75187]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2019, 4, 8, 0, 0),
#              'reviews_per_month': 0.08},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfcb653d40e79b506e9'),
#  'accom_id': 35978071,
#  'description': 'Urban Haven in the City! Near Yankee Stdm/Harlem',
#  'host': {'id': 30873670,
#           'name': 'Jay',
#           'listings_count': 1,
#           'neighbourhood_list': ['Longwood']},
#  'neighbourhood': {'name': 'Longwood', 'group': 'Bronx'},
#  'location': {'type': 'Point', 'coordinates': [-73.91097, 40.81961]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2019, 9, 22, 0, 0),
#              'reviews_per_month': 0.1},
#  'availability_365': 263}
# {'_id': ObjectId('60c21bfeb653d40e79b51de6'),
#  'accom_id': 43393934,
#  'description': 'Deluxe 2BR2BA w/ Queen Beds. Nice LR. Near Subway',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.90624, 40.7447]},
#  'room_type': 'Private room',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 252}
# {'_id': ObjectId('60c21bfeb653d40e79b525cd'),
#  'accom_id': 45581484,
#  'description': 'Private Studio on the Upper East Side',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96309, 40.76291]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 297}
# {'_id': ObjectId('60c21bfeb653d40e79b5264f'),
#  'accom_id': 45689285,
#  'description': 'Quaint UES One Bedroom Apartment',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95746, 40.76906]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 333}
# {'_id': ObjectId('60c21bfeb653d40e79b526e0'),
#  'accom_id': 45775472,
#  'description': 'Unique 2BR2BA House With Large Rooms+Elevator',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.9079, 40.74624]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 283}
# {'_id': ObjectId('60c21bfeb653d40e79b52704'),
#  'accom_id': 45796447,
#  'description': 'Wonderful 4BR Near Roosevelt Jackson Heights Stat',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.90317, 40.74301]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 311}
# {'_id': ObjectId('60c21bfeb653d40e79b5271f'),
#  'accom_id': 45817617,
#  'description': 'Easy commute Near Jackson Hts Roosevelt Av Station',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.89083, 40.73971]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 39}
# {'_id': ObjectId('60c21bfeb653d40e79b5281d'),
#  'accom_id': 46012353,
#  'description': 'PERFECTLY LOCATED STUDIO NEXT TO ⭐️ CENTRAL PARK ⭐️',
#  'host': {'id': 266793360,
#           'name': 'Morris',
#           'listings_count': 1,
#           'neighbourhood_list': ['Harlem']},
#  'neighbourhood': {'name': 'Harlem', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95362, 40.80399]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 27,
#              'last_review': datetime.datetime(2021, 4, 6, 0, 0),
#              'reviews_per_month': 5.0},
#  'availability_365': 344}
# {'_id': ObjectId('60c21bffb653d40e79b52adb'),
#  'accom_id': 46542773,
#  'description': 'Sleek Studio Apartment in Lenox Hill, Upper East Side',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96261, 40.7632]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bffb653d40e79b52d28'),
#  'accom_id': 47010749,
#  'description': 'Large Apartment - Brooklyn Charm',
#  'host': {'id': 66813379,
#           'name': nan,
#           'listings_count': 2,
#           'neighbourhood_list': ['Crown Heights']},
#  'neighbourhood': {'name': 'Crown Heights', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.94058, 40.66888]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 5,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2021, 3, 16, 0, 0),
#              'reviews_per_month': 1.46},
#  'availability_365': 346}
# {'_id': ObjectId('60c21bffb653d40e79b52d97'),
#  'accom_id': 47101598,
#  'description': 'Beautiful Brooklyn Studio Apartment Minutes From Manhattan',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Brooklyn Heights', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.99133, 40.69475]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 334}
# {'_id': ObjectId('60c21bffb653d40e79b5338e'),
#  'accom_id': 48316241,
#  'description': 'Sonder | Queen Room + Kitchenette in Flatiron District',
#  'host': {'id': 219517861,
#           'name': 'Sonder (NYC)',
#           'listings_count': 43,
#           'neighbourhood_list': ['Murray Hill',
#                                  'Financial District',
#                                  'Battery Park City',
#                                  'Midtown',
#                                  'Flatiron District']},
#  'neighbourhood': {'name': 'Flatiron District', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99012, 40.74295]},
#  'room_type': 'Private room',
#  'price': 152,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 322}
# {'_id': ObjectId('60c21bf6b653d40e79b4b44e'),
#  'accom_id': 3675957,
#  'description': 'Brooklyn Loft Studio, One Subway from Manhattan',
#  'host': {'id': 2076525,
#           'name': 'Douglas',
#           'listings_count': 1,
#           'neighbourhood_list': ['Navy Yard']},
#  'neighbourhood': {'name': 'Navy Yard', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.97604, 40.69828]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 7,
#  'reviews': {'number_of_reviews': 17,
#              'last_review': datetime.datetime(2020, 1, 1, 0, 0),
#              'reviews_per_month': 0.3},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf6b653d40e79b4b660'),
#  'accom_id': 4378951,
#  'description': 'Child-friendly 2BR w/ Yard access and Free Parking',
#  'host': {'id': 510577,
#           'name': 'Benjamin',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.93911, 40.68397]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 228,
#              'last_review': datetime.datetime(2020, 2, 16, 0, 0),
#              'reviews_per_month': 2.99},
#  'availability_365': 178}
# {'_id': ObjectId('60c21bf7b653d40e79b4c155'),
#  'accom_id': 7973730,
#  'description': 'Sunny Williamsburg apartment',
#  'host': {'id': 5828974,
#           'name': 'Farah',
#           'listings_count': 1,
#           'neighbourhood_list': ['Williamsburg']},
#  'neighbourhood': {'name': 'Williamsburg', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.95454, 40.71273]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 6,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2017, 7, 12, 0, 0),
#              'reviews_per_month': 0.03},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4cf8a'),
#  'accom_id': 13042637,
#  'description': 'Stunning 2BR Apartment in Sunnyside',
#  'host': {'id': 9427289,
#           'name': 'Steve',
#           'listings_count': 1,
#           'neighbourhood_list': ['Sunnyside']},
#  'neighbourhood': {'name': 'Sunnyside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.91679, 40.74717]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 201,
#              'last_review': datetime.datetime(2021, 4, 5, 0, 0),
#              'reviews_per_month': 3.53},
#  'availability_365': 270}
# {'_id': ObjectId('60c21bf8b653d40e79b4d367'),
#  'accom_id': 14148988,
#  'description': 'Heart of Manhattan, affordable place!',
#  'host': {'id': 4478946,
#           'name': 'Elka',
#           'listings_count': 1,
#           'neighbourhood_list': ['Midtown']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97216, 40.75165]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2016, 7, 31, 0, 0),
#              'reviews_per_month': 0.02},
#  'availability_365': 0}
# ...
#  'availability_365': 204}
# {'_id': ObjectId('60c21bfdb653d40e79b510a3'),
#  'accom_id': 39758327,
#  'description': 'Lux 2BR APT. Hudson Yards&Penn Station',
#  'host': {'id': 191009021,
#           'name': 'Matt',
#           'listings_count': 1,
#           'neighbourhood_list': ['Chelsea']},
#  'neighbourhood': {'name': 'Chelsea', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.9956, 40.75264]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 23,
#              'last_review': datetime.datetime(2021, 3, 27, 0, 0),
#              'reviews_per_month': 1.52},
#  'availability_365': 119}
# {'_id': ObjectId('60c21bfdb653d40e79b510d0'),
#  'accom_id': 39834665,
#  'description': 'Top floor studio in the heart of Upper East Side',
#  'host': {'id': 27606853,
#           'name': 'Ewa',
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper East Side']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95668, 40.77853]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 5,
#              'last_review': datetime.datetime(2020, 8, 19, 0, 0),
#              'reviews_per_month': 0.31},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfdb653d40e79b511bb'),
#  'accom_id': 40086154,
#  'description': 'Clean space',
#  'host': {'id': 302138294,
#           'name': 'Al',
#           'listings_count': 2,
#           'neighbourhood_list': ['Shore Acres']},
#  'neighbourhood': {'name': 'Shore Acres', 'group': 'Staten Island'},
#  'location': {'type': 'Point', 'coordinates': [-74.06337, 40.61225]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2020, 1, 1, 0, 0),
#              'reviews_per_month': 0.06},
#  'availability_365': 365}
# {'_id': ObjectId('60c21bfdb653d40e79b512f9'),
#  'accom_id': 40430111,
#  'description': 'NEW LUXURY 2 BED APT IN PRIVATE HOME NEAR TRAINS',
#  'host': {'id': 312697286,
#           'name': 'Steven',
#           'listings_count': 2,
#           'neighbourhood_list': ['Gravesend']},
#  'neighbourhood': {'name': 'Gravesend', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.97595, 40.6007]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 7,
#  'reviews': {'number_of_reviews': 10,
#              'last_review': datetime.datetime(2020, 12, 28, 0, 0),
#              'reviews_per_month': 0.62},
#  'availability_365': 313}
# {'_id': ObjectId('60c21bfdb653d40e79b51575'),
#  'accom_id': 41036360,
#  'description': 'Newly renovated, comfy and trendy space. #1',
#  'host': {'id': 212147885,
#           'name': 'Alisa',
#           'listings_count': 4,
#           'neighbourhood_list': ['Tompkinsville',
#                                  'Bedford-Stuyvesant',
#                                  'Crown Heights']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.90923, 40.67737]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 4,
#  'reviews': {'number_of_reviews': 9,
#              'last_review': datetime.datetime(2020, 11, 22, 0, 0),
#              'reviews_per_month': 0.69},
#  'availability_365': 96}
# {'_id': ObjectId('60c21bfdb653d40e79b51580'),
#  'accom_id': 41048681,
#  'description': 'Roomy and aesthetically pleasing  place #2',
#  'host': {'id': 212147885,
#           'name': 'Alisa',
#           'listings_count': 4,
#           'neighbourhood_list': ['Tompkinsville',
#                                  'Bedford-Stuyvesant',
#                                  'Crown Heights']},
#  'neighbourhood': {'name': 'Crown Heights', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.91053, 40.67555]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 5,
#  'reviews': {'number_of_reviews': 10,
#              'last_review': datetime.datetime(2020, 11, 16, 0, 0),
#              'reviews_per_month': 0.65},
#  'availability_365': 211}
# {'_id': ObjectId('60c21bfdb653d40e79b5168e'),
#  'accom_id': 41479095,
#  'description': 'Family Friendly, Enormous and Bright SpaHa Loft',
#  'host': {'id': 153555756,
#           'name': 'Ana',
#           'listings_count': 2,
#           'neighbourhood_list': ['East Harlem']},
#  'neighbourhood': {'name': 'East Harlem', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.94186, 40.79054]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 4,
#              'last_review': datetime.datetime(2020, 2, 23, 0, 0),
#              'reviews_per_month': 0.27},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfdb653d40e79b51971'),
#  'accom_id': 42429336,
#  'description': '★ SECOND AVE & 22ND STREET ★ (3F)',
#  'host': {'id': 337720916,
#           'name': 'Liz',
#           'listings_count': 3,
#           'neighbourhood_list': ['Gramercy', 'Kips Bay']},
#  'neighbourhood': {'name': 'Gramercy', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98074, 40.73671]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 7,
#  'reviews': {'number_of_reviews': 3,
#              'last_review': datetime.datetime(2020, 3, 28, 0, 0),
#              'reviews_per_month': 0.22},
#  'availability_365': 288}
# {'_id': ObjectId('60c21bfdb653d40e79b51b81'),
#  'accom_id': 42941437,
#  'description': "Gabriel's Luxury Suite",
#  'host': {'id': 23183510,
#           'name': 'Karen',
#           'listings_count': 2,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.93708, 40.68676]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 365}
# {'_id': ObjectId('60c21bfeb653d40e79b51ba5'),
#  'accom_id': 42972333,
#  'description': 'Clean & Private Studio | Work Remote w/ Desk | GLS',
#  'host': {'id': 30283594,
#           'name': 'Global Luxury Suites',
#           'listings_count': 68,
#           'neighbourhood_list': ['Midtown',
#                                  'Upper East Side',
#                                  'Theater District',
#                                  "Hell's Kitchen",
#                                  'Tribeca',
#                                  'Murray Hill',
#                                  'Chinatown',
#                                  'Williamsburg',
#                                  'Financial District',
#                                  'Mott Haven',
#                                  'Port Morris']},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99803, 40.76086]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 357}
# {'_id': ObjectId('60c21bfeb653d40e79b51ba6'),
#  'accom_id': 42972677,
#  'description': 'Bright Studio | Work Desk & WiFi | Midtown West',
#  'host': {'id': 30283594,
#           'name': 'Global Luxury Suites',
#           'listings_count': 68,
#           'neighbourhood_list': ['Midtown',
#                                  'Upper East Side',
#                                  'Theater District',
#                                  "Hell's Kitchen",
#                                  'Tribeca',
#                                  'Murray Hill',
#                                  'Chinatown',
#                                  'Williamsburg',
#                                  'Financial District',
#                                  'Mott Haven',
#                                  'Port Morris']},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99826, 40.76253]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 360}
# {'_id': ObjectId('60c21bfeb653d40e79b51d57'),
#  'accom_id': 43309210,
#  'description': 'Charming 2 Bedroom Flat in prime East Village',
#  'host': {'id': 188726696,
#           'name': 'Matteo',
#           'listings_count': 1,
#           'neighbourhood_list': ['East Village']},
#  'neighbourhood': {'name': 'East Village', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.9833, 40.72528]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 220}
# {'_id': ObjectId('60c21bfeb653d40e79b520b0'),
#  'accom_id': 44146260,
#  'description': 'Cozy & Stylish 1BR in Manhattan (Hell´s Kitchen)',
#  'host': {'id': 130155462,
#           'name': 'Fred',
#           'listings_count': 1,
#           'neighbourhood_list': ["Hell's Kitchen"]},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98954, 40.76385]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 24,
#              'last_review': datetime.datetime(2021, 3, 20, 0, 0),
#              'reviews_per_month': 2.64},
#  'availability_365': 283}
# {'_id': ObjectId('60c21bfeb653d40e79b5216c'),
#  'accom_id': 44339323,
#  'description': 'Sunny Quiet Oasis in Brooklyn',
#  'host': {'id': 35891761,
#           'name': 'Aditi',
#           'listings_count': 1,
#           'neighbourhood_list': ['Greenpoint']},
#  'neighbourhood': {'name': 'Greenpoint', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.94051, 40.72671]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 14,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfeb653d40e79b52271'),
#  'accom_id': 44642468,
#  'description': 'Quaint Island Community 20mi. from New York City!',
#  'host': {'id': 16794996,
#           'name': 'Amanda',
#           'listings_count': 1,
#           'neighbourhood_list': ['City Island']},
#  'neighbourhood': {'name': 'City Island', 'group': 'Bronx'},
#  'location': {'type': 'Point', 'coordinates': [-73.78796, 40.84892]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 5,
#              'last_review': datetime.datetime(2021, 4, 8, 0, 0),
#              'reviews_per_month': 3.66},
#  'availability_365': 327}
# {'_id': ObjectId('60c21bfeb653d40e79b526c1'),
#  'accom_id': 45759295,
#  'description': 'Well-lit 1st Fl 4BR-House -> 52 St station (7train)',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.90921, 40.74555]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 312}
# {'_id': ObjectId('60c21bfeb653d40e79b526ec'),
#  'accom_id': 45784235,
#  'description': 'Prime Location! Central Park. 2 Bedrooms Apt.',
#  'host': {'id': 86771798,
#           'name': 'Daia',
#           'listings_count': 18,
#           'neighbourhood_list': ['Tribeca',
#                                  'Midtown',
#                                  'Murray Hill',
#                                  'Kips Bay']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97906, 40.76654]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 60,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2021, 1, 4, 0, 0),
#              'reviews_per_month': 0.31},
#  'availability_365': 95}
# {'_id': ObjectId('60c21bfeb653d40e79b529c5'),
#  'accom_id': 46356156,
#  'description': 'The Beekman, A Thompson Hotel - Superior Queen',
#  'host': {'id': 373480843,
#           'name': 'The Beekman',
#           'listings_count': 3,
#           'neighbourhood_list': ['Financial District', 'Civic Center']},
#  'neighbourhood': {'name': 'Financial District', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00691, 40.71121]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 363}
# {'_id': ObjectId('60c21bffb653d40e79b52a9e'),
#  'accom_id': 46503564,
#  'description': 'Location! Location PRIME! Central Park - 2B/1B',
#  'host': {'id': 86771798,
#           'name': 'Daia',
#           'listings_count': 18,
#           'neighbourhood_list': ['Tribeca',
#                                  'Midtown',
#                                  'Murray Hill',
#                                  'Kips Bay']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97924, 40.76484]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 60,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 68}
# {'_id': ObjectId('60c21bffb653d40e79b52d1e'),
#  'accom_id': 47004464,
#  'description': 'NYC Apartment Just 25 minutes to Penn Station!',
#  'host': {'id': 379993600,
#           'name': 'Rob',
#           'listings_count': 2,
#           'neighbourhood_list': ['Bayside']},
#  'neighbourhood': {'name': 'Bayside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.77561, 40.76216]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bffb653d40e79b5338d'),
#  'accom_id': 48316162,
#  'description': 'Sonder | ADA-Accessible Room in Flatiron District',
#  'host': {'id': 219517861,
#           'name': 'Sonder (NYC)',
#           'listings_count': 43,
#           'neighbourhood_list': ['Murray Hill',
#                                  'Financial District',
#                                  'Battery Park City',
#                                  'Midtown',
#                                  'Flatiron District']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99042, 40.74463]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 322}
# {'_id': ObjectId('60c21bffb653d40e79b533b8'),
#  'accom_id': 48344963,
#  'description': 'TRYP by Wyndham - Luxury that sleeps 8',
#  'host': {'id': 38592279,
#           'name': 'Vk',
#           'listings_count': 19,
#           'neighbourhood_list': ['Midtown', 'Chelsea', "Hell's Kitchen"]},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99409, 40.75486]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2021, 4, 3, 0, 0),
#              'reviews_per_month': 1.0},
#  'availability_365': 2}

# %% [markdown]
# ---
# We can define the pipeline separately.
#
# For example, filter document where `150 < price < 170`.
#
# ----

# %%
# Pipeline

pipeline_1 = [
                {
                    '$match':{
                                'price':{'$gt':150, '$lt':170}
                             }
                }
            ]

# %%
# Aggregation Pipeline

cur = db.airbnb.aggregate(pipeline_1)

for doc in cur:
    pp.pprint(doc)
# Out:
# {'_id': ObjectId('60c21bf6b653d40e79b4aa69'),
#  'accom_id': 435909,
#  'description': 'Sunny West Village Dream',
#  'host': {'id': 2165401,
#           'name': 'Andrew',
#           'listings_count': 1,
#           'neighbourhood_list': ['West Village']},
#  'neighbourhood': {'name': 'West Village', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00418, 40.73553]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 88,
#  'reviews': {'number_of_reviews': 19,
#              'last_review': datetime.datetime(2016, 12, 24, 0, 0),
#              'reviews_per_month': 0.18},
#  'availability_365': 159}
# {'_id': ObjectId('60c21bf6b653d40e79b4af32'),
#  'accom_id': 1780748,
#  'description': 'Sunny 1 bedroom In The Heart of NYC',
#  'host': {'id': 9293512,
#           'name': 'Pk',
#           'listings_count': 1,
#           'neighbourhood_list': ['Murray Hill']},
#  'neighbourhood': {'name': 'Murray Hill', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97218, 40.74749]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 39,
#              'last_review': datetime.datetime(2019, 9, 26, 0, 0),
#              'reviews_per_month': 0.43},
#  'availability_365': 362}
# {'_id': ObjectId('60c21bf6b653d40e79b4b3d9'),
#  'accom_id': 3530395,
#  'description': '1 BR in Great NYC Neighborhood',
#  'host': {'id': 7665324,
#           'name': 'Edward',
#           'listings_count': 2,
#           'neighbourhood_list': ['Lower East Side']},
#  'neighbourhood': {'name': 'Lower East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99201, 40.72128]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 5,
#              'last_review': datetime.datetime(2019, 4, 8, 0, 0),
#              'reviews_per_month': 0.07},
#  'availability_365': 144}
# {'_id': ObjectId('60c21bf7b653d40e79b4bfd5'),
#  'accom_id': 7545274,
#  'description': 'Charming 1 Bedroom Apt - Midtown East',
#  'host': {'id': 25846948,
#           'name': 'Morgan',
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper East Side']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96248, 40.76157]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 19,
#              'last_review': datetime.datetime(2017, 6, 26, 0, 0),
#              'reviews_per_month': 0.28},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4d3c5'),
#  'accom_id': 14318774,
#  'description': 'New York Masterpiece',
#  'host': {'id': 37718300,
#           'name': 'Martha',
#           'listings_count': 2,
#           'neighbourhood_list': ['Forest Hills']},
#  'neighbourhood': {'name': 'Forest Hills', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.85542, 40.73438]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 117,
#              'last_review': datetime.datetime(2021, 3, 14, 0, 0),
#              'reviews_per_month': 2.1},
#  'availability_365': 354}
# {'_id': ObjectId('60c21bf9b653d40e79b4d810'),
#  'accom_id': 16308886,
#  'description': 'SUNNY 2BD W. ELEVATOR / PERFECT 4 SMALL FAMILY',
#  'host': {'id': 106714852,
#           'name': 'Ben',
#           'listings_count': 1,
#           'neighbourhood_list': ['Lower East Side']},
#  'neighbourhood': {'name': 'Lower East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98982, 40.71358]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2019, 1, 6, 0, 0),
#              'reviews_per_month': 0.06},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf9b653d40e79b4d8b3'),
#  'accom_id': 16428383,
#  'description': '2 blocks to 2 ⭐️⭐️⭐️⭐️⭐️',
#  'host': {'id': 45247495,
#           'name': 'Carlos',
#           'listings_count': 1,
#           'neighbourhood_list': ['Fieldston']},
#  'neighbourhood': {'name': 'Fieldston', 'group': 'Bronx'},
#  'location': {'type': 'Point', 'coordinates': [-73.89789, 40.89338]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 6,
#  'reviews': {'number_of_reviews': 14,
#              'last_review': datetime.datetime(2020, 11, 4, 0, 0),
#              'reviews_per_month': 0.3},
#  'availability_365': 345}
# {'_id': ObjectId('60c21bf9b653d40e79b4e105'),
#  'accom_id': 19969013,
#  'description': 'Downtown Brooklyn Condo',
#  'host': {'id': 71841088,
#           'name': 'Pristine Posh',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.94751, 40.69292]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf9b653d40e79b4e1dc'),
#  'accom_id': 20263650,
#  'description': 'Light Filled Quiet UWS studio',
#  'host': {'id': 170094,
#           'name': 'Lee',
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper West Side']},
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97674, 40.79312]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 9,
#              'last_review': datetime.datetime(2020, 1, 2, 0, 0),
#              'reviews_per_month': 0.21},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfab653d40e79b4e317'),
#  'accom_id': 20758288,
#  'description': 'Charming 1 bed in ❤️ of Greenwich Village.',
#  'host': {'id': 2739935,
#           'name': 'Brooke',
#           'listings_count': 1,
#           'neighbourhood_list': ['Greenwich Village']},
#  'neighbourhood': {'name': 'Greenwich Village', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99998, 40.72895]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 4,
#              'last_review': datetime.datetime(2018, 1, 3, 0, 0),
#              'reviews_per_month': 0.09},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfab653d40e79b4e3d1'),
#  'accom_id': 21025488,
#  'description': 'Apartment with Garden & Patio',
#  'host': {'id': 151421618,
#           'name': 'Adesh & Viviana',
#           'listings_count': 2,
#           'neighbourhood_list': ['Ozone Park']},
#  'neighbourhood': {'name': 'Ozone Park', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.84401, 40.68524]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 32,
#              'last_review': datetime.datetime(2020, 11, 1, 0, 0),
#              'reviews_per_month': 1.01},
#  'availability_365': 265}
# {'_id': ObjectId('60c21bfab653d40e79b4e41d'),
#  'accom_id': 21141576,
#  'description': 'Brand new, comfortable, refined, our first！全新，商务最佳',
#  'host': {'id': 152530167,
#           'name': 'Luxi',
#           'listings_count': 1,
#           'neighbourhood_list': ['Flushing']},
#  'neighbourhood': {'name': 'Flushing', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.82625, 40.76391]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 24,
#              'last_review': datetime.datetime(2019, 6, 6, 0, 0),
#              'reviews_per_month': 0.57},
#  'availability_365': 89}
# {'_id': ObjectId('60c21bfab653d40e79b4e4a7'),
#  'accom_id': 21293326,
#  'description': 'Huge Designer Room | Lower East Side /East Village',
#  'host': {'id': 10994839,
#           'name': 'Michael',
#           'listings_count': 1,
#           'neighbourhood_list': ['Lower East Side']},
#  'neighbourhood': {'name': 'Lower East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.9815, 40.7198]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 48,
#              'last_review': datetime.datetime(2020, 2, 28, 0, 0),
#              'reviews_per_month': 1.15},
#  'availability_365': 90}
# {'_id': ObjectId('60c21bfab653d40e79b4e515'),
#  'accom_id': 21450176,
#  'description': 'Private Room in Convenient Midtown East Location',
#  'host': {'id': 121809482,
#           'name': 'Gina',
#           'listings_count': 2,
#           'neighbourhood_list': ['Midtown']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97027, 40.75214]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 25,
#              'last_review': datetime.datetime(2019, 1, 18, 0, 0),
#              'reviews_per_month': 0.61},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfab653d40e79b4e91b'),
#  'accom_id': 22431770,
#  'description': 'Freehand New York - Queen Room',
#  'host': {'id': 164291123,
#           'name': 'Freehand',
#           'listings_count': 3,
#           'neighbourhood_list': ['Flatiron District']},
#  'neighbourhood': {'name': 'Flatiron District', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98599, 40.7403]},
#  'room_type': 'Hotel room',
#  'price': 151,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 153,
#              'last_review': datetime.datetime(2021, 3, 21, 0, 0),
#              'reviews_per_month': 4.01},
#  'availability_365': 365}
# {'_id': ObjectId('60c21bfab653d40e79b4e957'),
#  'accom_id': 22505480,
#  'description': 'Studio in Luxury Building - UWS - Indoor Pool, Gym',
#  'host': {'id': 126687208,
#           'name': nan,
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper West Side']},
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96413, 40.79289]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfbb653d40e79b4f50f'),
#  'accom_id': 28409473,
#  'description': 'CoZy room with your own bathroom/entrance in UES!',
#  'host': {'id': 109378554,
#           'name': 'Adele',
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper East Side']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95638, 40.76998]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 57,
#              'last_review': datetime.datetime(2020, 1, 28, 0, 0),
#              'reviews_per_month': 1.82},
#  'availability_365': 89}
# {'_id': ObjectId('60c21bfbb653d40e79b4f9e8'),
#  'accom_id': 30394133,
#  'description': 'Friendly Midtown East Studio w/ Great light + Gym by '
#                 'Blueground',
#  'host': {'id': 107434423,
#           'name': 'Blueground',
#           'listings_count': 266,
#           'neighbourhood_list': ['Kips Bay',
#                                  'Murray Hill',
#                                  'Tribeca',
#                                  'Upper East Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'East Village',
#                                  'Upper West Side',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Midtown',
#                                  'Nolita',
#                                  'SoHo',
#                                  'Battery Park City']},
#  'neighbourhood': {'name': 'Kips Bay', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97986, 40.74572]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2020, 7, 19, 0, 0),
#              'reviews_per_month': 0.08},
#  'availability_365': 342}
# {'_id': ObjectId('60c21bfcb653d40e79b4ff34'),
#  'accom_id': 32729130,
#  'description': 'cozy and charming experience in China Town!',
#  'host': {'id': 50333451,
#           'name': 'Jennifer',
#           'listings_count': 1,
#           'neighbourhood_list': ['Chinatown']},
#  'neighbourhood': {'name': 'Chinatown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99792, 40.71547]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfcb653d40e79b50112'),
#  'accom_id': 33743082,
#  'description': 'NEWLY-RENOVATED APARTMENT, 35 MINS FROM MANHATTAN',
#  'host': {'id': 619942,
#           'name': 'Stacy',
#           'listings_count': 6,
#           'neighbourhood_list': ['Cypress Hills']},
#  'neighbourhood': {'name': 'Cypress Hills', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.87265, 40.68851]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 28}
# {'_id': ObjectId('60c21bfcb653d40e79b50508'),
#  'accom_id': 35258943,
#  'description': 'The Baly Simpson Inn',
#  'host': {'id': 20324421,
#           'name': 'Marcus',
#           'listings_count': 1,
#           'neighbourhood_list': ['Prospect-Lefferts Gardens']},
#  'neighbourhood': {'name': 'Prospect-Lefferts Gardens', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.94986, 40.65889]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 125,
#              'last_review': datetime.datetime(2021, 4, 8, 0, 0),
#              'reviews_per_month': 5.65},
#  'availability_365': 65}
# {'_id': ObjectId('60c21bfcb653d40e79b5084e'),
#  'accom_id': 36601094,
#  'description': 'Sohotel, Deluxe Queen',
#  'host': {'id': 266797018,
#           'name': 'Sohotel',
#           'listings_count': 13,
#           'neighbourhood_list': ['Little Italy', 'Tribeca']},
#  'neighbourhood': {'name': 'Tribeca', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00945, 40.72179]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2020, 9, 20, 0, 0),
#              'reviews_per_month': 0.15},
#  'availability_365': 53}
# {'_id': ObjectId('60c21bfdb653d40e79b50d4f'),
#  'accom_id': 38697036,
#  'description': 'Spacious 1 bedroom apt with garden access',
#  'host': {'id': 31481921,
#           'name': 'Alexandre',
#           'listings_count': 1,
#           'neighbourhood_list': ['Carroll Gardens']},
#  'neighbourhood': {'name': 'Carroll Gardens', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-74.0003, 40.67732]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 37,
#              'last_review': datetime.datetime(2021, 3, 21, 0, 0),
#              'reviews_per_month': 1.99},
#  'availability_365': 29}
# {'_id': ObjectId('60c21bfdb653d40e79b50e5e'),
#  'accom_id': 39086622,
#  'description': 'Charming & Bright BR ☼ Balcony in the Heart of LES',
#  'host': {'id': 13006166,
#           'name': 'Patricia',
#           'listings_count': 2,
#           'neighbourhood_list': ['Lower East Side']},
#  'neighbourhood': {'name': 'Lower East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.9865, 40.71937]},
#  'room_type': 'Private room',
#  'price': 151,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 13,
#              'last_review': datetime.datetime(2020, 8, 16, 0, 0),
#              'reviews_per_month': 0.73},
#  'availability_365': 365}
# {'_id': ObjectId('60c21bfdb653d40e79b51366'),
#  'accom_id': 40537067,
#  'description': 'Stylish Parlour Apt in Bedford Stuyvesant',
#  'host': {'id': 67122613,
#           'name': 'Donna',
#           'listings_count': 2,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.92976, 40.68263]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 28,
#              'last_review': datetime.datetime(2021, 3, 28, 0, 0),
#              'reviews_per_month': 1.94},
#  'availability_365': 330}
# {'_id': ObjectId('60c21bfdb653d40e79b51678'),
#  'accom_id': 41430114,
#  'description': 'Private & Serene Bedford Ave Sanctuary w Backyard',
#  'host': {'id': 279237710,
#           'name': 'Ralph',
#           'listings_count': 1,
#           'neighbourhood_list': ['Williamsburg']},
#  'neighbourhood': {'name': 'Williamsburg', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.96233, 40.71442]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 3,
#              'last_review': datetime.datetime(2020, 2, 16, 0, 0),
#              'reviews_per_month': 0.21},
#  'availability_365': 39}
# {'_id': ObjectId('60c21bfdb653d40e79b51741'),
#  'accom_id': 41733738,
#  'description': 'Paradise OASIS STUDIO W/Backyard + RUM PUNCH',
#  'host': {'id': 329582733,
#           'name': 'Swipe',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bergen Beach']},
#  'neighbourhood': {'name': 'Bergen Beach', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.91445, 40.62806]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 71,
#              'last_review': datetime.datetime(2021, 3, 25, 0, 0),
#              'reviews_per_month': 4.93},
#  'availability_365': 364}
# {'_id': ObjectId('60c21bfdb653d40e79b51790'),
#  'accom_id': 41838215,
#  'description': 'Chelsea Studio w/ queen & full kitchen',
#  'host': {'id': 24709527,
#           'name': 'Richard',
#           'listings_count': 1,
#           'neighbourhood_list': ['Chelsea']},
#  'neighbourhood': {'name': 'Chelsea', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99569, 40.74858]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2020, 3, 14, 0, 0),
#              'reviews_per_month': 0.15},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfdb653d40e79b5186b'),
#  'accom_id': 42095151,
#  'description': '1 Bedroom in Fort Greene Luxury Building',
#  'host': {'id': 991082,
#           'name': 'Courtney',
#           'listings_count': 1,
#           'neighbourhood_list': ['Fort Greene']},
#  'neighbourhood': {'name': 'Fort Greene', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.9702, 40.68308]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 31,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2020, 12, 13, 0, 0),
#              'reviews_per_month': 0.25},
#  'availability_365': 251}
# {'_id': ObjectId('60c21bfeb653d40e79b52703'),
#  'accom_id': 45795737,
#  'description': 'Furnished 3BR Near 61 St Station-7 train. Cozy RMs',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.90077, 40.74239]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 217}
# {'_id': ObjectId('60c21bfeb653d40e79b529b9'),
#  'accom_id': 46353785,
#  'description': 'Luxury Penthouse in Downtown Brooklyn - Sanitized',
#  'host': {'id': 204049784,
#           'name': 'Jonathan',
#           'listings_count': 1,
#           'neighbourhood_list': ['Boerum Hill']},
#  'neighbourhood': {'name': 'Boerum Hill', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.97904, 40.6853]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 14,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 91}
# {'_id': ObjectId('60c21bffb653d40e79b52ce8'),
#  'accom_id': 46963460,
#  'description': 'Spacious & Stylish 3 BR Apt in Bushwick',
#  'host': {'id': 375549800,
#           'name': 'Kristina & Evans',
#           'listings_count': 12,
#           'neighbourhood_list': ['Bushwick']},
#  'neighbourhood': {'name': 'Bushwick', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.92084, 40.70007]},
#  'room_type': 'Entire home/apt',
#  'price': 151,
#  'minimum_nights': 35,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 119}
# {'_id': ObjectId('60c21bf6b653d40e79b4ab3d'),
#  'accom_id': 602070,
#  'description': 'Amazing Greenpoint/WBurg, BRKLN 1BR',
#  'host': {'id': 2640845,
#           'name': 'Zach',
#           'listings_count': 1,
#           'neighbourhood_list': ['Greenpoint']},
#  'neighbourhood': {'name': 'Greenpoint', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.95114, 40.72162]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 46,
#              'last_review': datetime.datetime(2020, 1, 21, 0, 0),
#              'reviews_per_month': 0.43},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf6b653d40e79b4b48d'),
#  'accom_id': 3767156,
#  'description': 'Mid-Century Modern Garden Paradise',
#  'host': {'id': 16351647,
#           'name': 'Carmia And Joe',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.91003, 40.68217]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 5,
#  'reviews': {'number_of_reviews': 278,
#              'last_review': datetime.datetime(2021, 3, 19, 0, 0),
#              'reviews_per_month': 3.41},
#  'availability_365': 264}
# {'_id': ObjectId('60c21bf7b653d40e79b4bb1a'),
#  'accom_id': 6044964,
#  'description': 'Beach Lovers Dream!',
#  'host': {'id': 31204745,
#           'name': 'Monika',
#           'listings_count': 1,
#           'neighbourhood_list': ['Arverne']},
#  'neighbourhood': {'name': 'Arverne', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.7929, 40.59005]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 232,
#              'last_review': datetime.datetime(2021, 3, 19, 0, 0),
#              'reviews_per_month': 3.25},
#  'availability_365': 270}
# {'_id': ObjectId('60c21bf7b653d40e79b4be09'),
#  'accom_id': 6965441,
#  'description': 'Chelsea NYC 1 Bedroom near Highline + Meatpacking',
#  'host': {'id': 19228782,
#           'name': 'Ben',
#           'listings_count': 1,
#           'neighbourhood_list': ['Chelsea']},
#  'neighbourhood': {'name': 'Chelsea', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00203, 40.74467]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 4,
#  'reviews': {'number_of_reviews': 19,
#              'last_review': datetime.datetime(2020, 12, 23, 0, 0),
#              'reviews_per_month': 0.32},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf7b653d40e79b4c247'),
#  'accom_id': 8381381,
#  'description': 'Studio in Manhattan',
#  'host': {'id': 2284111,
#           'name': 'Su',
#           'listings_count': 1,
#           'neighbourhood_list': ["Hell's Kitchen"]},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98388, 40.76599]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf7b653d40e79b4c61e'),
#  'accom_id': 9549544,
#  'description': 'Luxury Suite in the heart of Midtown NYC',
#  'host': {'id': 49451877,
#           'name': 'Sean',
#           'listings_count': 1,
#           'neighbourhood_list': ['Midtown']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98001, 40.76397]},
#  'room_type': 'Private room',
#  'price': 152,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2016, 12, 30, 0, 0),
#              'reviews_per_month': 0.03},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4c7d7'),
#  'accom_id': 9903132,
#  'description': 'large Tribeca loft',
#  'host': {'id': 50925964,
#           'name': nan,
#           'listings_count': 1,
#           'neighbourhood_list': ['Chinatown']},
#  'neighbourhood': {'name': 'Chinatown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00216, 40.71847]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 20,
#              'last_review': datetime.datetime(2020, 1, 5, 0, 0),
#              'reviews_per_month': 0.31},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4d186'),
#  'accom_id': 13595786,
#  'description': 'Light and spacious 2 bedroom loft in Bushwick',
#  'host': {'id': 6802844,
#           'name': 'Kaia',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bushwick']},
#  'neighbourhood': {'name': 'Bushwick', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.92019, 40.70627]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4d3b7'),
#  'accom_id': 14296562,
#  'description': 'Entire Home in Gramercy, Duplex Loft',
#  'host': {'id': 6543299,
#           'name': 'Sun-Young',
#           'listings_count': 1,
#           'neighbourhood_list': ['Kips Bay']},
#  'neighbourhood': {'name': 'Kips Bay', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98141, 40.73832]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 12,
#              'last_review': datetime.datetime(2018, 7, 8, 0, 0),
#              'reviews_per_month': 0.24},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4d3fc'),
#  'accom_id': 14429957,
#  'description': 'Amazing Private Room close Time Sq & Central Park.',
#  'host': {'id': 713764,
#           'name': 'Michelle & Heddy',
#           'listings_count': 2,
#           'neighbourhood_list': ["Hell's Kitchen", 'West Village']},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98902, 40.76475]},
#  'room_type': 'Private room',
#  'price': 152,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 161,
#              'last_review': datetime.datetime(2020, 3, 10, 0, 0),
#              'reviews_per_month': 2.88},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf9b653d40e79b4dbf0'),
#  'accom_id': 18103710,
#  'description': 'Elegant Upper East Side Studio',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96279, 40.763]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2020, 1, 20, 0, 0),
#              'reviews_per_month': 0.07},
#  'availability_365': 320}
# {'_id': ObjectId('60c21bf9b653d40e79b4dd80'),
#  'accom_id': 18789421,
#  'description': 'Peace in Brooklyn',
#  'host': {'id': 130774685,
#           'name': 'Edmund',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.92521, 40.68744]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 4,
#  'reviews': {'number_of_reviews': 123,
#              'last_review': datetime.datetime(2021, 3, 28, 0, 0),
#              'reviews_per_month': 2.66},
#  'availability_365': 347}
# {'_id': ObjectId('60c21bfab653d40e79b4e279'),
#  'accom_id': 20557017,
#  'description': 'Cozy Apartment/Near LGA airport and subway',
#  'host': {'id': 146812160,
#           'name': 'Bei Lei',
#           'listings_count': 1,
#           'neighbourhood_list': ['Flushing']},
#  'neighbourhood': {'name': 'Flushing', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.83184, 40.76164]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 19,
#              'last_review': datetime.datetime(2018, 1, 10, 0, 0),
#              'reviews_per_month': 0.43},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfab653d40e79b4e420'),
#  'accom_id': 21148292,
#  'description': 'Clean, Comfortable One Bedroom on the Upper East Side',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95842, 40.77118]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 3,
#              'last_review': datetime.datetime(2021, 2, 8, 0, 0),
#              'reviews_per_month': 0.07},
#  'availability_365': 311}
# {'_id': ObjectId('60c21bfbb653d40e79b4f2fc'),
#  'accom_id': 27477710,
#  'description': 'Beautiful Two Bedroom! 8min to LGA & 17 to JFK 中英文',
#  'host': {'id': 157337532,
#           'name': 'Henry',
#           'listings_count': 4,
#           'neighbourhood_list': ['College Point']},
#  'neighbourhood': {'name': 'College Point', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.84257, 40.77873]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 138,
#              'last_review': datetime.datetime(2021, 4, 4, 0, 0),
#              'reviews_per_month': 4.35},
#  'availability_365': 84}
# {'_id': ObjectId('60c21bfbb653d40e79b4faa5'),
#  'accom_id': 30674463,
#  'description': 'Prime Location Affordable 2 Bedrooms',
#  'host': {'id': 229284767,
#           'name': 'Ned',
#           'listings_count': 1,
#           'neighbourhood_list': ['Midtown']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98429, 40.75187]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2019, 4, 8, 0, 0),
#              'reviews_per_month': 0.08},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfcb653d40e79b506e9'),
#  'accom_id': 35978071,
#  'description': 'Urban Haven in the City! Near Yankee Stdm/Harlem',
#  'host': {'id': 30873670,
#           'name': 'Jay',
#           'listings_count': 1,
#           'neighbourhood_list': ['Longwood']},
#  'neighbourhood': {'name': 'Longwood', 'group': 'Bronx'},
#  'location': {'type': 'Point', 'coordinates': [-73.91097, 40.81961]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2019, 9, 22, 0, 0),
#              'reviews_per_month': 0.1},
#  'availability_365': 263}
# {'_id': ObjectId('60c21bfeb653d40e79b51de6'),
#  'accom_id': 43393934,
#  'description': 'Deluxe 2BR2BA w/ Queen Beds. Nice LR. Near Subway',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.90624, 40.7447]},
#  'room_type': 'Private room',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 252}
# {'_id': ObjectId('60c21bfeb653d40e79b525cd'),
#  'accom_id': 45581484,
#  'description': 'Private Studio on the Upper East Side',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96309, 40.76291]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 297}
# {'_id': ObjectId('60c21bfeb653d40e79b5264f'),
#  'accom_id': 45689285,
#  'description': 'Quaint UES One Bedroom Apartment',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95746, 40.76906]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 333}
# {'_id': ObjectId('60c21bfeb653d40e79b526e0'),
#  'accom_id': 45775472,
#  'description': 'Unique 2BR2BA House With Large Rooms+Elevator',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.9079, 40.74624]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 283}
# {'_id': ObjectId('60c21bfeb653d40e79b52704'),
#  'accom_id': 45796447,
#  'description': 'Wonderful 4BR Near Roosevelt Jackson Heights Stat',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.90317, 40.74301]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 311}
# {'_id': ObjectId('60c21bfeb653d40e79b5271f'),
#  'accom_id': 45817617,
#  'description': 'Easy commute Near Jackson Hts Roosevelt Av Station',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.89083, 40.73971]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 39}
# {'_id': ObjectId('60c21bfeb653d40e79b5281d'),
#  'accom_id': 46012353,
#  'description': 'PERFECTLY LOCATED STUDIO NEXT TO ⭐️ CENTRAL PARK ⭐️',
#  'host': {'id': 266793360,
#           'name': 'Morris',
#           'listings_count': 1,
#           'neighbourhood_list': ['Harlem']},
#  'neighbourhood': {'name': 'Harlem', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95362, 40.80399]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 27,
#              'last_review': datetime.datetime(2021, 4, 6, 0, 0),
#              'reviews_per_month': 5.0},
#  'availability_365': 344}
# {'_id': ObjectId('60c21bffb653d40e79b52adb'),
#  'accom_id': 46542773,
#  'description': 'Sleek Studio Apartment in Lenox Hill, Upper East Side',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.96261, 40.7632]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bffb653d40e79b52d28'),
#  'accom_id': 47010749,
#  'description': 'Large Apartment - Brooklyn Charm',
#  'host': {'id': 66813379,
#           'name': nan,
#           'listings_count': 2,
#           'neighbourhood_list': ['Crown Heights']},
#  'neighbourhood': {'name': 'Crown Heights', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.94058, 40.66888]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 5,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2021, 3, 16, 0, 0),
#              'reviews_per_month': 1.46},
#  'availability_365': 346}
# {'_id': ObjectId('60c21bffb653d40e79b52d97'),
#  'accom_id': 47101598,
#  'description': 'Beautiful Brooklyn Studio Apartment Minutes From Manhattan',
#  'host': {'id': 22541573,
#           'name': 'Ken',
#           'listings_count': 92,
#           'neighbourhood_list': ['Upper East Side',
#                                  'Tribeca',
#                                  'Chelsea',
#                                  'West Village',
#                                  "Hell's Kitchen",
#                                  'Civic Center',
#                                  'Upper West Side',
#                                  'Theater District',
#                                  'Financial District',
#                                  'Kips Bay',
#                                  'Gramercy',
#                                  'Murray Hill',
#                                  'Midtown',
#                                  'Brooklyn Heights']},
#  'neighbourhood': {'name': 'Brooklyn Heights', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.99133, 40.69475]},
#  'room_type': 'Entire home/apt',
#  'price': 152,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 334}
# {'_id': ObjectId('60c21bffb653d40e79b5338e'),
#  'accom_id': 48316241,
#  'description': 'Sonder | Queen Room + Kitchenette in Flatiron District',
#  'host': {'id': 219517861,
#           'name': 'Sonder (NYC)',
#           'listings_count': 43,
#           'neighbourhood_list': ['Murray Hill',
#                                  'Financial District',
#                                  'Battery Park City',
#                                  'Midtown',
#                                  'Flatiron District']},
#  'neighbourhood': {'name': 'Flatiron District', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99012, 40.74295]},
#  'room_type': 'Private room',
#  'price': 152,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 322}
# {'_id': ObjectId('60c21bf6b653d40e79b4b44e'),
#  'accom_id': 3675957,
#  'description': 'Brooklyn Loft Studio, One Subway from Manhattan',
#  'host': {'id': 2076525,
#           'name': 'Douglas',
#           'listings_count': 1,
#           'neighbourhood_list': ['Navy Yard']},
#  'neighbourhood': {'name': 'Navy Yard', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.97604, 40.69828]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 7,
#  'reviews': {'number_of_reviews': 17,
#              'last_review': datetime.datetime(2020, 1, 1, 0, 0),
#              'reviews_per_month': 0.3},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf6b653d40e79b4b660'),
#  'accom_id': 4378951,
#  'description': 'Child-friendly 2BR w/ Yard access and Free Parking',
#  'host': {'id': 510577,
#           'name': 'Benjamin',
#           'listings_count': 1,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.93911, 40.68397]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 228,
#              'last_review': datetime.datetime(2020, 2, 16, 0, 0),
#              'reviews_per_month': 2.99},
#  'availability_365': 178}
# {'_id': ObjectId('60c21bf7b653d40e79b4c155'),
#  'accom_id': 7973730,
#  'description': 'Sunny Williamsburg apartment',
#  'host': {'id': 5828974,
#           'name': 'Farah',
#           'listings_count': 1,
#           'neighbourhood_list': ['Williamsburg']},
#  'neighbourhood': {'name': 'Williamsburg', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.95454, 40.71273]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 6,
#  'reviews': {'number_of_reviews': 2,
#              'last_review': datetime.datetime(2017, 7, 12, 0, 0),
#              'reviews_per_month': 0.03},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bf8b653d40e79b4cf8a'),
#  'accom_id': 13042637,
#  'description': 'Stunning 2BR Apartment in Sunnyside',
#  'host': {'id': 9427289,
#           'name': 'Steve',
#           'listings_count': 1,
#           'neighbourhood_list': ['Sunnyside']},
#  'neighbourhood': {'name': 'Sunnyside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.91679, 40.74717]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 201,
#              'last_review': datetime.datetime(2021, 4, 5, 0, 0),
#              'reviews_per_month': 3.53},
#  'availability_365': 270}
# {'_id': ObjectId('60c21bf8b653d40e79b4d367'),
#  'accom_id': 14148988,
#  'description': 'Heart of Manhattan, affordable place!',
#  'host': {'id': 4478946,
#           'name': 'Elka',
#           'listings_count': 1,
#           'neighbourhood_list': ['Midtown']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97216, 40.75165]},
#  'room_type': 'Entire home/apt',
#  'price': 153,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2016, 7, 31, 0, 0),
#              'reviews_per_month': 0.02},
#  'availability_365': 0}
# ...
#  'availability_365': 204}
# {'_id': ObjectId('60c21bfdb653d40e79b510a3'),
#  'accom_id': 39758327,
#  'description': 'Lux 2BR APT. Hudson Yards&Penn Station',
#  'host': {'id': 191009021,
#           'name': 'Matt',
#           'listings_count': 1,
#           'neighbourhood_list': ['Chelsea']},
#  'neighbourhood': {'name': 'Chelsea', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.9956, 40.75264]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 23,
#              'last_review': datetime.datetime(2021, 3, 27, 0, 0),
#              'reviews_per_month': 1.52},
#  'availability_365': 119}
# {'_id': ObjectId('60c21bfdb653d40e79b510d0'),
#  'accom_id': 39834665,
#  'description': 'Top floor studio in the heart of Upper East Side',
#  'host': {'id': 27606853,
#           'name': 'Ewa',
#           'listings_count': 1,
#           'neighbourhood_list': ['Upper East Side']},
#  'neighbourhood': {'name': 'Upper East Side', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.95668, 40.77853]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 5,
#              'last_review': datetime.datetime(2020, 8, 19, 0, 0),
#              'reviews_per_month': 0.31},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfdb653d40e79b511bb'),
#  'accom_id': 40086154,
#  'description': 'Clean space',
#  'host': {'id': 302138294,
#           'name': 'Al',
#           'listings_count': 2,
#           'neighbourhood_list': ['Shore Acres']},
#  'neighbourhood': {'name': 'Shore Acres', 'group': 'Staten Island'},
#  'location': {'type': 'Point', 'coordinates': [-74.06337, 40.61225]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2020, 1, 1, 0, 0),
#              'reviews_per_month': 0.06},
#  'availability_365': 365}
# {'_id': ObjectId('60c21bfdb653d40e79b512f9'),
#  'accom_id': 40430111,
#  'description': 'NEW LUXURY 2 BED APT IN PRIVATE HOME NEAR TRAINS',
#  'host': {'id': 312697286,
#           'name': 'Steven',
#           'listings_count': 2,
#           'neighbourhood_list': ['Gravesend']},
#  'neighbourhood': {'name': 'Gravesend', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.97595, 40.6007]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 7,
#  'reviews': {'number_of_reviews': 10,
#              'last_review': datetime.datetime(2020, 12, 28, 0, 0),
#              'reviews_per_month': 0.62},
#  'availability_365': 313}
# {'_id': ObjectId('60c21bfdb653d40e79b51575'),
#  'accom_id': 41036360,
#  'description': 'Newly renovated, comfy and trendy space. #1',
#  'host': {'id': 212147885,
#           'name': 'Alisa',
#           'listings_count': 4,
#           'neighbourhood_list': ['Tompkinsville',
#                                  'Bedford-Stuyvesant',
#                                  'Crown Heights']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.90923, 40.67737]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 4,
#  'reviews': {'number_of_reviews': 9,
#              'last_review': datetime.datetime(2020, 11, 22, 0, 0),
#              'reviews_per_month': 0.69},
#  'availability_365': 96}
# {'_id': ObjectId('60c21bfdb653d40e79b51580'),
#  'accom_id': 41048681,
#  'description': 'Roomy and aesthetically pleasing  place #2',
#  'host': {'id': 212147885,
#           'name': 'Alisa',
#           'listings_count': 4,
#           'neighbourhood_list': ['Tompkinsville',
#                                  'Bedford-Stuyvesant',
#                                  'Crown Heights']},
#  'neighbourhood': {'name': 'Crown Heights', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.91053, 40.67555]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 5,
#  'reviews': {'number_of_reviews': 10,
#              'last_review': datetime.datetime(2020, 11, 16, 0, 0),
#              'reviews_per_month': 0.65},
#  'availability_365': 211}
# {'_id': ObjectId('60c21bfdb653d40e79b5168e'),
#  'accom_id': 41479095,
#  'description': 'Family Friendly, Enormous and Bright SpaHa Loft',
#  'host': {'id': 153555756,
#           'name': 'Ana',
#           'listings_count': 2,
#           'neighbourhood_list': ['East Harlem']},
#  'neighbourhood': {'name': 'East Harlem', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.94186, 40.79054]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 4,
#              'last_review': datetime.datetime(2020, 2, 23, 0, 0),
#              'reviews_per_month': 0.27},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfdb653d40e79b51971'),
#  'accom_id': 42429336,
#  'description': '★ SECOND AVE & 22ND STREET ★ (3F)',
#  'host': {'id': 337720916,
#           'name': 'Liz',
#           'listings_count': 3,
#           'neighbourhood_list': ['Gramercy', 'Kips Bay']},
#  'neighbourhood': {'name': 'Gramercy', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98074, 40.73671]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 7,
#  'reviews': {'number_of_reviews': 3,
#              'last_review': datetime.datetime(2020, 3, 28, 0, 0),
#              'reviews_per_month': 0.22},
#  'availability_365': 288}
# {'_id': ObjectId('60c21bfdb653d40e79b51b81'),
#  'accom_id': 42941437,
#  'description': "Gabriel's Luxury Suite",
#  'host': {'id': 23183510,
#           'name': 'Karen',
#           'listings_count': 2,
#           'neighbourhood_list': ['Bedford-Stuyvesant']},
#  'neighbourhood': {'name': 'Bedford-Stuyvesant', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.93708, 40.68676]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 365}
# {'_id': ObjectId('60c21bfeb653d40e79b51ba5'),
#  'accom_id': 42972333,
#  'description': 'Clean & Private Studio | Work Remote w/ Desk | GLS',
#  'host': {'id': 30283594,
#           'name': 'Global Luxury Suites',
#           'listings_count': 68,
#           'neighbourhood_list': ['Midtown',
#                                  'Upper East Side',
#                                  'Theater District',
#                                  "Hell's Kitchen",
#                                  'Tribeca',
#                                  'Murray Hill',
#                                  'Chinatown',
#                                  'Williamsburg',
#                                  'Financial District',
#                                  'Mott Haven',
#                                  'Port Morris']},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99803, 40.76086]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 357}
# {'_id': ObjectId('60c21bfeb653d40e79b51ba6'),
#  'accom_id': 42972677,
#  'description': 'Bright Studio | Work Desk & WiFi | Midtown West',
#  'host': {'id': 30283594,
#           'name': 'Global Luxury Suites',
#           'listings_count': 68,
#           'neighbourhood_list': ['Midtown',
#                                  'Upper East Side',
#                                  'Theater District',
#                                  "Hell's Kitchen",
#                                  'Tribeca',
#                                  'Murray Hill',
#                                  'Chinatown',
#                                  'Williamsburg',
#                                  'Financial District',
#                                  'Mott Haven',
#                                  'Port Morris']},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99826, 40.76253]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 360}
# {'_id': ObjectId('60c21bfeb653d40e79b51d57'),
#  'accom_id': 43309210,
#  'description': 'Charming 2 Bedroom Flat in prime East Village',
#  'host': {'id': 188726696,
#           'name': 'Matteo',
#           'listings_count': 1,
#           'neighbourhood_list': ['East Village']},
#  'neighbourhood': {'name': 'East Village', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.9833, 40.72528]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 220}
# {'_id': ObjectId('60c21bfeb653d40e79b520b0'),
#  'accom_id': 44146260,
#  'description': 'Cozy & Stylish 1BR in Manhattan (Hell´s Kitchen)',
#  'host': {'id': 130155462,
#           'name': 'Fred',
#           'listings_count': 1,
#           'neighbourhood_list': ["Hell's Kitchen"]},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98954, 40.76385]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 3,
#  'reviews': {'number_of_reviews': 24,
#              'last_review': datetime.datetime(2021, 3, 20, 0, 0),
#              'reviews_per_month': 2.64},
#  'availability_365': 283}
# {'_id': ObjectId('60c21bfeb653d40e79b5216c'),
#  'accom_id': 44339323,
#  'description': 'Sunny Quiet Oasis in Brooklyn',
#  'host': {'id': 35891761,
#           'name': 'Aditi',
#           'listings_count': 1,
#           'neighbourhood_list': ['Greenpoint']},
#  'neighbourhood': {'name': 'Greenpoint', 'group': 'Brooklyn'},
#  'location': {'type': 'Point', 'coordinates': [-73.94051, 40.72671]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 14,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bfeb653d40e79b52271'),
#  'accom_id': 44642468,
#  'description': 'Quaint Island Community 20mi. from New York City!',
#  'host': {'id': 16794996,
#           'name': 'Amanda',
#           'listings_count': 1,
#           'neighbourhood_list': ['City Island']},
#  'neighbourhood': {'name': 'City Island', 'group': 'Bronx'},
#  'location': {'type': 'Point', 'coordinates': [-73.78796, 40.84892]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 5,
#              'last_review': datetime.datetime(2021, 4, 8, 0, 0),
#              'reviews_per_month': 3.66},
#  'availability_365': 327}
# {'_id': ObjectId('60c21bfeb653d40e79b526c1'),
#  'accom_id': 45759295,
#  'description': 'Well-lit 1st Fl 4BR-House -> 52 St station (7train)',
#  'host': {'id': 137358866,
#           'name': 'Kaz',
#           'listings_count': 166,
#           'neighbourhood_list': ['Harlem',
#                                  'East Harlem',
#                                  'Sunnyside',
#                                  'Jackson Heights',
#                                  'Woodside',
#                                  'Maspeth',
#                                  'Astoria',
#                                  'Elmhurst',
#                                  'Bushwick',
#                                  'Long Island City',
#                                  'East Elmhurst']},
#  'neighbourhood': {'name': 'Woodside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.90921, 40.74555]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 312}
# {'_id': ObjectId('60c21bfeb653d40e79b526ec'),
#  'accom_id': 45784235,
#  'description': 'Prime Location! Central Park. 2 Bedrooms Apt.',
#  'host': {'id': 86771798,
#           'name': 'Daia',
#           'listings_count': 18,
#           'neighbourhood_list': ['Tribeca',
#                                  'Midtown',
#                                  'Murray Hill',
#                                  'Kips Bay']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97906, 40.76654]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 60,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2021, 1, 4, 0, 0),
#              'reviews_per_month': 0.31},
#  'availability_365': 95}
# {'_id': ObjectId('60c21bfeb653d40e79b529c5'),
#  'accom_id': 46356156,
#  'description': 'The Beekman, A Thompson Hotel - Superior Queen',
#  'host': {'id': 373480843,
#           'name': 'The Beekman',
#           'listings_count': 3,
#           'neighbourhood_list': ['Financial District', 'Civic Center']},
#  'neighbourhood': {'name': 'Financial District', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-74.00691, 40.71121]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 363}
# {'_id': ObjectId('60c21bffb653d40e79b52a9e'),
#  'accom_id': 46503564,
#  'description': 'Location! Location PRIME! Central Park - 2B/1B',
#  'host': {'id': 86771798,
#           'name': 'Daia',
#           'listings_count': 18,
#           'neighbourhood_list': ['Tribeca',
#                                  'Midtown',
#                                  'Murray Hill',
#                                  'Kips Bay']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.97924, 40.76484]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 60,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 68}
# {'_id': ObjectId('60c21bffb653d40e79b52d1e'),
#  'accom_id': 47004464,
#  'description': 'NYC Apartment Just 25 minutes to Penn Station!',
#  'host': {'id': 379993600,
#           'name': 'Rob',
#           'listings_count': 2,
#           'neighbourhood_list': ['Bayside']},
#  'neighbourhood': {'name': 'Bayside', 'group': 'Queens'},
#  'location': {'type': 'Point', 'coordinates': [-73.77561, 40.76216]},
#  'room_type': 'Entire home/apt',
#  'price': 169,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 0}
# {'_id': ObjectId('60c21bffb653d40e79b5338d'),
#  'accom_id': 48316162,
#  'description': 'Sonder | ADA-Accessible Room in Flatiron District',
#  'host': {'id': 219517861,
#           'name': 'Sonder (NYC)',
#           'listings_count': 43,
#           'neighbourhood_list': ['Murray Hill',
#                                  'Financial District',
#                                  'Battery Park City',
#                                  'Midtown',
#                                  'Flatiron District']},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99042, 40.74463]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 2,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 322}
# {'_id': ObjectId('60c21bffb653d40e79b533b8'),
#  'accom_id': 48344963,
#  'description': 'TRYP by Wyndham - Luxury that sleeps 8',
#  'host': {'id': 38592279,
#           'name': 'Vk',
#           'listings_count': 19,
#           'neighbourhood_list': ['Midtown', 'Chelsea', "Hell's Kitchen"]},
#  'neighbourhood': {'name': "Hell's Kitchen", 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.99409, 40.75486]},
#  'room_type': 'Private room',
#  'price': 169,
#  'minimum_nights': 1,
#  'reviews': {'number_of_reviews': 1,
#              'last_review': datetime.datetime(2021, 4, 3, 0, 0),
#              'reviews_per_month': 1.0},
#  'availability_365': 2}

# %% [markdown]
# ---
# In Pymongo, we need to use the [command](https://pymongo.readthedocs.io/en/stable/api/pymongo/database.html#pymongo.database.Database.command) to run the explain plan for the aggregation pipeline.
#
# ---

# %%
# Explain

pp.pprint(
    db.command('aggregate','airbnb',pipeline=pipeline_1, explain=True)
)
# Out:
# {'queryPlanner': {'plannerVersion': 1,
#                   'namespace': 'nyc.airbnb',
#                   'indexFilterSet': False,
#                   'parsedQuery': {'$and': [{'price': {'$lt': 170}},
#                                            {'price': {'$gt': 150}}]},
#                   'queryHash': '4291FEFF',
#                   'planCacheKey': 'B99FC200',
#                   'optimizedPipeline': True,
#                   'winningPlan': {'stage': 'FETCH',
#                                   'inputStage': {'stage': 'IXSCAN',
#                                                  'keyPattern': {'price': 1},
#                                                  'indexName': 'price_index',
#                                                  'isMultiKey': False,
#                                                  'multiKeyPaths': {'price': []},
#                                                  'isUnique': False,
#                                                  'isSparse': False,
#                                                  'isPartial': False,
#                                                  'indexVersion': 2,
#                                                  'direction': 'forward',
#                                                  'indexBounds': {'price': ['(150, '
#                                                                            '170)']}}},
#                   'rejectedPlans': []},
#  'serverInfo': {'host': 'whoami',
#                 'port': 27017,
#                 'version': '4.4.6',
#                 'gitVersion': '72e66213c2c3eab37d9358d5e78ad7f5c1d0d0d7'},
#  'ok': 1.0}

# %% [markdown]
# ---
# The `$match` stage can use an index to filter documents if it occurs at the beginning of a pipeline.
#
# ----

# %% [markdown]
# ---
# ### Exercise 1 -
#
# Using single field index find the documents that have the `room_type` as `Shared room`. Also check out the size of the index you just created.

# %% [markdown]
# ---
# ### Exercise 2 -
#
#
# Use aggregation pipeline to find the documents that have the `room_type` as `Shared room` and `price < 100`. Check the query execution using explain() method.
#
# ---
