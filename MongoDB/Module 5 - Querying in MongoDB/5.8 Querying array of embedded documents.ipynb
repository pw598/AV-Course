# %% [markdown]
# # Query array of embedded documents
#
# ----
# ### Connecting to MongoDB
#
# ----

# %%
# Importing the required libraries
import pymongo
import pprint as pp


pp.sorted = lambda x, key=None: x

# %%
# Connect to the mongo client - Atlas Cluster
# client = pymongo.MongoClient('<connection_string>')

## Connect to local MongoDB server
# client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
# Choose a database
db = client.sample_analytics

# %%
# Sample document
pp.pprint(db.transactions.find_one())
# Out:
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb1'),
#  'account_id': 443178,
#  'transaction_count': 66,
#  'bucket_start_date': datetime.datetime(1969, 2, 4, 0, 0),
#  'bucket_end_date': datetime.datetime(2017, 1, 3, 0, 0),
#  'transactions': [{'date': datetime.datetime(2003, 9, 9, 0, 0),
#                    'amount': 7514,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '19.1072802650074180519368383102118968963623046875',
#                    'total': '143572.1039112657392422534031'},
#                   {'date': datetime.datetime(2016, 6, 14, 0, 0),
#                    'amount': 9240,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '24.1525632387771480580340721644461154937744140625',
#                    'total': '223169.6843263008480562348268'},
#                   {'date': datetime.datetime(2002, 12, 4, 0, 0),
#                    'amount': 2824,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.046193953245431629284212249331176280975341796875',
#                    'total': '59434.45172396509892109861539'},
#                   {'date': datetime.datetime(2014, 7, 14, 0, 0),
#                    'amount': 7418,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '76.38514540536692720706923864781856536865234375',
#                    'total': '566625.0086170118660220396123'},
#                   {'date': datetime.datetime(2011, 10, 28, 0, 0),
#                    'amount': 5638,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '28.365657608641175357888641883619129657745361328125',
#                    'total': '159925.5775975189466677761629'},
#                   {'date': datetime.datetime(2010, 12, 20, 0, 0),
#                    'amount': 6774,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '45.3237971108758159743956639431416988372802734375',
#                    'total': '307023.4016290727774105562276'},
#                   {'date': datetime.datetime(2015, 10, 28, 0, 0),
#                    'amount': 7251,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '102.936674838205050264150486327707767486572265625',
#                    'total': '746393.8292518248194653551764'},
#                   {'date': datetime.datetime(2012, 2, 2, 0, 0),
#                    'amount': 8828,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '17.838862313630283296106426860205829143524169921875',
#                    'total': '157481.4765047281409380275363'},
#                   {'date': datetime.datetime(2016, 3, 14, 0, 0),
#                    'amount': 5585,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '22.645934804740733170547173358500003814697265625',
#                    'total': '126477.5458844769947575059632'},
#                   {'date': datetime.datetime(2012, 3, 1, 0, 0),
#                    'amount': 5789,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '16.0804676963220600782733527012169361114501953125',
#                    'total': '93089.82749400840579312443879'},
#                   {'date': datetime.datetime(2001, 1, 4, 0, 0),
#                    'amount': 7856,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '26.71098408678698632456871564500033855438232421875',
#                    'total': '209841.4909857985645658118301'},
#                   {'date': datetime.datetime(2015, 12, 14, 0, 0),
#                    'amount': 8539,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '120.2002067302756387334738974459469318389892578125',
#                    'total': '1026389.565269823679145133610'},
#                   {'date': datetime.datetime(2016, 10, 5, 0, 0),
#                    'amount': 4967,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '90.35066753097771652392111718654632568359375',
#                    'total': '448771.7656263663179743161891'},
#                   {'date': datetime.datetime(2016, 9, 26, 0, 0),
#                    'amount': 2893,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '30.227075585186970130280315061099827289581298828125',
#                    'total': '87446.92966794590458690095147'},
#                   {'date': datetime.datetime(1992, 7, 17, 0, 0),
#                    'amount': 9559,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '19.83986843992497739463942707516252994537353515625',
#                    'total': '189649.3024172428589153582834'},
#                   {'date': datetime.datetime(1978, 2, 16, 0, 0),
#                    'amount': 8269,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '13.2722697458426655003904670593328773975372314453125',
#                    'total': '109748.3985283730010227287721'},
#                   {'date': datetime.datetime(2016, 6, 1, 0, 0),
#                    'amount': 8081,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '143.758609271150135100469924509525299072265625',
#                    'total': '1161713.321520164241746897460'},
#                   {'date': datetime.datetime(1986, 10, 23, 0, 0),
#                    'amount': 6145,
#                    'transaction_code': 'sell',
#                    'symbol': 'adbe',
#                    'price': '0.2800000011920928955078125',
#                    'total': '1720.600007325410842895507812'},
#                   {'date': datetime.datetime(2010, 10, 22, 0, 0),
#                    'amount': 6973,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.268423447276756377277706633321940898895263671875',
#                    'total': '148304.7166978608222187574484'},
#                   {'date': datetime.datetime(2016, 7, 28, 0, 0),
#                    'amount': 3082,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '86.029571359374330086211557500064373016357421875',
#                    'total': '265143.1389295916853257040202'},
#                   {'date': datetime.datetime(1988, 11, 18, 0, 0),
#                    'amount': 2978,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '0.2432200014591217041015625',
#                    'total': '724.3091643452644348144531250'},
#                   {'date': datetime.datetime(2002, 2, 20, 0, 0),
#                    'amount': 9265,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '81.091017566265037430639495141804218292236328125',
#                    'total': '751308.2777514455717948749225'},
#                   {'date': datetime.datetime(2014, 8, 18, 0, 0),
#                    'amount': 9192,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '74.557668636076840584792080335319042205810546875',
#                    'total': '685334.0901028183186554088024'},
#                   {'date': datetime.datetime(1971, 11, 17, 0, 0),
#                    'amount': 7408,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '12.4267172965691319319603280746378004550933837890625',
#                    'total': '92057.12173298412935196211038'},
#                   {'date': datetime.datetime(2011, 12, 23, 0, 0),
#                    'amount': 3267,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '10.54898647579047832323340117000043392181396484375',
#                    'total': '34463.53881640749268200352162'},
#                   {'date': datetime.datetime(2012, 5, 24, 0, 0),
#                    'amount': 7582,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '10.1614266582902761371087763109244406223297119140625',
#                    'total': '77043.93692315687367155874199'},
#                   {'date': datetime.datetime(2012, 8, 20, 0, 0),
#                    'amount': 643,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '9.1583720360888047906655629049055278301239013671875',
#                    'total': '5888.833219205101480397956948'},
#                   {'date': datetime.datetime(2013, 3, 27, 0, 0),
#                    'amount': 3129,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '74.33570821035419839972746558487415313720703125',
#                    'total': '232596.4309901982867927472398'},
#                   {'date': datetime.datetime(2015, 10, 22, 0, 0),
#                    'amount': 4075,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '45.37162592751771938992533250711858272552490234375',
#                    'total': '184889.3756546347065139457300'},
#                   {'date': datetime.datetime(2016, 7, 21, 0, 0),
#                    'amount': 4386,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '27.936906667695467376688611693680286407470703125',
#                    'total': '122531.2726445123199141562509'},
#                   {'date': datetime.datetime(1993, 12, 2, 0, 0),
#                    'amount': 3093,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '2.978981080777631351708123474963940680027008056640625',
#                    'total': '9213.988482845213770833225908'},
#                   {'date': datetime.datetime(2011, 6, 1, 0, 0),
#                    'amount': 5053,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '34.76661582629167668301306548528373241424560546875',
#                    'total': '175675.7097702518422792650199'},
#                   {'date': datetime.datetime(2010, 12, 1, 0, 0),
#                    'amount': 1428,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '28.3197718777616813667918904684484004974365234375',
#                    'total': '40440.63424144368099177881959'},
#                   {'date': datetime.datetime(2002, 2, 5, 0, 0),
#                    'amount': 7974,
#                    'transaction_code': 'sell',
#                    'symbol': 'msft',
#                    'price': '23.08480386999243449963614693842828273773193359375',
#                    'total': '184078.2260593196727000986357'},
#                   {'date': datetime.datetime(2016, 10, 13, 0, 0),
#                    'amount': 5363,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '27.9515663517458960996009409427642822265625',
#                    'total': '149904.2503444132407821598463'},
#                   {'date': datetime.datetime(2009, 4, 15, 0, 0),
#                    'amount': 4050,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '35.82050501072183834594397922046482563018798828125',
#                    'total': '145073.0452934234453010731158'},
#                   {'date': datetime.datetime(2013, 6, 28, 0, 0),
#                    'amount': 7447,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '165.427301038519743769938941113650798797607421875',
#                    'total': '1231937.110833856531854735294'},
#                   {'date': datetime.datetime(1983, 5, 16, 0, 0),
#                    'amount': 1586,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '23.801111434215950879433876252733170986175537109375',
#                    'total': '37748.56273466649809478212774'},
#                   {'date': datetime.datetime(2005, 3, 16, 0, 0),
#                    'amount': 7124,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '36.91652269537627262252499349415302276611328125',
#                    'total': '262993.3076818605661628680537'},
#                   {'date': datetime.datetime(1993, 3, 19, 0, 0),
#                    'amount': 2940,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '11.3086767608907070581381049123592674732208251953125',
#                    'total': '33247.50967701867875092602844'},
#                   {'date': datetime.datetime(1993, 6, 18, 0, 0),
#                    'amount': 2273,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '4.16809173919640141292575208353810012340545654296875',
#                    'total': '9474.072523193420411580234486'},
#                   {'date': datetime.datetime(1994, 6, 28, 0, 0),
#                    'amount': 2342,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '12.5191271611065957358732703141868114471435546875',
#                    'total': '29319.79581131164721341519908'},
#                   {'date': datetime.datetime(2010, 9, 3, 0, 0),
#                    'amount': 6380,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '41.865973826467524077088455669581890106201171875',
#                    'total': '267104.9130128628036118243472'},
#                   {'date': datetime.datetime(1997, 9, 11, 0, 0),
#                    'amount': 9598,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '5.39232880197155584056645238888449966907501220703125',
#                    'total': '51755.57184132299295775681003'},
#                   {'date': datetime.datetime(2016, 3, 9, 0, 0),
#                    'amount': 4123,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '75.127503708197110654509742744266986846923828125',
#                    'total': '309750.6977888966872285436693'},
#                   {'date': datetime.datetime(2008, 4, 17, 0, 0),
#                    'amount': 2473,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '46.75625859046404997343415743671357631683349609375',
#                    'total': '115628.2274942175955843026713'},
#                   {'date': datetime.datetime(1979, 1, 11, 0, 0),
#                    'amount': 8901,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '16.159743422775360244258990860544145107269287109375',
#                    'total': '143837.8762061234815341492776'},
#                   {'date': datetime.datetime(2013, 1, 7, 0, 0),
#                    'amount': 2588,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '14.43803234005940083761743153445422649383544921875',
#                    'total': '37365.62769607372936775391281'},
#                   {'date': datetime.datetime(2003, 2, 19, 0, 0),
#                    'amount': 578,
#                    'transaction_code': 'sell',
#                    'symbol': 'adbe',
#                    'price': '14.1196581565672598657101843855343759059906005859375',
#                    'total': '8161.162414495876202380486575'},
#                   {'date': datetime.datetime(1982, 7, 22, 0, 0),
#                    'amount': 964,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '13.85120720985607789543792023323476314544677734375',
#                    'total': '13352.56375030125909120215510'},
#                   {'date': datetime.datetime(2016, 12, 8, 0, 0),
#                    'amount': 3970,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '26.247716617401248839769323240034282207489013671875',
#                    'total': '104203.4349710829578938842133'},
#                   {'date': datetime.datetime(2015, 9, 3, 0, 0),
#                    'amount': 6607,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '79.33405532799093862195149995386600494384765625',
#                    'total': '524160.1035520361314752335602'},
#                   {'date': datetime.datetime(2015, 12, 22, 0, 0),
#                    'amount': 4221,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '30.4044667242776398552450700663030147552490234375',
#                    'total': '128337.2540431759178289894407'},
#                   {'date': datetime.datetime(2008, 8, 19, 0, 0),
#                    'amount': 4799,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '43.96347030926532539751860895194113254547119140625',
#                    'total': '210980.6940141642965826918044'},
#                   {'date': datetime.datetime(1991, 5, 30, 0, 0),
#                    'amount': 4657,
#                    'transaction_code': 'sell',
#                    'symbol': 'msft',
#                    'price': '1.1517732225800922929437319908174686133861541748046875',
#                    'total': '5363.807897555489808238959881'},
#                   {'date': datetime.datetime(2014, 10, 6, 0, 0),
#                    'amount': 6397,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '66.439073760834702397914952598512172698974609375',
#                    'total': '425010.7548480595912394619518'},
#                   {'date': datetime.datetime(2007, 7, 11, 0, 0),
#                    'amount': 6352,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '90.5944805618852484485614695586264133453369140625',
#                    'total': '575456.1405290950981452624546'},
#                   {'date': datetime.datetime(2008, 2, 20, 0, 0),
#                    'amount': 2800,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '3.790661287329261330825147524592466652393341064453125',
#                    'total': '10613.85160452193172631041307'},
#                   {'date': datetime.datetime(2016, 1, 4, 0, 0),
#                    'amount': 1376,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '28.893855339485757127704346203245222568511962890625',
#                    'total': '39757.94494713240180772118038'},
#                   {'date': datetime.datetime(1989, 3, 16, 0, 0),
#                    'amount': 3044,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '1.2795149853767535663706667037331499159336090087890625',
#                    'total': '3894.843615486837856032309446'},
#                   {'date': datetime.datetime(1998, 6, 30, 0, 0),
#                    'amount': 7246,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '19.697308460376579120065798633731901645660400390625',
#                    'total': '142726.6971038886923039967769'},
#                   {'date': datetime.datetime(2014, 7, 7, 0, 0),
#                    'amount': 5935,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '38.65917577251284598105485201813280582427978515625',
#                    'total': '229442.2082098637408975605467'},
#                   {'date': datetime.datetime(2009, 9, 25, 0, 0),
#                    'amount': 4155,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '32.28257057551964948061140603385865688323974609375',
#                    'total': '134134.0807412841435919403921'},
#                   {'date': datetime.datetime(2016, 6, 27, 0, 0),
#                    'amount': 5199,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '25.54567484371674623844228335656225681304931640625',
#                    'total': '132811.9635124833636936614312'},
#                   {'date': datetime.datetime(2010, 4, 1, 0, 0),
#                    'amount': 9229,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '10.6848136359437528852822651970200240612030029296875',
#                    'total': '98610.14504612489537827002550'},
#                   {'date': datetime.datetime(2005, 7, 7, 0, 0),
#                    'amount': 2881,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '20.6769287918292690164889791049063205718994140625',
#                    'total': '59570.23184926012403650474880'}]}

# %% [markdown]
# ---
#
# For example, retrieve documents where `transactions.amount` > 9000.
#
# It will return only those documents that contains atleast one transaction where amount is greater than 9000.
#
# ---

# %%
# Query embedded documents
pp.pprint(
    db.transactions.find_one(
                                 # query 
                                 {'transactions.amount':{'$gt':9000}}
                            )
)
# Out:
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb1'),
#  'account_id': 443178,
#  'transaction_count': 66,
#  'bucket_start_date': datetime.datetime(1969, 2, 4, 0, 0),
#  'bucket_end_date': datetime.datetime(2017, 1, 3, 0, 0),
#  'transactions': [{'date': datetime.datetime(2003, 9, 9, 0, 0),
#                    'amount': 7514,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '19.1072802650074180519368383102118968963623046875',
#                    'total': '143572.1039112657392422534031'},
#                   {'date': datetime.datetime(2016, 6, 14, 0, 0),
#                    'amount': 9240,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '24.1525632387771480580340721644461154937744140625',
#                    'total': '223169.6843263008480562348268'},
#                   {'date': datetime.datetime(2002, 12, 4, 0, 0),
#                    'amount': 2824,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.046193953245431629284212249331176280975341796875',
#                    'total': '59434.45172396509892109861539'},
#                   {'date': datetime.datetime(2014, 7, 14, 0, 0),
#                    'amount': 7418,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '76.38514540536692720706923864781856536865234375',
#                    'total': '566625.0086170118660220396123'},
#                   {'date': datetime.datetime(2011, 10, 28, 0, 0),
#                    'amount': 5638,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '28.365657608641175357888641883619129657745361328125',
#                    'total': '159925.5775975189466677761629'},
#                   {'date': datetime.datetime(2010, 12, 20, 0, 0),
#                    'amount': 6774,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '45.3237971108758159743956639431416988372802734375',
#                    'total': '307023.4016290727774105562276'},
#                   {'date': datetime.datetime(2015, 10, 28, 0, 0),
#                    'amount': 7251,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '102.936674838205050264150486327707767486572265625',
#                    'total': '746393.8292518248194653551764'},
#                   {'date': datetime.datetime(2012, 2, 2, 0, 0),
#                    'amount': 8828,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '17.838862313630283296106426860205829143524169921875',
#                    'total': '157481.4765047281409380275363'},
#                   {'date': datetime.datetime(2016, 3, 14, 0, 0),
#                    'amount': 5585,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '22.645934804740733170547173358500003814697265625',
#                    'total': '126477.5458844769947575059632'},
#                   {'date': datetime.datetime(2012, 3, 1, 0, 0),
#                    'amount': 5789,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '16.0804676963220600782733527012169361114501953125',
#                    'total': '93089.82749400840579312443879'},
#                   {'date': datetime.datetime(2001, 1, 4, 0, 0),
#                    'amount': 7856,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '26.71098408678698632456871564500033855438232421875',
#                    'total': '209841.4909857985645658118301'},
#                   {'date': datetime.datetime(2015, 12, 14, 0, 0),
#                    'amount': 8539,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '120.2002067302756387334738974459469318389892578125',
#                    'total': '1026389.565269823679145133610'},
#                   {'date': datetime.datetime(2016, 10, 5, 0, 0),
#                    'amount': 4967,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '90.35066753097771652392111718654632568359375',
#                    'total': '448771.7656263663179743161891'},
#                   {'date': datetime.datetime(2016, 9, 26, 0, 0),
#                    'amount': 2893,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '30.227075585186970130280315061099827289581298828125',
#                    'total': '87446.92966794590458690095147'},
#                   {'date': datetime.datetime(1992, 7, 17, 0, 0),
#                    'amount': 9559,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '19.83986843992497739463942707516252994537353515625',
#                    'total': '189649.3024172428589153582834'},
#                   {'date': datetime.datetime(1978, 2, 16, 0, 0),
#                    'amount': 8269,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '13.2722697458426655003904670593328773975372314453125',
#                    'total': '109748.3985283730010227287721'},
#                   {'date': datetime.datetime(2016, 6, 1, 0, 0),
#                    'amount': 8081,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '143.758609271150135100469924509525299072265625',
#                    'total': '1161713.321520164241746897460'},
#                   {'date': datetime.datetime(1986, 10, 23, 0, 0),
#                    'amount': 6145,
#                    'transaction_code': 'sell',
#                    'symbol': 'adbe',
#                    'price': '0.2800000011920928955078125',
#                    'total': '1720.600007325410842895507812'},
#                   {'date': datetime.datetime(2010, 10, 22, 0, 0),
#                    'amount': 6973,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.268423447276756377277706633321940898895263671875',
#                    'total': '148304.7166978608222187574484'},
#                   {'date': datetime.datetime(2016, 7, 28, 0, 0),
#                    'amount': 3082,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '86.029571359374330086211557500064373016357421875',
#                    'total': '265143.1389295916853257040202'},
#                   {'date': datetime.datetime(1988, 11, 18, 0, 0),
#                    'amount': 2978,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '0.2432200014591217041015625',
#                    'total': '724.3091643452644348144531250'},
#                   {'date': datetime.datetime(2002, 2, 20, 0, 0),
#                    'amount': 9265,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '81.091017566265037430639495141804218292236328125',
#                    'total': '751308.2777514455717948749225'},
#                   {'date': datetime.datetime(2014, 8, 18, 0, 0),
#                    'amount': 9192,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '74.557668636076840584792080335319042205810546875',
#                    'total': '685334.0901028183186554088024'},
#                   {'date': datetime.datetime(1971, 11, 17, 0, 0),
#                    'amount': 7408,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '12.4267172965691319319603280746378004550933837890625',
#                    'total': '92057.12173298412935196211038'},
#                   {'date': datetime.datetime(2011, 12, 23, 0, 0),
#                    'amount': 3267,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '10.54898647579047832323340117000043392181396484375',
#                    'total': '34463.53881640749268200352162'},
#                   {'date': datetime.datetime(2012, 5, 24, 0, 0),
#                    'amount': 7582,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '10.1614266582902761371087763109244406223297119140625',
#                    'total': '77043.93692315687367155874199'},
#                   {'date': datetime.datetime(2012, 8, 20, 0, 0),
#                    'amount': 643,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '9.1583720360888047906655629049055278301239013671875',
#                    'total': '5888.833219205101480397956948'},
#                   {'date': datetime.datetime(2013, 3, 27, 0, 0),
#                    'amount': 3129,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '74.33570821035419839972746558487415313720703125',
#                    'total': '232596.4309901982867927472398'},
#                   {'date': datetime.datetime(2015, 10, 22, 0, 0),
#                    'amount': 4075,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '45.37162592751771938992533250711858272552490234375',
#                    'total': '184889.3756546347065139457300'},
#                   {'date': datetime.datetime(2016, 7, 21, 0, 0),
#                    'amount': 4386,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '27.936906667695467376688611693680286407470703125',
#                    'total': '122531.2726445123199141562509'},
#                   {'date': datetime.datetime(1993, 12, 2, 0, 0),
#                    'amount': 3093,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '2.978981080777631351708123474963940680027008056640625',
#                    'total': '9213.988482845213770833225908'},
#                   {'date': datetime.datetime(2011, 6, 1, 0, 0),
#                    'amount': 5053,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '34.76661582629167668301306548528373241424560546875',
#                    'total': '175675.7097702518422792650199'},
#                   {'date': datetime.datetime(2010, 12, 1, 0, 0),
#                    'amount': 1428,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '28.3197718777616813667918904684484004974365234375',
#                    'total': '40440.63424144368099177881959'},
#                   {'date': datetime.datetime(2002, 2, 5, 0, 0),
#                    'amount': 7974,
#                    'transaction_code': 'sell',
#                    'symbol': 'msft',
#                    'price': '23.08480386999243449963614693842828273773193359375',
#                    'total': '184078.2260593196727000986357'},
#                   {'date': datetime.datetime(2016, 10, 13, 0, 0),
#                    'amount': 5363,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '27.9515663517458960996009409427642822265625',
#                    'total': '149904.2503444132407821598463'},
#                   {'date': datetime.datetime(2009, 4, 15, 0, 0),
#                    'amount': 4050,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '35.82050501072183834594397922046482563018798828125',
#                    'total': '145073.0452934234453010731158'},
#                   {'date': datetime.datetime(2013, 6, 28, 0, 0),
#                    'amount': 7447,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '165.427301038519743769938941113650798797607421875',
#                    'total': '1231937.110833856531854735294'},
#                   {'date': datetime.datetime(1983, 5, 16, 0, 0),
#                    'amount': 1586,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '23.801111434215950879433876252733170986175537109375',
#                    'total': '37748.56273466649809478212774'},
#                   {'date': datetime.datetime(2005, 3, 16, 0, 0),
#                    'amount': 7124,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '36.91652269537627262252499349415302276611328125',
#                    'total': '262993.3076818605661628680537'},
#                   {'date': datetime.datetime(1993, 3, 19, 0, 0),
#                    'amount': 2940,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '11.3086767608907070581381049123592674732208251953125',
#                    'total': '33247.50967701867875092602844'},
#                   {'date': datetime.datetime(1993, 6, 18, 0, 0),
#                    'amount': 2273,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '4.16809173919640141292575208353810012340545654296875',
#                    'total': '9474.072523193420411580234486'},
#                   {'date': datetime.datetime(1994, 6, 28, 0, 0),
#                    'amount': 2342,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '12.5191271611065957358732703141868114471435546875',
#                    'total': '29319.79581131164721341519908'},
#                   {'date': datetime.datetime(2010, 9, 3, 0, 0),
#                    'amount': 6380,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '41.865973826467524077088455669581890106201171875',
#                    'total': '267104.9130128628036118243472'},
#                   {'date': datetime.datetime(1997, 9, 11, 0, 0),
#                    'amount': 9598,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '5.39232880197155584056645238888449966907501220703125',
#                    'total': '51755.57184132299295775681003'},
#                   {'date': datetime.datetime(2016, 3, 9, 0, 0),
#                    'amount': 4123,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '75.127503708197110654509742744266986846923828125',
#                    'total': '309750.6977888966872285436693'},
#                   {'date': datetime.datetime(2008, 4, 17, 0, 0),
#                    'amount': 2473,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '46.75625859046404997343415743671357631683349609375',
#                    'total': '115628.2274942175955843026713'},
#                   {'date': datetime.datetime(1979, 1, 11, 0, 0),
#                    'amount': 8901,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '16.159743422775360244258990860544145107269287109375',
#                    'total': '143837.8762061234815341492776'},
#                   {'date': datetime.datetime(2013, 1, 7, 0, 0),
#                    'amount': 2588,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '14.43803234005940083761743153445422649383544921875',
#                    'total': '37365.62769607372936775391281'},
#                   {'date': datetime.datetime(2003, 2, 19, 0, 0),
#                    'amount': 578,
#                    'transaction_code': 'sell',
#                    'symbol': 'adbe',
#                    'price': '14.1196581565672598657101843855343759059906005859375',
#                    'total': '8161.162414495876202380486575'},
#                   {'date': datetime.datetime(1982, 7, 22, 0, 0),
#                    'amount': 964,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '13.85120720985607789543792023323476314544677734375',
#                    'total': '13352.56375030125909120215510'},
#                   {'date': datetime.datetime(2016, 12, 8, 0, 0),
#                    'amount': 3970,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '26.247716617401248839769323240034282207489013671875',
#                    'total': '104203.4349710829578938842133'},
#                   {'date': datetime.datetime(2015, 9, 3, 0, 0),
#                    'amount': 6607,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '79.33405532799093862195149995386600494384765625',
#                    'total': '524160.1035520361314752335602'},
#                   {'date': datetime.datetime(2015, 12, 22, 0, 0),
#                    'amount': 4221,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '30.4044667242776398552450700663030147552490234375',
#                    'total': '128337.2540431759178289894407'},
#                   {'date': datetime.datetime(2008, 8, 19, 0, 0),
#                    'amount': 4799,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '43.96347030926532539751860895194113254547119140625',
#                    'total': '210980.6940141642965826918044'},
#                   {'date': datetime.datetime(1991, 5, 30, 0, 0),
#                    'amount': 4657,
#                    'transaction_code': 'sell',
#                    'symbol': 'msft',
#                    'price': '1.1517732225800922929437319908174686133861541748046875',
#                    'total': '5363.807897555489808238959881'},
#                   {'date': datetime.datetime(2014, 10, 6, 0, 0),
#                    'amount': 6397,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '66.439073760834702397914952598512172698974609375',
#                    'total': '425010.7548480595912394619518'},
#                   {'date': datetime.datetime(2007, 7, 11, 0, 0),
#                    'amount': 6352,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '90.5944805618852484485614695586264133453369140625',
#                    'total': '575456.1405290950981452624546'},
#                   {'date': datetime.datetime(2008, 2, 20, 0, 0),
#                    'amount': 2800,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '3.790661287329261330825147524592466652393341064453125',
#                    'total': '10613.85160452193172631041307'},
#                   {'date': datetime.datetime(2016, 1, 4, 0, 0),
#                    'amount': 1376,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '28.893855339485757127704346203245222568511962890625',
#                    'total': '39757.94494713240180772118038'},
#                   {'date': datetime.datetime(1989, 3, 16, 0, 0),
#                    'amount': 3044,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '1.2795149853767535663706667037331499159336090087890625',
#                    'total': '3894.843615486837856032309446'},
#                   {'date': datetime.datetime(1998, 6, 30, 0, 0),
#                    'amount': 7246,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '19.697308460376579120065798633731901645660400390625',
#                    'total': '142726.6971038886923039967769'},
#                   {'date': datetime.datetime(2014, 7, 7, 0, 0),
#                    'amount': 5935,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '38.65917577251284598105485201813280582427978515625',
#                    'total': '229442.2082098637408975605467'},
#                   {'date': datetime.datetime(2009, 9, 25, 0, 0),
#                    'amount': 4155,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '32.28257057551964948061140603385865688323974609375',
#                    'total': '134134.0807412841435919403921'},
#                   {'date': datetime.datetime(2016, 6, 27, 0, 0),
#                    'amount': 5199,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '25.54567484371674623844228335656225681304931640625',
#                    'total': '132811.9635124833636936614312'},
#                   {'date': datetime.datetime(2010, 4, 1, 0, 0),
#                    'amount': 9229,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '10.6848136359437528852822651970200240612030029296875',
#                    'total': '98610.14504612489537827002550'},
#                   {'date': datetime.datetime(2005, 7, 7, 0, 0),
#                    'amount': 2881,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '20.6769287918292690164889791049063205718994140625',
#                    'total': '59570.23184926012403650474880'}]}

# %% [markdown]
# ---
#
# Project only the `transactions.amount` and `transaction_count` fields.
#
# ----

# %%
# Query embedded documents
pp.pprint(
    db.transactions.find_one(
                                 # query 
                                 {'transactions.amount':{'$gt':9000}},
                                 # project
                                 {
                                     'transaction_count':1,
                                     'transactions.amount':1 
                                 }
                            )
)
# Out:
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb1'),
#  'transaction_count': 66,
#  'transactions': [{'amount': 7514},
#                   {'amount': 9240},
#                   {'amount': 2824},
#                   {'amount': 7418},
#                   {'amount': 5638},
#                   {'amount': 6774},
#                   {'amount': 7251},
#                   {'amount': 8828},
#                   {'amount': 5585},
#                   {'amount': 5789},
#                   {'amount': 7856},
#                   {'amount': 8539},
#                   {'amount': 4967},
#                   {'amount': 2893},
#                   {'amount': 9559},
#                   {'amount': 8269},
#                   {'amount': 8081},
#                   {'amount': 6145},
#                   {'amount': 6973},
#                   {'amount': 3082},
#                   {'amount': 2978},
#                   {'amount': 9265},
#                   {'amount': 9192},
#                   {'amount': 7408},
#                   {'amount': 3267},
#                   {'amount': 7582},
#                   {'amount': 643},
#                   {'amount': 3129},
#                   {'amount': 4075},
#                   {'amount': 4386},
#                   {'amount': 3093},
#                   {'amount': 5053},
#                   {'amount': 1428},
#                   {'amount': 7974},
#                   {'amount': 5363},
#                   {'amount': 4050},
#                   {'amount': 7447},
#                   {'amount': 1586},
#                   {'amount': 7124},
#                   {'amount': 2940},
#                   {'amount': 2273},
#                   {'amount': 2342},
#                   {'amount': 6380},
#                   {'amount': 9598},
#                   {'amount': 4123},
#                   {'amount': 2473},
#                   {'amount': 8901},
#                   {'amount': 2588},
#                   {'amount': 578},
#                   {'amount': 964},
#                   {'amount': 3970},
#                   {'amount': 6607},
#                   {'amount': 4221},
#                   {'amount': 4799},
#                   {'amount': 4657},
#                   {'amount': 6397},
#                   {'amount': 6352},
#                   {'amount': 2800},
#                   {'amount': 1376},
#                   {'amount': 3044},
#                   {'amount': 7246},
#                   {'amount': 5935},
#                   {'amount': 4155},
#                   {'amount': 5199},
#                   {'amount': 9229},
#                   {'amount': 2881}]}

# %% [markdown]
# ---
# **Multiple query conditions with array of embedded documents.**
#
# Retrieve document where the `amount < 5000` and `transaction_code` is `sell`.
#
# ---

# %%
# Multiple conditions to query embedded documents

pp.pprint(
    db.transactions.find_one(
                                # query
                                {
                                    'transactions.amount':{'$lt':5000},
                                    'transactions.transaction_code':'sell'
                                },
                                # project
                                {
                                    'transactions':1,
                                    'account_id':1
                                }
                            )
)
# Out:
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb1'),
#  'account_id': 443178,
#  'transactions': [{'date': datetime.datetime(2003, 9, 9, 0, 0),
#                    'amount': 7514,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '19.1072802650074180519368383102118968963623046875',
#                    'total': '143572.1039112657392422534031'},
#                   {'date': datetime.datetime(2016, 6, 14, 0, 0),
#                    'amount': 9240,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '24.1525632387771480580340721644461154937744140625',
#                    'total': '223169.6843263008480562348268'},
#                   {'date': datetime.datetime(2002, 12, 4, 0, 0),
#                    'amount': 2824,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.046193953245431629284212249331176280975341796875',
#                    'total': '59434.45172396509892109861539'},
#                   {'date': datetime.datetime(2014, 7, 14, 0, 0),
#                    'amount': 7418,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '76.38514540536692720706923864781856536865234375',
#                    'total': '566625.0086170118660220396123'},
#                   {'date': datetime.datetime(2011, 10, 28, 0, 0),
#                    'amount': 5638,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '28.365657608641175357888641883619129657745361328125',
#                    'total': '159925.5775975189466677761629'},
#                   {'date': datetime.datetime(2010, 12, 20, 0, 0),
#                    'amount': 6774,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '45.3237971108758159743956639431416988372802734375',
#                    'total': '307023.4016290727774105562276'},
#                   {'date': datetime.datetime(2015, 10, 28, 0, 0),
#                    'amount': 7251,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '102.936674838205050264150486327707767486572265625',
#                    'total': '746393.8292518248194653551764'},
#                   {'date': datetime.datetime(2012, 2, 2, 0, 0),
#                    'amount': 8828,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '17.838862313630283296106426860205829143524169921875',
#                    'total': '157481.4765047281409380275363'},
#                   {'date': datetime.datetime(2016, 3, 14, 0, 0),
#                    'amount': 5585,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '22.645934804740733170547173358500003814697265625',
#                    'total': '126477.5458844769947575059632'},
#                   {'date': datetime.datetime(2012, 3, 1, 0, 0),
#                    'amount': 5789,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '16.0804676963220600782733527012169361114501953125',
#                    'total': '93089.82749400840579312443879'},
#                   {'date': datetime.datetime(2001, 1, 4, 0, 0),
#                    'amount': 7856,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '26.71098408678698632456871564500033855438232421875',
#                    'total': '209841.4909857985645658118301'},
#                   {'date': datetime.datetime(2015, 12, 14, 0, 0),
#                    'amount': 8539,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '120.2002067302756387334738974459469318389892578125',
#                    'total': '1026389.565269823679145133610'},
#                   {'date': datetime.datetime(2016, 10, 5, 0, 0),
#                    'amount': 4967,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '90.35066753097771652392111718654632568359375',
#                    'total': '448771.7656263663179743161891'},
#                   {'date': datetime.datetime(2016, 9, 26, 0, 0),
#                    'amount': 2893,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '30.227075585186970130280315061099827289581298828125',
#                    'total': '87446.92966794590458690095147'},
#                   {'date': datetime.datetime(1992, 7, 17, 0, 0),
#                    'amount': 9559,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '19.83986843992497739463942707516252994537353515625',
#                    'total': '189649.3024172428589153582834'},
#                   {'date': datetime.datetime(1978, 2, 16, 0, 0),
#                    'amount': 8269,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '13.2722697458426655003904670593328773975372314453125',
#                    'total': '109748.3985283730010227287721'},
#                   {'date': datetime.datetime(2016, 6, 1, 0, 0),
#                    'amount': 8081,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '143.758609271150135100469924509525299072265625',
#                    'total': '1161713.321520164241746897460'},
#                   {'date': datetime.datetime(1986, 10, 23, 0, 0),
#                    'amount': 6145,
#                    'transaction_code': 'sell',
#                    'symbol': 'adbe',
#                    'price': '0.2800000011920928955078125',
#                    'total': '1720.600007325410842895507812'},
#                   {'date': datetime.datetime(2010, 10, 22, 0, 0),
#                    'amount': 6973,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.268423447276756377277706633321940898895263671875',
#                    'total': '148304.7166978608222187574484'},
#                   {'date': datetime.datetime(2016, 7, 28, 0, 0),
#                    'amount': 3082,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '86.029571359374330086211557500064373016357421875',
#                    'total': '265143.1389295916853257040202'},
#                   {'date': datetime.datetime(1988, 11, 18, 0, 0),
#                    'amount': 2978,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '0.2432200014591217041015625',
#                    'total': '724.3091643452644348144531250'},
#                   {'date': datetime.datetime(2002, 2, 20, 0, 0),
#                    'amount': 9265,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '81.091017566265037430639495141804218292236328125',
#                    'total': '751308.2777514455717948749225'},
#                   {'date': datetime.datetime(2014, 8, 18, 0, 0),
#                    'amount': 9192,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '74.557668636076840584792080335319042205810546875',
#                    'total': '685334.0901028183186554088024'},
#                   {'date': datetime.datetime(1971, 11, 17, 0, 0),
#                    'amount': 7408,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '12.4267172965691319319603280746378004550933837890625',
#                    'total': '92057.12173298412935196211038'},
#                   {'date': datetime.datetime(2011, 12, 23, 0, 0),
#                    'amount': 3267,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '10.54898647579047832323340117000043392181396484375',
#                    'total': '34463.53881640749268200352162'},
#                   {'date': datetime.datetime(2012, 5, 24, 0, 0),
#                    'amount': 7582,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '10.1614266582902761371087763109244406223297119140625',
#                    'total': '77043.93692315687367155874199'},
#                   {'date': datetime.datetime(2012, 8, 20, 0, 0),
#                    'amount': 643,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '9.1583720360888047906655629049055278301239013671875',
#                    'total': '5888.833219205101480397956948'},
#                   {'date': datetime.datetime(2013, 3, 27, 0, 0),
#                    'amount': 3129,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '74.33570821035419839972746558487415313720703125',
#                    'total': '232596.4309901982867927472398'},
#                   {'date': datetime.datetime(2015, 10, 22, 0, 0),
#                    'amount': 4075,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '45.37162592751771938992533250711858272552490234375',
#                    'total': '184889.3756546347065139457300'},
#                   {'date': datetime.datetime(2016, 7, 21, 0, 0),
#                    'amount': 4386,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '27.936906667695467376688611693680286407470703125',
#                    'total': '122531.2726445123199141562509'},
#                   {'date': datetime.datetime(1993, 12, 2, 0, 0),
#                    'amount': 3093,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '2.978981080777631351708123474963940680027008056640625',
#                    'total': '9213.988482845213770833225908'},
#                   {'date': datetime.datetime(2011, 6, 1, 0, 0),
#                    'amount': 5053,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '34.76661582629167668301306548528373241424560546875',
#                    'total': '175675.7097702518422792650199'},
#                   {'date': datetime.datetime(2010, 12, 1, 0, 0),
#                    'amount': 1428,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '28.3197718777616813667918904684484004974365234375',
#                    'total': '40440.63424144368099177881959'},
#                   {'date': datetime.datetime(2002, 2, 5, 0, 0),
#                    'amount': 7974,
#                    'transaction_code': 'sell',
#                    'symbol': 'msft',
#                    'price': '23.08480386999243449963614693842828273773193359375',
#                    'total': '184078.2260593196727000986357'},
#                   {'date': datetime.datetime(2016, 10, 13, 0, 0),
#                    'amount': 5363,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '27.9515663517458960996009409427642822265625',
#                    'total': '149904.2503444132407821598463'},
#                   {'date': datetime.datetime(2009, 4, 15, 0, 0),
#                    'amount': 4050,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '35.82050501072183834594397922046482563018798828125',
#                    'total': '145073.0452934234453010731158'},
#                   {'date': datetime.datetime(2013, 6, 28, 0, 0),
#                    'amount': 7447,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '165.427301038519743769938941113650798797607421875',
#                    'total': '1231937.110833856531854735294'},
#                   {'date': datetime.datetime(1983, 5, 16, 0, 0),
#                    'amount': 1586,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '23.801111434215950879433876252733170986175537109375',
#                    'total': '37748.56273466649809478212774'},
#                   {'date': datetime.datetime(2005, 3, 16, 0, 0),
#                    'amount': 7124,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '36.91652269537627262252499349415302276611328125',
#                    'total': '262993.3076818605661628680537'},
#                   {'date': datetime.datetime(1993, 3, 19, 0, 0),
#                    'amount': 2940,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '11.3086767608907070581381049123592674732208251953125',
#                    'total': '33247.50967701867875092602844'},
#                   {'date': datetime.datetime(1993, 6, 18, 0, 0),
#                    'amount': 2273,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '4.16809173919640141292575208353810012340545654296875',
#                    'total': '9474.072523193420411580234486'},
#                   {'date': datetime.datetime(1994, 6, 28, 0, 0),
#                    'amount': 2342,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '12.5191271611065957358732703141868114471435546875',
#                    'total': '29319.79581131164721341519908'},
#                   {'date': datetime.datetime(2010, 9, 3, 0, 0),
#                    'amount': 6380,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '41.865973826467524077088455669581890106201171875',
#                    'total': '267104.9130128628036118243472'},
#                   {'date': datetime.datetime(1997, 9, 11, 0, 0),
#                    'amount': 9598,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '5.39232880197155584056645238888449966907501220703125',
#                    'total': '51755.57184132299295775681003'},
#                   {'date': datetime.datetime(2016, 3, 9, 0, 0),
#                    'amount': 4123,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '75.127503708197110654509742744266986846923828125',
#                    'total': '309750.6977888966872285436693'},
#                   {'date': datetime.datetime(2008, 4, 17, 0, 0),
#                    'amount': 2473,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '46.75625859046404997343415743671357631683349609375',
#                    'total': '115628.2274942175955843026713'},
#                   {'date': datetime.datetime(1979, 1, 11, 0, 0),
#                    'amount': 8901,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '16.159743422775360244258990860544145107269287109375',
#                    'total': '143837.8762061234815341492776'},
#                   {'date': datetime.datetime(2013, 1, 7, 0, 0),
#                    'amount': 2588,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '14.43803234005940083761743153445422649383544921875',
#                    'total': '37365.62769607372936775391281'},
#                   {'date': datetime.datetime(2003, 2, 19, 0, 0),
#                    'amount': 578,
#                    'transaction_code': 'sell',
#                    'symbol': 'adbe',
#                    'price': '14.1196581565672598657101843855343759059906005859375',
#                    'total': '8161.162414495876202380486575'},
#                   {'date': datetime.datetime(1982, 7, 22, 0, 0),
#                    'amount': 964,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '13.85120720985607789543792023323476314544677734375',
#                    'total': '13352.56375030125909120215510'},
#                   {'date': datetime.datetime(2016, 12, 8, 0, 0),
#                    'amount': 3970,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '26.247716617401248839769323240034282207489013671875',
#                    'total': '104203.4349710829578938842133'},
#                   {'date': datetime.datetime(2015, 9, 3, 0, 0),
#                    'amount': 6607,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '79.33405532799093862195149995386600494384765625',
#                    'total': '524160.1035520361314752335602'},
#                   {'date': datetime.datetime(2015, 12, 22, 0, 0),
#                    'amount': 4221,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '30.4044667242776398552450700663030147552490234375',
#                    'total': '128337.2540431759178289894407'},
#                   {'date': datetime.datetime(2008, 8, 19, 0, 0),
#                    'amount': 4799,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '43.96347030926532539751860895194113254547119140625',
#                    'total': '210980.6940141642965826918044'},
#                   {'date': datetime.datetime(1991, 5, 30, 0, 0),
#                    'amount': 4657,
#                    'transaction_code': 'sell',
#                    'symbol': 'msft',
#                    'price': '1.1517732225800922929437319908174686133861541748046875',
#                    'total': '5363.807897555489808238959881'},
#                   {'date': datetime.datetime(2014, 10, 6, 0, 0),
#                    'amount': 6397,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '66.439073760834702397914952598512172698974609375',
#                    'total': '425010.7548480595912394619518'},
#                   {'date': datetime.datetime(2007, 7, 11, 0, 0),
#                    'amount': 6352,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '90.5944805618852484485614695586264133453369140625',
#                    'total': '575456.1405290950981452624546'},
#                   {'date': datetime.datetime(2008, 2, 20, 0, 0),
#                    'amount': 2800,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '3.790661287329261330825147524592466652393341064453125',
#                    'total': '10613.85160452193172631041307'},
#                   {'date': datetime.datetime(2016, 1, 4, 0, 0),
#                    'amount': 1376,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '28.893855339485757127704346203245222568511962890625',
#                    'total': '39757.94494713240180772118038'},
#                   {'date': datetime.datetime(1989, 3, 16, 0, 0),
#                    'amount': 3044,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '1.2795149853767535663706667037331499159336090087890625',
#                    'total': '3894.843615486837856032309446'},
#                   {'date': datetime.datetime(1998, 6, 30, 0, 0),
#                    'amount': 7246,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '19.697308460376579120065798633731901645660400390625',
#                    'total': '142726.6971038886923039967769'},
#                   {'date': datetime.datetime(2014, 7, 7, 0, 0),
#                    'amount': 5935,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '38.65917577251284598105485201813280582427978515625',
#                    'total': '229442.2082098637408975605467'},
#                   {'date': datetime.datetime(2009, 9, 25, 0, 0),
#                    'amount': 4155,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '32.28257057551964948061140603385865688323974609375',
#                    'total': '134134.0807412841435919403921'},
#                   {'date': datetime.datetime(2016, 6, 27, 0, 0),
#                    'amount': 5199,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '25.54567484371674623844228335656225681304931640625',
#                    'total': '132811.9635124833636936614312'},
#                   {'date': datetime.datetime(2010, 4, 1, 0, 0),
#                    'amount': 9229,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '10.6848136359437528852822651970200240612030029296875',
#                    'total': '98610.14504612489537827002550'},
#                   {'date': datetime.datetime(2005, 7, 7, 0, 0),
#                    'amount': 2881,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '20.6769287918292690164889791049063205718994140625',
#                    'total': '59570.23184926012403650474880'}]}

# %% [markdown]
# ---
# **`$` operator**
#
# Using [$](https://docs.mongodb.com/manual/reference/operator/projection/positional/#proj._S_) operator we can project the first element in an array that matches the conditions.
#
# ---
#
# For example, return the first embedded document from the `transactions` array field where `transaction.amount` < 5000 and `transaction.transaction_code` is `sell`.
#
# ---

# %%
# Query

pp.pprint(
    db.transactions.find_one(
                                # query
                                {
                                    'transactions.amount':{'$lt':5000},
                                    'transactions.transaction_code':'sell'
                                },
                                # project
                                {
                                    'transactions.$':1,
                                    'account_id':1
                                }
    ))
# Out:
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb1'),
#  'account_id': 443178,
#  'transactions': [{'date': datetime.datetime(2014, 7, 14, 0, 0),
#                    'amount': 7418,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '76.38514540536692720706923864781856536865234375',
#                    'total': '566625.0086170118660220396123'}]}

# %% [markdown]
# ---
# Above result did not consider the same embedded document for both the conditions. It matched the first condition in one embedded document, and the second condition in a different embedded document.
#
# That is a limitation of array fields. Multiple conditions may override each other internally and lead to undefined behavior.
#
# ----
# **`elemMatch` operator**
#
# To make sure both conditions match the same embedded document in the array, use the [$elemMatch](https://docs.mongodb.com/manual/reference/operator/query/elemMatch/#mongodb-query-op.-elemMatch) operator.
#
# ---
# For example, return the first embedded document from the array that matches the condition where the `amount` is less than 5000 and `transaction_code` is sell.
#
# ---

# %%
# Query

pp.pprint(
    db.transactions.find_one(
                            # query
                            {
                            'transactions':{
                                            '$elemMatch':{
                                                            'amount':{'$lt':5000},
                                                            'transaction_code':'sell'
                                                            }
                                            }
                            },
                            # project
                            {
                                'transactions.$':1,
                                'account_id':1
                            }
    ))
# Out:
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb1'),
#  'account_id': 443178,
#  'transactions': [{'date': datetime.datetime(2016, 7, 28, 0, 0),
#                    'amount': 3082,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '86.029571359374330086211557500064373016357421875',
#                    'total': '265143.1389295916853257040202'}]}

# %% [markdown]
# ----
# ### Question -
#
# Retrieve those documents that contains a transaction made after 1st January 2003, have the 'transaction_code' as 'buy' and the 'amount' is greater than 7000.
#
# ---

# %%
from datetime import datetime

# %%
# Question

cur = db.transactions.find(
                            # query
                            {
                            'transactions':{
                                            '$elemMatch':{
                                                            'date':{'$gt':datetime(2003,1,1)},
                                                            'amount':{'$gt':7000},
                                                            'transaction_code':'buy'
                                                            }
                                            }
                            },
                            # project
                            {
                                'transactions.$':1,
                                'account_id':1
                            }
    )

for doc in cur:
    pp.pprint(doc)
# Out:
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb1'),
#  'account_id': 443178,
#  'transactions': [{'date': datetime.datetime(2003, 9, 9, 0, 0),
#                    'amount': 7514,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '19.1072802650074180519368383102118968963623046875',
#                    'total': '143572.1039112657392422534031'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb2'),
#  'account_id': 716662,
#  'transactions': [{'date': datetime.datetime(2008, 3, 19, 0, 0),
#                    'amount': 8592,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '6.25868566899633460565155473886989057064056396484375',
#                    'total': '53774.62726801650693175815832'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb3'),
#  'account_id': 557378,
#  'transactions': [{'date': datetime.datetime(2011, 8, 23, 0, 0),
#                    'amount': 7530,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '12.1229215166617709797947100014425814151763916015625',
#                    'total': '91285.59902046313547785416631'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb4'),
#  'account_id': 278603,
#  'transactions': [{'date': datetime.datetime(2015, 3, 4, 0, 0),
#                    'amount': 7951,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '569.307836085921508129104040563106536865234375',
#                    'total': '4526566.604719161911134506227'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb5'),
#  'account_id': 674364,
#  'transactions': [{'date': datetime.datetime(2014, 8, 29, 0, 0),
#                    'amount': 9592,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '18.6219268728554681047171470709145069122314453125',
#                    'total': '178621.5225644296500604468747'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb6'),
#  'account_id': 383701,
#  'transactions': [{'date': datetime.datetime(2014, 7, 10, 0, 0),
#                    'amount': 7349,
#                    'transaction_code': 'buy',
#                    'symbol': 'ebay',
#                    'price': '21.270893409492867220933476346544921398162841796875',
#                    'total': '156319.7956663630812066401177'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb7'),
#  'account_id': 775690,
#  'transactions': [{'date': datetime.datetime(2015, 8, 7, 0, 0),
#                    'amount': 7397,
#                    'transaction_code': 'buy',
#                    'symbol': 'intc',
#                    'price': '26.975432147979805819204557337798178195953369140625',
#                    'total': '199537.2715986066236446561106'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb8'),
#  'account_id': 996263,
#  'transactions': [{'date': datetime.datetime(2013, 6, 6, 0, 0),
#                    'amount': 9359,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '31.328993088892193696892718435265123844146728515625',
#                    'total': '293208.0463189420408092189518'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb9'),
#  'account_id': 316726,
#  'transactions': [{'date': datetime.datetime(2016, 3, 2, 0, 0),
#                    'amount': 7206,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '2.213149022706194291032488763448782265186309814453125',
#                    'total': '15947.95185762083606118011403'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cba'),
#  'account_id': 126668,
#  'transactions': [{'date': datetime.datetime(2011, 3, 9, 0, 0),
#                    'amount': 9499,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '35.1363930393217316350273904390633106231689453125',
#                    'total': '333760.5974805171288011251818'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cbb'),
#  'account_id': 278866,
#  'transactions': [{'date': datetime.datetime(2016, 2, 1, 0, 0),
#                    'amount': 7085,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '76.833939744732532517446088604629039764404296875',
#                    'total': '544368.4630914299928861055378'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cbc'),
#  'account_id': 795909,
#  'transactions': [{'date': datetime.datetime(2009, 2, 4, 0, 0),
#                    'amount': 7443,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '19.863806059418212868195041664876043796539306640625',
#                    'total': '147846.3085002497583779756951'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cbd'),
#  'account_id': 136137,
#  'transactions': [{'date': datetime.datetime(2003, 5, 8, 0, 0),
#                    'amount': 8489,
#                    'transaction_code': 'buy',
#                    'symbol': 'bb',
#                    'price': '2.835572712016570573467788562993519008159637451171875',
#                    'total': '24071.17675230866759816805711'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cbe'),
#  'account_id': 831097,
#  'transactions': [{'date': datetime.datetime(2015, 3, 3, 0, 0),
#                    'amount': 7007,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '384.34053409813913049219991080462932586669921875',
#                    'total': '2693074.122425660887358844775'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cbf'),
#  'account_id': 462501,
#  'transactions': [{'date': datetime.datetime(2008, 11, 18, 0, 0),
#                    'amount': 9865,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '3.040651691582594740026479485095478594303131103515625',
#                    'total': '29996.02893746229711036122012'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cc0'),
#  'account_id': 968786,
#  'transactions': [{'date': datetime.datetime(2005, 7, 20, 0, 0),
#                    'amount': 9803,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '2.38912653188783252744542551226913928985595703125',
#                    'total': '23420.60739209642226654750630'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cc1'),
#  'account_id': 228290,
#  'transactions': [{'date': datetime.datetime(2012, 11, 7, 0, 0),
#                    'amount': 7268,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '11.777323543283376494628100772388279438018798828125',
#                    'total': '85597.58751258358036295703641'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cc3'),
#  'account_id': 116508,
#  'transactions': [{'date': datetime.datetime(2013, 5, 3, 0, 0),
#                    'amount': 7821,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '75.3967460353404561601564637385308742523193359375',
#                    'total': '589677.9507423977076285837029'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cc5'),
#  'account_id': 170945,
#  'transactions': [{'date': datetime.datetime(2014, 1, 21, 0, 0),
#                    'amount': 8768,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '46.9739833864050950751334312371909618377685546875',
#                    'total': '411867.8863319998736187699251'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cc6'),
#  'account_id': 771641,
#  'transactions': [{'date': datetime.datetime(2013, 11, 22, 0, 0),
#                    'amount': 9689,
#                    'transaction_code': 'buy',
#                    'symbol': 'aapl',
#                    'price': '68.9494847512784048149114823900163173675537109375',
#                    'total': '668051.5577551364642516773529'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cc7'),
#  'account_id': 55958,
#  'transactions': [{'date': datetime.datetime(2014, 11, 20, 0, 0),
#                    'amount': 8082,
#                    'transaction_code': 'buy',
#                    'symbol': 'znga',
#                    'price': '2.69361899179887842592506785877048969268798828125',
#                    'total': '21769.82869171853543832639843'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cc8'),
#  'account_id': 87389,
#  'transactions': [{'date': datetime.datetime(2016, 9, 9, 0, 0),
#                    'amount': 9847,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '763.790753586446271583554334938526153564453125',
#                    'total': '7521047.550565736436283259536'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cca'),
#  'account_id': 327942,
#  'transactions': [{'date': datetime.datetime(2005, 6, 23, 0, 0),
#                    'amount': 7359,
#                    'transaction_code': 'buy',
#                    'symbol': 'csco',
#                    'price': '16.6778248362038965524334344081580638885498046875',
#                    'total': '122732.1129696244747293576438'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ccb'),
#  'account_id': 951500,
#  'transactions': [{'date': datetime.datetime(2008, 2, 11, 0, 0),
#                    'amount': 7060,
#                    'transaction_code': 'buy',
#                    'symbol': 'ebay',
#                    'price': '11.8323824832977653187526811962015926837921142578125',
#                    'total': '83536.62033208222315039392925'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ccd'),
#  'account_id': 785350,
#  'transactions': [{'date': datetime.datetime(2015, 9, 2, 0, 0),
#                    'amount': 8238,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '76.02303957283317004112177528440952301025390625',
#                    'total': '626277.8000009996547987611848'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cce'),
#  'account_id': 387979,
#  'transactions': [{'date': datetime.datetime(2009, 2, 9, 0, 0),
#                    'amount': 8762,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '7.32214892073906664649030062719248235225677490234375',
#                    'total': '64156.66884351570195654801410'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ccf'),
#  'account_id': 198100,
#  'transactions': [{'date': datetime.datetime(2015, 1, 30, 0, 0),
#                    'amount': 7656,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '528.51336815468812346807681024074554443359375',
#                    'total': '4046298.346592292273271596059'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cd0'),
#  'account_id': 209363,
#  'transactions': [{'date': datetime.datetime(2008, 12, 11, 0, 0),
#                    'amount': 9229,
#                    'transaction_code': 'buy',
#                    'symbol': 'ebay',
#                    'price': '5.704513454793765703243479947559535503387451171875',
#                    'total': '52646.95467429166367523407644'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cd1'),
#  'account_id': 556654,
#  'transactions': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#                    'amount': 9275,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '44.69693492546749524763072258792817592620849609375',
#                    'total': '414564.0714337110184217749520'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cd2'),
#  'account_id': 433314,
#  'transactions': [{'date': datetime.datetime(2011, 11, 23, 0, 0),
#                    'amount': 9039,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '26.10434595091344789352660882286727428436279296875',
#                    'total': '235957.1830503066555095870171'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cd3'),
#  'account_id': 328304,
#  'transactions': [{'date': datetime.datetime(2007, 11, 5, 0, 0),
#                    'amount': 9599,
#                    'transaction_code': 'buy',
#                    'symbol': 'ebay',
#                    'price': '14.4886648926203491782871424220502376556396484375',
#                    'total': '139076.6943042627317623782801'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cd4'),
#  'account_id': 491860,
#  'transactions': [{'date': datetime.datetime(2012, 3, 15, 0, 0),
#                    'amount': 7373,
#                    'transaction_code': 'buy',
#                    'symbol': 'ebay',
#                    'price': '15.5948108092116495271284293266944587230682373046875',
#                    'total': '114980.5400963174919635179094'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cd5'),
#  'account_id': 463155,
#  'transactions': [{'date': datetime.datetime(2010, 8, 17, 0, 0),
#                    'amount': 9063,
#                    'transaction_code': 'buy',
#                    'symbol': 'aapl',
#                    'price': '32.29543892382616832037456333637237548828125',
#                    'total': '292693.5629666365634875546675'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cd6'),
#  'account_id': 487188,
#  'transactions': [{'date': datetime.datetime(2003, 7, 29, 0, 0),
#                    'amount': 8027,
#                    'transaction_code': 'buy',
#                    'symbol': 'ebay',
#                    'price': '11.370017027014029054043930955231189727783203125',
#                    'total': '91267.12667584161121681063378'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cd8'),
#  'account_id': 729049,
#  'transactions': [{'date': datetime.datetime(2015, 11, 20, 0, 0),
#                    'amount': 8610,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '31.16714754376160811943918815813958644866943359375',
#                    'total': '268349.1403517874459083714100'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cd9'),
#  'account_id': 149440,
#  'transactions': [{'date': datetime.datetime(2007, 4, 10, 0, 0),
#                    'amount': 7912,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '41.540727537577140537905506789684295654296875',
#                    'total': '328670.2362773103359359083697'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cda'),
#  'account_id': 701440,
#  'transactions': [{'date': datetime.datetime(2010, 2, 10, 0, 0),
#                    'amount': 7594,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '102.859048214227442485935171134769916534423828125',
#                    'total': '781111.6121388431982381916896'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cdb'),
#  'account_id': 842570,
#  'transactions': [{'date': datetime.datetime(2012, 7, 9, 0, 0),
#                    'amount': 8493,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '11.6472299741586713395236074575223028659820556640625',
#                    'total': '98919.92417052959568657399814'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cdc'),
#  'account_id': 987988,
#  'transactions': [{'date': datetime.datetime(2007, 11, 16, 0, 0),
#                    'amount': 9868,
#                    'transaction_code': 'buy',
#                    'symbol': 'bb',
#                    'price': '101.231776219755516876830370165407657623291015625',
#                    'total': '998955.1677365474405405620928'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cdd'),
#  'account_id': 324287,
#  'transactions': [{'date': datetime.datetime(2006, 3, 15, 0, 0),
#                    'amount': 8267,
#                    'transaction_code': 'buy',
#                    'symbol': 'csco',
#                    'price': '17.67683142973954346643949975259602069854736328125',
#                    'total': '146134.3654296568058370553445'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cde'),
#  'account_id': 422649,
#  'transactions': [{'date': datetime.datetime(2014, 2, 7, 0, 0),
#                    'amount': 8638,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '3.477354237283407645264787788619287312030792236328125',
#                    'total': '30037.38590165407523979723692'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cdf'),
#  'account_id': 794875,
#  'transactions': [{'date': datetime.datetime(2016, 6, 13, 0, 0),
#                    'amount': 8797,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '46.53873172406391489630550495348870754241943359375',
#                    'total': '409401.2229765902593427995271'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce0'),
#  'account_id': 383777,
#  'transactions': [{'date': datetime.datetime(2012, 2, 6, 0, 0),
#                    'amount': 8793,
#                    'transaction_code': 'buy',
#                    'symbol': 'ebay',
#                    'price': '13.7630747641472392928108092746697366237640380859375',
#                    'total': '121018.7164011466751016854460'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce1'),
#  'account_id': 503933,
#  'transactions': [{'date': datetime.datetime(2006, 8, 30, 0, 0),
#                    'amount': 7774,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '8.6880894051000989719568678992800414562225341796875',
#                    'total': '67541.20703524816940799269105'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce2'),
#  'account_id': 599752,
#  'transactions': [{'date': datetime.datetime(2016, 8, 17, 0, 0),
#                    'amount': 9985,
#                    'transaction_code': 'buy',
#                    'symbol': 'bb',
#                    'price': '8.2566782499318680521582791698165237903594970703125',
#                    'total': '82442.93232556970250080041751'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce3'),
#  'account_id': 161460,
#  'transactions': [{'date': datetime.datetime(2011, 3, 16, 0, 0),
#                    'amount': 9138,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '16.337366486030415302366236574016511440277099609375',
#                    'total': '149290.8549493459350330226698'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce4'),
#  'account_id': 839727,
#  'transactions': [{'date': datetime.datetime(2013, 10, 18, 0, 0),
#                    'amount': 9114,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '52.382624721886969609840889461338520050048828125',
#                    'total': '477415.2417152778410240898666'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce5'),
#  'account_id': 832510,
#  'transactions': [{'date': datetime.datetime(2014, 1, 17, 0, 0),
#                    'amount': 7329,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '4.172904382094284159165908931754529476165771484375',
#                    'total': '30583.21621636900860252694656'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce6'),
#  'account_id': 255695,
#  'transactions': [{'date': datetime.datetime(2014, 1, 22, 0, 0),
#                    'amount': 8379,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '76.4870167717527493778106872923672199249267578125',
#                    'total': '640884.7135305162870366757488'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce7'),
#  'account_id': 475387,
#  'transactions': [{'date': datetime.datetime(2010, 2, 3, 0, 0),
#                    'amount': 9785,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '23.658751678804581075610258267261087894439697265625',
#                    'total': '231500.8851771028258248463771'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce8'),
#  'account_id': 984021,
#  'transactions': [{'date': datetime.datetime(2010, 9, 10, 0, 0),
#                    'amount': 7759,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '29.297737889395687460591943818144500255584716796875',
#                    'total': '227321.1482838211390067328921'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ce9'),
#  'account_id': 581161,
#  'transactions': [{'date': datetime.datetime(2015, 11, 24, 0, 0),
#                    'amount': 7747,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '30.77212663527296143683997797779738903045654296875',
#                    'total': '238391.6650434596322511993094'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cea'),
#  'account_id': 296866,
#  'transactions': [{'date': datetime.datetime(2015, 5, 18, 0, 0),
#                    'amount': 8075,
#                    'transaction_code': 'buy',
#                    'symbol': 'znga',
#                    'price': '3.035875520859657061834013802581466734409332275390625',
#                    'total': '24514.69483094173077430966146'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ceb'),
#  'account_id': 330961,
#  'transactions': [{'date': datetime.datetime(2015, 6, 19, 0, 0),
#                    'amount': 8094,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '70.7987081220491489830237696878612041473388671875',
#                    'total': '573044.7435398658118685943919'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cec'),
#  'account_id': 612356,
#  'transactions': [{'date': datetime.datetime(2015, 10, 7, 0, 0),
#                    'amount': 8647,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '79.2145920266283809496599133126437664031982421875',
#                    'total': '684968.5772542556100717092704'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161ced'),
#  'account_id': 139582,
#  'transactions': [{'date': datetime.datetime(2010, 3, 25, 0, 0),
#                    'amount': 9100,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '129.619895267013561124258558265864849090576171875',
#                    'total': '1179541.046929823406230752880'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cee'),
#  'account_id': 347313,
#  'transactions': [{'date': datetime.datetime(2008, 11, 7, 0, 0),
#                    'amount': 9105,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '71.5230614708697629566813702695071697235107421875',
#                    'total': '651217.4746922691917205838763'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cef'),
#  'account_id': 813016,
#  'transactions': [{'date': datetime.datetime(2008, 2, 11, 0, 0),
#                    'amount': 7897,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '74.068374947648095485419617034494876861572265625',
#                    'total': '584917.9569615770100483587157'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf0'),
#  'account_id': 785786,
#  'transactions': [{'date': datetime.datetime(2016, 12, 6, 0, 0),
#                    'amount': 8766,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '25.594146898330127015697144088335335254669189453125',
#                    'total': '224358.2917107618934196011651'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf1'),
#  'account_id': 130514,
#  'transactions': [{'date': datetime.datetime(2016, 3, 2, 0, 0),
#                    'amount': 7074,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '70.471812302380754999830969609320163726806640625',
#                    'total': '498517.6002270414608688042790'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf2'),
#  'account_id': 199962,
#  'transactions': [{'date': datetime.datetime(2011, 1, 6, 0, 0),
#                    'amount': 9074,
#                    'transaction_code': 'buy',
#                    'symbol': 'csco',
#                    'price': '17.28926310835974078372601070441305637359619140625',
#                    'total': '156882.7734452562878715298211'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf3'),
#  'account_id': 375872,
#  'transactions': [{'date': datetime.datetime(2016, 1, 29, 0, 0),
#                    'amount': 8590,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '21.573392272105227362999357865191996097564697265625',
#                    'total': '185315.4396173839030481644841'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf4'),
#  'account_id': 914559,
#  'transactions': [{'date': datetime.datetime(2016, 2, 19, 0, 0),
#                    'amount': 9473,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '21.17021878410236013223766349256038665771484375',
#                    'total': '200545.4825418016575326873863'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf5'),
#  'account_id': 304914,
#  'transactions': [{'date': datetime.datetime(2014, 2, 19, 0, 0),
#                    'amount': 9926,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '76.2938585631470544967669411562383174896240234375',
#                    'total': '757292.8400977976629349086579'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf6'),
#  'account_id': 604732,
#  'transactions': [{'date': datetime.datetime(2012, 2, 15, 0, 0),
#                    'amount': 9776,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '188.7736110692231932262075133621692657470703125',
#                    'total': '1845450.821812725936979404651'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf7'),
#  'account_id': 849766,
#  'transactions': [{'date': datetime.datetime(2007, 2, 27, 0, 0),
#                    'amount': 9746,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '3.187910978077602042191074360744096338748931884765625',
#                    'total': '31069.38039234430950319421072'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf8'),
#  'account_id': 627629,
#  'transactions': [{'date': datetime.datetime(2009, 8, 6, 0, 0),
#                    'amount': 7514,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '32.2179019859054704966183635406196117401123046875',
#                    'total': '242085.3155220937053115903836'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cf9'),
#  'account_id': 175894,
#  'transactions': [{'date': datetime.datetime(2006, 11, 27, 0, 0),
#                    'amount': 9507,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '4.146003909797595810005077510140836238861083984375',
#                    'total': '39416.05917044574336571827189'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cfa'),
#  'account_id': 977774,
#  'transactions': [{'date': datetime.datetime(2014, 5, 2, 0, 0),
#                    'amount': 8842,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '36.705335647152224964884226210415363311767578125',
#                    'total': '324548.5777921199731395063282'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cfb'),
#  'account_id': 904434,
#  'transactions': [{'date': datetime.datetime(2015, 5, 19, 0, 0),
#                    'amount': 8470,
#                    'transaction_code': 'buy',
#                    'symbol': 'bb',
#                    'price': '10.1098051972481162152917022467590868473052978515625',
#                    'total': '85630.05002069154434352071803'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cfc'),
#  'account_id': 904260,
#  'transactions': [{'date': datetime.datetime(2015, 4, 14, 0, 0),
#                    'amount': 9820,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '68.97378601217081950380816124379634857177734375',
#                    'total': '677322.5786395174475273961434'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cfd'),
#  'account_id': 139687,
#  'transactions': [{'date': datetime.datetime(2005, 5, 3, 0, 0),
#                    'amount': 7213,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '14.3343153228925661579751249519176781177520751953125',
#                    'total': '103393.4164240240796974745763'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cff'),
#  'account_id': 371138,
#  'transactions': [{'date': datetime.datetime(2015, 6, 24, 0, 0),
#                    'amount': 7060,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '73.5563113392096283860155381262302398681640625',
#                    'total': '519307.5580548199764052696992'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d00'),
#  'account_id': 470650,
#  'transactions': [{'date': datetime.datetime(2016, 2, 17, 0, 0),
#                    'amount': 7375,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '22.38716200909725984047327074222266674041748046875',
#                    'total': '165105.3198170922913234903717'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d01'),
#  'account_id': 565468,
#  'transactions': [{'date': datetime.datetime(2007, 7, 13, 0, 0),
#                    'amount': 9957,
#                    'transaction_code': 'buy',
#                    'symbol': 'ebay',
#                    'price': '14.32345084548416735970022273249924182891845703125',
#                    'total': '142618.6000684858544005351177'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d02'),
#  'account_id': 276528,
#  'transactions': [{'date': datetime.datetime(2006, 1, 6, 0, 0),
#                    'amount': 8919,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '12.646052643989573738281251280568540096282958984375',
#                    'total': '112790.1435317430081717304802'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d03'),
#  'account_id': 332179,
#  'transactions': [{'date': datetime.datetime(2006, 7, 18, 0, 0),
#                    'amount': 7776,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '20.802791144269264123067841865122318267822265625',
#                    'total': '161762.5039378377978209755383'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d04'),
#  'account_id': 403363,
#  'transactions': [{'date': datetime.datetime(2016, 1, 6, 0, 0),
#                    'amount': 7050,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '2.474768028367223760000115362345241010189056396484375',
#                    'total': '17447.11459998892750800081330'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d05'),
#  'account_id': 931314,
#  'transactions': [{'date': datetime.datetime(2013, 1, 29, 0, 0),
#                    'amount': 9366,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '11.5963370764883766383945840061642229557037353515625',
#                    'total': '108611.2930583901355952036738'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d06'),
#  'account_id': 118127,
#  'transactions': [{'date': datetime.datetime(2016, 10, 27, 0, 0),
#                    'amount': 8056,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '75.0347888889446466009758296422660350799560546875',
#                    'total': '604480.2592893380730174612836'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d07'),
#  'account_id': 423171,
#  'transactions': [{'date': datetime.datetime(2008, 9, 19, 0, 0),
#                    'amount': 9212,
#                    'transaction_code': 'buy',
#                    'symbol': 'ebay',
#                    'price': '9.486255937484219913358174380846321582794189453125',
#                    'total': '87387.38969610463384185550240'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d08'),
#  'account_id': 235286,
#  'transactions': [{'date': datetime.datetime(2016, 4, 29, 0, 0),
#                    'amount': 7659,
#                    'transaction_code': 'buy',
#                    'symbol': 'intc',
#                    'price': '28.669035479169732383297741762362420558929443359375',
#                    'total': '219576.1427349609803236774042'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d09'),
#  'account_id': 895735,
#  'transactions': [{'date': datetime.datetime(2016, 2, 17, 0, 0),
#                    'amount': 9588,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '60.760430159376284109384869225323200225830078125',
#                    'total': '582571.0043680998120407821261'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d0a'),
#  'account_id': 78388,
#  'transactions': [{'date': datetime.datetime(2009, 3, 13, 0, 0),
#                    'amount': 7420,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '69.5943946324006077475132769905030727386474609375',
#                    'total': '516390.4081724125094865485153'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d0b'),
#  'account_id': 781775,
#  'transactions': [{'date': datetime.datetime(2005, 5, 23, 0, 0),
#                    'amount': 7786,
#                    'transaction_code': 'buy',
#                    'symbol': 'aapl',
#                    'price': '5.04734050105571174782426169258542358875274658203125',
#                    'total': '39298.59314121977166855970154'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d0c'),
#  'account_id': 973067,
#  'transactions': [{'date': datetime.datetime(2015, 10, 22, 0, 0),
#                    'amount': 8324,
#                    'transaction_code': 'buy',
#                    'symbol': 'fb',
#                    'price': '99.4081344716918238191283307969570159912109375',
#                    'total': '827473.3113423627414704242256'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d0d'),
#  'account_id': 740604,
#  'transactions': [{'date': datetime.datetime(2014, 7, 25, 0, 0),
#                    'amount': 8235,
#                    'transaction_code': 'buy',
#                    'symbol': 'znga',
#                    'price': '3.0034366735436659467950448743067681789398193359375',
#                    'total': '24733.30100663208907185719454'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d0e'),
#  'account_id': 356905,
#  'transactions': [{'date': datetime.datetime(2012, 6, 27, 0, 0),
#                    'amount': 9059,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '5.4910546836792537561677818302996456623077392578125',
#                    'total': '49743.46437945035977712393560'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d0f'),
#  'account_id': 673123,
#  'transactions': [{'date': datetime.datetime(2010, 6, 11, 0, 0),
#                    'amount': 7446,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '31.698195785047669659206803771667182445526123046875',
#                    'total': '236024.7658154649482824538609'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d11'),
#  'account_id': 236908,
#  'transactions': [{'date': datetime.datetime(2005, 9, 27, 0, 0),
#                    'amount': 8439,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '10.2516691060585234396285159164108335971832275390625',
#                    'total': '86513.83558602787930702504582'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d12'),
#  'account_id': 689102,
#  'transactions': [{'date': datetime.datetime(2014, 5, 16, 0, 0),
#                    'amount': 9574,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '72.03170148823249974157079122960567474365234375',
#                    'total': '689631.5100483379525257987552'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d13'),
#  'account_id': 658755,
#  'transactions': [{'date': datetime.datetime(2011, 12, 28, 0, 0),
#                    'amount': 7859,
#                    'transaction_code': 'buy',
#                    'symbol': 'bb',
#                    'price': '14.65434940229016547164064832031726837158203125',
#                    'total': '115168.5319525984104416238551'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d14'),
#  'account_id': 312052,
#  'transactions': [{'date': datetime.datetime(2003, 4, 29, 0, 0),
#                    'amount': 7983,
#                    'transaction_code': 'buy',
#                    'symbol': 'csco',
#                    'price': '12.6717130688448893494069125154055655002593994140625',
#                    'total': '101158.2854285887516763153826'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d15'),
#  'account_id': 918103,
#  'transactions': [{'date': datetime.datetime(2009, 1, 23, 0, 0),
#                    'amount': 8832,
#                    'transaction_code': 'buy',
#                    'symbol': 'aapl',
#                    'price': '11.4696092168504417685426233219914138317108154296875',
#                    'total': '101299.5886032231016997684492'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d16'),
#  'account_id': 893492,
#  'transactions': [{'date': datetime.datetime(2015, 8, 7, 0, 0),
#                    'amount': 8092,
#                    'transaction_code': 'buy',
#                    'symbol': 'fb',
#                    'price': '95.0808835584542322294510086067020893096923828125',
#                    'total': '769394.5097550116472007175616'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d17'),
#  'account_id': 788678,
#  'transactions': [{'date': datetime.datetime(2015, 1, 27, 0, 0),
#                    'amount': 8189,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '525.982993999153450204175896942615509033203125',
#                    'total': '4307274.737859067603721996420'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d18'),
#  'account_id': 827328,
#  'transactions': [{'date': datetime.datetime(2005, 3, 3, 0, 0),
#                    'amount': 9408,
#                    'transaction_code': 'buy',
#                    'symbol': 'csco',
#                    'price': '14.774625970531094054649656754918396472930908203125',
#                    'total': '138999.6811307565328661439708'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d19'),
#  'account_id': 595194,
#  'transactions': [{'date': datetime.datetime(2015, 7, 16, 0, 0),
#                    'amount': 7966,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '468.25883732325740993474028073251247406005859375',
#                    'total': '3730149.898117068527540141076'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d1a'),
#  'account_id': 358213,
#  'transactions': [{'date': datetime.datetime(2014, 8, 21, 0, 0),
#                    'amount': 9612,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '583.7889446881941921674297191202640533447265625',
#                    'total': '5611379.336342922575113334460'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d1b'),
#  'account_id': 767808,
#  'transactions': [{'date': datetime.datetime(2003, 1, 30, 0, 0),
#                    'amount': 7361,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '13.4403957316910034336387980147264897823333740234375',
#                    'total': '98934.75298097747627501519219'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d1c'),
#  'account_id': 522933,
#  'transactions': [{'date': datetime.datetime(2006, 3, 15, 0, 0),
#                    'amount': 9863,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '34.60288801006927172920768498443067073822021484375',
#                    'total': '341288.2844433132270651753970'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d1d'),
#  'account_id': 292314,
#  'transactions': [{'date': datetime.datetime(2016, 12, 14, 0, 0),
#                    'amount': 9918,
#                    'transaction_code': 'buy',
#                    'symbol': 'bb',
#                    'price': '7.803544355148449795933629502542316913604736328125',
#                    'total': '77395.55291436232507606973741'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d1e'),
#  'account_id': 120556,
#  'transactions': [{'date': datetime.datetime(2009, 1, 21, 0, 0),
#                    'amount': 8112,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '48.6835002073423908086624578572809696197509765625',
#                    'total': '394920.5536819614742398698581'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d1f'),
#  'account_id': 719065,
#  'transactions': [{'date': datetime.datetime(2004, 12, 29, 0, 0),
#                    'amount': 8367,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '7.0017109013021876506854823674075305461883544921875',
#                    'total': '58583.31511119540407328543097'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d20'),
#  'account_id': 202669,
#  'transactions': [{'date': datetime.datetime(2006, 7, 11, 0, 0),
#                    'amount': 8152,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '19.550557723807404642002438777126371860504150390625',
#                    'total': '159376.1465644779626416038809'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d21'),
#  'account_id': 585158,
#  'transactions': [{'date': datetime.datetime(2005, 2, 8, 0, 0),
#                    'amount': 7756,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '78.75601438130109954727231524884700775146484375',
#                    'total': '610831.6475413713280886440771'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d23'),
#  'account_id': 951849,
#  'transactions': [{'date': datetime.datetime(2014, 8, 1, 0, 0),
#                    'amount': 8476,
#                    'transaction_code': 'buy',
#                    'symbol': 'znga',
#                    'price': '2.837972736729510447872826262027956545352935791015625',
#                    'total': '24054.65691651933055617007540'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d24'),
#  'account_id': 563516,
#  'transactions': [{'date': datetime.datetime(2012, 12, 4, 0, 0),
#                    'amount': 8548,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '23.34204790289181374873805907554924488067626953125',
#                    'total': '199527.8254739192239242129290'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d25'),
#  'account_id': 346408,
#  'transactions': [{'date': datetime.datetime(2015, 3, 25, 0, 0),
#                    'amount': 8851,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '378.49205145978527298211702145636081695556640625',
#                    'total': '3350033.147470559451164717757'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d26'),
#  'account_id': 260799,
#  'transactions': [{'date': datetime.datetime(2006, 8, 22, 0, 0),
#                    'amount': 9687,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '16.624978029225449205341647029854357242584228515625',
#                    'total': '161046.1621691069264521445348'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d27'),
#  'account_id': 859697,
#  'transactions': [{'date': datetime.datetime(2009, 3, 25, 0, 0),
#                    'amount': 9097,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '33.59662340749012088281233445741236209869384765625',
#                    'total': '305628.4831379376296709438066'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d28'),
#  'account_id': 385397,
#  'transactions': [{'date': datetime.datetime(2010, 7, 27, 0, 0),
#                    'amount': 8679,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '9.7483294098510437919458126998506486415863037109375',
#                    'total': '84605.75094809720907029770842'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d29'),
#  'account_id': 330318,
#  'transactions': [{'date': datetime.datetime(2006, 10, 31, 0, 0),
#                    'amount': 9166,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '20.61640002811598293419592664577066898345947265625',
#                    'total': '188969.9226577110995748398636'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d2a'),
#  'account_id': 240640,
#  'transactions': [{'date': datetime.datetime(2005, 9, 12, 0, 0),
#                    'amount': 7675,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '44.35139491446528126061821240000426769256591796875',
#                    'total': '340396.9559685210336752447802'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d2b'),
#  'account_id': 839760,
#  'transactions': [{'date': datetime.datetime(2016, 3, 22, 0, 0),
#                    'amount': 8147,
#                    'transaction_code': 'buy',
#                    'symbol': 'fb',
#                    'price': '112.1525908282437882235171855427324771881103515625',
#                    'total': '913707.1574777021426569945106'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d2c'),
#  'account_id': 721914,
#  'transactions': [{'date': datetime.datetime(2013, 5, 1, 0, 0),
#                    'amount': 8938,
#                    'transaction_code': 'buy',
#                    'symbol': 'fb',
#                    'price': '27.78081959055483451948020956479012966156005859375',
#                    'total': '248304.9655003791109351141131'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d2d'),
#  'account_id': 985280,
#  'transactions': [{'date': datetime.datetime(2016, 3, 4, 0, 0),
#                    'amount': 8718,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '714.04811806036968846456147730350494384765625',
#                    'total': '6225071.493250302944034046959'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d2e'),
#  'account_id': 817222,
#  'transactions': [{'date': datetime.datetime(2016, 11, 10, 0, 0),
#                    'amount': 7914,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '758.6062705202458573694457300007343292236328125',
#                    'total': '6003610.024897225715221793507'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d2f'),
#  'account_id': 679236,
#  'transactions': [{'date': datetime.datetime(2006, 9, 19, 0, 0),
#                    'amount': 8971,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '8.6785312509793985924488879390992224216461181640625',
#                    'total': '77855.10385253618477285897370'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d31'),
#  'account_id': 323636,
#  'transactions': [{'date': datetime.datetime(2013, 4, 9, 0, 0),
#                    'amount': 9182,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '72.834658065571375118452124297618865966796875',
#                    'total': '668767.8303580763663376274053'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d32'),
#  'account_id': 702610,
#  'transactions': [{'date': datetime.datetime(2016, 2, 11, 0, 0),
#                    'amount': 9642,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '47.11246082442469429452103213407099246978759765625',
#                    'total': '454258.3472691029023877717918'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161d33'),
#  'account_id': 472963,
# ...
#                    'price': '22.500065355511662090748359332792460918426513671875',
#                    'total': '197438.0734946148348463168531'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816235a'),
#  'account_id': 935353,
#  'transactions': [{'date': datetime.datetime(2016, 1, 19, 0, 0),
#                    'amount': 8765,
#                    'transaction_code': 'buy',
#                    'symbol': 'znga',
#                    'price': '2.3002549250578407935563518549315631389617919921875',
#                    'total': '20161.73441813197455552142401'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816235b'),
#  'account_id': 172950,
#  'transactions': [{'date': datetime.datetime(2008, 9, 26, 0, 0),
#                    'amount': 7368,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '39.523301770490462558882427401840686798095703125',
#                    'total': '291207.6874449737281338457251'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816235c'),
#  'account_id': 453480,
#  'transactions': [{'date': datetime.datetime(2013, 12, 30, 0, 0),
#                    'amount': 8523,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '54.086631468945455480934469960629940032958984375',
#                    'total': '460980.3600098221170640044875'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816235d'),
#  'account_id': 844838,
#  'transactions': [{'date': datetime.datetime(2015, 3, 20, 0, 0),
#                    'amount': 7172,
#                    'transaction_code': 'buy',
#                    'symbol': 'znga',
#                    'price': '2.66474419985107235930854585603810846805572509765625',
#                    'total': '19111.54540133189096096089088'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816235e'),
#  'account_id': 576395,
#  'transactions': [{'date': datetime.datetime(2011, 5, 24, 0, 0),
#                    'amount': 8413,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '37.109273318141987374474410898983478546142578125',
#                    'total': '312200.3164255285397814532189'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162360'),
#  'account_id': 683382,
#  'transactions': [{'date': datetime.datetime(2016, 1, 4, 0, 0),
#                    'amount': 7942,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '28.700858264703288824648552690632641315460205078125',
#                    'total': '227942.2163382735198453588055'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162361'),
#  'account_id': 880595,
#  'transactions': [{'date': datetime.datetime(2016, 1, 4, 0, 0),
#                    'amount': 7969,
#                    'transaction_code': 'buy',
#                    'symbol': 'csco',
#                    'price': '24.621665227357862448798186960630118846893310546875',
#                    'total': '196210.0501968148058544727519'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162362'),
#  'account_id': 384995,
#  'transactions': [{'date': datetime.datetime(2008, 12, 29, 0, 0),
#                    'amount': 9786,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '4.2828083226221966839375454583205282688140869140625',
#                    'total': '41911.56224518081674901281986'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162363'),
#  'account_id': 611425,
#  'transactions': [{'date': datetime.datetime(2013, 5, 22, 0, 0),
#                    'amount': 9251,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '13.6129541169786563159505021758377552032470703125',
#                    'total': '125933.4385361695495788580956'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162364'),
#  'account_id': 943953,
#  'transactions': [{'date': datetime.datetime(2016, 12, 16, 0, 0),
#                    'amount': 9528,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '799.8477517188026695293956436216831207275390625',
#                    'total': '7620949.378376751835276081692'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162365'),
#  'account_id': 233540,
#  'transactions': [{'date': datetime.datetime(2013, 3, 18, 0, 0),
#                    'amount': 7938,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '2.583745012081924752322947824723087251186370849609375',
#                    'total': '20509.76790590631868393955983'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162366'),
#  'account_id': 578645,
#  'transactions': [{'date': datetime.datetime(2009, 5, 4, 0, 0),
#                    'amount': 7930,
#                    'transaction_code': 'buy',
#                    'symbol': 'amzn',
#                    'price': '81.0135500854502055290140560828149318695068359375',
#                    'total': '642437.4521776201298450814647'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162367'),
#  'account_id': 600800,
#  'transactions': [{'date': datetime.datetime(2016, 8, 15, 0, 0),
#                    'amount': 9034,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '87.048319529396138705124030821025371551513671875',
#                    'total': '786394.5186285647170620904944'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162368'),
#  'account_id': 784910,
#  'transactions': [{'date': datetime.datetime(2016, 6, 29, 0, 0),
#                    'amount': 9080,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '25.783363821759774481279237079434096813201904296875',
#                    'total': '234112.9435015787522900154727'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162369'),
#  'account_id': 134905,
#  'transactions': [{'date': datetime.datetime(2016, 8, 16, 0, 0),
#                    'amount': 7316,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '77.987737410976109231341979466378688812255859375',
#                    'total': '570558.2868987012151364979218'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816236a'),
#  'account_id': 617210,
#  'transactions': [{'date': datetime.datetime(2016, 6, 27, 0, 0),
#                    'amount': 9269,
#                    'transaction_code': 'buy',
#                    'symbol': 'aapl',
#                    'price': '90.4129130655846466879665968008339405059814453125',
#                    'total': '838037.2912049040901507623857'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816236b'),
#  'account_id': 981821,
#  'transactions': [{'date': datetime.datetime(2009, 8, 28, 0, 0),
#                    'amount': 8310,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '12.99053125575102995981069398112595081329345703125',
#                    'total': '107951.3147352910589660268670'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816236c'),
#  'account_id': 994208,
#  'transactions': [{'date': datetime.datetime(2007, 12, 10, 0, 0),
#                    'amount': 8434,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '48.18180781387072642019120394252240657806396484375',
#                    'total': '406365.3671021857066278926141'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816236d'),
#  'account_id': 223693,
#  'transactions': [{'date': datetime.datetime(2003, 1, 30, 0, 0),
#                    'amount': 7378,
#                    'transaction_code': 'buy',
#                    'symbol': 'intc',
#                    'price': '12.857656384720588249592765350826084613800048828125',
#                    'total': '94863.78880646850010549542276'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816236e'),
#  'account_id': 222581,
#  'transactions': [{'date': datetime.datetime(2015, 9, 11, 0, 0),
#                    'amount': 7125,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '99.26160242005352074556867592036724090576171875',
#                    'total': '707238.9172428813353121768159'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816236f'),
#  'account_id': 222061,
#  'transactions': [{'date': datetime.datetime(2014, 7, 23, 0, 0),
#                    'amount': 7611,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '594.8277777547885989406495355069637298583984375',
#                    'total': '4527234.216491696026537283615'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162370'),
#  'account_id': 129968,
#  'transactions': [{'date': datetime.datetime(2005, 3, 1, 0, 0),
#                    'amount': 8856,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.268039210782124115439728484489023685455322265625',
#                    'total': '188349.7552506864911663342355'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162372'),
#  'account_id': 896364,
#  'transactions': [{'date': datetime.datetime(2011, 12, 15, 0, 0),
#                    'amount': 8714,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '26.4338252840967697920859791338443756103515625',
#                    'total': '230344.3535256192519682372222'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162373'),
#  'account_id': 867364,
#  'transactions': [{'date': datetime.datetime(2015, 5, 27, 0, 0),
#                    'amount': 7911,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '44.60378149283332760433040675707161426544189453125',
#                    'total': '352860.5153898044546778578479'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162374'),
#  'account_id': 327916,
#  'transactions': [{'date': datetime.datetime(2011, 8, 10, 0, 0),
#                    'amount': 9146,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '23.014658445013015608537898515351116657257080078125',
#                    'total': '210492.0661380890407556876198'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162375'),
#  'account_id': 350748,
#  'transactions': [{'date': datetime.datetime(2014, 11, 13, 0, 0),
#                    'amount': 7447,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '62.7689504962926747566598351113498210906982421875',
#                    'total': '467440.3743458915489128457921'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162376'),
#  'account_id': 95914,
#  'transactions': [{'date': datetime.datetime(2016, 6, 9, 0, 0),
#                    'amount': 8873,
#                    'transaction_code': 'buy',
#                    'symbol': 'znga',
#                    'price': '2.590986992701223012858235961175523698329925537109375',
#                    'total': '22989.82758623795179309112768'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162377'),
#  'account_id': 632705,
#  'transactions': [{'date': datetime.datetime(2013, 4, 5, 0, 0),
#                    'amount': 8181,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '40.865554839656653030033339746296405792236328125',
#                    'total': '334321.1041432310784387027525'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162378'),
#  'account_id': 635650,
#  'transactions': [{'date': datetime.datetime(2007, 2, 27, 0, 0),
#                    'amount': 7291,
#                    'transaction_code': 'buy',
#                    'symbol': 'nvda',
#                    'price': '19.455429353751188870091937133111059665679931640625',
#                    'total': '141849.5354181999180518403136'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162379'),
#  'account_id': 206062,
#  'transactions': [{'date': datetime.datetime(2007, 2, 8, 0, 0),
#                    'amount': 8308,
#                    'transaction_code': 'buy',
#                    'symbol': 'crm',
#                    'price': '11.8237386950172531641101159038953483104705810546875',
#                    'total': '98231.62107820333928742684293'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816237a'),
#  'account_id': 593963,
#  'transactions': [{'date': datetime.datetime(2014, 9, 4, 0, 0),
#                    'amount': 8727,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '74.9349728236981462714538793079555034637451171875',
#                    'total': '653957.5078324137225109780047'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816237b'),
#  'account_id': 384335,
#  'transactions': [{'date': datetime.datetime(2014, 3, 14, 0, 0),
#                    'amount': 9374,
#                    'transaction_code': 'buy',
#                    'symbol': 'fb',
#                    'price': '68.826991994099358862513327039778232574462890625',
#                    'total': '645184.2229526873899771999277'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816237d'),
#  'account_id': 317449,
#  'transactions': [{'date': datetime.datetime(2015, 1, 2, 0, 0),
#                    'amount': 7970,
#                    'transaction_code': 'buy',
#                    'symbol': 'fb',
#                    'price': '77.934632514127571312201325781643390655517578125',
#                    'total': '621139.0211375967433582445665'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816237e'),
#  'account_id': 704067,
#  'transactions': [{'date': datetime.datetime(2016, 12, 8, 0, 0),
#                    'amount': 9441,
#                    'transaction_code': 'buy',
#                    'symbol': 'fb',
#                    'price': '117.7118395150060194964680704288184642791748046875',
#                    'total': '1111317.476861171830066155053'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee5816237f'),
#  'account_id': 719393,
#  'transactions': [{'date': datetime.datetime(2008, 2, 15, 0, 0),
#                    'amount': 9510,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '34.27373350295783183128150994889438152313232421875',
#                    'total': '325943.2056131289807154871596'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162380'),
#  'account_id': 131371,
#  'transactions': [{'date': datetime.datetime(2005, 3, 11, 0, 0),
#                    'amount': 8912,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.09688909797767308873517322354018688201904296875',
#                    'total': '188015.4756411770225668078638'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162382'),
#  'account_id': 744220,
#  'transactions': [{'date': datetime.datetime(2007, 5, 29, 0, 0),
#                    'amount': 8104,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '25.819719406908884451468111365102231502532958984375',
#                    'total': '209243.0060735895995946975745'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162383'),
#  'account_id': 996624,
#  'transactions': [{'date': datetime.datetime(2010, 5, 26, 0, 0),
#                    'amount': 9255,
#                    'transaction_code': 'buy',
#                    'symbol': 'amd',
#                    'price': '8.1953676171718985443703786586411297321319580078125',
#                    'total': '75848.12729692592102814785449'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162384'),
#  'account_id': 491353,
#  'transactions': [{'date': datetime.datetime(2014, 8, 25, 0, 0),
#                    'amount': 9819,
#                    'transaction_code': 'buy',
#                    'symbol': 'goog',
#                    'price': '583.962056291184808287653140723705291748046875',
#                    'total': '5733923.430723143632576466189'}]}
# {'_id': ObjectId('5ca4bbc1a2dd94ee58162385'),
#  'account_id': 481754,
#  'transactions': [{'date': datetime.datetime(2015, 1, 23, 0, 0),
#                    'amount': 9988,
#                    'transaction_code': 'buy',
#                    'symbol': 'fb',
#                    'price': '78.0533721087617351486187544651329517364501953125',
#                    'total': '779597.0806223122106644041196'}]}

# %%
# Count
db.transactions.find(
                        # query
                        {
                        'transactions':{
                                        '$elemMatch':{
                                                        'date':{'$gt':datetime(2003,1,1)},
                                                        'amount':{'$gt':7000},
                                                        'transaction_code':'buy'
                                                        }
                                        }
                        },
                        # project
                        {
                            'transactions.$':1,
                            'account_id':1
                        }
).count()
# Out:
# /home/avadmin/.local/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   app.launch_new_instance()
# 1620

# %% [markdown]
# ----
# ### Exercise 1 -
#
# How many documents contain at least one transaction with where 'symbol' was either 'sap' or 'msft' and 'amount' was more than 8000.
#
# ---

# %% [markdown]
# ----
# ### Exercise 2 -
#
# How many documents contain at least one transaction where 'symbol' is neither 'goog' nor 'fb' and 'amount' is more than 9000.
#
# ---
