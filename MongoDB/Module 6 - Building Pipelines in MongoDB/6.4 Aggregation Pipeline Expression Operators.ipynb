# %% [markdown]
# # Aggregation Pipeline Expression Operators
#
# ----
#
# - Expressions are the queries performed on a field. A sample expression object :-
#
# > - `{ <field1>: <expression1>, ... }`
#
# > - `'$project':{'ID':'$enrollee_id'}`
#
# - Expression operators are available to construct expressions for use in the aggregation pipeline stages.
#
#
# - In general, these expression operators take an array of arguments.
#
# > `{ <operator>: [ <argument1>, <argument2> ... ] }`
#
#
# - Expression operators - Arithmetic, Date, String, etc.
#
#
# - This lets us derive new fields from existing fields and pass on to next stage of pipeline.
#
# - [Aggregation Pipeline Expression operators](https://docs.mongodb.com/manual/reference/operator/aggregation/#aggregation-pipeline-operators)

# %% [markdown]
# ---
# ### Connecting to MongoDB using Pymongo
# ----

# %%
# Importing the required libraries
import pymongo
import pprint as pp

pp.sorted = lambda x, key=None: x

# %%
# Connect to local server
client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
# Using training dataset
db = client.training

# %%
# Sample document
pp.pprint(
    db.hr.find_one()
)
# Out:
# {'_id': ObjectId('60bc95fb12d1778df87722e2'),
#  'enrollee_id': 23798,
#  'gender': 'Male',
#  'date_of_enrollment': datetime.datetime(2016, 8, 4, 8, 4, 14, 780000),
#  'city': {'name': 'city_149', 'development_index': 0.689},
#  'education': {'level': 'Graduate', 'discipline': 'STEM'},
#  'experience': {'years': 3,
#                 'company_type': 'Pvt Ltd',
#                 'last_new_job': 1,
#                 'relevent_experience': 1},
#  'training_hours': 106}

# %% [markdown]
# ---
# ----
# ### [Arithmetic Expression Operators](https://docs.mongodb.com/manual/reference/operator/aggregation/#arithmetic-expression-operators)
#
# Arithmetic expressions perform mathematic operations on numbers.
#
# ----
#
# For example, let's say we need to look at `training_hours` after subtracting 3 hours from it for those documents where `education.discipline` is `STEM`.
#
# We will need to use [$subtract](https://docs.mongodb.com/manual/reference/operator/aggregation/subtract/#mongodb-expression-exp.-subtract) operator here.
#
# ---

# %%
# Use of aggregation operators

result = db.hr.aggregate(
        # Pipeline
        [
            # Stage 1
            {
                '$match':{'education.discipline':'STEM'}
            },
            # Stage 2
            {
                '$project':{
                                '_id':0,
                                'Actual_tranining_hours': '$training_hours',
                                'Modified_training_hours': {'$subtract': ['$training_hours', 3]}
                }
            }
        ])

# Print result
for doc in result:
    pp.pprint(doc)
# Out:
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 69, 'Modified_training_hours': 66}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 88, 'Modified_training_hours': 85}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 85, 'Modified_training_hours': 82}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 45, 'Modified_training_hours': 42}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 41, 'Modified_training_hours': 38}
# {'Actual_tranining_hours': 298, 'Modified_training_hours': 295}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 53, 'Modified_training_hours': 50}
# {'Actual_tranining_hours': 39, 'Modified_training_hours': 36}
# {'Actual_tranining_hours': 55, 'Modified_training_hours': 52}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 3, 'Modified_training_hours': 0}
# {'Actual_tranining_hours': 68, 'Modified_training_hours': 65}
# {'Actual_tranining_hours': 262, 'Modified_training_hours': 259}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 79, 'Modified_training_hours': 76}
# {'Actual_tranining_hours': 98, 'Modified_training_hours': 95}
# {'Actual_tranining_hours': 65, 'Modified_training_hours': 62}
# {'Actual_tranining_hours': 61, 'Modified_training_hours': 58}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 170, 'Modified_training_hours': 167}
# {'Actual_tranining_hours': 68, 'Modified_training_hours': 65}
# {'Actual_tranining_hours': 132, 'Modified_training_hours': 129}
# {'Actual_tranining_hours': 145, 'Modified_training_hours': 142}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 37, 'Modified_training_hours': 34}
# {'Actual_tranining_hours': 86, 'Modified_training_hours': 83}
# {'Actual_tranining_hours': 96, 'Modified_training_hours': 93}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 37, 'Modified_training_hours': 34}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 101, 'Modified_training_hours': 98}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 102, 'Modified_training_hours': 99}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 90, 'Modified_training_hours': 87}
# {'Actual_tranining_hours': 30, 'Modified_training_hours': 27}
# {'Actual_tranining_hours': 164, 'Modified_training_hours': 161}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 32, 'Modified_training_hours': 29}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 72, 'Modified_training_hours': 69}
# {'Actual_tranining_hours': 15, 'Modified_training_hours': 12}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 79, 'Modified_training_hours': 76}
# {'Actual_tranining_hours': 80, 'Modified_training_hours': 77}
# {'Actual_tranining_hours': 31, 'Modified_training_hours': 28}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 86, 'Modified_training_hours': 83}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 200, 'Modified_training_hours': 197}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 83, 'Modified_training_hours': 80}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 43, 'Modified_training_hours': 40}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 67, 'Modified_training_hours': 64}
# {'Actual_tranining_hours': 29, 'Modified_training_hours': 26}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 72, 'Modified_training_hours': 69}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 39, 'Modified_training_hours': 36}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 88, 'Modified_training_hours': 85}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 32, 'Modified_training_hours': 29}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 75, 'Modified_training_hours': 72}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 68, 'Modified_training_hours': 65}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 30, 'Modified_training_hours': 27}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 19, 'Modified_training_hours': 16}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 92, 'Modified_training_hours': 89}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 36, 'Modified_training_hours': 33}
# {'Actual_tranining_hours': 94, 'Modified_training_hours': 91}
# {'Actual_tranining_hours': 184, 'Modified_training_hours': 181}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 45, 'Modified_training_hours': 42}
# {'Actual_tranining_hours': 258, 'Modified_training_hours': 255}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 30, 'Modified_training_hours': 27}
# {'Actual_tranining_hours': 270, 'Modified_training_hours': 267}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 92, 'Modified_training_hours': 89}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 102, 'Modified_training_hours': 99}
# {'Actual_tranining_hours': 45, 'Modified_training_hours': 42}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 88, 'Modified_training_hours': 85}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 45, 'Modified_training_hours': 42}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 61, 'Modified_training_hours': 58}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 31, 'Modified_training_hours': 28}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 53, 'Modified_training_hours': 50}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 55, 'Modified_training_hours': 52}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 15, 'Modified_training_hours': 12}
# {'Actual_tranining_hours': 59, 'Modified_training_hours': 56}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 82, 'Modified_training_hours': 79}
# {'Actual_tranining_hours': 72, 'Modified_training_hours': 69}
# {'Actual_tranining_hours': 90, 'Modified_training_hours': 87}
# {'Actual_tranining_hours': 86, 'Modified_training_hours': 83}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 54, 'Modified_training_hours': 51}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 84, 'Modified_training_hours': 81}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 54, 'Modified_training_hours': 51}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 202, 'Modified_training_hours': 199}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 52, 'Modified_training_hours': 49}
# {'Actual_tranining_hours': 15, 'Modified_training_hours': 12}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 100, 'Modified_training_hours': 97}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 15, 'Modified_training_hours': 12}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 27, 'Modified_training_hours': 24}
# {'Actual_tranining_hours': 132, 'Modified_training_hours': 129}
# {'Actual_tranining_hours': 29, 'Modified_training_hours': 26}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 92, 'Modified_training_hours': 89}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 102, 'Modified_training_hours': 99}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 2, 'Modified_training_hours': -1}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 38, 'Modified_training_hours': 35}
# {'Actual_tranining_hours': 27, 'Modified_training_hours': 24}
# {'Actual_tranining_hours': 60, 'Modified_training_hours': 57}
# {'Actual_tranining_hours': 32, 'Modified_training_hours': 29}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 84, 'Modified_training_hours': 81}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 54, 'Modified_training_hours': 51}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 5, 'Modified_training_hours': 2}
# {'Actual_tranining_hours': 88, 'Modified_training_hours': 85}
# {'Actual_tranining_hours': 56, 'Modified_training_hours': 53}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 330, 'Modified_training_hours': 327}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 69, 'Modified_training_hours': 66}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 72, 'Modified_training_hours': 69}
# {'Actual_tranining_hours': 101, 'Modified_training_hours': 98}
# {'Actual_tranining_hours': 5, 'Modified_training_hours': 2}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 56, 'Modified_training_hours': 53}
# {'Actual_tranining_hours': 320, 'Modified_training_hours': 317}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 74, 'Modified_training_hours': 71}
# {'Actual_tranining_hours': 68, 'Modified_training_hours': 65}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 73, 'Modified_training_hours': 70}
# {'Actual_tranining_hours': 59, 'Modified_training_hours': 56}
# {'Actual_tranining_hours': 30, 'Modified_training_hours': 27}
# {'Actual_tranining_hours': 60, 'Modified_training_hours': 57}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 40, 'Modified_training_hours': 37}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 74, 'Modified_training_hours': 71}
# {'Actual_tranining_hours': 43, 'Modified_training_hours': 40}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 3, 'Modified_training_hours': 0}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 92, 'Modified_training_hours': 89}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 87, 'Modified_training_hours': 84}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 90, 'Modified_training_hours': 87}
# {'Actual_tranining_hours': 330, 'Modified_training_hours': 327}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 60, 'Modified_training_hours': 57}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 55, 'Modified_training_hours': 52}
# {'Actual_tranining_hours': 85, 'Modified_training_hours': 82}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 69, 'Modified_training_hours': 66}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 40, 'Modified_training_hours': 37}
# {'Actual_tranining_hours': 282, 'Modified_training_hours': 279}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 54, 'Modified_training_hours': 51}
# {'Actual_tranining_hours': 89, 'Modified_training_hours': 86}
# {'Actual_tranining_hours': 5, 'Modified_training_hours': 2}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 91, 'Modified_training_hours': 88}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 80, 'Modified_training_hours': 77}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 69, 'Modified_training_hours': 66}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 2, 'Modified_training_hours': -1}
# {'Actual_tranining_hours': 19, 'Modified_training_hours': 16}
# {'Actual_tranining_hours': 248, 'Modified_training_hours': 245}
# {'Actual_tranining_hours': 153, 'Modified_training_hours': 150}
# {'Actual_tranining_hours': 147, 'Modified_training_hours': 144}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 94, 'Modified_training_hours': 91}
# {'Actual_tranining_hours': 45, 'Modified_training_hours': 42}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 144, 'Modified_training_hours': 141}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 70, 'Modified_training_hours': 67}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 85, 'Modified_training_hours': 82}
# {'Actual_tranining_hours': 37, 'Modified_training_hours': 34}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 2, 'Modified_training_hours': -1}
# {'Actual_tranining_hours': 52, 'Modified_training_hours': 49}
# {'Actual_tranining_hours': 292, 'Modified_training_hours': 289}
# {'Actual_tranining_hours': 56, 'Modified_training_hours': 53}
# {'Actual_tranining_hours': 61, 'Modified_training_hours': 58}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 81, 'Modified_training_hours': 78}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 43, 'Modified_training_hours': 40}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 41, 'Modified_training_hours': 38}
# {'Actual_tranining_hours': 68, 'Modified_training_hours': 65}
# {'Actual_tranining_hours': 72, 'Modified_training_hours': 69}
# {'Actual_tranining_hours': 53, 'Modified_training_hours': 50}
# {'Actual_tranining_hours': 81, 'Modified_training_hours': 78}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 176, 'Modified_training_hours': 173}
# {'Actual_tranining_hours': 78, 'Modified_training_hours': 75}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 38, 'Modified_training_hours': 35}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 40, 'Modified_training_hours': 37}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 30, 'Modified_training_hours': 27}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 102, 'Modified_training_hours': 99}
# {'Actual_tranining_hours': 27, 'Modified_training_hours': 24}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 32, 'Modified_training_hours': 29}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 63, 'Modified_training_hours': 60}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 153, 'Modified_training_hours': 150}
# {'Actual_tranining_hours': 280, 'Modified_training_hours': 277}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 80, 'Modified_training_hours': 77}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 210, 'Modified_training_hours': 207}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 294, 'Modified_training_hours': 291}
# {'Actual_tranining_hours': 41, 'Modified_training_hours': 38}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 155, 'Modified_training_hours': 152}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 86, 'Modified_training_hours': 83}
# {'Actual_tranining_hours': 77, 'Modified_training_hours': 74}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 15, 'Modified_training_hours': 12}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 86, 'Modified_training_hours': 83}
# {'Actual_tranining_hours': 92, 'Modified_training_hours': 89}
# {'Actual_tranining_hours': 88, 'Modified_training_hours': 85}
# {'Actual_tranining_hours': 316, 'Modified_training_hours': 313}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 72, 'Modified_training_hours': 69}
# {'Actual_tranining_hours': 62, 'Modified_training_hours': 59}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 56, 'Modified_training_hours': 53}
# {'Actual_tranining_hours': 97, 'Modified_training_hours': 94}
# {'Actual_tranining_hours': 19, 'Modified_training_hours': 16}
# {'Actual_tranining_hours': 224, 'Modified_training_hours': 221}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 19, 'Modified_training_hours': 16}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 38, 'Modified_training_hours': 35}
# {'Actual_tranining_hours': 180, 'Modified_training_hours': 177}
# {'Actual_tranining_hours': 19, 'Modified_training_hours': 16}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 236, 'Modified_training_hours': 233}
# {'Actual_tranining_hours': 80, 'Modified_training_hours': 77}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 90, 'Modified_training_hours': 87}
# {'Actual_tranining_hours': 74, 'Modified_training_hours': 71}
# {'Actual_tranining_hours': 125, 'Modified_training_hours': 122}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 58, 'Modified_training_hours': 55}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 102, 'Modified_training_hours': 99}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 92, 'Modified_training_hours': 89}
# {'Actual_tranining_hours': 73, 'Modified_training_hours': 70}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 96, 'Modified_training_hours': 93}
# {'Actual_tranining_hours': 38, 'Modified_training_hours': 35}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 72, 'Modified_training_hours': 69}
# {'Actual_tranining_hours': 87, 'Modified_training_hours': 84}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 3, 'Modified_training_hours': 0}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 256, 'Modified_training_hours': 253}
# {'Actual_tranining_hours': 55, 'Modified_training_hours': 52}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 69, 'Modified_training_hours': 66}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 30, 'Modified_training_hours': 27}
# {'Actual_tranining_hours': 30, 'Modified_training_hours': 27}
# {'Actual_tranining_hours': 71, 'Modified_training_hours': 68}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 326, 'Modified_training_hours': 323}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 76, 'Modified_training_hours': 73}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 53, 'Modified_training_hours': 50}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 79, 'Modified_training_hours': 76}
# {'Actual_tranining_hours': 1, 'Modified_training_hours': -2}
# {'Actual_tranining_hours': 37, 'Modified_training_hours': 34}
# {'Actual_tranining_hours': 102, 'Modified_training_hours': 99}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 88, 'Modified_training_hours': 85}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 62, 'Modified_training_hours': 59}
# {'Actual_tranining_hours': 238, 'Modified_training_hours': 235}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 32, 'Modified_training_hours': 29}
# {'Actual_tranining_hours': 83, 'Modified_training_hours': 80}
# {'Actual_tranining_hours': 19, 'Modified_training_hours': 16}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 101, 'Modified_training_hours': 98}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 270, 'Modified_training_hours': 267}
# {'Actual_tranining_hours': 91, 'Modified_training_hours': 88}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 97, 'Modified_training_hours': 94}
# {'Actual_tranining_hours': 101, 'Modified_training_hours': 98}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 79, 'Modified_training_hours': 76}
# {'Actual_tranining_hours': 59, 'Modified_training_hours': 56}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 90, 'Modified_training_hours': 87}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 75, 'Modified_training_hours': 72}
# {'Actual_tranining_hours': 40, 'Modified_training_hours': 37}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 101, 'Modified_training_hours': 98}
# {'Actual_tranining_hours': 43, 'Modified_training_hours': 40}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 55, 'Modified_training_hours': 52}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 58, 'Modified_training_hours': 55}
# {'Actual_tranining_hours': 60, 'Modified_training_hours': 57}
# {'Actual_tranining_hours': 52, 'Modified_training_hours': 49}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 202, 'Modified_training_hours': 199}
# {'Actual_tranining_hours': 102, 'Modified_training_hours': 99}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 55, 'Modified_training_hours': 52}
# {'Actual_tranining_hours': 32, 'Modified_training_hours': 29}
# {'Actual_tranining_hours': 86, 'Modified_training_hours': 83}
# {'Actual_tranining_hours': 282, 'Modified_training_hours': 279}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 40, 'Modified_training_hours': 37}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 52, 'Modified_training_hours': 49}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 310, 'Modified_training_hours': 307}
# {'Actual_tranining_hours': 236, 'Modified_training_hours': 233}
# {'Actual_tranining_hours': 288, 'Modified_training_hours': 285}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 29, 'Modified_training_hours': 26}
# {'Actual_tranining_hours': 200, 'Modified_training_hours': 197}
# {'Actual_tranining_hours': 256, 'Modified_training_hours': 253}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 87, 'Modified_training_hours': 84}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 94, 'Modified_training_hours': 91}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 71, 'Modified_training_hours': 68}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 63, 'Modified_training_hours': 60}
# {'Actual_tranining_hours': 90, 'Modified_training_hours': 87}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 40, 'Modified_training_hours': 37}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 71, 'Modified_training_hours': 68}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 87, 'Modified_training_hours': 84}
# {'Actual_tranining_hours': 81, 'Modified_training_hours': 78}
# {'Actual_tranining_hours': 37, 'Modified_training_hours': 34}
# {'Actual_tranining_hours': 76, 'Modified_training_hours': 73}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 74, 'Modified_training_hours': 71}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 240, 'Modified_training_hours': 237}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 29, 'Modified_training_hours': 26}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 119, 'Modified_training_hours': 116}
# {'Actual_tranining_hours': 31, 'Modified_training_hours': 28}
# {'Actual_tranining_hours': 89, 'Modified_training_hours': 86}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 3, 'Modified_training_hours': 0}
# {'Actual_tranining_hours': 58, 'Modified_training_hours': 55}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 68, 'Modified_training_hours': 65}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 40, 'Modified_training_hours': 37}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 139, 'Modified_training_hours': 136}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 266, 'Modified_training_hours': 263}
# {'Actual_tranining_hours': 38, 'Modified_training_hours': 35}
# {'Actual_tranining_hours': 74, 'Modified_training_hours': 71}
# {'Actual_tranining_hours': 59, 'Modified_training_hours': 56}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 39, 'Modified_training_hours': 36}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 220, 'Modified_training_hours': 217}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 5, 'Modified_training_hours': 2}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 29, 'Modified_training_hours': 26}
# {'Actual_tranining_hours': 39, 'Modified_training_hours': 36}
# {'Actual_tranining_hours': 27, 'Modified_training_hours': 24}
# {'Actual_tranining_hours': 60, 'Modified_training_hours': 57}
# {'Actual_tranining_hours': 40, 'Modified_training_hours': 37}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 172, 'Modified_training_hours': 169}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 133, 'Modified_training_hours': 130}
# {'Actual_tranining_hours': 90, 'Modified_training_hours': 87}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 82, 'Modified_training_hours': 79}
# {'Actual_tranining_hours': 58, 'Modified_training_hours': 55}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 85, 'Modified_training_hours': 82}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 102, 'Modified_training_hours': 99}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 88, 'Modified_training_hours': 85}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 284, 'Modified_training_hours': 281}
# {'Actual_tranining_hours': 3, 'Modified_training_hours': 0}
# {'Actual_tranining_hours': 73, 'Modified_training_hours': 70}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 40, 'Modified_training_hours': 37}
# {'Actual_tranining_hours': 92, 'Modified_training_hours': 89}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 53, 'Modified_training_hours': 50}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 272, 'Modified_training_hours': 269}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 70, 'Modified_training_hours': 67}
# {'Actual_tranining_hours': 312, 'Modified_training_hours': 309}
# {'Actual_tranining_hours': 306, 'Modified_training_hours': 303}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 100, 'Modified_training_hours': 97}
# {'Actual_tranining_hours': 27, 'Modified_training_hours': 24}
# {'Actual_tranining_hours': 55, 'Modified_training_hours': 52}
# {'Actual_tranining_hours': 31, 'Modified_training_hours': 28}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 54, 'Modified_training_hours': 51}
# {'Actual_tranining_hours': 41, 'Modified_training_hours': 38}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 69, 'Modified_training_hours': 66}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 72, 'Modified_training_hours': 69}
# {'Actual_tranining_hours': 52, 'Modified_training_hours': 49}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 31, 'Modified_training_hours': 28}
# {'Actual_tranining_hours': 96, 'Modified_training_hours': 93}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 172, 'Modified_training_hours': 169}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 79, 'Modified_training_hours': 76}
# {'Actual_tranining_hours': 38, 'Modified_training_hours': 35}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 37, 'Modified_training_hours': 34}
# {'Actual_tranining_hours': 216, 'Modified_training_hours': 213}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 31, 'Modified_training_hours': 28}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 39, 'Modified_training_hours': 36}
# {'Actual_tranining_hours': 147, 'Modified_training_hours': 144}
# ...
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 314, 'Modified_training_hours': 311}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 3, 'Modified_training_hours': 0}
# {'Actual_tranining_hours': 32, 'Modified_training_hours': 29}
# {'Actual_tranining_hours': 86, 'Modified_training_hours': 83}
# {'Actual_tranining_hours': 69, 'Modified_training_hours': 66}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 83, 'Modified_training_hours': 80}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 31, 'Modified_training_hours': 28}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 80, 'Modified_training_hours': 77}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 46, 'Modified_training_hours': 43}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 84, 'Modified_training_hours': 81}
# {'Actual_tranining_hours': 29, 'Modified_training_hours': 26}
# {'Actual_tranining_hours': 87, 'Modified_training_hours': 84}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 100, 'Modified_training_hours': 97}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 15, 'Modified_training_hours': 12}
# {'Actual_tranining_hours': 67, 'Modified_training_hours': 64}
# {'Actual_tranining_hours': 322, 'Modified_training_hours': 319}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 58, 'Modified_training_hours': 55}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 85, 'Modified_training_hours': 82}
# {'Actual_tranining_hours': 100, 'Modified_training_hours': 97}
# {'Actual_tranining_hours': 54, 'Modified_training_hours': 51}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 36, 'Modified_training_hours': 33}
# {'Actual_tranining_hours': 92, 'Modified_training_hours': 89}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 90, 'Modified_training_hours': 87}
# {'Actual_tranining_hours': 67, 'Modified_training_hours': 64}
# {'Actual_tranining_hours': 54, 'Modified_training_hours': 51}
# {'Actual_tranining_hours': 55, 'Modified_training_hours': 52}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 98, 'Modified_training_hours': 95}
# {'Actual_tranining_hours': 149, 'Modified_training_hours': 146}
# {'Actual_tranining_hours': 88, 'Modified_training_hours': 85}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 19, 'Modified_training_hours': 16}
# {'Actual_tranining_hours': 82, 'Modified_training_hours': 79}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 145, 'Modified_training_hours': 142}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 85, 'Modified_training_hours': 82}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 45, 'Modified_training_hours': 42}
# {'Actual_tranining_hours': 17, 'Modified_training_hours': 14}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 84, 'Modified_training_hours': 81}
# {'Actual_tranining_hours': 4, 'Modified_training_hours': 1}
# {'Actual_tranining_hours': 57, 'Modified_training_hours': 54}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 70, 'Modified_training_hours': 67}
# {'Actual_tranining_hours': 30, 'Modified_training_hours': 27}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 125, 'Modified_training_hours': 122}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 25, 'Modified_training_hours': 22}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 5, 'Modified_training_hours': 2}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 94, 'Modified_training_hours': 91}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 88, 'Modified_training_hours': 85}
# {'Actual_tranining_hours': 27, 'Modified_training_hours': 24}
# {'Actual_tranining_hours': 56, 'Modified_training_hours': 53}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 72, 'Modified_training_hours': 69}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 226, 'Modified_training_hours': 223}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 56, 'Modified_training_hours': 53}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 27, 'Modified_training_hours': 24}
# {'Actual_tranining_hours': 19, 'Modified_training_hours': 16}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 95, 'Modified_training_hours': 92}
# {'Actual_tranining_hours': 36, 'Modified_training_hours': 33}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 306, 'Modified_training_hours': 303}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 48, 'Modified_training_hours': 45}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 8, 'Modified_training_hours': 5}
# {'Actual_tranining_hours': 68, 'Modified_training_hours': 65}
# {'Actual_tranining_hours': 85, 'Modified_training_hours': 82}
# {'Actual_tranining_hours': 94, 'Modified_training_hours': 91}
# {'Actual_tranining_hours': 61, 'Modified_training_hours': 58}
# {'Actual_tranining_hours': 47, 'Modified_training_hours': 44}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 21, 'Modified_training_hours': 18}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 182, 'Modified_training_hours': 179}
# {'Actual_tranining_hours': 22, 'Modified_training_hours': 19}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 50, 'Modified_training_hours': 47}
# {'Actual_tranining_hours': 62, 'Modified_training_hours': 59}
# {'Actual_tranining_hours': 288, 'Modified_training_hours': 285}
# {'Actual_tranining_hours': 66, 'Modified_training_hours': 63}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 24, 'Modified_training_hours': 21}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 39, 'Modified_training_hours': 36}
# {'Actual_tranining_hours': 23, 'Modified_training_hours': 20}
# {'Actual_tranining_hours': 256, 'Modified_training_hours': 253}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 100, 'Modified_training_hours': 97}
# {'Actual_tranining_hours': 45, 'Modified_training_hours': 42}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 36, 'Modified_training_hours': 33}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 99, 'Modified_training_hours': 96}
# {'Actual_tranining_hours': 51, 'Modified_training_hours': 48}
# {'Actual_tranining_hours': 19, 'Modified_training_hours': 16}
# {'Actual_tranining_hours': 31, 'Modified_training_hours': 28}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 52, 'Modified_training_hours': 49}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 148, 'Modified_training_hours': 145}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 31, 'Modified_training_hours': 28}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 37, 'Modified_training_hours': 34}
# {'Actual_tranining_hours': 62, 'Modified_training_hours': 59}
# {'Actual_tranining_hours': 92, 'Modified_training_hours': 89}
# {'Actual_tranining_hours': 81, 'Modified_training_hours': 78}
# {'Actual_tranining_hours': 258, 'Modified_training_hours': 255}
# {'Actual_tranining_hours': 141, 'Modified_training_hours': 138}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 36, 'Modified_training_hours': 33}
# {'Actual_tranining_hours': 81, 'Modified_training_hours': 78}
# {'Actual_tranining_hours': 12, 'Modified_training_hours': 9}
# {'Actual_tranining_hours': 71, 'Modified_training_hours': 68}
# {'Actual_tranining_hours': 61, 'Modified_training_hours': 58}
# {'Actual_tranining_hours': 35, 'Modified_training_hours': 32}
# {'Actual_tranining_hours': 148, 'Modified_training_hours': 145}
# {'Actual_tranining_hours': 194, 'Modified_training_hours': 191}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 56, 'Modified_training_hours': 53}
# {'Actual_tranining_hours': 96, 'Modified_training_hours': 93}
# {'Actual_tranining_hours': 84, 'Modified_training_hours': 81}
# {'Actual_tranining_hours': 44, 'Modified_training_hours': 41}
# {'Actual_tranining_hours': 3, 'Modified_training_hours': 0}
# {'Actual_tranining_hours': 6, 'Modified_training_hours': 3}
# {'Actual_tranining_hours': 26, 'Modified_training_hours': 23}
# {'Actual_tranining_hours': 33, 'Modified_training_hours': 30}
# {'Actual_tranining_hours': 34, 'Modified_training_hours': 31}
# {'Actual_tranining_hours': 102, 'Modified_training_hours': 99}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 37, 'Modified_training_hours': 34}
# {'Actual_tranining_hours': 95, 'Modified_training_hours': 92}
# {'Actual_tranining_hours': 20, 'Modified_training_hours': 17}
# {'Actual_tranining_hours': 39, 'Modified_training_hours': 36}
# {'Actual_tranining_hours': 224, 'Modified_training_hours': 221}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 90, 'Modified_training_hours': 87}
# {'Actual_tranining_hours': 11, 'Modified_training_hours': 8}
# {'Actual_tranining_hours': 100, 'Modified_training_hours': 97}
# {'Actual_tranining_hours': 41, 'Modified_training_hours': 38}
# {'Actual_tranining_hours': 96, 'Modified_training_hours': 93}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 10, 'Modified_training_hours': 7}
# {'Actual_tranining_hours': 84, 'Modified_training_hours': 81}
# {'Actual_tranining_hours': 78, 'Modified_training_hours': 75}
# {'Actual_tranining_hours': 16, 'Modified_training_hours': 13}
# {'Actual_tranining_hours': 58, 'Modified_training_hours': 55}
# {'Actual_tranining_hours': 9, 'Modified_training_hours': 6}
# {'Actual_tranining_hours': 67, 'Modified_training_hours': 64}
# {'Actual_tranining_hours': 28, 'Modified_training_hours': 25}
# {'Actual_tranining_hours': 98, 'Modified_training_hours': 95}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 54, 'Modified_training_hours': 51}
# {'Actual_tranining_hours': 83, 'Modified_training_hours': 80}
# {'Actual_tranining_hours': 7, 'Modified_training_hours': 4}
# {'Actual_tranining_hours': 288, 'Modified_training_hours': 285}
# {'Actual_tranining_hours': 64, 'Modified_training_hours': 61}
# {'Actual_tranining_hours': 54, 'Modified_training_hours': 51}
# {'Actual_tranining_hours': 13, 'Modified_training_hours': 10}
# {'Actual_tranining_hours': 14, 'Modified_training_hours': 11}
# {'Actual_tranining_hours': 32, 'Modified_training_hours': 29}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 42, 'Modified_training_hours': 39}
# {'Actual_tranining_hours': 71, 'Modified_training_hours': 68}
# {'Actual_tranining_hours': 18, 'Modified_training_hours': 15}
# {'Actual_tranining_hours': 41, 'Modified_training_hours': 38}
# {'Actual_tranining_hours': 84, 'Modified_training_hours': 81}

# %% [markdown]
# ---
# **We can refer to these derived fields in the subsequent stages of pipeline.**
#
# For example, we only keep those documents from previous step where the Modified_training_hours is greater than 100 hours.
#
# ----

# %%
# Use of aggregation operators

result = db.hr.aggregate(
       
        # Pipeline
        [
            # Stage 1
            {
                '$match':{'education.discipline':'STEM'}
            },
            
            # Stage 2
            {
                '$project':{
                                '_id':0,
                                'Actual_tranining_hours': '$training_hours',
                                'Modified_training_hours': {'$subtract': ['$training_hours', 3]}
                            }
            },
            
            # Stage 3
            {
                '$match':{'Modified_training_hours':{'$gt':100}}
            }
        ])

# Print result
for doc in result:
    pp.pprint(doc)
# Out:
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 298, 'Modified_training_hours': 295}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 262, 'Modified_training_hours': 259}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 170, 'Modified_training_hours': 167}
# {'Actual_tranining_hours': 132, 'Modified_training_hours': 129}
# {'Actual_tranining_hours': 145, 'Modified_training_hours': 142}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 164, 'Modified_training_hours': 161}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 200, 'Modified_training_hours': 197}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 184, 'Modified_training_hours': 181}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 258, 'Modified_training_hours': 255}
# {'Actual_tranining_hours': 270, 'Modified_training_hours': 267}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 202, 'Modified_training_hours': 199}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 132, 'Modified_training_hours': 129}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 330, 'Modified_training_hours': 327}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 320, 'Modified_training_hours': 317}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 330, 'Modified_training_hours': 327}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 282, 'Modified_training_hours': 279}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 248, 'Modified_training_hours': 245}
# {'Actual_tranining_hours': 153, 'Modified_training_hours': 150}
# {'Actual_tranining_hours': 147, 'Modified_training_hours': 144}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 144, 'Modified_training_hours': 141}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 292, 'Modified_training_hours': 289}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 176, 'Modified_training_hours': 173}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 153, 'Modified_training_hours': 150}
# {'Actual_tranining_hours': 280, 'Modified_training_hours': 277}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 210, 'Modified_training_hours': 207}
# {'Actual_tranining_hours': 294, 'Modified_training_hours': 291}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 155, 'Modified_training_hours': 152}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 316, 'Modified_training_hours': 313}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 224, 'Modified_training_hours': 221}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 180, 'Modified_training_hours': 177}
# {'Actual_tranining_hours': 236, 'Modified_training_hours': 233}
# {'Actual_tranining_hours': 125, 'Modified_training_hours': 122}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 256, 'Modified_training_hours': 253}
# {'Actual_tranining_hours': 326, 'Modified_training_hours': 323}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 238, 'Modified_training_hours': 235}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 270, 'Modified_training_hours': 267}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 202, 'Modified_training_hours': 199}
# {'Actual_tranining_hours': 282, 'Modified_training_hours': 279}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 310, 'Modified_training_hours': 307}
# {'Actual_tranining_hours': 236, 'Modified_training_hours': 233}
# {'Actual_tranining_hours': 288, 'Modified_training_hours': 285}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 200, 'Modified_training_hours': 197}
# {'Actual_tranining_hours': 256, 'Modified_training_hours': 253}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 240, 'Modified_training_hours': 237}
# {'Actual_tranining_hours': 119, 'Modified_training_hours': 116}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 139, 'Modified_training_hours': 136}
# {'Actual_tranining_hours': 266, 'Modified_training_hours': 263}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 220, 'Modified_training_hours': 217}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 172, 'Modified_training_hours': 169}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 133, 'Modified_training_hours': 130}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 284, 'Modified_training_hours': 281}
# {'Actual_tranining_hours': 272, 'Modified_training_hours': 269}
# {'Actual_tranining_hours': 312, 'Modified_training_hours': 309}
# {'Actual_tranining_hours': 306, 'Modified_training_hours': 303}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 172, 'Modified_training_hours': 169}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 216, 'Modified_training_hours': 213}
# {'Actual_tranining_hours': 147, 'Modified_training_hours': 144}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 180, 'Modified_training_hours': 177}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 332, 'Modified_training_hours': 329}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 310, 'Modified_training_hours': 307}
# {'Actual_tranining_hours': 144, 'Modified_training_hours': 141}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 290, 'Modified_training_hours': 287}
# {'Actual_tranining_hours': 120, 'Modified_training_hours': 117}
# {'Actual_tranining_hours': 121, 'Modified_training_hours': 118}
# {'Actual_tranining_hours': 180, 'Modified_training_hours': 177}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 328, 'Modified_training_hours': 325}
# {'Actual_tranining_hours': 147, 'Modified_training_hours': 144}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 120, 'Modified_training_hours': 117}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 290, 'Modified_training_hours': 287}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 190, 'Modified_training_hours': 187}
# {'Actual_tranining_hours': 170, 'Modified_training_hours': 167}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 200, 'Modified_training_hours': 197}
# {'Actual_tranining_hours': 292, 'Modified_training_hours': 289}
# {'Actual_tranining_hours': 268, 'Modified_training_hours': 265}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 278, 'Modified_training_hours': 275}
# {'Actual_tranining_hours': 336, 'Modified_training_hours': 333}
# {'Actual_tranining_hours': 316, 'Modified_training_hours': 313}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 322, 'Modified_training_hours': 319}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 244, 'Modified_training_hours': 241}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 324, 'Modified_training_hours': 321}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 143, 'Modified_training_hours': 140}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 194, 'Modified_training_hours': 191}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 298, 'Modified_training_hours': 295}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 248, 'Modified_training_hours': 245}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 119, 'Modified_training_hours': 116}
# {'Actual_tranining_hours': 129, 'Modified_training_hours': 126}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 210, 'Modified_training_hours': 207}
# {'Actual_tranining_hours': 246, 'Modified_training_hours': 243}
# {'Actual_tranining_hours': 143, 'Modified_training_hours': 140}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 214, 'Modified_training_hours': 211}
# {'Actual_tranining_hours': 145, 'Modified_training_hours': 142}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 312, 'Modified_training_hours': 309}
# {'Actual_tranining_hours': 330, 'Modified_training_hours': 327}
# {'Actual_tranining_hours': 202, 'Modified_training_hours': 199}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 127, 'Modified_training_hours': 124}
# {'Actual_tranining_hours': 326, 'Modified_training_hours': 323}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 164, 'Modified_training_hours': 161}
# {'Actual_tranining_hours': 254, 'Modified_training_hours': 251}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 165, 'Modified_training_hours': 162}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 151, 'Modified_training_hours': 148}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 190, 'Modified_training_hours': 187}
# {'Actual_tranining_hours': 167, 'Modified_training_hours': 164}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 121, 'Modified_training_hours': 118}
# {'Actual_tranining_hours': 276, 'Modified_training_hours': 273}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 282, 'Modified_training_hours': 279}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 117, 'Modified_training_hours': 114}
# {'Actual_tranining_hours': 212, 'Modified_training_hours': 209}
# {'Actual_tranining_hours': 147, 'Modified_training_hours': 144}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 212, 'Modified_training_hours': 209}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 312, 'Modified_training_hours': 309}
# {'Actual_tranining_hours': 139, 'Modified_training_hours': 136}
# {'Actual_tranining_hours': 326, 'Modified_training_hours': 323}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 132, 'Modified_training_hours': 129}
# {'Actual_tranining_hours': 190, 'Modified_training_hours': 187}
# {'Actual_tranining_hours': 135, 'Modified_training_hours': 132}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 250, 'Modified_training_hours': 247}
# {'Actual_tranining_hours': 170, 'Modified_training_hours': 167}
# {'Actual_tranining_hours': 266, 'Modified_training_hours': 263}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 210, 'Modified_training_hours': 207}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 180, 'Modified_training_hours': 177}
# {'Actual_tranining_hours': 145, 'Modified_training_hours': 142}
# {'Actual_tranining_hours': 190, 'Modified_training_hours': 187}
# {'Actual_tranining_hours': 135, 'Modified_training_hours': 132}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 132, 'Modified_training_hours': 129}
# {'Actual_tranining_hours': 200, 'Modified_training_hours': 197}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 127, 'Modified_training_hours': 124}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 155, 'Modified_training_hours': 152}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 214, 'Modified_training_hours': 211}
# {'Actual_tranining_hours': 248, 'Modified_training_hours': 245}
# {'Actual_tranining_hours': 210, 'Modified_training_hours': 207}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 284, 'Modified_training_hours': 281}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 308, 'Modified_training_hours': 305}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 190, 'Modified_training_hours': 187}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 212, 'Modified_training_hours': 209}
# {'Actual_tranining_hours': 149, 'Modified_training_hours': 146}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 167, 'Modified_training_hours': 164}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 308, 'Modified_training_hours': 305}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 153, 'Modified_training_hours': 150}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 212, 'Modified_training_hours': 209}
# {'Actual_tranining_hours': 282, 'Modified_training_hours': 279}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 190, 'Modified_training_hours': 187}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 278, 'Modified_training_hours': 275}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 135, 'Modified_training_hours': 132}
# {'Actual_tranining_hours': 210, 'Modified_training_hours': 207}
# {'Actual_tranining_hours': 292, 'Modified_training_hours': 289}
# {'Actual_tranining_hours': 132, 'Modified_training_hours': 129}
# {'Actual_tranining_hours': 294, 'Modified_training_hours': 291}
# {'Actual_tranining_hours': 141, 'Modified_training_hours': 138}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 312, 'Modified_training_hours': 309}
# {'Actual_tranining_hours': 232, 'Modified_training_hours': 229}
# {'Actual_tranining_hours': 139, 'Modified_training_hours': 136}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 292, 'Modified_training_hours': 289}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 170, 'Modified_training_hours': 167}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 148, 'Modified_training_hours': 145}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 242, 'Modified_training_hours': 239}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 290, 'Modified_training_hours': 287}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 226, 'Modified_training_hours': 223}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 212, 'Modified_training_hours': 209}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 165, 'Modified_training_hours': 162}
# {'Actual_tranining_hours': 268, 'Modified_training_hours': 265}
# {'Actual_tranining_hours': 320, 'Modified_training_hours': 317}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 190, 'Modified_training_hours': 187}
# {'Actual_tranining_hours': 320, 'Modified_training_hours': 317}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 149, 'Modified_training_hours': 146}
# {'Actual_tranining_hours': 164, 'Modified_training_hours': 161}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 182, 'Modified_training_hours': 179}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 184, 'Modified_training_hours': 181}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 304, 'Modified_training_hours': 301}
# {'Actual_tranining_hours': 155, 'Modified_training_hours': 152}
# {'Actual_tranining_hours': 144, 'Modified_training_hours': 141}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 182, 'Modified_training_hours': 179}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 212, 'Modified_training_hours': 209}
# {'Actual_tranining_hours': 143, 'Modified_training_hours': 140}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 242, 'Modified_training_hours': 239}
# {'Actual_tranining_hours': 188, 'Modified_training_hours': 185}
# {'Actual_tranining_hours': 226, 'Modified_training_hours': 223}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 144, 'Modified_training_hours': 141}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 188, 'Modified_training_hours': 185}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 210, 'Modified_training_hours': 207}
# {'Actual_tranining_hours': 330, 'Modified_training_hours': 327}
# {'Actual_tranining_hours': 224, 'Modified_training_hours': 221}
# {'Actual_tranining_hours': 332, 'Modified_training_hours': 329}
# {'Actual_tranining_hours': 220, 'Modified_training_hours': 217}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 228, 'Modified_training_hours': 225}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 165, 'Modified_training_hours': 162}
# {'Actual_tranining_hours': 282, 'Modified_training_hours': 279}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 148, 'Modified_training_hours': 145}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 148, 'Modified_training_hours': 145}
# {'Actual_tranining_hours': 182, 'Modified_training_hours': 179}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 246, 'Modified_training_hours': 243}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 136, 'Modified_training_hours': 133}
# {'Actual_tranining_hours': 118, 'Modified_training_hours': 115}
# {'Actual_tranining_hours': 300, 'Modified_training_hours': 297}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 188, 'Modified_training_hours': 185}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 234, 'Modified_training_hours': 231}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 190, 'Modified_training_hours': 187}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 135, 'Modified_training_hours': 132}
# {'Actual_tranining_hours': 118, 'Modified_training_hours': 115}
# {'Actual_tranining_hours': 246, 'Modified_training_hours': 243}
# {'Actual_tranining_hours': 121, 'Modified_training_hours': 118}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 200, 'Modified_training_hours': 197}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 326, 'Modified_training_hours': 323}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 232, 'Modified_training_hours': 229}
# {'Actual_tranining_hours': 118, 'Modified_training_hours': 115}
# {'Actual_tranining_hours': 167, 'Modified_training_hours': 164}
# {'Actual_tranining_hours': 144, 'Modified_training_hours': 141}
# {'Actual_tranining_hours': 308, 'Modified_training_hours': 305}
# {'Actual_tranining_hours': 194, 'Modified_training_hours': 191}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 139, 'Modified_training_hours': 136}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 141, 'Modified_training_hours': 138}
# {'Actual_tranining_hours': 170, 'Modified_training_hours': 167}
# {'Actual_tranining_hours': 161, 'Modified_training_hours': 158}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 155, 'Modified_training_hours': 152}
# {'Actual_tranining_hours': 129, 'Modified_training_hours': 126}
# {'Actual_tranining_hours': 220, 'Modified_training_hours': 217}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 182, 'Modified_training_hours': 179}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 153, 'Modified_training_hours': 150}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 262, 'Modified_training_hours': 259}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 143, 'Modified_training_hours': 140}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 190, 'Modified_training_hours': 187}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 210, 'Modified_training_hours': 207}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 149, 'Modified_training_hours': 146}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 328, 'Modified_training_hours': 325}
# {'Actual_tranining_hours': 142, 'Modified_training_hours': 139}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 125, 'Modified_training_hours': 122}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 316, 'Modified_training_hours': 313}
# {'Actual_tranining_hours': 133, 'Modified_training_hours': 130}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 172, 'Modified_training_hours': 169}
# {'Actual_tranining_hours': 129, 'Modified_training_hours': 126}
# {'Actual_tranining_hours': 324, 'Modified_training_hours': 321}
# {'Actual_tranining_hours': 145, 'Modified_training_hours': 142}
# {'Actual_tranining_hours': 202, 'Modified_training_hours': 199}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 139, 'Modified_training_hours': 136}
# {'Actual_tranining_hours': 314, 'Modified_training_hours': 311}
# {'Actual_tranining_hours': 240, 'Modified_training_hours': 237}
# {'Actual_tranining_hours': 258, 'Modified_training_hours': 255}
# {'Actual_tranining_hours': 176, 'Modified_training_hours': 173}
# {'Actual_tranining_hours': 246, 'Modified_training_hours': 243}
# {'Actual_tranining_hours': 234, 'Modified_training_hours': 231}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 202, 'Modified_training_hours': 199}
# {'Actual_tranining_hours': 212, 'Modified_training_hours': 209}
# {'Actual_tranining_hours': 244, 'Modified_training_hours': 241}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 176, 'Modified_training_hours': 173}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 184, 'Modified_training_hours': 181}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 164, 'Modified_training_hours': 161}
# {'Actual_tranining_hours': 276, 'Modified_training_hours': 273}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 220, 'Modified_training_hours': 217}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 143, 'Modified_training_hours': 140}
# {'Actual_tranining_hours': 143, 'Modified_training_hours': 140}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 133, 'Modified_training_hours': 130}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 258, 'Modified_training_hours': 255}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 226, 'Modified_training_hours': 223}
# {'Actual_tranining_hours': 117, 'Modified_training_hours': 114}
# {'Actual_tranining_hours': 248, 'Modified_training_hours': 245}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 306, 'Modified_training_hours': 303}
# {'Actual_tranining_hours': 148, 'Modified_training_hours': 145}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 336, 'Modified_training_hours': 333}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 182, 'Modified_training_hours': 179}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 236, 'Modified_training_hours': 233}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 300, 'Modified_training_hours': 297}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 322, 'Modified_training_hours': 319}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 316, 'Modified_training_hours': 313}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 286, 'Modified_training_hours': 283}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 248, 'Modified_training_hours': 245}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 226, 'Modified_training_hours': 223}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 119, 'Modified_training_hours': 116}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 127, 'Modified_training_hours': 124}
# {'Actual_tranining_hours': 133, 'Modified_training_hours': 130}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 144, 'Modified_training_hours': 141}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 260, 'Modified_training_hours': 257}
# {'Actual_tranining_hours': 324, 'Modified_training_hours': 321}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 136, 'Modified_training_hours': 133}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 119, 'Modified_training_hours': 116}
# {'Actual_tranining_hours': 328, 'Modified_training_hours': 325}
# {'Actual_tranining_hours': 118, 'Modified_training_hours': 115}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 121, 'Modified_training_hours': 118}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 117, 'Modified_training_hours': 114}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 302, 'Modified_training_hours': 299}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 176, 'Modified_training_hours': 173}
# {'Actual_tranining_hours': 141, 'Modified_training_hours': 138}
# {'Actual_tranining_hours': 143, 'Modified_training_hours': 140}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 129, 'Modified_training_hours': 126}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 284, 'Modified_training_hours': 281}
# {'Actual_tranining_hours': 258, 'Modified_training_hours': 255}
# {'Actual_tranining_hours': 266, 'Modified_training_hours': 263}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 322, 'Modified_training_hours': 319}
# {'Actual_tranining_hours': 244, 'Modified_training_hours': 241}
# {'Actual_tranining_hours': 109, 'Modified_training_hours': 106}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 324, 'Modified_training_hours': 321}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 127, 'Modified_training_hours': 124}
# {'Actual_tranining_hours': 322, 'Modified_training_hours': 319}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 141, 'Modified_training_hours': 138}
# {'Actual_tranining_hours': 260, 'Modified_training_hours': 257}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 135, 'Modified_training_hours': 132}
# {'Actual_tranining_hours': 282, 'Modified_training_hours': 279}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 206, 'Modified_training_hours': 203}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 194, 'Modified_training_hours': 191}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 212, 'Modified_training_hours': 209}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 141, 'Modified_training_hours': 138}
# {'Actual_tranining_hours': 184, 'Modified_training_hours': 181}
# {'Actual_tranining_hours': 119, 'Modified_training_hours': 116}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 326, 'Modified_training_hours': 323}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 334, 'Modified_training_hours': 331}
# {'Actual_tranining_hours': 322, 'Modified_training_hours': 319}
# {'Actual_tranining_hours': 200, 'Modified_training_hours': 197}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 298, 'Modified_training_hours': 295}
# {'Actual_tranining_hours': 254, 'Modified_training_hours': 251}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 324, 'Modified_training_hours': 321}
# {'Actual_tranining_hours': 135, 'Modified_training_hours': 132}
# {'Actual_tranining_hours': 320, 'Modified_training_hours': 317}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 143, 'Modified_training_hours': 140}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 298, 'Modified_training_hours': 295}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 165, 'Modified_training_hours': 162}
# {'Actual_tranining_hours': 214, 'Modified_training_hours': 211}
# ...
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 260, 'Modified_training_hours': 257}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 232, 'Modified_training_hours': 229}
# {'Actual_tranining_hours': 334, 'Modified_training_hours': 331}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 132, 'Modified_training_hours': 129}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 226, 'Modified_training_hours': 223}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 176, 'Modified_training_hours': 173}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 117, 'Modified_training_hours': 114}
# {'Actual_tranining_hours': 332, 'Modified_training_hours': 329}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 176, 'Modified_training_hours': 173}
# {'Actual_tranining_hours': 202, 'Modified_training_hours': 199}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 246, 'Modified_training_hours': 243}
# {'Actual_tranining_hours': 142, 'Modified_training_hours': 139}
# {'Actual_tranining_hours': 142, 'Modified_training_hours': 139}
# {'Actual_tranining_hours': 246, 'Modified_training_hours': 243}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 117, 'Modified_training_hours': 114}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 161, 'Modified_training_hours': 158}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 153, 'Modified_training_hours': 150}
# {'Actual_tranining_hours': 129, 'Modified_training_hours': 126}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 298, 'Modified_training_hours': 295}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 167, 'Modified_training_hours': 164}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 180, 'Modified_training_hours': 177}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 214, 'Modified_training_hours': 211}
# {'Actual_tranining_hours': 188, 'Modified_training_hours': 185}
# {'Actual_tranining_hours': 314, 'Modified_training_hours': 311}
# {'Actual_tranining_hours': 128, 'Modified_training_hours': 125}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 136, 'Modified_training_hours': 133}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 222, 'Modified_training_hours': 219}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 314, 'Modified_training_hours': 311}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 280, 'Modified_training_hours': 277}
# {'Actual_tranining_hours': 118, 'Modified_training_hours': 115}
# {'Actual_tranining_hours': 130, 'Modified_training_hours': 127}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 133, 'Modified_training_hours': 130}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 332, 'Modified_training_hours': 329}
# {'Actual_tranining_hours': 196, 'Modified_training_hours': 193}
# {'Actual_tranining_hours': 136, 'Modified_training_hours': 133}
# {'Actual_tranining_hours': 125, 'Modified_training_hours': 122}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 118, 'Modified_training_hours': 115}
# {'Actual_tranining_hours': 280, 'Modified_training_hours': 277}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 182, 'Modified_training_hours': 179}
# {'Actual_tranining_hours': 262, 'Modified_training_hours': 259}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 306, 'Modified_training_hours': 303}
# {'Actual_tranining_hours': 154, 'Modified_training_hours': 151}
# {'Actual_tranining_hours': 224, 'Modified_training_hours': 221}
# {'Actual_tranining_hours': 161, 'Modified_training_hours': 158}
# {'Actual_tranining_hours': 176, 'Modified_training_hours': 173}
# {'Actual_tranining_hours': 136, 'Modified_training_hours': 133}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 125, 'Modified_training_hours': 122}
# {'Actual_tranining_hours': 136, 'Modified_training_hours': 133}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 280, 'Modified_training_hours': 277}
# {'Actual_tranining_hours': 155, 'Modified_training_hours': 152}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 141, 'Modified_training_hours': 138}
# {'Actual_tranining_hours': 214, 'Modified_training_hours': 211}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 192, 'Modified_training_hours': 189}
# {'Actual_tranining_hours': 328, 'Modified_training_hours': 325}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 135, 'Modified_training_hours': 132}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 286, 'Modified_training_hours': 283}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 118, 'Modified_training_hours': 115}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 328, 'Modified_training_hours': 325}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 228, 'Modified_training_hours': 225}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 260, 'Modified_training_hours': 257}
# {'Actual_tranining_hours': 272, 'Modified_training_hours': 269}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 157, 'Modified_training_hours': 154}
# {'Actual_tranining_hours': 232, 'Modified_training_hours': 229}
# {'Actual_tranining_hours': 188, 'Modified_training_hours': 185}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 200, 'Modified_training_hours': 197}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 194, 'Modified_training_hours': 191}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 117, 'Modified_training_hours': 114}
# {'Actual_tranining_hours': 316, 'Modified_training_hours': 313}
# {'Actual_tranining_hours': 220, 'Modified_training_hours': 217}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 139, 'Modified_training_hours': 136}
# {'Actual_tranining_hours': 226, 'Modified_training_hours': 223}
# {'Actual_tranining_hours': 113, 'Modified_training_hours': 110}
# {'Actual_tranining_hours': 134, 'Modified_training_hours': 131}
# {'Actual_tranining_hours': 172, 'Modified_training_hours': 169}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 158, 'Modified_training_hours': 155}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 316, 'Modified_training_hours': 313}
# {'Actual_tranining_hours': 160, 'Modified_training_hours': 157}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 165, 'Modified_training_hours': 162}
# {'Actual_tranining_hours': 163, 'Modified_training_hours': 160}
# {'Actual_tranining_hours': 151, 'Modified_training_hours': 148}
# {'Actual_tranining_hours': 121, 'Modified_training_hours': 118}
# {'Actual_tranining_hours': 214, 'Modified_training_hours': 211}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 145, 'Modified_training_hours': 142}
# {'Actual_tranining_hours': 332, 'Modified_training_hours': 329}
# {'Actual_tranining_hours': 194, 'Modified_training_hours': 191}
# {'Actual_tranining_hours': 106, 'Modified_training_hours': 103}
# {'Actual_tranining_hours': 146, 'Modified_training_hours': 143}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 122, 'Modified_training_hours': 119}
# {'Actual_tranining_hours': 264, 'Modified_training_hours': 261}
# {'Actual_tranining_hours': 143, 'Modified_training_hours': 140}
# {'Actual_tranining_hours': 139, 'Modified_training_hours': 136}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 133, 'Modified_training_hours': 130}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 139, 'Modified_training_hours': 136}
# {'Actual_tranining_hours': 114, 'Modified_training_hours': 111}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 314, 'Modified_training_hours': 311}
# {'Actual_tranining_hours': 104, 'Modified_training_hours': 101}
# {'Actual_tranining_hours': 150, 'Modified_training_hours': 147}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 124, 'Modified_training_hours': 121}
# {'Actual_tranining_hours': 110, 'Modified_training_hours': 107}
# {'Actual_tranining_hours': 322, 'Modified_training_hours': 319}
# {'Actual_tranining_hours': 166, 'Modified_training_hours': 163}
# {'Actual_tranining_hours': 111, 'Modified_training_hours': 108}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 149, 'Modified_training_hours': 146}
# {'Actual_tranining_hours': 204, 'Modified_training_hours': 201}
# {'Actual_tranining_hours': 145, 'Modified_training_hours': 142}
# {'Actual_tranining_hours': 112, 'Modified_training_hours': 109}
# {'Actual_tranining_hours': 126, 'Modified_training_hours': 123}
# {'Actual_tranining_hours': 125, 'Modified_training_hours': 122}
# {'Actual_tranining_hours': 168, 'Modified_training_hours': 165}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 156, 'Modified_training_hours': 153}
# {'Actual_tranining_hours': 116, 'Modified_training_hours': 113}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 108, 'Modified_training_hours': 105}
# {'Actual_tranining_hours': 226, 'Modified_training_hours': 223}
# {'Actual_tranining_hours': 105, 'Modified_training_hours': 102}
# {'Actual_tranining_hours': 306, 'Modified_training_hours': 303}
# {'Actual_tranining_hours': 107, 'Modified_training_hours': 104}
# {'Actual_tranining_hours': 140, 'Modified_training_hours': 137}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 131, 'Modified_training_hours': 128}
# {'Actual_tranining_hours': 182, 'Modified_training_hours': 179}
# {'Actual_tranining_hours': 288, 'Modified_training_hours': 285}
# {'Actual_tranining_hours': 198, 'Modified_training_hours': 195}
# {'Actual_tranining_hours': 256, 'Modified_training_hours': 253}
# {'Actual_tranining_hours': 174, 'Modified_training_hours': 171}
# {'Actual_tranining_hours': 138, 'Modified_training_hours': 135}
# {'Actual_tranining_hours': 218, 'Modified_training_hours': 215}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 148, 'Modified_training_hours': 145}
# {'Actual_tranining_hours': 152, 'Modified_training_hours': 149}
# {'Actual_tranining_hours': 162, 'Modified_training_hours': 159}
# {'Actual_tranining_hours': 258, 'Modified_training_hours': 255}
# {'Actual_tranining_hours': 141, 'Modified_training_hours': 138}
# {'Actual_tranining_hours': 148, 'Modified_training_hours': 145}
# {'Actual_tranining_hours': 194, 'Modified_training_hours': 191}
# {'Actual_tranining_hours': 224, 'Modified_training_hours': 221}
# {'Actual_tranining_hours': 123, 'Modified_training_hours': 120}
# {'Actual_tranining_hours': 288, 'Modified_training_hours': 285}
# {'Actual_tranining_hours': 178, 'Modified_training_hours': 175}

# %% [markdown]
# ----
# **We can even subtract two field values.**
#
# For example, we subtract the `experience.relevant_experience` from `expereience.years`.
#
# ----

# %%
# Use of aggregation operators

result = db.hr.aggregate(
       
        # Pipeline
        [
            # Stage 1
            {
                '$match':{'education.discipline':'STEM'}
            },
            
            # Stage 2
            {
                '$project':{
                                '_id':0,
                                'Total_Exp': '$experience.years',
                                'Relevant_Exp': '$experience.relevent_experience',
                                # Subtract
                                'Result': {'$subtract': ['$experience.years', '$experience.relevent_experience']}
                            }
            }
        ])

# Print result
for doc in result:
    pp.pprint(doc)
# Out:
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 15, 'Relevant_Exp': 0, 'Result': 15}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 13, 'Relevant_Exp': 0, 'Result': 13}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 15, 'Relevant_Exp': 0, 'Result': 15}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 9, 'Relevant_Exp': 0, 'Result': 9}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 15, 'Relevant_Exp': 0, 'Result': 15}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 0, 'Relevant_Exp': 1, 'Result': -1}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 9, 'Relevant_Exp': 0, 'Result': 9}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 0, 'Relevant_Exp': 1, 'Result': -1}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 12, 'Relevant_Exp': 0, 'Result': 12}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 0, 'Relevant_Exp': 1, 'Result': -1}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 14, 'Relevant_Exp': 0, 'Result': 14}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 16, 'Relevant_Exp': 0, 'Result': 16}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 0, 'Result': 7}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 12, 'Relevant_Exp': 0, 'Result': 12}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 13, 'Relevant_Exp': 0, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 19, 'Relevant_Exp': 0, 'Result': 19}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 11, 'Relevant_Exp': 0, 'Result': 11}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 11, 'Relevant_Exp': 0, 'Result': 11}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 12, 'Relevant_Exp': 0, 'Result': 12}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 9, 'Relevant_Exp': 0, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 7, 'Relevant_Exp': 0, 'Result': 7}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 18, 'Relevant_Exp': 0, 'Result': 18}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 7, 'Relevant_Exp': 0, 'Result': 7}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 7, 'Relevant_Exp': 0, 'Result': 7}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 1, 'Relevant_Exp': 1, 'Result': 0}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 13, 'Relevant_Exp': 0, 'Result': 13}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 9, 'Relevant_Exp': 0, 'Result': 9}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 1, 'Relevant_Exp': 1, 'Result': 0}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 1, 'Relevant_Exp': 1, 'Result': 0}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 1, 'Relevant_Exp': 1, 'Result': 0}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 7, 'Relevant_Exp': 0, 'Result': 7}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 11, 'Relevant_Exp': 0, 'Result': 11}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 0, 'Result': 15}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 16, 'Relevant_Exp': 0, 'Result': 16}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 7, 'Relevant_Exp': 0, 'Result': 7}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 18, 'Relevant_Exp': 0, 'Result': 18}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 9, 'Relevant_Exp': 0, 'Result': 9}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 11, 'Relevant_Exp': 0, 'Result': 11}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 12, 'Relevant_Exp': 0, 'Result': 12}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 18, 'Relevant_Exp': 0, 'Result': 18}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 0, 'Result': 10}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 11, 'Relevant_Exp': 0, 'Result': 11}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 18, 'Relevant_Exp': 0, 'Result': 18}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 13, 'Relevant_Exp': 0, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 7, 'Relevant_Exp': 0, 'Result': 7}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 17, 'Relevant_Exp': 0, 'Result': 17}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 13, 'Relevant_Exp': 0, 'Result': 13}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 8, 'Relevant_Exp': 0, 'Result': 8}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# ...
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 16, 'Relevant_Exp': 0, 'Result': 16}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 14, 'Relevant_Exp': 0, 'Result': 14}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 14, 'Relevant_Exp': 0, 'Result': 14}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 0, 'Result': 15}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 1, 'Relevant_Exp': 1, 'Result': 0}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 7, 'Relevant_Exp': 0, 'Result': 7}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 2, 'Relevant_Exp': 1, 'Result': 1}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 1, 'Relevant_Exp': 0, 'Result': 1}
# {'Total_Exp': 12, 'Relevant_Exp': 0, 'Result': 12}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 15, 'Relevant_Exp': 0, 'Result': 15}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 10, 'Relevant_Exp': 1, 'Result': 9}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 12, 'Relevant_Exp': 0, 'Result': 12}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 0, 'Relevant_Exp': 0, 'Result': 0}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 13, 'Relevant_Exp': 1, 'Result': 12}
# {'Total_Exp': 16, 'Relevant_Exp': 0, 'Result': 16}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 7, 'Relevant_Exp': 0, 'Result': 7}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 11, 'Relevant_Exp': 0, 'Result': 11}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 12, 'Relevant_Exp': 0, 'Result': 12}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 6, 'Relevant_Exp': 0, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 11, 'Relevant_Exp': 0, 'Result': 11}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 12, 'Relevant_Exp': 1, 'Result': 11}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 15, 'Relevant_Exp': 1, 'Result': 14}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 4, 'Relevant_Exp': 0, 'Result': 4}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 18, 'Relevant_Exp': 1, 'Result': 17}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 3, 'Relevant_Exp': 1, 'Result': 2}
# {'Total_Exp': 2, 'Relevant_Exp': 0, 'Result': 2}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 14, 'Relevant_Exp': 1, 'Result': 13}
# {'Total_Exp': 4, 'Relevant_Exp': 1, 'Result': 3}
# {'Total_Exp': 7, 'Relevant_Exp': 1, 'Result': 6}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 9, 'Relevant_Exp': 1, 'Result': 8}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 3, 'Relevant_Exp': 0, 'Result': 3}
# {'Total_Exp': 8, 'Relevant_Exp': 1, 'Result': 7}
# {'Total_Exp': 16, 'Relevant_Exp': 1, 'Result': 15}
# {'Total_Exp': 20, 'Relevant_Exp': 0, 'Result': 20}
# {'Total_Exp': 17, 'Relevant_Exp': 1, 'Result': 16}
# {'Total_Exp': 5, 'Relevant_Exp': 0, 'Result': 5}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 6, 'Relevant_Exp': 1, 'Result': 5}
# {'Total_Exp': 19, 'Relevant_Exp': 1, 'Result': 18}
# {'Total_Exp': 5, 'Relevant_Exp': 1, 'Result': 4}
# {'Total_Exp': 11, 'Relevant_Exp': 1, 'Result': 10}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}
# {'Total_Exp': 20, 'Relevant_Exp': 1, 'Result': 19}

# %% [markdown]
# ---
# **We can nest as many operations in the expression operators.**
#
# For example, we want to print the `city.development_index` as an absolute value out of 10 instead of a fraction.
#
# ----

# %%
# Sample document
pp.pprint(
    db.hr.find_one())
# Out:
# {'_id': ObjectId('60bc95fb12d1778df87722e2'),
#  'enrollee_id': 23798,
#  'gender': 'Male',
#  'date_of_enrollment': datetime.datetime(2016, 8, 4, 8, 4, 14, 780000),
#  'city': {'name': 'city_149', 'development_index': 0.689},
#  'education': {'level': 'Graduate', 'discipline': 'STEM'},
#  'experience': {'years': 3,
#                 'company_type': 'Pvt Ltd',
#                 'last_new_job': 1,
#                 'relevent_experience': 1},
#  'training_hours': 106}

# %% [markdown]
# ---
# ----
# We first multiple the value by 10 using [\$multiply](https://docs.mongodb.com/manual/reference/operator/aggregation/multiply/#mongodb-expression-exp.-multiply) operator and then we take the [\$floor](https://docs.mongodb.com/manual/reference/operator/aggregation/floor/#mongodb-expression-exp.-floor) value.
#
# ---

# %%
# Nested operators

result = db.hr.aggregate(
        
        # Pipeline
        [
            # Stage 1
            {
                '$match':{'education.discipline':'STEM'}
            },
            
            # Stage 2
            {
                '$project':{
                            '_id':0,
                            'city.development_index':1,
                            'Index': {
                                        # Take floor value
                                        '$floor':{
                                                    # Multiply by 10
                                                    '$multiply': ['$city.development_index', 10]
                                                 }
                                     }
                        }
            }
        ])

# Print results
for doc in result:
    pp.pprint(doc)
# Out:
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.843}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.915}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.843}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.727}, 'Index': 7.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.743}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.579}, 'Index': 5.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.856}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.847}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.827}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.527}, 'Index': 5.0}
# {'city': {'development_index': 0.764}, 'Index': 7.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.847}, 'Index': 8.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.903}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.893}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.727}, 'Index': 7.0}
# {'city': {'development_index': 0.725}, 'Index': 7.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.738}, 'Index': 7.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.762}, 'Index': 7.0}
# {'city': {'development_index': 0.89}, 'Index': 8.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.865}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.767}, 'Index': 7.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.725}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.878}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.682}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.766}, 'Index': 7.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.727}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.794}, 'Index': 7.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.691}, 'Index': 6.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.827}, 'Index': 8.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.827}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.796}, 'Index': 7.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.767}, 'Index': 7.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.579}, 'Index': 5.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.893}, 'Index': 8.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.789}, 'Index': 7.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.762}, 'Index': 7.0}
# {'city': {'development_index': 0.89}, 'Index': 8.0}
# {'city': {'development_index': 0.89}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.827}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.847}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.915}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.789}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.836}, 'Index': 8.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.64}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.878}, 'Index': 8.0}
# {'city': {'development_index': 0.74}, 'Index': 7.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.479}, 'Index': 4.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.896}, 'Index': 8.0}
# {'city': {'development_index': 0.836}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.836}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.848}, 'Index': 8.0}
# {'city': {'development_index': 0.558}, 'Index': 5.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.738}, 'Index': 7.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.896}, 'Index': 8.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.767}, 'Index': 7.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.836}, 'Index': 8.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.512}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.527}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.878}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.518}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.848}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.743}, 'Index': 7.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.776}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.893}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.74}, 'Index': 7.0}
# {'city': {'development_index': 0.527}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.762}, 'Index': 7.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.896}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.764}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.735}, 'Index': 7.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.762}, 'Index': 7.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.843}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.893}, 'Index': 8.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.949}, 'Index': 9.0}
# {'city': {'development_index': 0.767}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.722}, 'Index': 7.0}
# {'city': {'development_index': 0.625}, 'Index': 6.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.745}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.73}, 'Index': 7.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.865}, 'Index': 8.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.738}, 'Index': 7.0}
# {'city': {'development_index': 0.74}, 'Index': 7.0}
# {'city': {'development_index': 0.527}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.738}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.682}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.479}, 'Index': 4.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.738}, 'Index': 7.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.843}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.843}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.743}, 'Index': 7.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.691}, 'Index': 6.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.915}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.767}, 'Index': 7.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.789}, 'Index': 7.0}
# {'city': {'development_index': 0.896}, 'Index': 8.0}
# {'city': {'development_index': 0.555}, 'Index': 5.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.767}, 'Index': 7.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.743}, 'Index': 7.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.776}, 'Index': 7.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.896}, 'Index': 8.0}
# {'city': {'development_index': 0.769}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.843}, 'Index': 8.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.794}, 'Index': 7.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.847}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.691}, 'Index': 6.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.527}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.89}, 'Index': 8.0}
# {'city': {'development_index': 0.827}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.448}, 'Index': 4.0}
# {'city': {'development_index': 0.766}, 'Index': 7.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.893}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.949}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.743}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.903}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.896}, 'Index': 8.0}
# {'city': {'development_index': 0.647}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.558}, 'Index': 5.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.682}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.848}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.776}, 'Index': 7.0}
# {'city': {'development_index': 0.847}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.878}, 'Index': 8.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.843}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.764}, 'Index': 7.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.848}, 'Index': 8.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.527}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.691}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.743}, 'Index': 7.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.893}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.89}, 'Index': 8.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.789}, 'Index': 7.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.682}, 'Index': 6.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.764}, 'Index': 7.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.727}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.725}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.738}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.558}, 'Index': 5.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.923}, 'Index': 9.0}
# {'city': {'development_index': 0.767}, 'Index': 7.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.682}, 'Index': 6.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.579}, 'Index': 5.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.796}, 'Index': 7.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.766}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.949}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.579}, 'Index': 5.0}
# ...
# {'city': {'development_index': 0.762}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.689}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.764}, 'Index': 7.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.767}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.666}, 'Index': 6.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.763}, 'Index': 7.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.742}, 'Index': 7.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.762}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.893}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.766}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.949}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.738}, 'Index': 7.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.827}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.89}, 'Index': 8.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.788}, 'Index': 7.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.878}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.895}, 'Index': 8.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.893}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.925}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.836}, 'Index': 8.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.579}, 'Index': 5.0}
# {'city': {'development_index': 0.579}, 'Index': 5.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.895}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.767}, 'Index': 7.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.893}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.89}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.836}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.804}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.512}, 'Index': 5.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.763}, 'Index': 7.0}
# {'city': {'development_index': 0.743}, 'Index': 7.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.915}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.763}, 'Index': 7.0}
# {'city': {'development_index': 0.884}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.691}, 'Index': 6.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.802}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.855}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.878}, 'Index': 8.0}
# {'city': {'development_index': 0.887}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.762}, 'Index': 7.0}
# {'city': {'development_index': 0.949}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.558}, 'Index': 5.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.74}, 'Index': 7.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.55}, 'Index': 5.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.899}, 'Index': 8.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.843}, 'Index': 8.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.843}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.897}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.924}, 'Index': 9.0}
# {'city': {'development_index': 0.579}, 'Index': 5.0}
# {'city': {'development_index': 0.847}, 'Index': 8.0}
# {'city': {'development_index': 0.878}, 'Index': 8.0}
# {'city': {'development_index': 0.624}, 'Index': 6.0}
# {'city': {'development_index': 0.91}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.754}, 'Index': 7.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.866}, 'Index': 8.0}
# {'city': {'development_index': 0.913}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.776}, 'Index': 7.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.698}, 'Index': 6.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.92}, 'Index': 9.0}
# {'city': {'development_index': 0.926}, 'Index': 9.0}
# {'city': {'development_index': 0.939}, 'Index': 9.0}
# {'city': {'development_index': 0.794}, 'Index': 7.0}

# %% [markdown]
# ----
# Aggregation Pipeline Expression operators link - (https://docs.mongodb.com/manual/reference/operator/aggregation/#aggregation-pipeline-operators)
#
# ----

# %% [markdown]
# ---
# ### Exercise 1 -
#
# Return the enrollee_id and number of months of total experience of an enrollee by using the [$multiply]() operator on the experience.years field.
#
# ----

# %% [markdown]
# ----
# ### Exercise 2 -
#
# Return the enrollee_id, city name and development_index truncated to first decimal place where the education discipline of the enrollee is not STEM.
#
# *Hint - Use [$trunc](https://docs.mongodb.com/manual/reference/operator/aggregation/trunc/#-trunc--aggregation-) operator.*
#
# ----
