# %% [markdown]
# # Date Expression Operators

# %% [markdown]
# ---
# ### Connecting to MongoDB using Pymongo
# ----

# %%
# Importing the required libraries
import pymongo
import pprint as pp

pp.sorted = lambda x, key=None: x

# %%
# Connect to the mongo client - Atlas Cluster
client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
# training dataset
db = client.training

# %%
# Sample hr document
pp.pprint(
    db.hr.find_one()
)
# Out:
# {'_id': ObjectId('60bc95fb12d1778df87722e2'),
#  'enrollee_id': 23798,
#  'gender': 'Male',
#  'date_of_enrollment': datetime.datetime(2016, 8, 4, 8, 4, 14, 780000),
#  'city': {'name': 'city_149', 'development_index': 0.689},
#  'education': {'level': 'Graduate', 'discipline': 'STEM'},
#  'experience': {'years': 3,
#                 'company_type': 'Pvt Ltd',
#                 'last_new_job': 1,
#                 'relevent_experience': 1},
#  'training_hours': 106}

# %% [markdown]
# ---
# ---
# ### [Date Expression Operators](https://docs.mongodb.com/manual/reference/operator/aggregation/#date-expression-operators)
#
# Return date objects or components of a date object.
#
# ----
#
# For example, we can return day of month, month, year, etc. from operators like  [\$dayOfMonth](https://docs.mongodb.com/manual/reference/operator/aggregation/dayOfMonth/#mongodb-expression-exp.-dayOfMonth), [\$month](https://docs.mongodb.com/manual/reference/operator/aggregation/month/#mongodb-expression-exp.-month), [\$year](https://docs.mongodb.com/manual/reference/operator/aggregation/year/#mongodb-expression-exp.-year).
#
# ---

# %%
# Date expression operators

result = db.hr.aggregate(
        # Pipeline
        [
            # Stage 1
            {
                '$match':{'education.discipline':'STEM'}
            },
            
            # Stage 2
            {
                '$project':{
                            '_id':0,
                            'Original_date':'$date_of_enrollment',
                            # day of month
                            'Day_of_Month':{'$dayOfMonth':'$date_of_enrollment'},
                            # day of year
                            'Day_of_year':{'$dayOfYear':'$date_of_enrollment'},
                            # day of week
                            'Day_of_Week':{'$isoDayOfWeek':'$date_of_enrollment'},
                            # week of year
                            'Week_of_Year':{'$isoWeek':'$date_of_enrollment'},
                            # month
                            'Month':{'$month':'$date_of_enrollment'},
                            # year
                            'Year':{'$year':'$date_of_enrollment'},
                            # hour
                            'Hour':{'$hour':'$date_of_enrollment'},
                            # minute
                            'Minute':{'$minute':'$date_of_enrollment'},
                            # second
                            'Second':{'$second':'$date_of_enrollment'},
                            # Millisecond
                            'Millisecond':{'$millisecond':'$date_of_enrollment'}
                            }
            },
            
            # Stage 3
            {
                '$limit':1
            }
        ])

# Print results
for doc in result:
    pp.pprint(doc)
# Out:
# {'Original_date': datetime.datetime(2016, 8, 4, 8, 4, 14, 780000),
#  'Day_of_Month': 4,
#  'Day_of_year': 217,
#  'Day_of_Week': 4,
#  'Week_of_Year': 31,
#  'Month': 8,
#  'Year': 2016,
#  'Hour': 8,
#  'Minute': 4,
#  'Second': 14,
#  'Millisecond': 780}

# %% [markdown]
# ---
# **These returned dat objects can then be used in subsequent stages.**
#
# ----

# %%
# Date expression operators

result = db.hr.aggregate(
        # Pipeline
        [
            # Stage 1
            {
                '$match':{'education.discipline':'STEM'}
            },
            
            # Stage 2
            {
                '$project':{
                            '_id':0,
                            'Original_date':'$date_of_enrollment',
                            'Day':{'$dayOfMonth':'$date_of_enrollment'},
                            'Month':{'$month':'$date_of_enrollment'},
                            'Year':{'$year':'$date_of_enrollment'},
                            }
            },
            
            # Stage 3
            {
                '$match': {
                            'Month':{'$gt':6},
                            'Year':{'$gt':2018}
                        }
            }
        ])

# Print results
for doc in result:
    pp.pprint(doc)
# Out:
# {'Original_date': datetime.datetime(2020, 7, 22, 20, 23, 31, 838000),
#  'Day': 22,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 28, 16, 37, 38, 665000),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 4, 2, 32, 20, 81000),
#  'Day': 4,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 5, 1, 11, 47, 17000),
#  'Day': 5,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 12, 21, 38, 17, 999000),
#  'Day': 12,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 22, 8, 35, 5, 529000),
#  'Day': 22,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 15, 14, 32, 14, 105000),
#  'Day': 15,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 5, 11, 20, 18, 527000),
#  'Day': 5,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 7, 4, 38, 35, 375000),
#  'Day': 7,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 21, 17, 44, 18, 518000),
#  'Day': 21,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 5, 11, 8, 30, 124000),
#  'Day': 5,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 1, 23, 50, 11, 808000),
#  'Day': 1,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 30, 2, 9, 50, 546000),
#  'Day': 30,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 24, 20, 15, 3, 478000),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 10, 4, 50, 21, 295000),
#  'Day': 10,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 14, 12, 41, 25, 477000),
#  'Day': 14,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 8, 3, 29, 39, 352000),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 11, 14, 0, 35, 581000),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 8, 1, 55, 39, 982000),
#  'Day': 8,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 3, 11, 55, 3, 430000),
#  'Day': 3,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 17, 18, 30, 18, 406000),
#  'Day': 17,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 2, 14, 19, 37, 823000),
#  'Day': 2,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 18, 22, 16, 36, 57000),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 31, 18, 34, 38, 596000),
#  'Day': 31,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 11, 8, 55, 18, 897000),
#  'Day': 11,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 22, 7, 2, 38, 875000),
#  'Day': 22,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 15, 13, 20, 27, 838000),
#  'Day': 15,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 21, 3, 8, 54, 152000),
#  'Day': 21,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 10, 1, 42, 44, 203000),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 27, 22, 25, 48, 700000),
#  'Day': 27,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 1, 11, 44, 40, 743000),
#  'Day': 1,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 14, 23, 9, 11, 86000),
#  'Day': 14,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 20, 14, 4, 20, 254000),
#  'Day': 20,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 27, 14, 44, 46, 478000),
#  'Day': 27,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 30, 11, 32, 20, 646000),
#  'Day': 30,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 24, 17, 15, 35, 664000),
#  'Day': 24,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 26, 14, 19, 20, 241000),
#  'Day': 26,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 23, 18, 34, 23, 793000),
#  'Day': 23,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 28, 12, 30, 32, 506000),
#  'Day': 28,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 14, 12, 7, 39, 597000),
#  'Day': 14,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 1, 22, 47, 25, 462000),
#  'Day': 1,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 10, 6, 40, 57, 192000),
#  'Day': 10,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 11, 20, 12, 59, 544000),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 29, 19, 0, 54, 546000),
#  'Day': 29,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 17, 8, 26, 25, 189000),
#  'Day': 17,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 8, 23, 36, 52, 184000),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 25, 4, 51, 9, 871000),
#  'Day': 25,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 4, 5, 51, 3, 793000),
#  'Day': 4,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 18, 20, 48, 11, 533000),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 20, 10, 23, 5, 531000),
#  'Day': 20,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 28, 21, 39, 36, 833000),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 4, 11, 34, 20, 555000),
#  'Day': 4,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 15, 21, 32, 49, 292000),
#  'Day': 15,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 26, 12, 55, 29, 301000),
#  'Day': 26,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 11, 14, 37, 7, 849000),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 7, 13, 45, 52, 397000),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 13, 4, 2, 14, 823000),
#  'Day': 13,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 20, 16, 31, 25, 639000),
#  'Day': 20,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 19, 16, 43, 0, 276000),
#  'Day': 19,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 28, 13, 36, 10, 581000),
#  'Day': 28,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 5, 6, 5, 18, 338000),
#  'Day': 5,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 24, 9, 11, 31, 619000),
#  'Day': 24,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 24, 21, 35, 37, 768000),
#  'Day': 24,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 29, 7, 28, 29, 507000),
#  'Day': 29,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 27, 13, 7, 37, 886000),
#  'Day': 27,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 15, 11, 35, 57, 879000),
#  'Day': 15,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 4, 16, 15, 24, 582000),
#  'Day': 4,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 11, 15, 23, 34, 18000),
#  'Day': 11,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 17, 14, 17, 26, 532000),
#  'Day': 17,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 30, 4, 56, 11, 858000),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 27, 10, 21, 31, 771000),
#  'Day': 27,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 6, 19, 33, 32, 777000),
#  'Day': 6,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 5, 23, 23, 32, 882000),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 5, 19, 1, 58, 198000),
#  'Day': 5,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 29, 20, 6, 47, 749000),
#  'Day': 29,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 26, 15, 57, 32, 222000),
#  'Day': 26,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 18, 12, 34, 6, 793000),
#  'Day': 18,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 21, 18, 15, 40, 597000),
#  'Day': 21,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 3, 12, 12, 55, 413000),
#  'Day': 3,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 12, 8, 41, 50, 597000),
#  'Day': 12,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 27, 2, 21, 28, 403000),
#  'Day': 27,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 20, 9, 7, 35, 259000),
#  'Day': 20,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 11, 11, 16, 51, 378000),
#  'Day': 11,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 23, 8, 21, 31, 512000),
#  'Day': 23,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 14, 16, 29, 33, 201000),
#  'Day': 14,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 8, 13, 45, 14, 459000),
#  'Day': 8,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 19, 22, 23, 27, 975000),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 8, 9, 29, 33, 416000),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 27, 1, 51, 40, 261000),
#  'Day': 27,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 19, 18, 25, 20, 971000),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 23, 7, 29, 12, 556000),
#  'Day': 23,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 3, 8, 42, 20, 683000),
#  'Day': 3,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 30, 23, 18, 18, 940000),
#  'Day': 30,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 24, 1, 31, 25, 480000),
#  'Day': 24,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 1, 14, 11, 6, 863000),
#  'Day': 1,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 7, 1, 56, 31, 101000),
#  'Day': 7,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 5, 10, 24, 52, 479000),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 7, 12, 51, 11, 918000),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 26, 9, 26, 8, 526000),
#  'Day': 26,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 13, 11, 27, 41, 36000),
#  'Day': 13,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 13, 15, 30, 1, 420000),
#  'Day': 13,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 9, 9, 8, 38, 868000),
#  'Day': 9,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 8, 11, 41, 25, 845000),
#  'Day': 8,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 16, 10, 21, 33, 185000),
#  'Day': 16,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 21, 20, 44, 41, 393000),
#  'Day': 21,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 16, 13, 39, 54, 135000),
#  'Day': 16,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 13, 13, 15, 50, 115000),
#  'Day': 13,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 26, 20, 23, 58, 604000),
#  'Day': 26,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 6, 5, 49, 55, 599000),
#  'Day': 6,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 8, 22, 41, 19, 844000),
#  'Day': 8,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 6, 2, 58, 47, 896000),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 23, 10, 2, 21, 643000),
#  'Day': 23,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 4, 15, 16, 35, 199000),
#  'Day': 4,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 31, 19, 11, 9, 448000),
#  'Day': 31,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 25, 13, 45, 42, 193000),
#  'Day': 25,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 17, 13, 53, 17, 971000),
#  'Day': 17,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 14, 4, 10, 38, 564000),
#  'Day': 14,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 28, 10, 14, 38, 450000),
#  'Day': 28,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 9, 19, 20, 40, 34000),
#  'Day': 9,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 3, 0, 57, 39, 377000),
#  'Day': 3,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 15, 0, 30, 59, 444000),
#  'Day': 15,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 10, 5, 50, 52, 920000),
#  'Day': 10,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 5, 3, 35, 14, 213000),
#  'Day': 5,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 15, 1, 57, 12, 662000),
#  'Day': 15,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 1, 9, 0, 41, 387000),
#  'Day': 1,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 5, 17, 52, 33, 881000),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 2, 4, 32, 38, 423000),
#  'Day': 2,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 8, 14, 52, 1, 933000),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 10, 18, 34, 14, 901000),
#  'Day': 10,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 25, 19, 48, 48, 837000),
#  'Day': 25,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 19, 16, 31, 38, 785000),
#  'Day': 19,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 17, 6, 50, 6, 989000),
#  'Day': 17,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 26, 10, 18, 20, 703000),
#  'Day': 26,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 5, 9, 48, 38, 166000),
#  'Day': 5,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 12, 19, 6, 22, 840000),
#  'Day': 12,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 7, 0, 28, 8, 892000),
#  'Day': 7,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 5, 4, 36, 12, 617000),
#  'Day': 5,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 16, 2, 6, 3, 448000),
#  'Day': 16,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 11, 5, 20, 21, 620000),
#  'Day': 11,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 5, 21, 16, 59, 152000),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 18, 13, 47, 51, 720000),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 11, 21, 34, 25, 384000),
#  'Day': 11,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 3, 15, 1, 49, 386000),
#  'Day': 3,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 10, 3, 50, 26, 413000),
#  'Day': 10,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 4, 1, 33, 22, 246000),
#  'Day': 4,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 9, 6, 29, 46, 540000),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 29, 22, 43, 9, 295000),
#  'Day': 29,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 12, 19, 36, 26, 44000),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 24, 8, 41, 1, 681000),
#  'Day': 24,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 26, 23, 54, 32, 387000),
#  'Day': 26,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 12, 11, 44, 2, 559000),
#  'Day': 12,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 21, 6, 4, 7, 823000),
#  'Day': 21,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 18, 20, 33, 30, 174000),
#  'Day': 18,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 30, 23, 41, 3, 475000),
#  'Day': 30,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 27, 11, 59, 27, 379000),
#  'Day': 27,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 11, 20, 49, 22, 102000),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 24, 3, 49, 52, 721000),
#  'Day': 24,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 19, 20, 36, 27, 556000),
#  'Day': 19,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 2, 1, 53, 8, 872000),
#  'Day': 2,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 22, 6, 10, 36, 145000),
#  'Day': 22,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 8, 9, 57, 29, 464000),
#  'Day': 8,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 18, 18, 37, 59, 690000),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 18, 16, 20, 54, 226000),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 18, 0, 41, 25, 63000),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 29, 6, 29, 56, 928000),
#  'Day': 29,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 19, 7, 6, 17, 257000),
#  'Day': 19,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 23, 9, 15, 56, 124000),
#  'Day': 23,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 9, 9, 52, 31, 453000),
#  'Day': 9,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 15, 13, 39, 59, 282000),
#  'Day': 15,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 1, 1, 17, 49, 260000),
#  'Day': 1,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 17, 5, 55, 30, 557000),
#  'Day': 17,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 20, 7, 24, 44, 692000),
#  'Day': 20,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 9, 7, 11, 28, 344000),
#  'Day': 9,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 21, 3, 40, 10, 323000),
#  'Day': 21,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 11, 20, 47, 33, 827000),
#  'Day': 11,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 28, 5, 35, 29, 728000),
#  'Day': 28,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 6, 7, 59, 25, 570000),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 6, 1, 9, 50, 233000),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 2, 21, 17, 11, 110000),
#  'Day': 2,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 20, 15, 56, 52, 673000),
#  'Day': 20,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 28, 20, 57, 46, 816000),
#  'Day': 28,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 19, 19, 46, 57, 573000),
#  'Day': 19,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 15, 4, 2, 29, 7000),
#  'Day': 15,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 2, 14, 17, 45, 841000),
#  'Day': 2,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 3, 4, 43, 43, 421000),
#  'Day': 3,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 1, 1, 49, 16, 537000),
#  'Day': 1,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 14, 12, 40, 36, 724000),
#  'Day': 14,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 6, 3, 56, 7, 189000),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 25, 3, 38, 7, 373000),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 25, 2, 4, 8, 333000),
#  'Day': 25,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 13, 8, 33, 40, 395000),
#  'Day': 13,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 9, 16, 1, 58, 349000),
#  'Day': 9,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 9, 8, 49, 5, 104000),
#  'Day': 9,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 10, 5, 34, 0, 10000),
#  'Day': 10,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 7, 8, 14, 59, 387000),
#  'Day': 7,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 1, 2, 20, 30, 731000),
#  'Day': 1,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 28, 6, 48, 22, 66000),
#  'Day': 28,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 7, 16, 51, 19, 620000),
#  'Day': 7,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 26, 21, 59, 28, 470000),
#  'Day': 26,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 25, 7, 1, 39, 461000),
#  'Day': 25,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 27, 23, 18, 19, 723000),
#  'Day': 27,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 31, 14, 35, 31, 989000),
#  'Day': 31,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 3, 0, 20, 32, 469000),
#  'Day': 3,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 2, 4, 48, 47, 746000),
#  'Day': 2,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 7, 20, 2, 51, 690000),
#  'Day': 7,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 16, 14, 6, 44, 298000),
#  'Day': 16,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 10, 22, 14, 57, 984000),
#  'Day': 10,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 27, 17, 48, 54, 980000),
#  'Day': 27,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 28, 20, 6, 50, 501000),
#  'Day': 28,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 12, 18, 46, 42, 173000),
#  'Day': 12,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 1, 8, 57, 29, 294000),
#  'Day': 1,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 7, 21, 59, 54, 784000),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 29, 23, 8, 55, 673000),
#  'Day': 29,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 20, 5, 18, 53, 773000),
#  'Day': 20,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 23, 17, 58, 45, 385000),
#  'Day': 23,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 8, 6, 31, 16, 540000),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 19, 3, 45, 59, 350000),
#  'Day': 19,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 8, 9, 26, 53, 853000),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 26, 6, 48, 49, 720000),
#  'Day': 26,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 18, 16, 5, 34, 825000),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 27, 15, 19, 57, 187000),
#  'Day': 27,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 6, 0, 21, 7, 381000),
#  'Day': 6,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 20, 12, 42, 36, 165000),
#  'Day': 20,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 5, 16, 59, 15, 576000),
#  'Day': 5,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 16, 19, 7, 21, 32000),
#  'Day': 16,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 17, 22, 14, 7, 851000),
#  'Day': 17,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 6, 20, 44, 34, 617000),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 28, 15, 19, 2, 783000),
#  'Day': 28,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 7, 14, 40, 50, 222000),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 28, 21, 40, 31, 527000),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 14, 6, 38, 45, 642000),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 14, 18, 9, 46, 781000),
#  'Day': 14,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 14, 4, 55, 10, 746000),
#  'Day': 14,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 13, 7, 29, 1, 46000),
#  'Day': 13,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 31, 16, 13, 38, 882000),
#  'Day': 31,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 8, 15, 8, 46, 211000),
#  'Day': 8,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 6, 3, 18, 35, 903000),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 14, 5, 49, 52, 731000),
#  'Day': 14,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 6, 23, 22, 31, 755000),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 7, 10, 50, 59, 307000),
#  'Day': 7,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 18, 4, 35, 52, 592000),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 3, 8, 43, 8, 445000),
#  'Day': 3,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 5, 9, 21, 38, 340000),
#  'Day': 5,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 8, 0, 53, 47, 395000),
#  'Day': 8,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 3, 23, 28, 42, 746000),
#  'Day': 3,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 21, 9, 48, 36, 417000),
#  'Day': 21,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 23, 16, 17, 10, 450000),
#  'Day': 23,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 30, 1, 9, 31, 337000),
#  'Day': 30,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 10, 9, 13, 49, 489000),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 28, 5, 17, 31, 782000),
#  'Day': 28,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 20, 6, 14, 51, 968000),
#  'Day': 20,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 26, 3, 26, 22, 434000),
#  'Day': 26,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 16, 10, 36, 48, 18000),
#  'Day': 16,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 16, 22, 11, 22, 27000),
#  'Day': 16,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 8, 16, 11, 4, 684000),
#  'Day': 8,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 31, 20, 2, 11, 975000),
#  'Day': 31,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 29, 0, 14, 19, 352000),
#  'Day': 29,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 25, 21, 44, 21, 598000),
#  'Day': 25,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 24, 16, 15, 53, 568000),
#  'Day': 24,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 21, 22, 13, 57, 98000),
#  'Day': 21,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 3, 19, 18, 42, 5000),
#  'Day': 3,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 27, 10, 10, 41, 840000),
#  'Day': 27,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 25, 3, 2, 28, 464000),
#  'Day': 25,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 1, 4, 29, 47, 212000),
#  'Day': 1,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 6, 18, 14, 54, 455000),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 7, 3, 12, 15, 770000),
#  'Day': 7,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 20, 23, 10, 0, 267000),
#  'Day': 20,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 16, 16, 45, 46, 870000),
#  'Day': 16,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 1, 19, 41, 50, 134000),
#  'Day': 1,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 23, 1, 57, 55, 97000),
#  'Day': 23,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 25, 8, 45, 55, 770000),
#  'Day': 25,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 15, 9, 32, 18, 939000),
#  'Day': 15,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 24, 12, 46, 58, 692000),
#  'Day': 24,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 15, 3, 49, 7, 677000),
#  'Day': 15,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 26, 9, 45, 11, 770000),
#  'Day': 26,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 15, 6, 10, 28, 590000),
#  'Day': 15,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 20, 4, 36, 10, 876000),
#  'Day': 20,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 15, 7, 58, 17, 644000),
#  'Day': 15,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 23, 8, 47, 50, 240000),
#  'Day': 23,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 23, 18, 35, 2, 466000),
#  'Day': 23,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 23, 11, 9, 28, 914000),
#  'Day': 23,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 4, 23, 34, 44, 927000),
#  'Day': 4,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 13, 8, 35, 3, 204000),
#  'Day': 13,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 9, 10, 15, 59, 566000),
#  'Day': 9,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 24, 23, 7, 13, 433000),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 11, 14, 30, 34, 39000),
#  'Day': 11,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 17, 15, 13, 11, 463000),
#  'Day': 17,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 28, 5, 48, 24, 984000),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 25, 15, 34, 10, 890000),
#  'Day': 25,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 13, 13, 55, 37, 423000),
#  'Day': 13,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 5, 23, 18, 26, 504000),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 1, 14, 50, 13, 144000),
#  'Day': 1,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 23, 22, 41, 11, 129000),
#  'Day': 23,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 24, 9, 3, 50, 116000),
#  'Day': 24,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 6, 2, 58, 58, 660000),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 2, 20, 28, 12, 678000),
#  'Day': 2,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 30, 20, 22, 5, 717000),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 2, 4, 54, 44, 516000),
#  'Day': 2,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 29, 15, 13, 48, 515000),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 15, 22, 3, 53, 270000),
#  'Day': 15,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 24, 2, 30, 41, 712000),
#  'Day': 24,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 8, 9, 57, 2, 526000),
#  'Day': 8,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 9, 10, 2, 34, 28000),
#  'Day': 9,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 28, 6, 53, 13, 723000),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 21, 10, 12, 3, 36000),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 13, 21, 49, 31, 22000),
#  'Day': 13,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 19, 7, 3, 30, 529000),
#  'Day': 19,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 21, 14, 57, 43, 179000),
#  'Day': 21,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 18, 11, 48, 40, 731000),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 6, 3, 53, 11, 43000),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 6, 10, 24, 19, 436000),
#  'Day': 6,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 1, 4, 33, 11, 505000),
#  'Day': 1,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 6, 9, 48, 35, 492000),
#  'Day': 6,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 24, 10, 6, 15, 709000),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 9, 21, 30, 15, 544000),
#  'Day': 9,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 18, 5, 58, 58, 639000),
#  'Day': 18,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 19, 9, 13, 55, 599000),
#  'Day': 19,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 24, 2, 1, 12, 374000),
#  'Day': 24,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 7, 14, 42, 49, 44000),
#  'Day': 7,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 19, 23, 45, 54, 17000),
#  'Day': 19,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 21, 6, 11, 22, 520000),
#  'Day': 21,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 21, 17, 52, 1, 32000),
#  'Day': 21,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 5, 4, 6, 37, 876000),
#  'Day': 5,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 26, 19, 29, 56, 582000),
#  'Day': 26,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 6, 22, 51, 28, 49000),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 23, 2, 34, 10, 629000),
#  'Day': 23,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 6, 14, 6, 50, 257000),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 15, 8, 46, 42, 582000),
#  'Day': 15,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 10, 12, 9, 18, 344000),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 17, 5, 40, 54, 341000),
#  'Day': 17,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 26, 21, 47, 30, 249000),
#  'Day': 26,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 14, 13, 1, 24, 89000),
#  'Day': 14,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 31, 13, 51, 32, 382000),
#  'Day': 31,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 22, 14, 29, 34, 3000),
#  'Day': 22,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 12, 20, 28, 41, 764000),
#  'Day': 12,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 26, 4, 48, 19, 986000),
#  'Day': 26,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 17, 18, 50, 5, 961000),
#  'Day': 17,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 27, 14, 36, 49, 501000),
#  'Day': 27,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 8, 6, 26, 20, 321000),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 21, 8, 54, 48, 40000),
#  'Day': 21,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 4, 16, 54, 17, 721000),
#  'Day': 4,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 14, 21, 44, 21, 195000),
#  'Day': 14,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 30, 20, 44, 37, 784000),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 21, 22, 22, 39, 174000),
#  'Day': 21,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 3, 17, 5, 28, 444000),
#  'Day': 3,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 19, 16, 21, 36, 852000),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 7, 2, 6, 47, 294000),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 25, 4, 15, 42, 845000),
#  'Day': 25,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 25, 23, 52, 54, 72000),
#  'Day': 25,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 19, 13, 37, 59, 640000),
#  'Day': 19,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 12, 14, 8, 34, 767000),
#  'Day': 12,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 10, 17, 22, 13, 247000),
#  'Day': 10,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 26, 6, 41, 32, 710000),
#  'Day': 26,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 3, 16, 21, 42, 311000),
#  'Day': 3,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 11, 2, 49, 14, 523000),
#  'Day': 11,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 9, 12, 17, 26, 720000),
#  'Day': 9,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 26, 1, 7, 50, 234000),
#  'Day': 26,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 6, 8, 13, 19, 922000),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 22, 9, 27, 57, 756000),
#  'Day': 22,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 3, 21, 17, 41, 597000),
#  'Day': 3,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 8, 15, 25, 24, 490000),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 7, 11, 37, 53, 803000),
#  'Day': 7,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 27, 20, 5, 1, 673000),
#  'Day': 27,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 17, 3, 51, 17, 892000),
#  'Day': 17,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 10, 16, 49, 55, 190000),
#  'Day': 10,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 22, 8, 15, 6, 555000),
#  'Day': 22,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 13, 12, 47, 38, 279000),
#  'Day': 13,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 1, 12, 18, 2, 785000),
#  'Day': 1,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 13, 5, 16, 33, 163000),
#  'Day': 13,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 16, 17, 38, 22, 233000),
#  'Day': 16,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 29, 21, 51, 59, 912000),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 20, 11, 6, 42, 148000),
#  'Day': 20,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 26, 20, 42, 32, 238000),
#  'Day': 26,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 28, 6, 25, 2, 480000),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 9, 23, 4, 1, 434000),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 19, 16, 26, 4, 595000),
#  'Day': 19,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 8, 10, 24, 51, 285000),
#  'Day': 8,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 1, 7, 48, 23, 729000),
#  'Day': 1,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 23, 15, 24, 35, 720000),
#  'Day': 23,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 15, 21, 53, 31, 25000),
#  'Day': 15,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 23, 22, 40, 57, 36000),
#  'Day': 23,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 19, 22, 47, 30, 525000),
#  'Day': 19,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 3, 9, 16, 14, 669000),
#  'Day': 3,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 18, 8, 12, 42, 604000),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 22, 0, 51, 8, 816000),
#  'Day': 22,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 29, 14, 6, 3, 146000),
#  'Day': 29,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 25, 21, 34, 46, 416000),
#  'Day': 25,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 10, 14, 5, 49, 179000),
#  'Day': 10,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 28, 20, 51, 58, 323000),
#  'Day': 28,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 31, 19, 19, 12, 397000),
#  'Day': 31,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 8, 14, 51, 6, 670000),
#  'Day': 8,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 25, 3, 51, 29, 787000),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 11, 17, 27, 57, 425000),
#  'Day': 11,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 28, 20, 2, 51, 758000),
#  'Day': 28,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 26, 6, 58, 56, 748000),
#  'Day': 26,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 19, 13, 10, 24, 137000),
#  'Day': 19,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 30, 3, 1, 24, 773000),
#  'Day': 30,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 5, 6, 44, 14, 168000),
#  'Day': 5,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 12, 7, 40, 53, 437000),
#  'Day': 12,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 10, 1, 49, 54, 351000),
#  'Day': 10,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 3, 6, 54, 9, 488000),
#  'Day': 3,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 30, 9, 18, 23, 298000),
#  'Day': 30,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 4, 1, 15, 56, 56000),
#  'Day': 4,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 8, 10, 6, 30, 421000),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 7, 13, 37, 55, 42000),
#  'Day': 7,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 22, 14, 19, 20, 533000),
#  'Day': 22,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 8, 23, 8, 58, 355000),
#  'Day': 8,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 17, 7, 52, 36, 273000),
#  'Day': 17,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 1, 1, 2, 24, 778000),
#  'Day': 1,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 8, 6, 8, 54, 497000),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 12, 4, 34, 56, 683000),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 23, 4, 35, 23, 784000),
#  'Day': 23,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 16, 5, 52, 36, 843000),
#  'Day': 16,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 4, 1, 30, 11, 870000),
#  'Day': 4,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 12, 13, 55, 52, 248000),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 13, 2, 41, 7, 689000),
#  'Day': 13,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 26, 19, 25, 45, 231000),
#  'Day': 26,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 20, 8, 36, 56, 676000),
#  'Day': 20,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 3, 0, 57, 4, 928000),
#  'Day': 3,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 29, 2, 7, 41, 921000),
#  'Day': 29,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 2, 16, 30, 31, 343000),
#  'Day': 2,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 29, 20, 50, 59, 343000),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 27, 17, 14, 31, 934000),
#  'Day': 27,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 8, 1, 21, 57, 216000),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 23, 7, 54, 21, 421000),
#  'Day': 23,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 25, 5, 28, 33, 145000),
#  'Day': 25,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 27, 12, 20, 35, 750000),
#  'Day': 27,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 25, 8, 44, 0, 323000),
#  'Day': 25,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 4, 12, 25, 58, 4000),
#  'Day': 4,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 10, 8, 28, 53, 421000),
#  'Day': 10,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 16, 20, 2, 58, 458000),
#  'Day': 16,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 26, 5, 55, 17, 768000),
#  'Day': 26,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 14, 23, 58, 20, 171000),
#  'Day': 14,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 29, 9, 43, 46, 65000),
#  'Day': 29,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 26, 10, 47, 7, 146000),
#  'Day': 26,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 6, 15, 26, 24, 863000),
#  'Day': 6,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 26, 8, 46, 54, 1000),
#  'Day': 26,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 6, 21, 47, 32, 365000),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2019}
# ...
# {'Original_date': datetime.datetime(2020, 9, 27, 22, 18, 17, 438000),
#  'Day': 27,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 18, 13, 45, 26, 153000),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 16, 1, 45, 7, 337000),
#  'Day': 16,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 17, 20, 8, 51, 736000),
#  'Day': 17,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 28, 2, 49, 39, 42000),
#  'Day': 28,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 13, 1, 48, 28, 972000),
#  'Day': 13,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 1, 5, 44, 27, 566000),
#  'Day': 1,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 3, 1, 34, 2, 295000),
#  'Day': 3,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 30, 9, 25, 34, 835000),
#  'Day': 30,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 6, 7, 15, 5, 560000),
#  'Day': 6,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 19, 0, 34, 38, 651000),
#  'Day': 19,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 14, 11, 17, 35, 736000),
#  'Day': 14,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 10, 0, 11, 9, 94000),
#  'Day': 10,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 10, 10, 21, 0, 513000),
#  'Day': 10,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 24, 19, 35, 27, 332000),
#  'Day': 24,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 10, 22, 11, 31, 912000),
#  'Day': 10,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 29, 21, 6, 7, 273000),
#  'Day': 29,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 10, 4, 29, 3, 834000),
#  'Day': 10,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 12, 20, 3, 14, 709000),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 24, 12, 22, 33, 508000),
#  'Day': 24,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 11, 23, 53, 41, 220000),
#  'Day': 11,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 23, 6, 4, 34, 158000),
#  'Day': 23,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 3, 11, 29, 3, 708000),
#  'Day': 3,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 21, 17, 23, 8, 248000),
#  'Day': 21,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 26, 13, 29, 27, 636000),
#  'Day': 26,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 28, 17, 43, 20, 792000),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 9, 1, 44, 21, 647000),
#  'Day': 9,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 21, 13, 13, 28, 783000),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 7, 3, 31, 50, 805000),
#  'Day': 7,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 31, 11, 58, 10, 68000),
#  'Day': 31,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 20, 10, 54, 45, 130000),
#  'Day': 20,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 18, 0, 50, 29, 468000),
#  'Day': 18,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 26, 1, 4, 11, 950000),
#  'Day': 26,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 21, 9, 4, 45, 891000),
#  'Day': 21,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 28, 11, 30, 19, 372000),
#  'Day': 28,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 3, 17, 15, 38, 338000),
#  'Day': 3,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 28, 4, 0, 24, 551000),
#  'Day': 28,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 14, 9, 29, 31, 758000),
#  'Day': 14,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 23, 22, 44, 26, 701000),
#  'Day': 23,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 26, 0, 44, 57, 276000),
#  'Day': 26,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 4, 16, 12, 53, 234000),
#  'Day': 4,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 7, 19, 10, 52, 545000),
#  'Day': 7,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 8, 6, 7, 58, 719000),
#  'Day': 8,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 12, 22, 55, 3, 64000),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 26, 13, 13, 11, 36000),
#  'Day': 26,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 18, 14, 19, 54, 593000),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 7, 4, 46, 25, 765000),
#  'Day': 7,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 24, 22, 6, 35, 994000),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 12, 5, 42, 0, 32000),
#  'Day': 12,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 24, 5, 44, 4, 696000),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 22, 22, 33, 36, 627000),
#  'Day': 22,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 28, 11, 14, 41, 15000),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 19, 17, 10, 21, 530000),
#  'Day': 19,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 8, 20, 7, 34, 908000),
#  'Day': 8,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 14, 8, 41, 46, 73000),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 10, 14, 31, 22, 868000),
#  'Day': 10,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 9, 6, 0, 1, 471000),
#  'Day': 9,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 18, 14, 42, 39, 838000),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 4, 10, 57, 28, 759000),
#  'Day': 4,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 22, 1, 19, 24, 232000),
#  'Day': 22,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 3, 0, 4, 50, 49000),
#  'Day': 3,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 25, 9, 33, 39, 115000),
#  'Day': 25,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 22, 17, 10, 39, 799000),
#  'Day': 22,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 20, 16, 57, 52, 941000),
#  'Day': 20,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 2, 8, 32, 47, 802000),
#  'Day': 2,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 27, 5, 51, 5, 769000),
#  'Day': 27,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 3, 8, 17, 38, 962000),
#  'Day': 3,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 20, 3, 47, 28, 28000),
#  'Day': 20,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 19, 8, 13, 41, 613000),
#  'Day': 19,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 11, 1, 2, 22, 333000),
#  'Day': 11,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 24, 4, 20, 16, 611000),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 29, 4, 32, 10, 608000),
#  'Day': 29,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 5, 14, 58, 48, 173000),
#  'Day': 5,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 30, 11, 56, 59, 611000),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 6, 23, 21, 45, 82000),
#  'Day': 6,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 24, 3, 34, 24, 24000),
#  'Day': 24,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 3, 14, 33, 44, 633000),
#  'Day': 3,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 26, 3, 1, 22, 520000),
#  'Day': 26,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 21, 17, 36, 52, 220000),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 6, 1, 27, 16, 177000),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 30, 1, 49, 48, 503000),
#  'Day': 30,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 20, 16, 57, 11, 800000),
#  'Day': 20,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 11, 23, 36, 17, 507000),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 25, 14, 32, 54, 553000),
#  'Day': 25,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 18, 15, 35, 23, 442000),
#  'Day': 18,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 9, 12, 7, 42, 98000),
#  'Day': 9,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 27, 11, 4, 13, 813000),
#  'Day': 27,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 22, 20, 15, 48, 429000),
#  'Day': 22,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 15, 6, 20, 8, 801000),
#  'Day': 15,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 23, 9, 50, 23, 902000),
#  'Day': 23,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 28, 16, 36, 50, 437000),
#  'Day': 28,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 15, 11, 45, 20, 252000),
#  'Day': 15,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 14, 21, 45, 32, 621000),
#  'Day': 14,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 19, 13, 8, 5, 100000),
#  'Day': 19,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 18, 14, 57, 51, 73000),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 4, 7, 37, 52, 490000),
#  'Day': 4,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 30, 3, 3, 25, 1000),
#  'Day': 30,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 1, 2, 2, 43, 992000),
#  'Day': 1,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 13, 1, 21, 22, 423000),
#  'Day': 13,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 4, 17, 43, 29, 925000),
#  'Day': 4,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 22, 16, 55, 52, 291000),
#  'Day': 22,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 8, 8, 36, 31, 237000),
#  'Day': 8,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 29, 19, 21, 18, 436000),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 25, 9, 43, 32, 359000),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 28, 17, 46, 13, 824000),
#  'Day': 28,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 27, 4, 47, 10, 844000),
#  'Day': 27,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 23, 18, 30, 28, 940000),
#  'Day': 23,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 23, 9, 42, 57, 138000),
#  'Day': 23,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 1, 18, 24, 11, 779000),
#  'Day': 1,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 22, 13, 47, 46, 484000),
#  'Day': 22,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 10, 4, 22, 24, 143000),
#  'Day': 10,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 27, 18, 44, 47, 72000),
#  'Day': 27,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 25, 14, 33, 49, 793000),
#  'Day': 25,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 10, 11, 49, 50, 965000),
#  'Day': 10,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 8, 7, 11, 29, 572000),
#  'Day': 8,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 16, 3, 17, 19, 706000),
#  'Day': 16,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 30, 16, 0, 4, 243000),
#  'Day': 30,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 5, 11, 40, 39, 176000),
#  'Day': 5,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 30, 21, 21, 45, 925000),
#  'Day': 30,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 21, 17, 18, 42, 960000),
#  'Day': 21,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 18, 9, 53, 7, 77000),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 14, 15, 40, 57, 239000),
#  'Day': 14,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 4, 19, 34, 32, 798000),
#  'Day': 4,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 9, 7, 17, 58, 342000),
#  'Day': 9,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 15, 12, 49, 39, 72000),
#  'Day': 15,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 8, 20, 32, 1, 744000),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 24, 11, 47, 45, 498000),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 13, 2, 9, 28, 155000),
#  'Day': 13,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 17, 8, 5, 37, 211000),
#  'Day': 17,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 15, 17, 2, 32, 744000),
#  'Day': 15,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 12, 18, 23, 39, 381000),
#  'Day': 12,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 5, 9, 21, 30, 21000),
#  'Day': 5,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 16, 11, 39, 59, 870000),
#  'Day': 16,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 14, 8, 14, 22, 842000),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 28, 0, 28, 39, 431000),
#  'Day': 28,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 23, 13, 31, 55, 515000),
#  'Day': 23,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 23, 17, 3, 55, 193000),
#  'Day': 23,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 29, 20, 24, 8, 881000),
#  'Day': 29,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 1, 16, 49, 8, 798000),
#  'Day': 1,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 9, 18, 34, 34, 24000),
#  'Day': 9,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 12, 17, 57, 46, 544000),
#  'Day': 12,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 16, 23, 36, 33, 635000),
#  'Day': 16,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 29, 23, 31, 21, 304000),
#  'Day': 29,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 31, 22, 29, 3, 274000),
#  'Day': 31,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 8, 17, 16, 30, 798000),
#  'Day': 8,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 28, 6, 0, 2, 325000),
#  'Day': 28,
#  'Month': 10,
#  'Year': 2020}

# %% [markdown]
# ---
# ### Question -
#
# Difference between current date and the date of enrollment for enrollees.
#
# ----

# %%
# Date expression operators

result = db.hr.aggregate(
        
        # Pipeline
        [            
            # Stage 1
            {
                '$project':{
                            '_id':1,
                            'Difference':{
                                    # Answer returned in milliseconds
                                    '$subtract':['$$NOW', '$date_of_enrollment']
                                         }
                            }
            }
        ])

# Print results
for doc in result:
    pp.pprint(doc)
# Out:
# {'_id': ObjectId('60bc95fb12d1778df87722e2'), 'Difference': 152693345232}
# {'_id': ObjectId('60bc95fb12d1778df87722e3'), 'Difference': 36311718586}
# {'_id': ObjectId('60bc95fb12d1778df87722e4'), 'Difference': 142361135756}
# {'_id': ObjectId('60bc95fb12d1778df87722e5'), 'Difference': 162241394277}
# {'_id': ObjectId('60bc95fb12d1778df87722e6'), 'Difference': 153876823382}
# {'_id': ObjectId('60bc95fb12d1778df87722e7'), 'Difference': 53947060900}
# {'_id': ObjectId('60bc95fb12d1778df87722e8'), 'Difference': 132601629560}
# {'_id': ObjectId('60bc95fb12d1778df87722e9'), 'Difference': 70032290674}
# {'_id': ObjectId('60bc95fb12d1778df87722ea'), 'Difference': 27541788174}
# {'_id': ObjectId('60bc95fb12d1778df87722eb'), 'Difference': 115711830430}
# {'_id': ObjectId('60bc95fb12d1778df87722ec'), 'Difference': 80364437554}
# {'_id': ObjectId('60bc95fb12d1778df87722ed'), 'Difference': 116824191584}
# {'_id': ObjectId('60bc95fb12d1778df87722ee'), 'Difference': 32854987802}
# {'_id': ObjectId('60bc95fb12d1778df87722ef'), 'Difference': 53302541347}
# {'_id': ObjectId('60bc95fb12d1778df87722f0'), 'Difference': 77069579926}
# {'_id': ObjectId('60bc95fb12d1778df87722f1'), 'Difference': 96208338455}
# {'_id': ObjectId('60bc95fb12d1778df87722f2'), 'Difference': 35088075352}
# {'_id': ObjectId('60bc95fb12d1778df87722f3'), 'Difference': 23804459931}
# {'_id': ObjectId('60bc95fb12d1778df87722f4'), 'Difference': 33263404889}
# {'_id': ObjectId('60bc95fb12d1778df87722f5'), 'Difference': 129116473101}
# {'_id': ObjectId('60bc95fb12d1778df87722f6'), 'Difference': 125276368201}
# {'_id': ObjectId('60bc95fb12d1778df87722f7'), 'Difference': 31848568509}
# {'_id': ObjectId('60bc95fb12d1778df87722f8'), 'Difference': 69803864989}
# {'_id': ObjectId('60bc95fb12d1778df87722f9'), 'Difference': 96004414559}
# {'_id': ObjectId('60bc95fb12d1778df87722fa'), 'Difference': 200011043029}
# {'_id': ObjectId('60bc95fb12d1778df87722fb'), 'Difference': 160529136037}
# {'_id': ObjectId('60bc95fb12d1778df87722fc'), 'Difference': 103951629153}
# {'_id': ObjectId('60bc95fb12d1778df87722fd'), 'Difference': 72755419799}
# {'_id': ObjectId('60bc95fb12d1778df87722fe'), 'Difference': 13727554929}
# {'_id': ObjectId('60bc95fb12d1778df87722ff'), 'Difference': 93377730372}
# {'_id': ObjectId('60bc95fb12d1778df8772300'), 'Difference': 170434717310}
# {'_id': ObjectId('60bc95fb12d1778df8772301'), 'Difference': 103430564217}
# {'_id': ObjectId('60bc95fb12d1778df8772302'), 'Difference': 36407523397}
# {'_id': ObjectId('60bc95fb12d1778df8772303'), 'Difference': 162493697475}
# {'_id': ObjectId('60bc95fb12d1778df8772304'), 'Difference': 44707415012}
# {'_id': ObjectId('60bc95fb12d1778df8772305'), 'Difference': 66388946895}
# {'_id': ObjectId('60bc95fb12d1778df8772306'), 'Difference': 143232477833}
# {'_id': ObjectId('60bc95fb12d1778df8772307'), 'Difference': 102552403062}
# {'_id': ObjectId('60bc95fb12d1778df8772308'), 'Difference': 89692627140}
# {'_id': ObjectId('60bc95fb12d1778df8772309'), 'Difference': 107930840382}
# {'_id': ObjectId('60bc95fb12d1778df877230a'), 'Difference': 112262126243}
# {'_id': ObjectId('60bc95fb12d1778df877230b'), 'Difference': 193438234843}
# {'_id': ObjectId('60bc95fb12d1778df877230c'), 'Difference': 122972939427}
# {'_id': ObjectId('60bc95fb12d1778df877230d'), 'Difference': 145590666695}
# {'_id': ObjectId('60bc95fb12d1778df877230e'), 'Difference': 171186618265}
# {'_id': ObjectId('60bc95fb12d1778df877230f'), 'Difference': 129488236066}
# {'_id': ObjectId('60bc95fb12d1778df8772310'), 'Difference': 67202851644}
# {'_id': ObjectId('60bc95fb12d1778df8772311'), 'Difference': 160288784789}
# {'_id': ObjectId('60bc95fb12d1778df8772312'), 'Difference': 23722892995}
# {'_id': ObjectId('60bc95fb12d1778df8772313'), 'Difference': 61256917145}
# {'_id': ObjectId('60bc95fb12d1778df8772314'), 'Difference': 52074902013}
# {'_id': ObjectId('60bc95fb12d1778df8772315'), 'Difference': 32000672790}
# {'_id': ObjectId('60bc95fb12d1778df8772316'), 'Difference': 96831288390}
# {'_id': ObjectId('60bc95fb12d1778df8772317'), 'Difference': 59206694483}
# {'_id': ObjectId('60bc95fb12d1778df8772318'), 'Difference': 126393743662}
# {'_id': ObjectId('60bc95fb12d1778df8772319'), 'Difference': 165333564445}
# {'_id': ObjectId('60bc95fb12d1778df877231a'), 'Difference': 51759299635}
# {'_id': ObjectId('60bc95fb12d1778df877231b'), 'Difference': 46570865907}
# {'_id': ObjectId('60bc95fb12d1778df877231c'), 'Difference': 116280068632}
# {'_id': ObjectId('60bc95fb12d1778df877231d'), 'Difference': 148304277562}
# {'_id': ObjectId('60bc95fb12d1778df877231e'), 'Difference': 78362717062}
# {'_id': ObjectId('60bc95fb12d1778df877231f'), 'Difference': 69583436247}
# {'_id': ObjectId('60bc95fb12d1778df8772320'), 'Difference': 198664891638}
# {'_id': ObjectId('60bc95fb12d1778df8772321'), 'Difference': 21094381485}
# {'_id': ObjectId('60bc95fb12d1778df8772322'), 'Difference': 20945684637}
# {'_id': ObjectId('60bc95fb12d1778df8772323'), 'Difference': 52073640561}
# {'_id': ObjectId('60bc95fb12d1778df8772324'), 'Difference': 85555722976}
# {'_id': ObjectId('60bc95fb12d1778df8772325'), 'Difference': 125378705710}
# {'_id': ObjectId('60bc95fb12d1778df8772326'), 'Difference': 177964073957}
# {'_id': ObjectId('60bc95fb12d1778df8772327'), 'Difference': 96734012237}
# {'_id': ObjectId('60bc95fb12d1778df8772328'), 'Difference': 147980821840}
# {'_id': ObjectId('60bc95fb12d1778df8772329'), 'Difference': 27637741494}
# {'_id': ObjectId('60bc95fb12d1778df877232a'), 'Difference': 85232257867}
# {'_id': ObjectId('60bc95fb12d1778df877232b'), 'Difference': 18999049685}
# {'_id': ObjectId('60bc95fb12d1778df877232c'), 'Difference': 46404067972}
# {'_id': ObjectId('60bc95fb12d1778df877232d'), 'Difference': 86696282216}
# {'_id': ObjectId('60bc95fb12d1778df877232e'), 'Difference': 193270306413}
# {'_id': ObjectId('60bc95fb12d1778df877232f'), 'Difference': 105288017091}
# {'_id': ObjectId('60bc95fb12d1778df8772330'), 'Difference': 89564784370}
# {'_id': ObjectId('60bc95fb12d1778df8772331'), 'Difference': 23687089888}
# {'_id': ObjectId('60bc95fb12d1778df8772332'), 'Difference': 142834135117}
# {'_id': ObjectId('60bc95fb12d1778df8772333'), 'Difference': 136138373047}
# {'_id': ObjectId('60bc95fb12d1778df8772334'), 'Difference': 144596172807}
# {'_id': ObjectId('60bc95fb12d1778df8772335'), 'Difference': 176912793545}
# {'_id': ObjectId('60bc95fb12d1778df8772336'), 'Difference': 166345914769}
# {'_id': ObjectId('60bc95fb12d1778df8772337'), 'Difference': 108832815944}
# {'_id': ObjectId('60bc95fb12d1778df8772338'), 'Difference': 98193556793}
# {'_id': ObjectId('60bc95fb12d1778df8772339'), 'Difference': 71054201730}
# {'_id': ObjectId('60bc95fb12d1778df877233a'), 'Difference': 21394988204}
# {'_id': ObjectId('60bc95fb12d1778df877233b'), 'Difference': 142243350998}
# {'_id': ObjectId('60bc95fb12d1778df877233c'), 'Difference': 159420653413}
# {'_id': ObjectId('60bc95fb12d1778df877233d'), 'Difference': 69729330973}
# {'_id': ObjectId('60bc95fb12d1778df877233e'), 'Difference': 115724416225}
# {'_id': ObjectId('60bc95fb12d1778df877233f'), 'Difference': 158185283743}
# {'_id': ObjectId('60bc95fb12d1778df8772340'), 'Difference': 105415829027}
# {'_id': ObjectId('60bc95fb12d1778df8772341'), 'Difference': 47911409466}
# {'_id': ObjectId('60bc95fb12d1778df8772342'), 'Difference': 16742296534}
# {'_id': ObjectId('60bc95fb12d1778df8772343'), 'Difference': 194264446069}
# {'_id': ObjectId('60bc95fb12d1778df8772344'), 'Difference': 54900178717}
# {'_id': ObjectId('60bc95fb12d1778df8772345'), 'Difference': 193868223446}
# {'_id': ObjectId('60bc95fb12d1778df8772346'), 'Difference': 98054873831}
# {'_id': ObjectId('60bc95fb12d1778df8772347'), 'Difference': 111629103465}
# {'_id': ObjectId('60bc95fb12d1778df8772348'), 'Difference': 20311914535}
# {'_id': ObjectId('60bc95fb12d1778df8772349'), 'Difference': 52195327196}
# {'_id': ObjectId('60bc95fb12d1778df877234a'), 'Difference': 91093100670}
# {'_id': ObjectId('60bc95fb12d1778df877234b'), 'Difference': 115517455717}
# {'_id': ObjectId('60bc95fb12d1778df877234c'), 'Difference': 82128736311}
# {'_id': ObjectId('60bc95fb12d1778df877234d'), 'Difference': 117844130255}
# {'_id': ObjectId('60bc95fb12d1778df877234e'), 'Difference': 62300476667}
# {'_id': ObjectId('60bc95fb12d1778df877234f'), 'Difference': 150368727595}
# {'_id': ObjectId('60bc95fb12d1778df8772350'), 'Difference': 92366136757}
# {'_id': ObjectId('60bc95fb12d1778df8772351'), 'Difference': 64444931023}
# {'_id': ObjectId('60bc95fb12d1778df8772352'), 'Difference': 121027521119}
# {'_id': ObjectId('60bc95fb12d1778df8772353'), 'Difference': 123163854394}
# {'_id': ObjectId('60bc95fb12d1778df8772354'), 'Difference': 38459009686}
# {'_id': ObjectId('60bc95fb12d1778df8772355'), 'Difference': 202623068394}
# {'_id': ObjectId('60bc95fb12d1778df8772356'), 'Difference': 105557748624}
# {'_id': ObjectId('60bc95fb12d1778df8772357'), 'Difference': 150230213658}
# {'_id': ObjectId('60bc95fb12d1778df8772358'), 'Difference': 115763430766}
# {'_id': ObjectId('60bc95fb12d1778df8772359'), 'Difference': 114232755916}
# {'_id': ObjectId('60bc95fb12d1778df877235a'), 'Difference': 201975969287}
# {'_id': ObjectId('60bc95fb12d1778df877235b'), 'Difference': 141339077868}
# {'_id': ObjectId('60bc95fb12d1778df877235c'), 'Difference': 23455420660}
# {'_id': ObjectId('60bc95fb12d1778df877235d'), 'Difference': 142188209719}
# {'_id': ObjectId('60bc95fb12d1778df877235e'), 'Difference': 57459164431}
# {'_id': ObjectId('60bc95fb12d1778df877235f'), 'Difference': 15598660030}
# {'_id': ObjectId('60bc95fb12d1778df8772360'), 'Difference': 26535496582}
# {'_id': ObjectId('60bc95fb12d1778df8772361'), 'Difference': 190122905423}
# {'_id': ObjectId('60bc95fb12d1778df8772362'), 'Difference': 61961943476}
# {'_id': ObjectId('60bc95fb12d1778df8772363'), 'Difference': 61169630988}
# {'_id': ObjectId('60bc95fb12d1778df8772364'), 'Difference': 70687426623}
# {'_id': ObjectId('60bc95fb12d1778df8772365'), 'Difference': 133719830733}
# {'_id': ObjectId('60bc95fb12d1778df8772366'), 'Difference': 14761381606}
# {'_id': ObjectId('60bc95fb12d1778df8772367'), 'Difference': 195003179757}
# {'_id': ObjectId('60bc95fb12d1778df8772368'), 'Difference': 200106261046}
# {'_id': ObjectId('60bc95fb12d1778df8772369'), 'Difference': 16702504180}
# {'_id': ObjectId('60bc95fb12d1778df877236a'), 'Difference': 130234246172}
# {'_id': ObjectId('60bc95fb12d1778df877236b'), 'Difference': 61640994354}
# {'_id': ObjectId('60bc95fb12d1778df877236c'), 'Difference': 16072422189}
# {'_id': ObjectId('60bc95fb12d1778df877236d'), 'Difference': 200451094535}
# {'_id': ObjectId('60bc95fb12d1778df877236e'), 'Difference': 150050648757}
# {'_id': ObjectId('60bc95fb12d1778df877236f'), 'Difference': 100424269003}
# {'_id': ObjectId('60bc95fb12d1778df8772370'), 'Difference': 17253403955}
# {'_id': ObjectId('60bc95fb12d1778df8772371'), 'Difference': 164103323481}
# {'_id': ObjectId('60bc95fb12d1778df8772372'), 'Difference': 41565459642}
# {'_id': ObjectId('60bc95fb12d1778df8772373'), 'Difference': 160527140077}
# {'_id': ObjectId('60bc95fb12d1778df8772374'), 'Difference': 62599104199}
# {'_id': ObjectId('60bc95fb12d1778df8772375'), 'Difference': 177801047266}
# {'_id': ObjectId('60bc95fb12d1778df8772376'), 'Difference': 125816611531}
# {'_id': ObjectId('60bc95fb12d1778df8772377'), 'Difference': 178327896278}
# {'_id': ObjectId('60bc95fb12d1778df8772378'), 'Difference': 55714721416}
# {'_id': ObjectId('60bc95fb12d1778df8772379'), 'Difference': 186330006987}
# {'_id': ObjectId('60bc95fb12d1778df877237a'), 'Difference': 185487642095}
# {'_id': ObjectId('60bc95fb12d1778df877237b'), 'Difference': 78431573613}
# {'_id': ObjectId('60bc95fb12d1778df877237c'), 'Difference': 195129093144}
# {'_id': ObjectId('60bc95fb12d1778df877237d'), 'Difference': 122202376306}
# {'_id': ObjectId('60bc95fb12d1778df877237e'), 'Difference': 188669040982}
# {'_id': ObjectId('60bc95fb12d1778df877237f'), 'Difference': 138581901146}
# {'_id': ObjectId('60bc95fb12d1778df8772380'), 'Difference': 60155881115}
# {'_id': ObjectId('60bc95fb12d1778df8772381'), 'Difference': 27589841137}
# {'_id': ObjectId('60bc95fb12d1778df8772382'), 'Difference': 157842073920}
# {'_id': ObjectId('60bc95fb12d1778df8772383'), 'Difference': 41646220255}
# {'_id': ObjectId('60bc95fb12d1778df8772384'), 'Difference': 51845572174}
# {'_id': ObjectId('60bc95fb12d1778df8772385'), 'Difference': 66336937720}
# {'_id': ObjectId('60bc95fb12d1778df8772386'), 'Difference': 193986853567}
# {'_id': ObjectId('60bc95fb12d1778df8772387'), 'Difference': 200547274698}
# {'_id': ObjectId('60bc95fb12d1778df8772388'), 'Difference': 50809513336}
# {'_id': ObjectId('60bc95fb12d1778df8772389'), 'Difference': 87618690389}
# {'_id': ObjectId('60bc95fb12d1778df877238a'), 'Difference': 61257768447}
# {'_id': ObjectId('60bc95fb12d1778df877238b'), 'Difference': 120163776818}
# {'_id': ObjectId('60bc95fb12d1778df877238c'), 'Difference': 87911849016}
# {'_id': ObjectId('60bc95fb12d1778df877238d'), 'Difference': 180404220832}
# {'_id': ObjectId('60bc95fb12d1778df877238e'), 'Difference': 186153706170}
# {'_id': ObjectId('60bc95fb12d1778df877238f'), 'Difference': 56634265860}
# {'_id': ObjectId('60bc95fb12d1778df8772390'), 'Difference': 57589835809}
# {'_id': ObjectId('60bc95fb12d1778df8772391'), 'Difference': 79737243096}
# {'_id': ObjectId('60bc95fb12d1778df8772392'), 'Difference': 45505651312}
# {'_id': ObjectId('60bc95fb12d1778df8772393'), 'Difference': 182718767013}
# {'_id': ObjectId('60bc95fb12d1778df8772394'), 'Difference': 144333370306}
# {'_id': ObjectId('60bc95fb12d1778df8772395'), 'Difference': 113529651642}
# {'_id': ObjectId('60bc95fb12d1778df8772396'), 'Difference': 181094249985}
# {'_id': ObjectId('60bc95fb12d1778df8772397'), 'Difference': 78553232975}
# {'_id': ObjectId('60bc95fb12d1778df8772398'), 'Difference': 32647919501}
# {'_id': ObjectId('60bc95fb12d1778df8772399'), 'Difference': 187602593992}
# {'_id': ObjectId('60bc95fb12d1778df877239a'), 'Difference': 110457546104}
# {'_id': ObjectId('60bc95fb12d1778df877239b'), 'Difference': 96457038365}
# {'_id': ObjectId('60bc95fb12d1778df877239c'), 'Difference': 126904632161}
# {'_id': ObjectId('60bc95fb12d1778df877239d'), 'Difference': 124801254896}
# {'_id': ObjectId('60bc95fb12d1778df877239e'), 'Difference': 85930602782}
# {'_id': ObjectId('60bc95fb12d1778df877239f'), 'Difference': 61228771373}
# {'_id': ObjectId('60bc95fb12d1778df87723a0'), 'Difference': 197626004175}
# {'_id': ObjectId('60bc95fb12d1778df87723a1'), 'Difference': 142190708535}
# {'_id': ObjectId('60bc95fb12d1778df87723a2'), 'Difference': 121821381358}
# {'_id': ObjectId('60bc95fb12d1778df87723a3'), 'Difference': 170419994837}
# {'_id': ObjectId('60bc95fb12d1778df87723a4'), 'Difference': 163769558313}
# {'_id': ObjectId('60bc95fb12d1778df87723a5'), 'Difference': 87807860165}
# {'_id': ObjectId('60bc95fb12d1778df87723a6'), 'Difference': 78048782365}
# {'_id': ObjectId('60bc95fb12d1778df87723a7'), 'Difference': 147805804774}
# {'_id': ObjectId('60bc95fb12d1778df87723a8'), 'Difference': 53060919269}
# {'_id': ObjectId('60bc95fb12d1778df87723a9'), 'Difference': 177770685322}
# {'_id': ObjectId('60bc95fb12d1778df87723aa'), 'Difference': 69459105074}
# {'_id': ObjectId('60bc95fb12d1778df87723ab'), 'Difference': 180240220008}
# {'_id': ObjectId('60bc95fb12d1778df87723ac'), 'Difference': 132178758156}
# {'_id': ObjectId('60bc95fb12d1778df87723ad'), 'Difference': 81806760410}
# {'_id': ObjectId('60bc95fb12d1778df87723ae'), 'Difference': 165081592714}
# {'_id': ObjectId('60bc95fb12d1778df87723af'), 'Difference': 157805296350}
# {'_id': ObjectId('60bc95fb12d1778df87723b0'), 'Difference': 61599986907}
# {'_id': ObjectId('60bc95fb12d1778df87723b1'), 'Difference': 82813305359}
# {'_id': ObjectId('60bc95fb12d1778df87723b2'), 'Difference': 114164383947}
# {'_id': ObjectId('60bc95fb12d1778df87723b3'), 'Difference': 191111594303}
# {'_id': ObjectId('60bc95fb12d1778df87723b4'), 'Difference': 79587991353}
# {'_id': ObjectId('60bc95fb12d1778df87723b5'), 'Difference': 83823137397}
# {'_id': ObjectId('60bc95fb12d1778df87723b6'), 'Difference': 115729314088}
# {'_id': ObjectId('60bc95fb12d1778df87723b7'), 'Difference': 193315493804}
# {'_id': ObjectId('60bc95fb12d1778df87723b8'), 'Difference': 49218248926}
# {'_id': ObjectId('60bc95fb12d1778df87723b9'), 'Difference': 139797737392}
# {'_id': ObjectId('60bc95fb12d1778df87723ba'), 'Difference': 152785526625}
# {'_id': ObjectId('60bc95fb12d1778df87723bb'), 'Difference': 54002939758}
# {'_id': ObjectId('60bc95fb12d1778df87723bc'), 'Difference': 85121406344}
# {'_id': ObjectId('60bc95fb12d1778df87723bd'), 'Difference': 122175930083}
# {'_id': ObjectId('60bc95fb12d1778df87723be'), 'Difference': 103169928767}
# {'_id': ObjectId('60bc95fb12d1778df87723bf'), 'Difference': 94262673598}
# {'_id': ObjectId('60bc95fb12d1778df87723c0'), 'Difference': 148644863462}
# {'_id': ObjectId('60bc95fb12d1778df87723c1'), 'Difference': 107017599495}
# {'_id': ObjectId('60bc95fb12d1778df87723c2'), 'Difference': 88638167750}
# {'_id': ObjectId('60bc95fb12d1778df87723c3'), 'Difference': 180781835303}
# {'_id': ObjectId('60bc95fb12d1778df87723c4'), 'Difference': 192255717904}
# {'_id': ObjectId('60bc95fb12d1778df87723c5'), 'Difference': 13910913534}
# {'_id': ObjectId('60bc95fb12d1778df87723c6'), 'Difference': 55826459366}
# {'_id': ObjectId('60bc95fb12d1778df87723c7'), 'Difference': 179787602008}
# {'_id': ObjectId('60bc95fb12d1778df87723c8'), 'Difference': 170713844576}
# {'_id': ObjectId('60bc95fb12d1778df87723c9'), 'Difference': 14161064348}
# {'_id': ObjectId('60bc95fb12d1778df87723ca'), 'Difference': 177561370166}
# {'_id': ObjectId('60bc95fb12d1778df87723cb'), 'Difference': 45621239771}
# {'_id': ObjectId('60bc95fb12d1778df87723cc'), 'Difference': 16834736219}
# {'_id': ObjectId('60bc95fb12d1778df87723cd'), 'Difference': 140479084923}
# {'_id': ObjectId('60bc95fb12d1778df87723ce'), 'Difference': 178010550823}
# {'_id': ObjectId('60bc95fb12d1778df87723cf'), 'Difference': 170677637208}
# {'_id': ObjectId('60bc95fb12d1778df87723d0'), 'Difference': 173927517658}
# {'_id': ObjectId('60bc95fb12d1778df87723d1'), 'Difference': 17645177946}
# {'_id': ObjectId('60bc95fb12d1778df87723d2'), 'Difference': 149029563493}
# {'_id': ObjectId('60bc95fb12d1778df87723d3'), 'Difference': 45454967506}
# {'_id': ObjectId('60bc95fb12d1778df87723d4'), 'Difference': 114568263909}
# {'_id': ObjectId('60bc95fb12d1778df87723d5'), 'Difference': 182385781057}
# {'_id': ObjectId('60bc95fb12d1778df87723d6'), 'Difference': 58963201062}
# {'_id': ObjectId('60bc95fb12d1778df87723d7'), 'Difference': 151177510349}
# {'_id': ObjectId('60bc95fb12d1778df87723d8'), 'Difference': 77492268060}
# {'_id': ObjectId('60bc95fb12d1778df87723d9'), 'Difference': 37485548678}
# {'_id': ObjectId('60bc95fb12d1778df87723da'), 'Difference': 146098032316}
# {'_id': ObjectId('60bc95fb12d1778df87723db'), 'Difference': 75296735078}
# {'_id': ObjectId('60bc95fb12d1778df87723dc'), 'Difference': 51466276902}
# {'_id': ObjectId('60bc95fb12d1778df87723dd'), 'Difference': 71959212261}
# {'_id': ObjectId('60bc95fb12d1778df87723de'), 'Difference': 173275289295}
# {'_id': ObjectId('60bc95fb12d1778df87723df'), 'Difference': 67771378338}
# {'_id': ObjectId('60bc95fb12d1778df87723e0'), 'Difference': 185316687790}
# {'_id': ObjectId('60bc95fb12d1778df87723e1'), 'Difference': 35044113039}
# {'_id': ObjectId('60bc95fb12d1778df87723e2'), 'Difference': 120003550791}
# {'_id': ObjectId('60bc95fb12d1778df87723e3'), 'Difference': 160561040041}
# {'_id': ObjectId('60bc95fb12d1778df87723e4'), 'Difference': 77628911563}
# {'_id': ObjectId('60bc95fb12d1778df87723e5'), 'Difference': 39842441253}
# {'_id': ObjectId('60bc95fb12d1778df87723e6'), 'Difference': 159893910422}
# {'_id': ObjectId('60bc95fb12d1778df87723e7'), 'Difference': 17348385751}
# {'_id': ObjectId('60bc95fb12d1778df87723e8'), 'Difference': 110401902706}
# {'_id': ObjectId('60bc95fb12d1778df87723e9'), 'Difference': 185062927300}
# {'_id': ObjectId('60bc95fb12d1778df87723ea'), 'Difference': 74786445436}
# {'_id': ObjectId('60bc95fb12d1778df87723eb'), 'Difference': 83028020555}
# {'_id': ObjectId('60bc95fb12d1778df87723ec'), 'Difference': 75416145772}
# {'_id': ObjectId('60bc95fb12d1778df87723ed'), 'Difference': 17635540415}
# {'_id': ObjectId('60bc95fb12d1778df87723ee'), 'Difference': 182711564499}
# {'_id': ObjectId('60bc95fb12d1778df87723ef'), 'Difference': 106568952183}
# {'_id': ObjectId('60bc95fb12d1778df87723f0'), 'Difference': 124116333988}
# {'_id': ObjectId('60bc95fb12d1778df87723f1'), 'Difference': 53021154550}
# {'_id': ObjectId('60bc95fb12d1778df87723f2'), 'Difference': 47031142820}
# {'_id': ObjectId('60bc95fb12d1778df87723f3'), 'Difference': 94854495494}
# {'_id': ObjectId('60bc95fb12d1778df87723f4'), 'Difference': 101563457129}
# {'_id': ObjectId('60bc95fb12d1778df87723f5'), 'Difference': 70357202698}
# {'_id': ObjectId('60bc95fb12d1778df87723f6'), 'Difference': 192287917012}
# {'_id': ObjectId('60bc95fb12d1778df87723f7'), 'Difference': 136927348123}
# {'_id': ObjectId('60bc95fb12d1778df87723f8'), 'Difference': 104768408629}
# {'_id': ObjectId('60bc95fb12d1778df87723f9'), 'Difference': 25814420468}
# {'_id': ObjectId('60bc95fb12d1778df87723fa'), 'Difference': 14395845721}
# {'_id': ObjectId('60bc95fb12d1778df87723fb'), 'Difference': 124200512170}
# {'_id': ObjectId('60bc95fb12d1778df87723fc'), 'Difference': 113924385821}
# {'_id': ObjectId('60bc95fb12d1778df87723fd'), 'Difference': 108806863480}
# {'_id': ObjectId('60bc95fb12d1778df87723fe'), 'Difference': 154948963950}
# {'_id': ObjectId('60bc95fb12d1778df87723ff'), 'Difference': 67014994175}
# {'_id': ObjectId('60bc95fb12d1778df8772400'), 'Difference': 32790110987}
# {'_id': ObjectId('60bc95fb12d1778df8772401'), 'Difference': 159002860177}
# {'_id': ObjectId('60bc95fb12d1778df8772402'), 'Difference': 114011326503}
# {'_id': ObjectId('60bc95fb12d1778df8772403'), 'Difference': 69899870100}
# {'_id': ObjectId('60bc95fb12d1778df8772404'), 'Difference': 124563978242}
# {'_id': ObjectId('60bc95fb12d1778df8772405'), 'Difference': 168636139317}
# {'_id': ObjectId('60bc95fb12d1778df8772406'), 'Difference': 107308160141}
# {'_id': ObjectId('60bc95fb12d1778df8772407'), 'Difference': 68818447388}
# {'_id': ObjectId('60bc95fb12d1778df8772408'), 'Difference': 164706624595}
# {'_id': ObjectId('60bc95fb12d1778df8772409'), 'Difference': 194849604846}
# {'_id': ObjectId('60bc95fb12d1778df877240a'), 'Difference': 180469354870}
# {'_id': ObjectId('60bc95fb12d1778df877240b'), 'Difference': 39679724413}
# {'_id': ObjectId('60bc95fb12d1778df877240c'), 'Difference': 62968796105}
# {'_id': ObjectId('60bc95fb12d1778df877240d'), 'Difference': 37309872468}
# {'_id': ObjectId('60bc95fb12d1778df877240e'), 'Difference': 72270507323}
# {'_id': ObjectId('60bc95fb12d1778df877240f'), 'Difference': 45345145466}
# {'_id': ObjectId('60bc95fb12d1778df8772410'), 'Difference': 70515225782}
# {'_id': ObjectId('60bc95fb12d1778df8772411'), 'Difference': 200275966372}
# {'_id': ObjectId('60bc95fb12d1778df8772412'), 'Difference': 130742528875}
# {'_id': ObjectId('60bc95fb12d1778df8772413'), 'Difference': 179627780144}
# {'_id': ObjectId('60bc95fb12d1778df8772414'), 'Difference': 132975851416}
# {'_id': ObjectId('60bc95fb12d1778df8772415'), 'Difference': 35616998495}
# {'_id': ObjectId('60bc95fb12d1778df8772416'), 'Difference': 96381522627}
# {'_id': ObjectId('60bc95fb12d1778df8772417'), 'Difference': 112480494124}
# {'_id': ObjectId('60bc95fb12d1778df8772418'), 'Difference': 191953190205}
# {'_id': ObjectId('60bc95fb12d1778df8772419'), 'Difference': 122386584303}
# {'_id': ObjectId('60bc95fb12d1778df877241a'), 'Difference': 64215985646}
# {'_id': ObjectId('60bc95fb12d1778df877241b'), 'Difference': 171403901865}
# {'_id': ObjectId('60bc95fb12d1778df877241c'), 'Difference': 69515300519}
# {'_id': ObjectId('60bc95fb12d1778df877241d'), 'Difference': 44261339779}
# {'_id': ObjectId('60bc95fb12d1778df877241e'), 'Difference': 134766404135}
# {'_id': ObjectId('60bc95fb12d1778df877241f'), 'Difference': 148307639829}
# {'_id': ObjectId('60bc95fb12d1778df8772420'), 'Difference': 99417025326}
# {'_id': ObjectId('60bc95fb12d1778df8772421'), 'Difference': 171000514454}
# {'_id': ObjectId('60bc95fb12d1778df8772422'), 'Difference': 132413068799}
# {'_id': ObjectId('60bc95fb12d1778df8772423'), 'Difference': 139363488923}
# {'_id': ObjectId('60bc95fb12d1778df8772424'), 'Difference': 37624581149}
# {'_id': ObjectId('60bc95fb12d1778df8772425'), 'Difference': 89229127546}
# {'_id': ObjectId('60bc95fb12d1778df8772426'), 'Difference': 90276882436}
# {'_id': ObjectId('60bc95fb12d1778df8772427'), 'Difference': 152302150036}
# {'_id': ObjectId('60bc95fb12d1778df8772428'), 'Difference': 51690414823}
# {'_id': ObjectId('60bc95fb12d1778df8772429'), 'Difference': 129852325419}
# {'_id': ObjectId('60bc95fb12d1778df877242a'), 'Difference': 105689026209}
# {'_id': ObjectId('60bc95fb12d1778df877242b'), 'Difference': 55005387828}
# {'_id': ObjectId('60bc95fb12d1778df877242c'), 'Difference': 76805524744}
# {'_id': ObjectId('60bc95fb12d1778df877242d'), 'Difference': 61359084230}
# {'_id': ObjectId('60bc95fb12d1778df877242e'), 'Difference': 45741730141}
# {'_id': ObjectId('60bc95fb12d1778df877242f'), 'Difference': 117737574698}
# {'_id': ObjectId('60bc95fb12d1778df8772430'), 'Difference': 168304425641}
# {'_id': ObjectId('60bc95fb12d1778df8772431'), 'Difference': 139551838731}
# {'_id': ObjectId('60bc95fb12d1778df8772432'), 'Difference': 88683266217}
# {'_id': ObjectId('60bc95fb12d1778df8772433'), 'Difference': 157330595897}
# {'_id': ObjectId('60bc95fb12d1778df8772434'), 'Difference': 61261698349}
# {'_id': ObjectId('60bc95fb12d1778df8772435'), 'Difference': 78252825304}
# {'_id': ObjectId('60bc95fb12d1778df8772436'), 'Difference': 144712414057}
# {'_id': ObjectId('60bc95fb12d1778df8772437'), 'Difference': 47552536219}
# {'_id': ObjectId('60bc95fb12d1778df8772438'), 'Difference': 197897818440}
# {'_id': ObjectId('60bc95fb12d1778df8772439'), 'Difference': 113419777473}
# {'_id': ObjectId('60bc95fb12d1778df877243a'), 'Difference': 37246844202}
# {'_id': ObjectId('60bc95fb12d1778df877243b'), 'Difference': 109280958449}
# {'_id': ObjectId('60bc95fb12d1778df877243c'), 'Difference': 173399499617}
# {'_id': ObjectId('60bc95fb12d1778df877243d'), 'Difference': 176537187387}
# {'_id': ObjectId('60bc95fb12d1778df877243e'), 'Difference': 202102683365}
# {'_id': ObjectId('60bc95fb12d1778df877243f'), 'Difference': 34061943413}
# {'_id': ObjectId('60bc95fb12d1778df8772440'), 'Difference': 124558343659}
# {'_id': ObjectId('60bc95fb12d1778df8772441'), 'Difference': 174965161160}
# {'_id': ObjectId('60bc95fb12d1778df8772442'), 'Difference': 168614704809}
# {'_id': ObjectId('60bc95fb12d1778df8772443'), 'Difference': 25207508479}
# {'_id': ObjectId('60bc95fb12d1778df8772444'), 'Difference': 104794362518}
# {'_id': ObjectId('60bc95fb12d1778df8772445'), 'Difference': 107707810086}
# {'_id': ObjectId('60bc95fb12d1778df8772446'), 'Difference': 113891264601}
# {'_id': ObjectId('60bc95fb12d1778df8772447'), 'Difference': 158575155120}
# {'_id': ObjectId('60bc95fb12d1778df8772448'), 'Difference': 112301320608}
# {'_id': ObjectId('60bc95fb12d1778df8772449'), 'Difference': 27750614481}
# {'_id': ObjectId('60bc95fb12d1778df877244a'), 'Difference': 33685232088}
# {'_id': ObjectId('60bc95fb12d1778df877244b'), 'Difference': 25443144216}
# {'_id': ObjectId('60bc95fb12d1778df877244c'), 'Difference': 97954790308}
# {'_id': ObjectId('60bc95fb12d1778df877244d'), 'Difference': 96165356696}
# {'_id': ObjectId('60bc95fb12d1778df877244e'), 'Difference': 178583951830}
# {'_id': ObjectId('60bc95fb12d1778df877244f'), 'Difference': 55962823179}
# {'_id': ObjectId('60bc95fb12d1778df8772450'), 'Difference': 38414042740}
# {'_id': ObjectId('60bc95fb12d1778df8772451'), 'Difference': 37053740987}
# {'_id': ObjectId('60bc95fb12d1778df8772452'), 'Difference': 136310300846}
# {'_id': ObjectId('60bc95fb12d1778df8772453'), 'Difference': 174923457596}
# {'_id': ObjectId('60bc95fb12d1778df8772454'), 'Difference': 151154834617}
# {'_id': ObjectId('60bc95fb12d1778df8772455'), 'Difference': 28505525956}
# {'_id': ObjectId('60bc95fb12d1778df8772456'), 'Difference': 188461170783}
# {'_id': ObjectId('60bc95fb12d1778df8772457'), 'Difference': 83371922758}
# {'_id': ObjectId('60bc95fb12d1778df8772458'), 'Difference': 178992172336}
# {'_id': ObjectId('60bc95fb12d1778df8772459'), 'Difference': 95090080210}
# {'_id': ObjectId('60bc95fb12d1778df877245a'), 'Difference': 195511563619}
# {'_id': ObjectId('60bc95fb12d1778df877245b'), 'Difference': 90768196883}
# {'_id': ObjectId('60bc95fb12d1778df877245c'), 'Difference': 50123939457}
# {'_id': ObjectId('60bc95fb12d1778df877245d'), 'Difference': 124134435811}
# {'_id': ObjectId('60bc95fb12d1778df877245e'), 'Difference': 124426870092}
# {'_id': ObjectId('60bc95fb12d1778df877245f'), 'Difference': 37115413043}
# {'_id': ObjectId('60bc95fb12d1778df8772460'), 'Difference': 179432362318}
# {'_id': ObjectId('60bc95fb12d1778df8772461'), 'Difference': 149752677048}
# {'_id': ObjectId('60bc95fb12d1778df8772462'), 'Difference': 94766044239}
# {'_id': ObjectId('60bc95fb12d1778df8772463'), 'Difference': 110265183400}
# {'_id': ObjectId('60bc95fb12d1778df8772464'), 'Difference': 104238795978}
# {'_id': ObjectId('60bc95fb12d1778df8772465'), 'Difference': 156733844498}
# {'_id': ObjectId('60bc95fb12d1778df8772466'), 'Difference': 196544044707}
# {'_id': ObjectId('60bc95fb12d1778df8772467'), 'Difference': 184785718690}
# {'_id': ObjectId('60bc95fb12d1778df8772468'), 'Difference': 191035350595}
# {'_id': ObjectId('60bc95fb12d1778df8772469'), 'Difference': 48907180948}
# {'_id': ObjectId('60bc95fb12d1778df877246a'), 'Difference': 164050647728}
# {'_id': ObjectId('60bc95fb12d1778df877246b'), 'Difference': 153314498096}
# {'_id': ObjectId('60bc95fb12d1778df877246c'), 'Difference': 100975035416}
# {'_id': ObjectId('60bc95fb12d1778df877246d'), 'Difference': 162953065965}
# {'_id': ObjectId('60bc95fb12d1778df877246e'), 'Difference': 198521931414}
# {'_id': ObjectId('60bc95fb12d1778df877246f'), 'Difference': 121905416744}
# {'_id': ObjectId('60bc95fb12d1778df8772470'), 'Difference': 113093899046}
# {'_id': ObjectId('60bc95fb12d1778df8772471'), 'Difference': 110779623917}
# {'_id': ObjectId('60bc95fb12d1778df8772472'), 'Difference': 159601080279}
# {'_id': ObjectId('60bc95fb12d1778df8772473'), 'Difference': 113222794919}
# {'_id': ObjectId('60bc95fb12d1778df8772474'), 'Difference': 22114243603}
# {'_id': ObjectId('60bc95fb12d1778df8772475'), 'Difference': 106610813264}
# {'_id': ObjectId('60bc95fb12d1778df8772476'), 'Difference': 127969479170}
# {'_id': ObjectId('60bc95fb12d1778df8772477'), 'Difference': 190713372083}
# {'_id': ObjectId('60bc95fb12d1778df8772478'), 'Difference': 102477491364}
# {'_id': ObjectId('60bc95fb12d1778df8772479'), 'Difference': 103703148640}
# {'_id': ObjectId('60bc95fb12d1778df877247a'), 'Difference': 46545630720}
# {'_id': ObjectId('60bc95fb12d1778df877247b'), 'Difference': 56167070711}
# {'_id': ObjectId('60bc95fb12d1778df877247c'), 'Difference': 181513143163}
# {'_id': ObjectId('60bc95fb12d1778df877247d'), 'Difference': 152758455010}
# {'_id': ObjectId('60bc95fb12d1778df877247e'), 'Difference': 25834572163}
# {'_id': ObjectId('60bc95fb12d1778df877247f'), 'Difference': 173515172435}
# {'_id': ObjectId('60bc95fb12d1778df8772480'), 'Difference': 145373713075}
# {'_id': ObjectId('60bc95fb12d1778df8772481'), 'Difference': 115757471365}
# {'_id': ObjectId('60bc95fb12d1778df8772482'), 'Difference': 44205079293}
# {'_id': ObjectId('60bc95fb12d1778df8772483'), 'Difference': 107910915052}
# {'_id': ObjectId('60bc95fb12d1778df8772484'), 'Difference': 150910107313}
# {'_id': ObjectId('60bc95fb12d1778df8772485'), 'Difference': 18234447615}
# {'_id': ObjectId('60bc95fb12d1778df8772486'), 'Difference': 96121023336}
# {'_id': ObjectId('60bc95fb12d1778df8772487'), 'Difference': 37158775652}
# {'_id': ObjectId('60bc95fb12d1778df8772488'), 'Difference': 187073672959}
# {'_id': ObjectId('60bc95fb12d1778df8772489'), 'Difference': 110075969401}
# {'_id': ObjectId('60bc95fb12d1778df877248a'), 'Difference': 161060449228}
# {'_id': ObjectId('60bc95fb12d1778df877248b'), 'Difference': 98697375107}
# {'_id': ObjectId('60bc95fb12d1778df877248c'), 'Difference': 97406976213}
# {'_id': ObjectId('60bc95fb12d1778df877248d'), 'Difference': 107337229729}
# {'_id': ObjectId('60bc95fb12d1778df877248e'), 'Difference': 160473665381}
# {'_id': ObjectId('60bc95fb12d1778df877248f'), 'Difference': 145273874039}
# {'_id': ObjectId('60bc95fb12d1778df8772490'), 'Difference': 191288207319}
# {'_id': ObjectId('60bc95fb12d1778df8772491'), 'Difference': 181199430859}
# {'_id': ObjectId('60bc95fb12d1778df8772492'), 'Difference': 119512143769}
# {'_id': ObjectId('60bc95fb12d1778df8772493'), 'Difference': 18092564829}
# {'_id': ObjectId('60bc95fb12d1778df8772494'), 'Difference': 154484321544}
# {'_id': ObjectId('60bc95fb12d1778df8772495'), 'Difference': 52051865189}
# {'_id': ObjectId('60bc95fb12d1778df8772496'), 'Difference': 178287262339}
# {'_id': ObjectId('60bc95fb12d1778df8772497'), 'Difference': 97471733778}
# {'_id': ObjectId('60bc95fb12d1778df8772498'), 'Difference': 113957130043}
# {'_id': ObjectId('60bc95fb12d1778df8772499'), 'Difference': 110185544930}
# {'_id': ObjectId('60bc95fb12d1778df877249a'), 'Difference': 172771995241}
# {'_id': ObjectId('60bc95fb12d1778df877249b'), 'Difference': 128121469102}
# {'_id': ObjectId('60bc95fb12d1778df877249c'), 'Difference': 186099998239}
# {'_id': ObjectId('60bc95fb12d1778df877249d'), 'Difference': 190059997549}
# {'_id': ObjectId('60bc95fb12d1778df877249e'), 'Difference': 130510359200}
# {'_id': ObjectId('60bc95fb12d1778df877249f'), 'Difference': 187877345979}
# {'_id': ObjectId('60bc95fb12d1778df87724a0'), 'Difference': 70329335077}
# {'_id': ObjectId('60bc95fb12d1778df87724a1'), 'Difference': 113635141811}
# {'_id': ObjectId('60bc95fb12d1778df87724a2'), 'Difference': 145663193818}
# {'_id': ObjectId('60bc95fb12d1778df87724a3'), 'Difference': 60108390735}
# {'_id': ObjectId('60bc95fb12d1778df87724a4'), 'Difference': 164097817691}
# {'_id': ObjectId('60bc95fb12d1778df87724a5'), 'Difference': 93224167658}
# {'_id': ObjectId('60bc95fb12d1778df87724a6'), 'Difference': 93842644876}
# {'_id': ObjectId('60bc95fb12d1778df87724a7'), 'Difference': 102545685391}
# {'_id': ObjectId('60bc95fb12d1778df87724a8'), 'Difference': 107917667423}
# {'_id': ObjectId('60bc95fb12d1778df87724a9'), 'Difference': 53994114373}
# {'_id': ObjectId('60bc95fb12d1778df87724aa'), 'Difference': 178672604162}
# {'_id': ObjectId('60bc95fb12d1778df87724ab'), 'Difference': 17187019736}
# {'_id': ObjectId('60bc95fb12d1778df87724ac'), 'Difference': 107571032371}
# {'_id': ObjectId('60bc95fb12d1778df87724ad'), 'Difference': 93495754058}
# {'_id': ObjectId('60bc95fb12d1778df87724ae'), 'Difference': 16982964446}
# {'_id': ObjectId('60bc95fb12d1778df87724af'), 'Difference': 71599082983}
# {'_id': ObjectId('60bc95fb12d1778df87724b0'), 'Difference': 63162812087}
# {'_id': ObjectId('60bc95fb12d1778df87724b1'), 'Difference': 48043029431}
# {'_id': ObjectId('60bc95fb12d1778df87724b2'), 'Difference': 23705281674}
# {'_id': ObjectId('60bc95fb12d1778df87724b3'), 'Difference': 53674908393}
# {'_id': ObjectId('60bc95fb12d1778df87724b4'), 'Difference': 160830157565}
# {'_id': ObjectId('60bc95fb12d1778df87724b5'), 'Difference': 24686262244}
# {'_id': ObjectId('60bc95fb12d1778df87724b6'), 'Difference': 96348023451}
# {'_id': ObjectId('60bc95fb12d1778df87724b7'), 'Difference': 150655596393}
# {'_id': ObjectId('60bc95fb12d1778df87724b8'), 'Difference': 73483455365}
# {'_id': ObjectId('60bc95fb12d1778df87724b9'), 'Difference': 78651459645}
# {'_id': ObjectId('60bc95fb12d1778df87724ba'), 'Difference': 118083306384}
# {'_id': ObjectId('60bc95fb12d1778df87724bb'), 'Difference': 88438579001}
# {'_id': ObjectId('60bc95fb12d1778df87724bc'), 'Difference': 150252033877}
# {'_id': ObjectId('60bc95fb12d1778df87724bd'), 'Difference': 55927490505}
# {'_id': ObjectId('60bc95fb12d1778df87724be'), 'Difference': 21779142126}
# {'_id': ObjectId('60bc95fb12d1778df87724bf'), 'Difference': 111320960952}
# {'_id': ObjectId('60bc95fb12d1778df87724c0'), 'Difference': 152140839435}
# {'_id': ObjectId('60bc95fb12d1778df87724c1'), 'Difference': 40229961242}
# {'_id': ObjectId('60bc95fb12d1778df87724c2'), 'Difference': 177266967411}
# {'_id': ObjectId('60bc95fb12d1778df87724c3'), 'Difference': 163148684710}
# {'_id': ObjectId('60bc95fb12d1778df87724c4'), 'Difference': 89743127732}
# {'_id': ObjectId('60bc95fb12d1778df87724c5'), 'Difference': 67526970422}
# {'_id': ObjectId('60bc95fb12d1778df87724c6'), 'Difference': 57122242133}
# {'_id': ObjectId('60bc95fb12d1778df87724c7'), 'Difference': 186993379657}
# {'_id': ObjectId('60bc95fb12d1778df87724c8'), 'Difference': 156731694345}
# {'_id': ObjectId('60bc95fb12d1778df87724c9'), 'Difference': 134163851248}
# {'_id': ObjectId('60bc95fb12d1778df87724ca'), 'Difference': 60734275430}
# {'_id': ObjectId('60bc95fb12d1778df87724cb'), 'Difference': 124764045097}
# {'_id': ObjectId('60bc95fb12d1778df87724cc'), 'Difference': 103037479343}
# {'_id': ObjectId('60bc95fb12d1778df87724cd'), 'Difference': 141116682360}
# {'_id': ObjectId('60bc95fb12d1778df87724ce'), 'Difference': 30538288133}
# {'_id': ObjectId('60bc95fb12d1778df87724cf'), 'Difference': 15290985994}
# {'_id': ObjectId('60bc95fb12d1778df87724d0'), 'Difference': 40218823491}
# {'_id': ObjectId('60bc95fb12d1778df87724d1'), 'Difference': 195894675947}
# {'_id': ObjectId('60bc95fb12d1778df87724d2'), 'Difference': 94236300319}
# {'_id': ObjectId('60bc95fb12d1778df87724d3'), 'Difference': 177631007197}
# {'_id': ObjectId('60bc95fb12d1778df87724d4'), 'Difference': 76608804023}
# {'_id': ObjectId('60bc95fb12d1778df87724d5'), 'Difference': 14776553480}
# {'_id': ObjectId('60bc95fb12d1778df87724d6'), 'Difference': 166510819701}
# {'_id': ObjectId('60bc95fb12d1778df87724d7'), 'Difference': 121464083202}
# {'_id': ObjectId('60bc95fb12d1778df87724d8'), 'Difference': 128287319785}
# {'_id': ObjectId('60bc95fb12d1778df87724d9'), 'Difference': 159992811170}
# {'_id': ObjectId('60bc95fb12d1778df87724da'), 'Difference': 85858349173}
# {'_id': ObjectId('60bc95fb12d1778df87724db'), 'Difference': 116374967215}
# {'_id': ObjectId('60bc95fb12d1778df87724dc'), 'Difference': 21549428154}
# {'_id': ObjectId('60bc95fb12d1778df87724dd'), 'Difference': 48141108241}
# {'_id': ObjectId('60bc95fb12d1778df87724de'), 'Difference': 182684982261}
# {'_id': ObjectId('60bc95fb12d1778df87724df'), 'Difference': 145235910034}
# {'_id': ObjectId('60bc95fb12d1778df87724e0'), 'Difference': 28927187235}
# {'_id': ObjectId('60bc95fb12d1778df87724e1'), 'Difference': 15780587130}
# {'_id': ObjectId('60bc95fb12d1778df87724e2'), 'Difference': 182194909810}
# {'_id': ObjectId('60bc95fb12d1778df87724e3'), 'Difference': 56737766943}
# {'_id': ObjectId('60bc95fb12d1778df87724e4'), 'Difference': 165844112118}
# {'_id': ObjectId('60bc95fb12d1778df87724e5'), 'Difference': 194286122096}
# {'_id': ObjectId('60bc95fb12d1778df87724e6'), 'Difference': 121134971560}
# {'_id': ObjectId('60bc95fb12d1778df87724e7'), 'Difference': 44447468422}
# {'_id': ObjectId('60bc95fb12d1778df87724e8'), 'Difference': 21066681814}
# {'_id': ObjectId('60bc95fb12d1778df87724e9'), 'Difference': 66207566105}
# {'_id': ObjectId('60bc95fb12d1778df87724ea'), 'Difference': 77884910003}
# {'_id': ObjectId('60bc95fb12d1778df87724eb'), 'Difference': 45341192263}
# {'_id': ObjectId('60bc95fb12d1778df87724ec'), 'Difference': 21855347790}
# {'_id': ObjectId('60bc95fb12d1778df87724ed'), 'Difference': 99467039940}
# {'_id': ObjectId('60bc95fb12d1778df87724ee'), 'Difference': 132746534671}
# {'_id': ObjectId('60bc95fb12d1778df87724ef'), 'Difference': 189839771424}
# {'_id': ObjectId('60bc95fb12d1778df87724f0'), 'Difference': 93851390324}
# {'_id': ObjectId('60bc95fb12d1778df87724f1'), 'Difference': 126070849873}
# {'_id': ObjectId('60bc95fb12d1778df87724f2'), 'Difference': 95226757472}
# {'_id': ObjectId('60bc95fb12d1778df87724f3'), 'Difference': 127240245621}
# {'_id': ObjectId('60bc95fb12d1778df87724f4'), 'Difference': 200920558376}
# {'_id': ObjectId('60bc95fb12d1778df87724f5'), 'Difference': 74193215628}
# {'_id': ObjectId('60bc95fb12d1778df87724f6'), 'Difference': 150099504393}
# {'_id': ObjectId('60bc95fb12d1778df87724f7'), 'Difference': 64230664851}
# {'_id': ObjectId('60bc95fb12d1778df87724f8'), 'Difference': 35626215417}
# {'_id': ObjectId('60bc95fb12d1778df87724f9'), 'Difference': 75565025794}
# {'_id': ObjectId('60bc95fb12d1778df87724fa'), 'Difference': 22558753219}
# {'_id': ObjectId('60bc95fb12d1778df87724fb'), 'Difference': 88070030580}
# {'_id': ObjectId('60bc95fb12d1778df87724fc'), 'Difference': 56579859415}
# {'_id': ObjectId('60bc95fb12d1778df87724fd'), 'Difference': 103766813721}
# {'_id': ObjectId('60bc95fb12d1778df87724fe'), 'Difference': 186103874803}
# {'_id': ObjectId('60bc95fb12d1778df87724ff'), 'Difference': 62939138588}
# {'_id': ObjectId('60bc95fb12d1778df8772500'), 'Difference': 194506374545}
# {'_id': ObjectId('60bc95fb12d1778df8772501'), 'Difference': 76994737291}
# {'_id': ObjectId('60bc95fb12d1778df8772502'), 'Difference': 163057853876}
# {'_id': ObjectId('60bc95fb12d1778df8772503'), 'Difference': 189057492438}
# {'_id': ObjectId('60bc95fb12d1778df8772504'), 'Difference': 52886424599}
# {'_id': ObjectId('60bc95fb12d1778df8772505'), 'Difference': 35628322572}
# {'_id': ObjectId('60bc95fb12d1778df8772506'), 'Difference': 116711321104}
# {'_id': ObjectId('60bc95fb12d1778df8772507'), 'Difference': 126776952284}
# {'_id': ObjectId('60bc95fb12d1778df8772508'), 'Difference': 123752756289}
# {'_id': ObjectId('60bc95fb12d1778df8772509'), 'Difference': 46851089415}
# {'_id': ObjectId('60bc95fb12d1778df877250a'), 'Difference': 119095111375}
# {'_id': ObjectId('60bc95fb12d1778df877250b'), 'Difference': 167377654112}
# {'_id': ObjectId('60bc95fb12d1778df877250c'), 'Difference': 194618056554}
# {'_id': ObjectId('60bc95fb12d1778df877250d'), 'Difference': 75369958663}
# {'_id': ObjectId('60bc95fb12d1778df877250e'), 'Difference': 23388269064}
# {'_id': ObjectId('60bc95fb12d1778df877250f'), 'Difference': 105853659739}
# {'_id': ObjectId('60bc95fb12d1778df8772510'), 'Difference': 34383559330}
# {'_id': ObjectId('60bc95fb12d1778df8772511'), 'Difference': 65486139015}
# {'_id': ObjectId('60bc95fb12d1778df8772512'), 'Difference': 88449510158}
# {'_id': ObjectId('60bc95fb12d1778df8772513'), 'Difference': 101551998114}
# {'_id': ObjectId('60bc95fb12d1778df8772514'), 'Difference': 180925182413}
# {'_id': ObjectId('60bc95fb12d1778df8772515'), 'Difference': 79830316467}
# {'_id': ObjectId('60bc95fb12d1778df8772516'), 'Difference': 21393290462}
# {'_id': ObjectId('60bc95fb12d1778df8772517'), 'Difference': 39607257177}
# {'_id': ObjectId('60bc95fb12d1778df8772518'), 'Difference': 48169911609}
# {'_id': ObjectId('60bc95fb12d1778df8772519'), 'Difference': 35406934798}
# {'_id': ObjectId('60bc95fb12d1778df877251a'), 'Difference': 14535944753}
# {'_id': ObjectId('60bc95fb12d1778df877251b'), 'Difference': 92290004897}
# {'_id': ObjectId('60bc95fb12d1778df877251c'), 'Difference': 196467522857}
# {'_id': ObjectId('60bc95fb12d1778df877251d'), 'Difference': 95361760416}
# {'_id': ObjectId('60bc95fb12d1778df877251e'), 'Difference': 70901562888}
# {'_id': ObjectId('60bc95fb12d1778df877251f'), 'Difference': 76313597948}
# {'_id': ObjectId('60bc95fb12d1778df8772520'), 'Difference': 82251112344}
# {'_id': ObjectId('60bc95fb12d1778df8772521'), 'Difference': 185060709007}
# {'_id': ObjectId('60bc95fb12d1778df8772522'), 'Difference': 49520188634}
# {'_id': ObjectId('60bc95fb12d1778df8772523'), 'Difference': 48493908500}
# {'_id': ObjectId('60bc95fb12d1778df8772524'), 'Difference': 28247026811}
# {'_id': ObjectId('60bc95fb12d1778df8772525'), 'Difference': 173432276176}
# {'_id': ObjectId('60bc95fb12d1778df8772526'), 'Difference': 134554711619}
# {'_id': ObjectId('60bc95fb12d1778df8772527'), 'Difference': 26096885553}
# {'_id': ObjectId('60bc95fb12d1778df8772528'), 'Difference': 192833561240}
# {'_id': ObjectId('60bc95fb12d1778df8772529'), 'Difference': 156627676870}
# {'_id': ObjectId('60bc95fb12d1778df877252a'), 'Difference': 124392100971}
# {'_id': ObjectId('60bc95fb12d1778df877252b'), 'Difference': 144331894720}
# {'_id': ObjectId('60bc95fb12d1778df877252c'), 'Difference': 14574592037}
# {'_id': ObjectId('60bc95fb12d1778df877252d'), 'Difference': 85113819866}
# {'_id': ObjectId('60bc95fb12d1778df877252e'), 'Difference': 44930061011}
# {'_id': ObjectId('60bc95fb12d1778df877252f'), 'Difference': 181616382855}
# {'_id': ObjectId('60bc95fb12d1778df8772530'), 'Difference': 136416573078}
# {'_id': ObjectId('60bc95fb12d1778df8772531'), 'Difference': 106469390062}
# {'_id': ObjectId('60bc95fb12d1778df8772532'), 'Difference': 15420110704}
# {'_id': ObjectId('60bc95fb12d1778df8772533'), 'Difference': 95195778974}
# {'_id': ObjectId('60bc95fb12d1778df8772534'), 'Difference': 144841114057}
# {'_id': ObjectId('60bc95fb12d1778df8772535'), 'Difference': 88196632441}
# {'_id': ObjectId('60bc95fb12d1778df8772536'), 'Difference': 142463703543}
# {'_id': ObjectId('60bc95fb12d1778df8772537'), 'Difference': 190426641829}
# {'_id': ObjectId('60bc95fb12d1778df8772538'), 'Difference': 180486341140}
# {'_id': ObjectId('60bc95fb12d1778df8772539'), 'Difference': 67282115963}
# {'_id': ObjectId('60bc95fb12d1778df877253a'), 'Difference': 78988731921}
# {'_id': ObjectId('60bc95fb12d1778df877253b'), 'Difference': 93309911375}
# {'_id': ObjectId('60bc95fb12d1778df877253c'), 'Difference': 78423040778}
# {'_id': ObjectId('60bc95fb12d1778df877253d'), 'Difference': 113997927450}
# {'_id': ObjectId('60bc95fb12d1778df877253e'), 'Difference': 41453172346}
# {'_id': ObjectId('60bc95fb12d1778df877253f'), 'Difference': 103328522511}
# {'_id': ObjectId('60bc95fb12d1778df8772540'), 'Difference': 93865098070}
# {'_id': ObjectId('60bc95fb12d1778df8772541'), 'Difference': 133110111621}
# {'_id': ObjectId('60bc95fb12d1778df8772542'), 'Difference': 107860635158}
# {'_id': ObjectId('60bc95fb12d1778df8772543'), 'Difference': 116894176938}
# {'_id': ObjectId('60bc95fb12d1778df8772544'), 'Difference': 23433826596}
# {'_id': ObjectId('60bc95fb12d1778df8772545'), 'Difference': 140667911374}
# {'_id': ObjectId('60bc95fb12d1778df8772546'), 'Difference': 74051437296}
# {'_id': ObjectId('60bc95fb12d1778df8772547'), 'Difference': 19227699751}
# {'_id': ObjectId('60bc95fb12d1778df8772548'), 'Difference': 201465187597}
# {'_id': ObjectId('60bc95fb12d1778df8772549'), 'Difference': 94631800052}
# {'_id': ObjectId('60bc95fb12d1778df877254a'), 'Difference': 120137179534}
# {'_id': ObjectId('60bc95fb12d1778df877254b'), 'Difference': 91157215234}
# {'_id': ObjectId('60bc95fb12d1778df877254c'), 'Difference': 157791371474}
# {'_id': ObjectId('60bc95fb12d1778df877254d'), 'Difference': 199034677470}
# {'_id': ObjectId('60bc95fb12d1778df877254e'), 'Difference': 94989307491}
# {'_id': ObjectId('60bc95fb12d1778df877254f'), 'Difference': 83802722819}
# {'_id': ObjectId('60bc95fb12d1778df8772550'), 'Difference': 179797163617}
# {'_id': ObjectId('60bc95fb12d1778df8772551'), 'Difference': 142880013958}
# {'_id': ObjectId('60bc95fb12d1778df8772552'), 'Difference': 68327608812}
# {'_id': ObjectId('60bc95fb12d1778df8772553'), 'Difference': 142340434235}
# {'_id': ObjectId('60bc95fb12d1778df8772554'), 'Difference': 70233815142}
# {'_id': ObjectId('60bc95fb12d1778df8772555'), 'Difference': 73794773876}
# {'_id': ObjectId('60bc95fb12d1778df8772556'), 'Difference': 158798325412}
# {'_id': ObjectId('60bc95fb12d1778df8772557'), 'Difference': 178285248838}
# {'_id': ObjectId('60bc95fb12d1778df8772558'), 'Difference': 45605464942}
# {'_id': ObjectId('60bc95fb12d1778df8772559'), 'Difference': 201669797609}
# {'_id': ObjectId('60bc95fb12d1778df877255a'), 'Difference': 113643695804}
# {'_id': ObjectId('60bc95fb12d1778df877255b'), 'Difference': 82265512444}
# {'_id': ObjectId('60bc95fb12d1778df877255c'), 'Difference': 36709818180}
# {'_id': ObjectId('60bc95fb12d1778df877255d'), 'Difference': 99549715952}
# {'_id': ObjectId('60bc95fb12d1778df877255e'), 'Difference': 198008635083}
# {'_id': ObjectId('60bc95fb12d1778df877255f'), 'Difference': 14588879041}
# {'_id': ObjectId('60bc95fb12d1778df8772560'), 'Difference': 29460594996}
# {'_id': ObjectId('60bc95fb12d1778df8772561'), 'Difference': 113288714790}
# {'_id': ObjectId('60bc95fb12d1778df8772562'), 'Difference': 129312214205}
# {'_id': ObjectId('60bc95fb12d1778df8772563'), 'Difference': 192081167629}
# {'_id': ObjectId('60bc95fb12d1778df8772564'), 'Difference': 174104788554}
# {'_id': ObjectId('60bc95fb12d1778df8772565'), 'Difference': 122471623864}
# {'_id': ObjectId('60bc95fb12d1778df8772566'), 'Difference': 108936682514}
# {'_id': ObjectId('60bc95fb12d1778df8772567'), 'Difference': 166887580872}
# {'_id': ObjectId('60bc95fb12d1778df8772568'), 'Difference': 117056571088}
# {'_id': ObjectId('60bc95fb12d1778df8772569'), 'Difference': 132595667971}
# {'_id': ObjectId('60bc95fb12d1778df877256a'), 'Difference': 70183863370}
# {'_id': ObjectId('60bc95fb12d1778df877256b'), 'Difference': 22145047456}
# {'_id': ObjectId('60bc95fb12d1778df877256c'), 'Difference': 162857684894}
# {'_id': ObjectId('60bc95fb12d1778df877256d'), 'Difference': 40613706353}
# ...
# {'_id': ObjectId('60bc960012d1778df87769c0'), 'Difference': 86916758004}
# {'_id': ObjectId('60bc960012d1778df87769c1'), 'Difference': 101074796059}
# {'_id': ObjectId('60bc960012d1778df87769c2'), 'Difference': 117037128611}
# {'_id': ObjectId('60bc960012d1778df87769c3'), 'Difference': 149665973919}
# {'_id': ObjectId('60bc960012d1778df87769c4'), 'Difference': 162734992569}
# {'_id': ObjectId('60bc960012d1778df87769c5'), 'Difference': 91254756096}
# {'_id': ObjectId('60bc960012d1778df87769c6'), 'Difference': 59744160306}
# {'_id': ObjectId('60bc960012d1778df87769c7'), 'Difference': 120049639919}
# {'_id': ObjectId('60bc960012d1778df87769c8'), 'Difference': 175430002049}
# {'_id': ObjectId('60bc960012d1778df87769c9'), 'Difference': 196932822883}
# {'_id': ObjectId('60bc960012d1778df87769ca'), 'Difference': 196785253268}
# {'_id': ObjectId('60bc960012d1778df87769cb'), 'Difference': 50539995769}
# {'_id': ObjectId('60bc960012d1778df87769cc'), 'Difference': 60664360836}
# {'_id': ObjectId('60bc960012d1778df87769cd'), 'Difference': 126637446891}
# {'_id': ObjectId('60bc960012d1778df87769ce'), 'Difference': 26847094087}
# {'_id': ObjectId('60bc960012d1778df87769cf'), 'Difference': 39190534765}
# {'_id': ObjectId('60bc960012d1778df87769d0'), 'Difference': 194653312357}
# {'_id': ObjectId('60bc960012d1778df87769d1'), 'Difference': 93349322128}
# {'_id': ObjectId('60bc960012d1778df87769d2'), 'Difference': 53904877052}
# {'_id': ObjectId('60bc960012d1778df87769d3'), 'Difference': 201977755249}
# {'_id': ObjectId('60bc960012d1778df87769d4'), 'Difference': 190462173149}
# {'_id': ObjectId('60bc960012d1778df87769d5'), 'Difference': 48920412935}
# {'_id': ObjectId('60bc960012d1778df87769d6'), 'Difference': 49245142773}
# {'_id': ObjectId('60bc960012d1778df87769d7'), 'Difference': 181093805952}
# {'_id': ObjectId('60bc960012d1778df87769d8'), 'Difference': 82179202455}
# {'_id': ObjectId('60bc960012d1778df87769d9'), 'Difference': 15880727214}
# {'_id': ObjectId('60bc960012d1778df87769da'), 'Difference': 130891184558}
# {'_id': ObjectId('60bc960012d1778df87769db'), 'Difference': 44218866621}
# {'_id': ObjectId('60bc960012d1778df87769dc'), 'Difference': 49707321670}
# {'_id': ObjectId('60bc960012d1778df87769dd'), 'Difference': 164399662691}
# {'_id': ObjectId('60bc960012d1778df87769de'), 'Difference': 139924407748}
# {'_id': ObjectId('60bc960012d1778df87769df'), 'Difference': 99770740003}
# {'_id': ObjectId('60bc960012d1778df87769e0'), 'Difference': 68610837847}
# {'_id': ObjectId('60bc960012d1778df87769e1'), 'Difference': 72729879740}
# {'_id': ObjectId('60bc960012d1778df87769e2'), 'Difference': 202544561110}
# {'_id': ObjectId('60bc960012d1778df87769e3'), 'Difference': 169069373148}
# {'_id': ObjectId('60bc960012d1778df87769e4'), 'Difference': 81291757687}
# {'_id': ObjectId('60bc960012d1778df87769e5'), 'Difference': 152812881239}
# {'_id': ObjectId('60bc960012d1778df87769e6'), 'Difference': 168947905501}
# {'_id': ObjectId('60bc960012d1778df87769e7'), 'Difference': 33237171628}
# {'_id': ObjectId('60bc960012d1778df87769e8'), 'Difference': 137644380005}
# {'_id': ObjectId('60bc960012d1778df87769e9'), 'Difference': 199708986492}
# {'_id': ObjectId('60bc960012d1778df87769ea'), 'Difference': 59796220940}
# {'_id': ObjectId('60bc960012d1778df87769eb'), 'Difference': 180806544493}
# {'_id': ObjectId('60bc960012d1778df87769ec'), 'Difference': 36655004563}
# {'_id': ObjectId('60bc960012d1778df87769ed'), 'Difference': 97894418387}
# {'_id': ObjectId('60bc960012d1778df87769ee'), 'Difference': 161840774552}
# {'_id': ObjectId('60bc960012d1778df87769ef'), 'Difference': 149235174285}
# {'_id': ObjectId('60bc960012d1778df87769f0'), 'Difference': 83539687888}
# {'_id': ObjectId('60bc960012d1778df87769f1'), 'Difference': 122433522705}
# {'_id': ObjectId('60bc960012d1778df87769f2'), 'Difference': 118123255197}
# {'_id': ObjectId('60bc960012d1778df87769f3'), 'Difference': 85647137640}
# {'_id': ObjectId('60bc960012d1778df87769f4'), 'Difference': 148335226248}
# {'_id': ObjectId('60bc960012d1778df87769f5'), 'Difference': 23394078268}
# {'_id': ObjectId('60bc960012d1778df87769f6'), 'Difference': 180566038063}
# {'_id': ObjectId('60bc960012d1778df87769f7'), 'Difference': 69848692462}
# {'_id': ObjectId('60bc960012d1778df87769f8'), 'Difference': 168413469435}
# {'_id': ObjectId('60bc960012d1778df87769f9'), 'Difference': 31474456051}
# {'_id': ObjectId('60bc960012d1778df87769fa'), 'Difference': 198468389933}
# {'_id': ObjectId('60bc960012d1778df87769fb'), 'Difference': 63075917949}
# {'_id': ObjectId('60bc960012d1778df87769fc'), 'Difference': 100509809221}
# {'_id': ObjectId('60bc960012d1778df87769fd'), 'Difference': 43729658413}
# {'_id': ObjectId('60bc960012d1778df87769fe'), 'Difference': 44293249464}
# {'_id': ObjectId('60bc960012d1778df87769ff'), 'Difference': 30534433508}
# {'_id': ObjectId('60bc960012d1778df8776a00'), 'Difference': 66344486703}
# {'_id': ObjectId('60bc960012d1778df8776a01'), 'Difference': 36407987129}
# {'_id': ObjectId('60bc960012d1778df8776a02'), 'Difference': 115723986707}
# {'_id': ObjectId('60bc960012d1778df8776a03'), 'Difference': 197332812856}
# {'_id': ObjectId('60bc960012d1778df8776a04'), 'Difference': 153011758037}
# {'_id': ObjectId('60bc960012d1778df8776a05'), 'Difference': 111415652951}
# {'_id': ObjectId('60bc960012d1778df8776a06'), 'Difference': 76266862788}
# {'_id': ObjectId('60bc960012d1778df8776a07'), 'Difference': 140663949600}
# {'_id': ObjectId('60bc960012d1778df8776a08'), 'Difference': 120317644792}
# {'_id': ObjectId('60bc960012d1778df8776a09'), 'Difference': 182696843068}
# {'_id': ObjectId('60bc960012d1778df8776a0a'), 'Difference': 89500707555}
# {'_id': ObjectId('60bc960012d1778df8776a0b'), 'Difference': 15174924893}
# {'_id': ObjectId('60bc960012d1778df8776a0c'), 'Difference': 151161799185}
# {'_id': ObjectId('60bc960012d1778df8776a0d'), 'Difference': 125387890186}
# {'_id': ObjectId('60bc960012d1778df8776a0e'), 'Difference': 146302754796}
# {'_id': ObjectId('60bc960012d1778df8776a0f'), 'Difference': 187687728156}
# {'_id': ObjectId('60bc960012d1778df8776a10'), 'Difference': 199531138065}
# {'_id': ObjectId('60bc960012d1778df8776a11'), 'Difference': 152387557076}
# {'_id': ObjectId('60bc960012d1778df8776a12'), 'Difference': 124805215188}
# {'_id': ObjectId('60bc960012d1778df8776a13'), 'Difference': 161101902674}
# {'_id': ObjectId('60bc960012d1778df8776a14'), 'Difference': 40306791529}
# {'_id': ObjectId('60bc960012d1778df8776a15'), 'Difference': 143126387849}
# {'_id': ObjectId('60bc960012d1778df8776a16'), 'Difference': 58298968209}
# {'_id': ObjectId('60bc960012d1778df8776a17'), 'Difference': 16772734514}
# {'_id': ObjectId('60bc960012d1778df8776a18'), 'Difference': 146137900189}
# {'_id': ObjectId('60bc960012d1778df8776a19'), 'Difference': 107643685167}
# {'_id': ObjectId('60bc960012d1778df8776a1a'), 'Difference': 60007431857}
# {'_id': ObjectId('60bc960012d1778df8776a1b'), 'Difference': 35200829996}
# {'_id': ObjectId('60bc960012d1778df8776a1c'), 'Difference': 113937596108}
# {'_id': ObjectId('60bc960012d1778df8776a1d'), 'Difference': 148918565643}
# {'_id': ObjectId('60bc960012d1778df8776a1e'), 'Difference': 136771384955}
# {'_id': ObjectId('60bc960012d1778df8776a1f'), 'Difference': 14798862801}
# {'_id': ObjectId('60bc960012d1778df8776a20'), 'Difference': 54424247268}
# {'_id': ObjectId('60bc960012d1778df8776a21'), 'Difference': 118094078396}
# {'_id': ObjectId('60bc960012d1778df8776a22'), 'Difference': 177631578240}
# {'_id': ObjectId('60bc960012d1778df8776a23'), 'Difference': 139904237600}
# {'_id': ObjectId('60bc960012d1778df8776a24'), 'Difference': 157472277320}
# {'_id': ObjectId('60bc960012d1778df8776a25'), 'Difference': 145783011053}
# {'_id': ObjectId('60bc960012d1778df8776a26'), 'Difference': 86659306472}
# {'_id': ObjectId('60bc960012d1778df8776a27'), 'Difference': 67228374008}
# {'_id': ObjectId('60bc960012d1778df8776a28'), 'Difference': 101658648910}
# {'_id': ObjectId('60bc960012d1778df8776a29'), 'Difference': 76714756534}
# {'_id': ObjectId('60bc960012d1778df8776a2a'), 'Difference': 57356980631}
# {'_id': ObjectId('60bc960012d1778df8776a2b'), 'Difference': 57994309991}
# {'_id': ObjectId('60bc960012d1778df8776a2c'), 'Difference': 132956960990}
# {'_id': ObjectId('60bc960012d1778df8776a2d'), 'Difference': 111075668169}
# {'_id': ObjectId('60bc960012d1778df8776a2e'), 'Difference': 72207599450}
# {'_id': ObjectId('60bc960012d1778df8776a2f'), 'Difference': 59714000142}
# {'_id': ObjectId('60bc960012d1778df8776a30'), 'Difference': 133992226231}
# {'_id': ObjectId('60bc960012d1778df8776a31'), 'Difference': 135147505492}
# {'_id': ObjectId('60bc960012d1778df8776a32'), 'Difference': 106230811787}
# {'_id': ObjectId('60bc960012d1778df8776a33'), 'Difference': 126827059202}
# {'_id': ObjectId('60bc960012d1778df8776a34'), 'Difference': 130795984517}
# {'_id': ObjectId('60bc960012d1778df8776a35'), 'Difference': 111073770090}
# {'_id': ObjectId('60bc960012d1778df8776a36'), 'Difference': 67403091193}
# {'_id': ObjectId('60bc960012d1778df8776a37'), 'Difference': 192177989731}
# {'_id': ObjectId('60bc960012d1778df8776a38'), 'Difference': 25598337170}
# {'_id': ObjectId('60bc960012d1778df8776a39'), 'Difference': 106551160094}
# {'_id': ObjectId('60bc960012d1778df8776a3a'), 'Difference': 64073029717}
# {'_id': ObjectId('60bc960012d1778df8776a3b'), 'Difference': 124598270138}
# {'_id': ObjectId('60bc960012d1778df8776a3c'), 'Difference': 124294225686}
# {'_id': ObjectId('60bc960012d1778df8776a3d'), 'Difference': 195568101811}
# {'_id': ObjectId('60bc960012d1778df8776a3e'), 'Difference': 80079156175}
# {'_id': ObjectId('60bc960012d1778df8776a3f'), 'Difference': 174891827934}
# {'_id': ObjectId('60bc960012d1778df8776a40'), 'Difference': 171189555116}
# {'_id': ObjectId('60bc960012d1778df8776a41'), 'Difference': 166353355016}
# {'_id': ObjectId('60bc960012d1778df8776a42'), 'Difference': 19146280581}
# {'_id': ObjectId('60bc960012d1778df8776a43'), 'Difference': 150922043037}
# {'_id': ObjectId('60bc960012d1778df8776a44'), 'Difference': 68576779843}
# {'_id': ObjectId('60bc960012d1778df8776a45'), 'Difference': 15273346233}
# {'_id': ObjectId('60bc960012d1778df8776a46'), 'Difference': 119241686721}
# {'_id': ObjectId('60bc960012d1778df8776a47'), 'Difference': 186468339922}
# {'_id': ObjectId('60bc960012d1778df8776a48'), 'Difference': 139001668301}
# {'_id': ObjectId('60bc960012d1778df8776a49'), 'Difference': 77316304026}
# {'_id': ObjectId('60bc960012d1778df8776a4a'), 'Difference': 106893745470}
# {'_id': ObjectId('60bc960012d1778df8776a4b'), 'Difference': 38389443964}
# {'_id': ObjectId('60bc960012d1778df8776a4c'), 'Difference': 119623231644}
# {'_id': ObjectId('60bc960012d1778df8776a4d'), 'Difference': 164053756230}
# {'_id': ObjectId('60bc960012d1778df8776a4e'), 'Difference': 195221305017}
# {'_id': ObjectId('60bc960012d1778df8776a4f'), 'Difference': 191388205747}
# {'_id': ObjectId('60bc960012d1778df8776a50'), 'Difference': 101662283437}
# {'_id': ObjectId('60bc960012d1778df8776a51'), 'Difference': 27480084497}
# {'_id': ObjectId('60bc960012d1778df8776a52'), 'Difference': 112811895966}
# {'_id': ObjectId('60bc960012d1778df8776a53'), 'Difference': 101166210328}
# {'_id': ObjectId('60bc960012d1778df8776a54'), 'Difference': 119040383481}
# {'_id': ObjectId('60bc960012d1778df8776a55'), 'Difference': 27467364819}
# {'_id': ObjectId('60bc960012d1778df8776a56'), 'Difference': 55880951131}
# {'_id': ObjectId('60bc960012d1778df8776a57'), 'Difference': 175799149949}
# {'_id': ObjectId('60bc960012d1778df8776a58'), 'Difference': 136794099324}
# {'_id': ObjectId('60bc960012d1778df8776a59'), 'Difference': 175745429726}
# {'_id': ObjectId('60bc960012d1778df8776a5a'), 'Difference': 187201695611}
# {'_id': ObjectId('60bc960012d1778df8776a5b'), 'Difference': 147642746350}
# {'_id': ObjectId('60bc960012d1778df8776a5c'), 'Difference': 73315848526}
# {'_id': ObjectId('60bc960012d1778df8776a5d'), 'Difference': 136423532051}
# {'_id': ObjectId('60bc960012d1778df8776a5e'), 'Difference': 29369051214}
# {'_id': ObjectId('60bc960012d1778df8776a5f'), 'Difference': 18044325988}
# {'_id': ObjectId('60bc960012d1778df8776a60'), 'Difference': 162661089468}
# {'_id': ObjectId('60bc960012d1778df8776a61'), 'Difference': 131671716130}
# {'_id': ObjectId('60bc960012d1778df8776a62'), 'Difference': 117578995667}
# {'_id': ObjectId('60bc960012d1778df8776a63'), 'Difference': 179087459568}
# {'_id': ObjectId('60bc960012d1778df8776a64'), 'Difference': 25736133468}
# {'_id': ObjectId('60bc960012d1778df8776a65'), 'Difference': 40395659157}
# {'_id': ObjectId('60bc960012d1778df8776a66'), 'Difference': 191827973174}
# {'_id': ObjectId('60bc960012d1778df8776a67'), 'Difference': 195090000007}
# {'_id': ObjectId('60bc960012d1778df8776a68'), 'Difference': 56992606377}
# {'_id': ObjectId('60bc960012d1778df8776a69'), 'Difference': 91683313271}
# {'_id': ObjectId('60bc960012d1778df8776a6a'), 'Difference': 14908902645}
# {'_id': ObjectId('60bc960012d1778df8776a6b'), 'Difference': 113549319299}
# {'_id': ObjectId('60bc960012d1778df8776a6c'), 'Difference': 178113127601}
# {'_id': ObjectId('60bc960012d1778df8776a6d'), 'Difference': 68348516632}
# {'_id': ObjectId('60bc960012d1778df8776a6e'), 'Difference': 53191318708}
# {'_id': ObjectId('60bc960012d1778df8776a6f'), 'Difference': 29446092720}
# {'_id': ObjectId('60bc960012d1778df8776a70'), 'Difference': 124481927190}
# {'_id': ObjectId('60bc960012d1778df8776a71'), 'Difference': 23879497112}
# {'_id': ObjectId('60bc960012d1778df8776a72'), 'Difference': 54388597318}
# {'_id': ObjectId('60bc960012d1778df8776a73'), 'Difference': 62818260262}
# {'_id': ObjectId('60bc960012d1778df8776a74'), 'Difference': 128056545888}
# {'_id': ObjectId('60bc960012d1778df8776a75'), 'Difference': 50430256738}
# {'_id': ObjectId('60bc960012d1778df8776a76'), 'Difference': 142492607646}
# {'_id': ObjectId('60bc960012d1778df8776a77'), 'Difference': 71119891879}
# {'_id': ObjectId('60bc960012d1778df8776a78'), 'Difference': 44439266504}
# {'_id': ObjectId('60bc960012d1778df8776a79'), 'Difference': 66483922629}
# {'_id': ObjectId('60bc960012d1778df8776a7a'), 'Difference': 43894460331}
# {'_id': ObjectId('60bc960012d1778df8776a7b'), 'Difference': 124174041714}
# {'_id': ObjectId('60bc960012d1778df8776a7c'), 'Difference': 130934168758}
# {'_id': ObjectId('60bc960012d1778df8776a7d'), 'Difference': 194284795577}
# {'_id': ObjectId('60bc960012d1778df8776a7e'), 'Difference': 136005267441}
# {'_id': ObjectId('60bc960012d1778df8776a7f'), 'Difference': 133394013825}
# {'_id': ObjectId('60bc960012d1778df8776a80'), 'Difference': 137578078096}
# {'_id': ObjectId('60bc960012d1778df8776a81'), 'Difference': 107192719382}
# {'_id': ObjectId('60bc960012d1778df8776a82'), 'Difference': 61082143102}
# {'_id': ObjectId('60bc960012d1778df8776a83'), 'Difference': 117804010970}
# {'_id': ObjectId('60bc960012d1778df8776a84'), 'Difference': 121674757563}
# {'_id': ObjectId('60bc960012d1778df8776a85'), 'Difference': 26084209214}
# {'_id': ObjectId('60bc960012d1778df8776a86'), 'Difference': 181283998960}
# {'_id': ObjectId('60bc960012d1778df8776a87'), 'Difference': 80947385813}
# {'_id': ObjectId('60bc960012d1778df8776a88'), 'Difference': 125396261668}
# {'_id': ObjectId('60bc960012d1778df8776a89'), 'Difference': 89119909128}
# {'_id': ObjectId('60bc960012d1778df8776a8a'), 'Difference': 71162750089}
# {'_id': ObjectId('60bc960012d1778df8776a8b'), 'Difference': 139600568147}
# {'_id': ObjectId('60bc960012d1778df8776a8c'), 'Difference': 153151075105}
# {'_id': ObjectId('60bc960012d1778df8776a8d'), 'Difference': 62487353999}
# {'_id': ObjectId('60bc960012d1778df8776a8e'), 'Difference': 169972300025}
# {'_id': ObjectId('60bc960012d1778df8776a8f'), 'Difference': 94153157098}
# {'_id': ObjectId('60bc960012d1778df8776a90'), 'Difference': 179770021826}
# {'_id': ObjectId('60bc960012d1778df8776a91'), 'Difference': 19126397687}
# {'_id': ObjectId('60bc960012d1778df8776a92'), 'Difference': 148728831998}
# {'_id': ObjectId('60bc960012d1778df8776a93'), 'Difference': 35237390729}
# {'_id': ObjectId('60bc960012d1778df8776a94'), 'Difference': 133553176227}
# {'_id': ObjectId('60bc960012d1778df8776a95'), 'Difference': 71375786088}
# {'_id': ObjectId('60bc960012d1778df8776a96'), 'Difference': 40523197130}
# {'_id': ObjectId('60bc960012d1778df8776a97'), 'Difference': 30881269816}
# {'_id': ObjectId('60bc960012d1778df8776a98'), 'Difference': 89208961173}

# %% [markdown]
# ----
# ----
# ### Exercise 1 -
#
# How many enrollees from STEM discipline enrolled in the year 2019?
#
# ----

# %% [markdown]
# ----
# ### Exercise 2 -
#
# Count the number of enrollees from 'Business Degree' or 'Humanities' discipline who joined training in the first week of any year.
#
# *Hint - use [$isoWeek](https://docs.mongodb.com/manual/reference/operator/aggregation/isoWeek/#-isoweek--aggregation-) operator.*
#
# ----
