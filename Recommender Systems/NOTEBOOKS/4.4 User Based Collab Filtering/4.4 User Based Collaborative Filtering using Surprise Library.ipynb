# %% [markdown]
# ## Surprise Library Introduction
#
# Surprise is an easy-to-use Python scikit learn like tool for recommender systems. Surprise library provides essential tools to build and experiment with various collaborative filtering methods. It provides support for:
# 1. Cross Validation
# 2. Grid Search
# 3. Built-in Datasets
# 4. Various Collaborative filtering methods
#
#
# ## Installation
# Surprise library can be easily installed in the current environment using pip or conda
#
#
# `$ pip install numpy`
#
# `$ pip install scikit-surprise`
#
# With conda you can use:
#
# `$ conda install -c conda-forge scikit-surprise`
#
# For the latest version, you can also clone the repo and build the source (you’ll first need Cython and numpy):
#
# `$ pip install numpy cython`
#
# `$ git clone https://github.com/NicolasHug/surprise.git`
#
# `$ cd surprise`
#
# `$ python setup.py install`

# %% [markdown]
# ## Table of Content
#
# [1. Reading Dataset](#Reading-Dataset)
#
# [2. Merging Movie information to ratings dataframe](#merge)
#
# [3. Creating train and test data & setting evaluation metric](#eval)
#
# [4. Importing Surprise & Loading Dataset](#dataload)
#
# [5. Grid Search CV for Neighbourhood size and similarity measure](#gridsearch)
#
# [6. Fitting Model on complete train set & checking performance on test data](#testperf)
#
# [7. What's Next?](#whatsnext)

# %% [markdown]
# ## 1. Reading Dataset <a class="anchor" id="Reading-Dataset"></a>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, pairwise_distances
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

# %%
#Reading ratings file:
ratings = pd.read_csv('ratings.csv')

#Reading Movie Info File
movie_info = pd.read_csv('movie_info.csv')

# %% [markdown]
# ## 2.  Merging Movie information to ratings dataframe <a class="anchor" id="merge"></a>

# %% [markdown]
# The movie names are contained in a separate file. Let's merge that data with ratings and store it in ratings dataframe. The idea is to bring movie title information in ratings dataframe as it would be useful later on

# %%
ratings = ratings.merge(movie_info[['movie id','movie title']], how='left', left_on = 'movie_id', right_on = 'movie id')

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  unix_timestamp  movie id  \
# 0      196       242       3       881250949       242
# 1      186       302       3       891717742       302
# 2       22       377       1       878887116       377
# 3      244        51       2       880606923        51
# 4      166       346       1       886397596       346
#
#                   movie title
# 0                Kolya (1996)
# 1    L.A. Confidential (1997)
# 2         Heavyweights (1994)
# 3  Legends of the Fall (1994)
# 4         Jackie Brown (1997)

# %% [markdown]
# Lets also combine movie id and movie title separated by ': ' and store it in a new column named movie

# %%
ratings['movie'] = ratings['movie_id'].map(str) + str(': ') + ratings['movie title'].map(str)

# %%
ratings.columns
# Out:
# Index(['user_id', 'movie_id', 'rating', 'unix_timestamp', 'movie id',
#        'movie title', 'movie'],
#       dtype='object')

# %% [markdown]
# Keeping the columns movie, user_id and rating in the ratings dataframe and drop all others

# %%
ratings = ratings.drop(['movie id', 'movie title', 'movie_id','unix_timestamp'], axis = 1)

# %%
ratings = ratings[['user_id','movie','rating']]

# %% [markdown]
# ## 3. Creating Train & Test Data & Setting Evaluation Metric <a class="anchor" id="eval"></a>
# In order to test how well we do with a given rating prediction method, we would first need to define our train and test set, we will only use the train set to build different models and evaluate our model using the test set.

# %%
#Assign X as the original ratings dataframe
X = ratings.copy()

#Split into training and test datasets
X_train, X_test = train_test_split(X, test_size = 0.25, random_state=42)

# %%
#Function that computes the root mean squared error (or RMSE)
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %% [markdown]
# ## 4. Importing Surprise & Loading Dataset <a class="anchor" id="dataload"></a>

# %%
#Importing functions to be used in this notebook from Surprise Package
from surprise import Dataset, Reader
from surprise.model_selection import GridSearchCV
from surprise.prediction_algorithms import KNNWithMeans

# %% [markdown]
# To load a dataset from a pandas dataframe within Surprise, you will need the load_from_df() method.
# 1. You will also need a `Reader` object and the `rating_scale` parameter must be specified.
# 2. The dataframe here must have three columns, corresponding to the user (raw) ids, the item (raw) ids, and the ratings in this order.
# 3. Each row thus corresponds to a given rating

# %%
#Reader object to import ratings from X_train
reader = Reader(rating_scale=(1, 5))

#Storing Data in surprise format from X_train
data = Dataset.load_from_df(X_train[['user_id','movie','rating']], reader)

# %% [markdown]
# ## 5. Grid Search for Neighbourhood size and similarity measure <a class="anchor" id="gridsearch"></a>

# %% [markdown]
# The `cross_validate()` function reports accuracy metric over a cross-validation procedure for a given set of parameters. If you want to know which parameter combination yields the best results, the `GridSearchCV` class comes to the rescue.
#
# Given a dict of parameters, this class exhaustively tries all the combinations of parameters and reports the best parameters for any accuracy measure (averaged over the different splits). It is heavily inspired from scikit-learn’s GridSearchCV.

# %%
#Defining the parameter grid with k as the neighbourhood size & trying 2 similarity measures KNNwithMeans
#& 5 folds
param_grid = {"k":list(range(1,50,5)),
              "sim_options":{"name":["cosine","pearson"]}}

#KNNWithMeans by default does user based collaborative filtering and here we are trying to find the best set of 
#parameters
gs = GridSearchCV(KNNWithMeans, 
                  param_grid, 
                  measures=['rmse'], 
                  cv=5, 
                  n_jobs = -1)

#We fit the grid search on data to find out the best score
gs.fit(data)

#Printing the best score
print(gs.best_score['rmse'])

#Printing the best set of parameters
print(gs.best_params['rmse'])
# Out:
# 0.9625349082619087
# {'k': 46, 'sim_options': {'name': 'pearson', 'user_based': True}}

# %% [markdown]
# ## 6. Fitting Model on complete train set & checking performance on test data<a class="anchor" id="testperf"></a>

# %%
#Defining similarity measure as per the best parameters
sim_options = {'name': 'pearson'}

#Fitting the model on train data
model = KNNWithMeans(k = 46, sim_options = sim_options)

#Build full trainset will essentially fit the knnwithmeans on the complete train set instead of a part of it
#like we do in cross validation
model.fit(data.build_full_trainset())
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
#id pairs for test set
id_pairs = zip(X_test['user_id'], X_test['movie'])

#Making predictions for test set using predict method from Surprise
[model.predict(uid = user, iid = movie) for (user, movie) in id_pairs]
# Out:
# [Prediction(uid=877, iid="381: Muriel's Wedding (1994)", r_ui=None, est=4.104196596682839, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid=815, iid='602: American in Paris, An (1951)', r_ui=None, est=3.728344392131596, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid=94, iid='431: Highlander (1986)', r_ui=None, est=3.556145118850295, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=416, iid="875: She's So Lovely (1997)", r_ui=None, est=3.331263765779608, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid=500, iid='182: GoodFellas (1990)', r_ui=None, est=3.9628659616218593, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=259, iid='1074: Reality Bites (1994)', r_ui=None, est=3.277829437744131, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=598, iid='286: English Patient, The (1996)', r_ui=None, est=3.534383641100695, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=886, iid="496: It's a Wonderful Life (1946)", r_ui=None, est=3.6749578045934337, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 44, 'was_impossible': False}),
#  Prediction(uid=344, iid='562: Quick and the Dead, The (1995)', r_ui=None, est=3.190254965485588, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid=230, iid='51: Legends of the Fall (1994)', r_ui=None, est=3.91683252980598, details={'actual_k': 42, 'was_impossible': False}),
#  Prediction(uid=405, iid='1274: Robocop 3 (1993)', r_ui=None, est=1, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid=541, iid='622: Swiss Family Robinson (1960)', r_ui=None, est=3.4104938652017833, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid=790, iid='226: Die Hard 2 (1990)', r_ui=None, est=3.0448040990822163, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=456, iid='959: Dazed and Confused (1993)', r_ui=None, est=3.5054129232374973, details={'actual_k': 42, 'was_impossible': False}),
#  Prediction(uid=281, iid='301: In & Out (1997)', r_ui=None, est=3.127035639178555, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=551, iid='447: Carrie (1976)', r_ui=None, est=3.878731032879611, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=833, iid='1353: 1-900 (1994)', r_ui=None, est=3.231328744899171, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=442, iid='68: Crow, The (1994)', r_ui=None, est=3.2004537616212545, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=468, iid='275: Sense and Sensibility (1995)', r_ui=None, est=4.484374832529913, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=846, iid='565: Village of the Damned (1995)', r_ui=None, est=2.6050368669437876, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid=159, iid='286: English Patient, The (1996)', r_ui=None, est=3.7256795626043373, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=856, iid="307: Devil's Advocate, The (1997)", r_ui=None, est=3.323317907892898, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=325, iid='517: Manhattan (1979)', r_ui=None, est=3.809509646749862, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=363, iid='443: Birds, The (1963)', r_ui=None, est=3.279727760337123, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=693, iid='127: Godfather, The (1972)', r_ui=None, est=3.6656494880464607, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=502, iid='261: Air Bud (1997)', r_ui=None, est=1.9224783562680956, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid=542, iid='90: So I Married an Axe Murderer (1993)', r_ui=None, est=2.9565959883557262, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=682, iid='683: Rocket Man (1997)', r_ui=None, est=2.3566711317548354, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid=833, iid='435: Butch Cassidy and the Sundance Kid (1969)', r_ui=None, est=3.4993281599617565, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=405, iid='1078: Oliver & Company (1988)', r_ui=None, est=1.3718879025943163, details={'actual_k': 16, 'was_impossible': False}),
# ...
#  Prediction(uid=11, iid='654: Chinatown (1974)', r_ui=None, est=3.834309257852078, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=401, iid='133: Gone with the Wind (1939)', r_ui=None, est=3.2457366867863726, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=633, iid='405: Mission: Impossible (1996)', r_ui=None, est=3.185975929524881, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=886, iid='95: Aladdin (1992)', r_ui=None, est=3.456912072305789, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=90, iid='270: Gattaca (1997)', r_ui=None, est=4.176142655906958, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=427, iid="245: Devil's Own, The (1997)", r_ui=None, est=4.198449343645088, details={'actual_k': 42, 'was_impossible': False}),
#  Prediction(uid=101, iid='24: Rumble in the Bronx (1995)', r_ui=None, est=2.845815324490288, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=666, iid='742: Ransom (1996)', r_ui=None, est=3.695282199593661, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=897, iid='616: Night of the Living Dead (1968)', r_ui=None, est=3.668836074083952, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid=39, iid='345: Deconstructing Harry (1997)', r_ui=None, est=3.2968171478530635, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid=805, iid='806: Menace II Society (1993)', r_ui=None, est=3.315105231809296, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid=286, iid='741: Last Supper, The (1995)', r_ui=None, est=3.95716187968716, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid=880, iid='227: Star Trek VI: The Undiscovered Country (1991)', r_ui=None, est=3.198012139806016, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=58, iid='144: Die Hard (1988)', r_ui=None, est=4.147011374488392, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=593, iid='11: Seven (Se7en) (1995)', r_ui=None, est=3.8727381535953413, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=178, iid='993: Hercules (1997)', r_ui=None, est=3.588598615099744, details={'actual_k': 45, 'was_impossible': False}),
#  Prediction(uid=655, iid='321: Mother (1996)', r_ui=None, est=2.57011322587763, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=919, iid='305: Ice Storm, The (1997)', r_ui=None, est=3.8241057824534916, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=94, iid='731: Corrina, Corrina (1994)', r_ui=None, est=3.083402316222701, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid=922, iid="421: William Shakespeare's Romeo and Juliet (1996)", r_ui=None, est=3.301817945161144, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=7, iid='132: Wizard of Oz, The (1939)', r_ui=None, est=4.343576356074849, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=446, iid='688: Leave It to Beaver (1997)', r_ui=None, est=1.3133371926324229, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid=295, iid='1039: Hamlet (1996)', r_ui=None, est=4.484444079296726, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=577, iid='50: Star Wars (1977)', r_ui=None, est=4.5854004671055435, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=803, iid='264: Mimic (1997)', r_ui=None, est=2.5197628996259813, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=453, iid='246: Chasing Amy (1997)', r_ui=None, est=4.020352319312932, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=263, iid='271: Starship Troopers (1997)', r_ui=None, est=3.7398977428197075, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=658, iid='201: Evil Dead II (1987)', r_ui=None, est=3.982884739869791, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid=195, iid='198: Nikita (La Femme Nikita) (1990)', r_ui=None, est=3.8710568246365185, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=109, iid='63: Santa Clause, The (1994)', r_ui=None, est=3.163979112315816, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=450, iid='311: Wings of the Dove, The (1997)', r_ui=None, est=4.10304046462684, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=653, iid='310: Rainmaker, The (1997)', r_ui=None, est=2.9307673076596, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=429, iid='491: Adventures of Robin Hood, The (1938)', r_ui=None, est=3.7314691987645303, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=642, iid='240: Beavis and Butt-head Do America (1996)', r_ui=None, est=2.716391841690714, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=694, iid='144: Die Hard (1988)', r_ui=None, est=4.513953598713602, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=625, iid='174: Raiders of the Lost Ark (1981)', r_ui=None, est=4.211134691125099, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=270, iid='387: Age of Innocence, The (1993)', r_ui=None, est=4.13313544090569, details={'actual_k': 34, 'was_impossible': False}),
#  ...]

# %% [markdown]
# We can see that unlike scikit learn, this doesn't just output a list of predictions but also details such as `actual_k` and `was_impossible`.
#
# 1. `was_impossible`
# Was impossible means there were no or not enough neighbours to make the predictions.
#
# 2. `actual_k`
# For each of these algorithms, the actual number of neighbors that are aggregated to compute an estimation is necessarily less than or equal to 𝑘.
#
# Firstly, There might just not exist enough neighbors
#
# Secondly, For predictions you only include neighbors for which the similarity measure is positive
#
# For a given prediction, the actual number of neighbors can be retrieved in the 'actual_k' field of the details dictionary of the prediction.
#
# If we want to check performance on test set, we need to extract predicted ratings from this which can be done by subseting this tuple

# %%
#id pairs for test set
id_pairs = zip(X_test['user_id'], X_test['movie'])

#Making predictions for test set using predict method from Surprise
y_pred = [model.predict(uid = user, iid = movie)[3] for (user, movie) in id_pairs]

#Actual rating values for test set
y_true = X_test['rating']

# Checking performance on test set
rmse(y_true, y_pred)
# Out:
# 0.9512496782880885

# %% [markdown]
# ## 7. What's Next? <a class="anchor" id="whatsnext"></a>
# We again see improvement as compared to the last notebook where we did not optimize for number of neighbours. Now there is another parameter that you can play around with called `min_k`. This parameter is the minimum number of neighbors to take into account for aggregation. If there are not enough neighbors, the prediction is set to the global mean of all ratings. Try tweaking this parameter along with the others to see if you get a further improvement in performance.
