# %% [markdown]
# ## Table of Contents
#
# ### 1. Data Loading and Preprocessing
# > #### 1.1 Load the Data
# > #### 1.2 Define custom dataset and dataloader
# > #### 1.3 Data Exploration
# ### 2. Image Segmentation using Pretrained U-Net
# > #### 2.1 Define model architecture
# > #### 2.2 Train the model
# > #### 2.3 Calculate IoU score
#
# ---

# %% [markdown]
# ### 1. Data Loading and Preprocessing

# %% [markdown]
# #### 1.1 Load the Data

# %%
# Upload data from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# get images
# !unzip /content/drive/My\ Drive/images_BloodCellSegmentation.zip
# Out:
# Archive:  /content/drive/My Drive/images_BloodCellSegmentation.zip
#   inflating: images_BloodCellSegmentation/001.bmp
#   inflating: images_BloodCellSegmentation/002.bmp
#   inflating: images_BloodCellSegmentation/003.bmp
#   inflating: images_BloodCellSegmentation/004.bmp
#   inflating: images_BloodCellSegmentation/005.bmp
#   inflating: images_BloodCellSegmentation/006.bmp
#   inflating: images_BloodCellSegmentation/007.bmp
#   inflating: images_BloodCellSegmentation/008.bmp
#   inflating: images_BloodCellSegmentation/009.bmp
#   inflating: images_BloodCellSegmentation/010.bmp
#   inflating: images_BloodCellSegmentation/011.bmp
#   inflating: images_BloodCellSegmentation/012.bmp
#   inflating: images_BloodCellSegmentation/013.bmp
#   inflating: images_BloodCellSegmentation/014.bmp
#   inflating: images_BloodCellSegmentation/015.bmp
#   inflating: images_BloodCellSegmentation/016.bmp
#   inflating: images_BloodCellSegmentation/017.bmp
#   inflating: images_BloodCellSegmentation/018.bmp
#   inflating: images_BloodCellSegmentation/019.bmp
#   inflating: images_BloodCellSegmentation/020.bmp
#   inflating: images_BloodCellSegmentation/021.bmp
#   inflating: images_BloodCellSegmentation/022.bmp
#   inflating: images_BloodCellSegmentation/023.bmp
#   inflating: images_BloodCellSegmentation/024.bmp
#   inflating: images_BloodCellSegmentation/025.bmp
#   inflating: images_BloodCellSegmentation/026.bmp
#   inflating: images_BloodCellSegmentation/027.bmp
#   inflating: images_BloodCellSegmentation/028.bmp
#   inflating: images_BloodCellSegmentation/029.bmp
#   inflating: images_BloodCellSegmentation/030.bmp
#   inflating: images_BloodCellSegmentation/031.bmp
#   inflating: images_BloodCellSegmentation/032.bmp
#   inflating: images_BloodCellSegmentation/033.bmp
#   inflating: images_BloodCellSegmentation/034.bmp
#   inflating: images_BloodCellSegmentation/035.bmp
#   inflating: images_BloodCellSegmentation/036.bmp
#   inflating: images_BloodCellSegmentation/037.bmp
#   inflating: images_BloodCellSegmentation/038.bmp
#   inflating: images_BloodCellSegmentation/039.bmp
#   inflating: images_BloodCellSegmentation/040.bmp
#   inflating: images_BloodCellSegmentation/041.bmp
#   inflating: images_BloodCellSegmentation/042.bmp
#   inflating: images_BloodCellSegmentation/043.bmp
#   inflating: images_BloodCellSegmentation/044.bmp
#   inflating: images_BloodCellSegmentation/045.bmp
#   inflating: images_BloodCellSegmentation/046.bmp
#   inflating: images_BloodCellSegmentation/047.bmp
#   inflating: images_BloodCellSegmentation/048.bmp
#   inflating: images_BloodCellSegmentation/049.bmp
#   inflating: images_BloodCellSegmentation/050.bmp
#   inflating: images_BloodCellSegmentation/051.bmp
#   inflating: images_BloodCellSegmentation/052.bmp
#   inflating: images_BloodCellSegmentation/053.bmp
#   inflating: images_BloodCellSegmentation/054.bmp
#   inflating: images_BloodCellSegmentation/055.bmp
#   inflating: images_BloodCellSegmentation/056.bmp
#   inflating: images_BloodCellSegmentation/057.bmp
#   inflating: images_BloodCellSegmentation/058.bmp
#   inflating: images_BloodCellSegmentation/059.bmp
#   inflating: images_BloodCellSegmentation/060.bmp
#   inflating: images_BloodCellSegmentation/061.bmp
#   inflating: images_BloodCellSegmentation/062.bmp
#   inflating: images_BloodCellSegmentation/063.bmp
#   inflating: images_BloodCellSegmentation/064.bmp
#   inflating: images_BloodCellSegmentation/065.bmp
#   inflating: images_BloodCellSegmentation/066.bmp
#   inflating: images_BloodCellSegmentation/067.bmp
#   inflating: images_BloodCellSegmentation/068.bmp
#   inflating: images_BloodCellSegmentation/069.bmp
#   inflating: images_BloodCellSegmentation/070.bmp
#   inflating: images_BloodCellSegmentation/071.bmp
#   inflating: images_BloodCellSegmentation/072.bmp
#   inflating: images_BloodCellSegmentation/073.bmp
#   inflating: images_BloodCellSegmentation/074.bmp
#   inflating: images_BloodCellSegmentation/075.bmp
#   inflating: images_BloodCellSegmentation/076.bmp
#   inflating: images_BloodCellSegmentation/077.bmp
#   inflating: images_BloodCellSegmentation/078.bmp
#   inflating: images_BloodCellSegmentation/079.bmp
#   inflating: images_BloodCellSegmentation/080.bmp
#   inflating: images_BloodCellSegmentation/081.bmp
#   inflating: images_BloodCellSegmentation/082.bmp
#   inflating: images_BloodCellSegmentation/083.bmp
#   inflating: images_BloodCellSegmentation/084.bmp
#   inflating: images_BloodCellSegmentation/085.bmp
#   inflating: images_BloodCellSegmentation/086.bmp
#   inflating: images_BloodCellSegmentation/087.bmp
#   inflating: images_BloodCellSegmentation/088.bmp
#   inflating: images_BloodCellSegmentation/089.bmp
#   inflating: images_BloodCellSegmentation/090.bmp
#   inflating: images_BloodCellSegmentation/091.bmp
#   inflating: images_BloodCellSegmentation/092.bmp
#   inflating: images_BloodCellSegmentation/093.bmp
#   inflating: images_BloodCellSegmentation/094.bmp
#   inflating: images_BloodCellSegmentation/095.bmp
#   inflating: images_BloodCellSegmentation/096.bmp
#   inflating: images_BloodCellSegmentation/097.bmp
#   inflating: images_BloodCellSegmentation/098.bmp
#   inflating: images_BloodCellSegmentation/099.bmp
#   inflating: images_BloodCellSegmentation/100.bmp

# %%
# get targets
# !unzip /content/drive/My\ Drive/targets_BloodCellSegmentation.zip
# Out:
# Archive:  /content/drive/My Drive/targets_BloodCellSegmentation.zip
#   inflating: targets_BloodCellSegmentation/001.png
#   inflating: targets_BloodCellSegmentation/002.png
#   inflating: targets_BloodCellSegmentation/003.png
#   inflating: targets_BloodCellSegmentation/004.png
#   inflating: targets_BloodCellSegmentation/005.png
#   inflating: targets_BloodCellSegmentation/006.png
#   inflating: targets_BloodCellSegmentation/007.png
#   inflating: targets_BloodCellSegmentation/008.png
#   inflating: targets_BloodCellSegmentation/009.png
#   inflating: targets_BloodCellSegmentation/010.png
#  extracting: targets_BloodCellSegmentation/011.png
#  extracting: targets_BloodCellSegmentation/012.png
#   inflating: targets_BloodCellSegmentation/013.png
#   inflating: targets_BloodCellSegmentation/014.png
#   inflating: targets_BloodCellSegmentation/015.png
#   inflating: targets_BloodCellSegmentation/016.png
#  extracting: targets_BloodCellSegmentation/017.png
#  extracting: targets_BloodCellSegmentation/018.png
#   inflating: targets_BloodCellSegmentation/019.png
#   inflating: targets_BloodCellSegmentation/020.png
#   inflating: targets_BloodCellSegmentation/021.png
#   inflating: targets_BloodCellSegmentation/022.png
#   inflating: targets_BloodCellSegmentation/023.png
#   inflating: targets_BloodCellSegmentation/024.png
#   inflating: targets_BloodCellSegmentation/025.png
#   inflating: targets_BloodCellSegmentation/026.png
#   inflating: targets_BloodCellSegmentation/027.png
#   inflating: targets_BloodCellSegmentation/028.png
#   inflating: targets_BloodCellSegmentation/029.png
#   inflating: targets_BloodCellSegmentation/030.png
#  extracting: targets_BloodCellSegmentation/031.png
#   inflating: targets_BloodCellSegmentation/032.png
#   inflating: targets_BloodCellSegmentation/033.png
#   inflating: targets_BloodCellSegmentation/034.png
#   inflating: targets_BloodCellSegmentation/035.png
#   inflating: targets_BloodCellSegmentation/036.png
#   inflating: targets_BloodCellSegmentation/037.png
#   inflating: targets_BloodCellSegmentation/038.png
#   inflating: targets_BloodCellSegmentation/039.png
#   inflating: targets_BloodCellSegmentation/040.png
#   inflating: targets_BloodCellSegmentation/041.png
#   inflating: targets_BloodCellSegmentation/042.png
#   inflating: targets_BloodCellSegmentation/043.png
#   inflating: targets_BloodCellSegmentation/044.png
#  extracting: targets_BloodCellSegmentation/045.png
#   inflating: targets_BloodCellSegmentation/046.png
#   inflating: targets_BloodCellSegmentation/047.png
#   inflating: targets_BloodCellSegmentation/048.png
#   inflating: targets_BloodCellSegmentation/049.png
#   inflating: targets_BloodCellSegmentation/050.png
#   inflating: targets_BloodCellSegmentation/051.png
#   inflating: targets_BloodCellSegmentation/052.png
#   inflating: targets_BloodCellSegmentation/053.png
#   inflating: targets_BloodCellSegmentation/054.png
#   inflating: targets_BloodCellSegmentation/055.png
#   inflating: targets_BloodCellSegmentation/056.png
#   inflating: targets_BloodCellSegmentation/057.png
#   inflating: targets_BloodCellSegmentation/058.png
#   inflating: targets_BloodCellSegmentation/059.png
#   inflating: targets_BloodCellSegmentation/060.png
#   inflating: targets_BloodCellSegmentation/061.png
#   inflating: targets_BloodCellSegmentation/062.png
#   inflating: targets_BloodCellSegmentation/063.png
#   inflating: targets_BloodCellSegmentation/064.png
#   inflating: targets_BloodCellSegmentation/065.png
#   inflating: targets_BloodCellSegmentation/066.png
#   inflating: targets_BloodCellSegmentation/067.png
#   inflating: targets_BloodCellSegmentation/068.png
#   inflating: targets_BloodCellSegmentation/069.png
#   inflating: targets_BloodCellSegmentation/070.png
#   inflating: targets_BloodCellSegmentation/071.png
#   inflating: targets_BloodCellSegmentation/072.png
#   inflating: targets_BloodCellSegmentation/073.png
#   inflating: targets_BloodCellSegmentation/074.png
#   inflating: targets_BloodCellSegmentation/075.png
#   inflating: targets_BloodCellSegmentation/076.png
#   inflating: targets_BloodCellSegmentation/077.png
#   inflating: targets_BloodCellSegmentation/078.png
#   inflating: targets_BloodCellSegmentation/079.png
#   inflating: targets_BloodCellSegmentation/080.png
#   inflating: targets_BloodCellSegmentation/081.png
#   inflating: targets_BloodCellSegmentation/082.png
#   inflating: targets_BloodCellSegmentation/083.png
#   inflating: targets_BloodCellSegmentation/084.png
#   inflating: targets_BloodCellSegmentation/085.png
#   inflating: targets_BloodCellSegmentation/086.png
#   inflating: targets_BloodCellSegmentation/087.png
#   inflating: targets_BloodCellSegmentation/088.png
#   inflating: targets_BloodCellSegmentation/089.png
#   inflating: targets_BloodCellSegmentation/090.png
#   inflating: targets_BloodCellSegmentation/091.png
#   inflating: targets_BloodCellSegmentation/092.png
#   inflating: targets_BloodCellSegmentation/093.png
#   inflating: targets_BloodCellSegmentation/094.png
#   inflating: targets_BloodCellSegmentation/095.png
#   inflating: targets_BloodCellSegmentation/096.png
#   inflating: targets_BloodCellSegmentation/097.png
#   inflating: targets_BloodCellSegmentation/098.png
#   inflating: targets_BloodCellSegmentation/099.png
#  extracting: targets_BloodCellSegmentation/100.png

# %%
# import libraries and modules
# %matplotlib inline

import os
import torch
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# import pytorch related modules
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Compose, ToTensor, Resize

from torch.hub import load

# %%
# set seed
seed = 42
np.random.seed(seed)
torch.manual_seed(seed);

# %%
# define filepaths
images_dir = '/content/images_BloodCellSegmentation'
targets_dir = '/content/targets_BloodCellSegmentation'

# %% [markdown]
# #### 1.2 Define custom dataset and dataloader

# %%
# define custom dataset class
class BloodCellSegDataset(Dataset):
    def __init__(self, images_dir, masks_dir):

        # get all image names
        self.image_names = os.listdir(images_dir)

        # get image and target paths
        self.images_paths = []
        self.masks_paths = []
        for image_name in self.image_names:
            self.images_paths.append(os.path.join(images_dir, image_name))
            self.masks_paths.append(os.path.join(masks_dir, image_name.split('.')[0] + '.png'))
    
    def __getitem__(self, idx):
        
        # read data
        image = Image.open(self.images_paths[idx])
        mask = Image.open(self.masks_paths[idx])

        # preprocess mask
        mask = np.array(mask)
        mask = ((mask == 128) | (mask == 255))
        mask = Image.fromarray(mask)

        # apply data augmentation
        transform = Compose([
                    Resize(224),
                    ToTensor()
                    ])
        
        image = transform(image)
        mask = transform(mask)
        
        return image, mask
        
    def __len__(self):
        return len(self.image_names)

# %%
# create instance of custom dataset
dataset = BloodCellSegDataset(images_dir, targets_dir)

# create dataloader
data_loader = DataLoader(
    dataset, 
    batch_size=8,
    num_workers=4,
    shuffle=True
)

# %% [markdown]
# #### 1.3 Data Exploration

# %%
# check for one iteration of loop
for batch_x, batch_y in data_loader:
    break

# %%
# get shapes of batches
batch_x.shape, batch_y.shape
# Out:
# (torch.Size([8, 3, 224, 224]), torch.Size([8, 1, 224, 224]))

# %%
# print image
plt.imshow(np.transpose(batch_x[1], (1, 2, 0)))

# %%
# print mask
plt.imshow(batch_y[1].squeeze(), cmap='gray')

# %% [markdown]
# ### 2. Image Segmentation using Pretrained U-Net

# %% [markdown]
# #### 2.1 Define model architecture

# %%
# define model
model = torch.hub.load('mateuszbuda/brain-segmentation-pytorch', 'unet',
    in_channels=3, out_channels=1, init_features=32, pretrained=True)
# Out:
# Downloading: "https://github.com/mateuszbuda/brain-segmentation-pytorch/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://github.com/mateuszbuda/brain-segmentation-pytorch/releases/download/v1.0/unet-e012d006.pt" to /root/.cache/torch/hub/checkpoints/unet-e012d006.pt

# %%
# print model architecture
model
# Out:
# UNet(
#   (encoder1): Sequential(
#     (enc1conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (enc1norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (enc1relu1): ReLU(inplace=True)
#     (enc1conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (enc1norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (enc1relu2): ReLU(inplace=True)
#   )
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder2): Sequential(
#     (enc2conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (enc2norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (enc2relu1): ReLU(inplace=True)
#     (enc2conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (enc2norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (enc2relu2): ReLU(inplace=True)
#   )
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder3): Sequential(
#     (enc3conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (enc3norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (enc3relu1): ReLU(inplace=True)
#     (enc3conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (enc3norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (enc3relu2): ReLU(inplace=True)
#   )
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder4): Sequential(
#     (enc4conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (enc4norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (enc4relu1): ReLU(inplace=True)
#     (enc4conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (enc4norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (enc4relu2): ReLU(inplace=True)
#   )
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bottleneck): Sequential(
#     (bottleneckconv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bottlenecknorm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bottleneckrelu1): ReLU(inplace=True)
#     (bottleneckconv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bottlenecknorm2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bottleneckrelu2): ReLU(inplace=True)
#   )
#   (upconv4): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (decoder4): Sequential(
#     (dec4conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dec4norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dec4relu1): ReLU(inplace=True)
#     (dec4conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dec4norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dec4relu2): ReLU(inplace=True)
#   )
#   (upconv3): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (decoder3): Sequential(
#     (dec3conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dec3norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dec3relu1): ReLU(inplace=True)
#     (dec3conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dec3norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dec3relu2): ReLU(inplace=True)
#   )
#   (upconv2): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (decoder2): Sequential(
#     (dec2conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dec2norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dec2relu1): ReLU(inplace=True)
#     (dec2conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dec2norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dec2relu2): ReLU(inplace=True)
#   )
#   (upconv1): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#   (decoder1): Sequential(
#     (dec1conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dec1norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dec1relu1): ReLU(inplace=True)
#     (dec1conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dec1norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dec1relu2): ReLU(inplace=True)
#   )
#   (conv): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
# check forward pass
model.forward??

# %%
# check model on one image
output = model(batch_x[1].view(1, 3, 224, 224)).detach().numpy()

# %%
# print output
plt.imshow(output.squeeze(), cmap='gray')

# %% [markdown]
# #### 2.2 Train the model

# %%
# transfer model to GPU
model = model.to("cuda")

# %%
# define optimization and loss function
criterion = torch.nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# set model to train
model.train()

# train model
for epoch in range(5):

    # initialize variables
    epoch_loss = cnt = 0

    # loop through the data
    for batch_x, batch_y in data_loader:
        # get batch images and targets and transfer them to GPU
        batch_x = batch_x.to("cuda").float()
        batch_y = batch_y.to("cuda").float()

        # clear gradients
        optimizer.zero_grad()

        # pass images to model
        outputs = model(batch_x)

        # get loss
        loss = criterion(outputs, batch_y)

        # do a backward pass
        loss.backward()

        # update gradients
        optimizer.step()

        # sum loss and get count
        epoch_loss += loss.item()
        cnt += 1

    # take average loss for all batches
    epoch_loss /= cnt
    
    # print loss
    print("Training loss for epoch {} is {} ".format(epoch + 1, epoch_loss))
# Out:
# Training loss for epoch 1 is 0.6526697487212144
# Training loss for epoch 2 is 0.066653890391955
# Training loss for epoch 3 is 0.06335378739123161
# Training loss for epoch 4 is 0.04695989879278036
# Training loss for epoch 5 is 0.05172331272982634

# %% [markdown]
# #### 2.3 Calculate IoU score

# %%
# get sample data
image = Image.open('/content/images_BloodCellSegmentation/002.bmp')
gt_mask = Image.open('/content/targets_BloodCellSegmentation/002.png')

# preprocess mask
gt_mask = np.array(gt_mask)
gt_mask = ((gt_mask == 128) | (gt_mask == 255))
gt_mask = Image.fromarray(gt_mask)

# apply data augmentation
transform = Compose([
            Resize(224),
            ToTensor()
            ])
        
image = transform(image)

gt_mask = transform(gt_mask)

# %%
# get prediction
model.eval()
output = model(image.unsqueeze(dim=0).to('cuda')).cpu().detach().numpy()

# %%
# print shape
output.shape
# Out:
# (1, 1, 224, 224)

# %%
# plot ground truth mask
plt.imshow(gt_mask.squeeze(), cmap='gray')

# %%
# plot predicted mask
plt.imshow((output.squeeze() > 0.5).astype(int), cmap='gray')

# %%
# convert predicted mask to flattened numpy array
mask = (output.squeeze() > 0.5).astype(int)
pred = mask.ravel().copy()

# convert ground truth mask to flattened numpy array
gt_mask = gt_mask.numpy()
target = gt_mask.ravel().copy().astype(int)

# get class indices for WBC
pred_inds = pred == 1
target_inds = target == 1

# calculate intersection
intersection = pred_inds[target_inds].sum()

# calculate union
union = pred_inds.sum() + target_inds.sum() - intersection

# get IoU score
iou = (float(intersection) / float(max(union, 1)))
iou
# Out:
# 0.9162029109589042
